# %%
reset()

from SageNP import NewmanPenrose

########################################################
# Define 4-dim. the manifold:
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
########################################################
MyCoordinates.<t,z,x,y> = MyManifold.chart(r't z x y')
###################################################
# Define the metric functions
var('Lambda, m, r')
F = function('F',imag_part_func=0)(r,x)
G = function('G',imag_part_func=0)(r,y)
A = function('A',imag_part_func=0)(x)
B = function('B',imag_part_func=0)(y)
#var('\lambda')
########################################################
# Parametre belirleyin: (tetradlarınızın tipine göre aşağıdaki kısmı tanımlayın.)
tetrad_type = 'covariant'  # 'covariant' ya da 'contravariant' olabilir.
###################################################
# Enter null tetrad elements
# These vectors define the Static Spherical spacetime
lvec=[sqrt(1/2)*(e^(Lambda*(F-G))*B)^(1/2)*r, -sqrt(1/2)*(e^(Lambda*(G-F))*A)^(1/2)*r, 0, 0]
nvec=[sqrt(1/2)*(e^(Lambda*(F-G))*B)^(1/2)*r, sqrt(1/2)*(e^(Lambda*(G-F))*A)^(1/2)*r, 0, 0]
mvec=[0, 0, sqrt(1/2)*r*(1/sqrt(A))*(e^(Lambda*(F+G))*e^(-Lambda^2*r^4*A*B))^(1/2), sqrt(1/2)*r*I*(1/sqrt(B))*(e^(Lambda*(F+G))*e^(-Lambda^2*r^4*A*B))^(1/2)]
mbarvec=[0, 0, sqrt(1/2)*r*(1/sqrt(A))*(e^(Lambda*(F+G))*e^(-Lambda^2*r^4*A*B))^(1/2), -sqrt(1/2)*r*I*(1/sqrt(B))*(e^(Lambda*(F+G))*e^(-Lambda^2*r^4*A*B))^(1/2)]
########################################################
# Define the object "met" of the class "SageNP":
met=NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
########################################################
#f fonksiyonu derivative operatörleri hesaplamak için kullanılıyor.(bu satırı değiştirmeyin!)
f=MyManifold.scalar_field(function('f')(*MyCoordinates))
# Out:
# 'The metric:'
# g = -r^2*B(y)*e^(Lambda*F(r, x) - Lambda*G(r, y)) dt⊗dt + r^2*A(x)*e^(-Lambda*F(r, x) + Lambda*G(r, y)) dz⊗dz + r^2*e^(-Lambda^2*r^4*A(x)*B(y) + Lambda*F(r, x) + Lambda*G(r, y))/A(x) dx⊗dx + r^2*e^(-Lambda^2*r^4*A(x)*B(y) + Lambda*F(r, x) + Lambda*G(r, y))/B(y) dy⊗dy

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' -1/8*((2*sqrt(2)*Lambda*A(x)*diff(F(r, x), x) - sqrt(2)*diff(A(x), x))*sqrt(B(y))*e^(1/2*Lambda^2*r^4*A(x)*B(y)) - (2*I*sqrt(2)*Lambda*B(y)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) - I*sqrt(2)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y))*sqrt(A(x)))*e^(-1/2*Lambda*F(r, x) - 1/2*Lambda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'tauNP=' -1/8*sqrt(2)*(sqrt(B(y))*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x) + I*sqrt(A(x))*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y))*e^(-1/2*Lambda*F(r, x) - 1/2*Lambda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'sigmaNP=' 0
# 'rhoNP=' 0
# 'piNP=' 1/8*sqrt(2)*(sqrt(B(y))*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x) - I*sqrt(A(x))*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y))*e^(-1/2*Lambda*F(r, x) - 1/2*Lambda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'nuNP=' 1/8*((2*sqrt(2)*Lambda*A(x)*diff(F(r, x), x) - sqrt(2)*diff(A(x), x))*sqrt(B(y))*e^(1/2*Lambda^2*r^4*A(x)*B(y)) - (-2*I*sqrt(2)*Lambda*B(y)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + I*sqrt(2)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y))*sqrt(A(x)))*e^(-1/2*Lambda*F(r, x) - 1/2*Lambda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'muNP=' 0
# 'lambdaNP=' 0
# 'epsilonNP=' 0
# 'gammaNP=' 0
# 'betaNP=' -1/8*sqrt(2)*((Lambda^2*r^4*B(y)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x) - Lambda*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(F(r, x), x))*sqrt(A(x)) + (I*Lambda^2*r^4*A(x)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y) - I*Lambda*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*sqrt(B(y)))*e^(-1/2*Lambda*F(r, x) - 1/2*Lambda*G(r, y))/r
# 'alphaNP=' 1/8*sqrt(2)*((Lambda^2*r^4*B(y)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x) - Lambda*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(F(r, x), x))*sqrt(A(x)) - (I*Lambda^2*r^4*A(x)*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y) - I*Lambda*e^(1/2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*sqrt(B(y)))*e^(-1/2*Lambda*F(r, x) - 1/2*Lambda*G(r, y))/r

# %%
met.calculate_Weyl()
met.show_Weyl()
# Out:
# Calculating Weyl components...
# 'Psi0NP=' -1/8*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - (2*Lambda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - Lambda^2*r^4*diff(A(x), x)^2 - 2*Lambda^2*diff(G(r, y), y)^2 + 2*Lambda*diff(G(r, y), y, y))*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) + 2*(-I*Lambda^3*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(F(r, x), x) + I*Lambda^3*r^4*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (3*Lambda*diff(A(x), x)*diff(F(r, x), x) - 2*(Lambda^2*diff(F(r, x), x)^2 - Lambda*diff(F(r, x), x, x))*A(x) - diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) - (2*Lambda^3*r^4*A(x)*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 3*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y) + e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'Psi1NP=' 0
# 'Psi2NP=' -1/24*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - 3*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) + (Lambda^2*r^4*diff(A(x), x)^2 + 2*Lambda^2*r^4*A(x)*diff(A(x), x, x) + 2*Lambda^2*diff(G(r, y), y)^2 - 2*Lambda*diff(G(r, y), y, y))*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) - (3*Lambda*diff(A(x), x)*diff(F(r, x), x) - 2*(Lambda^2*diff(F(r, x), x)^2 - Lambda*diff(F(r, x), x, x))*A(x) - diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) + (2*Lambda^2*r^4*A(x)*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) + e^(Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'Psi3NP=' 0
# 'Psi4NP=' -1/8*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - (2*Lambda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - Lambda^2*r^4*diff(A(x), x)^2 - 2*Lambda^2*diff(G(r, y), y)^2 + 2*Lambda*diff(G(r, y), y, y))*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) - 2*(-I*Lambda^3*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(F(r, x), x) + I*Lambda^3*r^4*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (3*Lambda*diff(A(x), x)*diff(F(r, x), x) - 2*(Lambda^2*diff(F(r, x), x)^2 - Lambda*diff(F(r, x), x, x))*A(x) - diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) - (2*Lambda^3*r^4*A(x)*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 3*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y) + e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2

# %%
met.calculate_Ricci()
met.show_Ricci()
# Out:
# Calculating Ricci components...
# 'Phi00NP=' -1/8*(2*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) + 2*Lambda*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y, y) - (2*Lambda*diff(A(x), x)*diff(F(r, x), x) + 2*Lambda*A(x)*diff(F(r, x), x, x) - diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) - e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 1/8*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - 2*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) - (Lambda^2*r^4*diff(A(x), x)^2 - Lambda^2*diff(G(r, y), y)^2)*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) + 2*(-I*Lambda^2*r^4*e^(Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(B(y), y) + I*Lambda^2*e^(Lambda^2*r^4*A(x)*B(y))*diff(F(r, x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (Lambda^2*A(x)*diff(F(r, x), x)^2 - 2*Lambda*diff(A(x), x)*diff(F(r, x), x) + diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) + e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'Phi20NP=' 1/8*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - 2*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) - (Lambda^2*r^4*diff(A(x), x)^2 - Lambda^2*diff(G(r, y), y)^2)*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) - 2*(-I*Lambda^2*r^4*e^(Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(B(y), y) + I*Lambda^2*e^(Lambda^2*r^4*A(x)*B(y))*diff(F(r, x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (Lambda^2*A(x)*diff(F(r, x), x)^2 - 2*Lambda*diff(A(x), x)*diff(F(r, x), x) + diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) + e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'Phi11NP=' 1/16*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 + 2*Lambda^2*r^4*A(x)*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y) - (Lambda^2*diff(F(r, x), x)^2 + 2*Lambda*diff(F(r, x), x, x))*A(x)*e^(Lambda^2*r^4*A(x)*B(y)) + (Lambda^2*r^4*diff(A(x), x)^2 + 2*Lambda^2*r^4*A(x)*diff(A(x), x, x) - Lambda^2*diff(G(r, y), y)^2 - 2*Lambda*diff(G(r, y), y, y))*B(y)*e^(Lambda^2*r^4*A(x)*B(y)))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'Phi12NP=' 0
# 'Phi21NP=' 0
# 'Phi22NP=' -1/8*(2*Lambda*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) + 2*Lambda*B(y)*e^(Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y, y) - (2*Lambda*diff(A(x), x)*diff(F(r, x), x) + 2*Lambda*A(x)*diff(F(r, x), x, x) - diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) - e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2
# 'LambdaNP=' 1/48*(Lambda^2*r^4*A(x)*e^(Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 + (Lambda^2*r^4*diff(A(x), x)^2 + 2*Lambda^2*r^4*A(x)*diff(A(x), x, x) - Lambda^2*diff(G(r, y), y)^2 - 2*Lambda*diff(G(r, y), y, y))*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) - ((Lambda^2*diff(F(r, x), x)^2 + 2*Lambda*diff(F(r, x), x, x))*A(x) + 2*diff(A(x), x, x))*e^(Lambda^2*r^4*A(x)*B(y)) + 2*(Lambda^2*r^4*A(x)*B(y)*e^(Lambda^2*r^4*A(x)*B(y)) - e^(Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y, y))*e^(-Lambda*F(r, x) - Lambda*G(r, y))/r^2

# %%
met.calculate_NPeq()
met.show_NPeq()
# Out:
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0

# %%
met.calculate_Bianchi()
met.show_Bianchi()
# Out:
# Calculating Bianchi identities...
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
met.calculate_PetrovinvINP()
met.calculate_PetrovinvJNP()
met.calculate_PetrovinvKNP()
met.calculate_PetrovinvLNP()
met.calculate_PetrovinvNNP()

show(met.PetrovinvINP.expr())
show(met.PetrovinvJNP.expr())
show(met.PetrovinvKNP.expr())
show(met.PetrovinvLNP.expr())
show(met.PetrovinvNNP.expr())
a=met.PetrovinvINP.expr()
b=met.PetrovinvJNP.expr()
show(bool(a^3==27*b^2))
# Out:
# 1/48*(3*Lambda^6*r^8*A(x)*B(y)^3*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)^2*diff(G(r, y), y)^2 + Lambda^4*r^8*A(x)^2*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^4 - (3*Lambda^5*r^8*A(x)*diff(A(x), x)^3*diff(F(r, x), x) - Lambda^4*r^8*diff(A(x), x)^4 - Lambda^4*r^8*A(x)^2*diff(A(x), x, x)^2 - 4*Lambda^4*diff(G(r, y), y)^4 + 8*Lambda^3*diff(G(r, y), y)^2*diff(G(r, y), y, y) - 4*Lambda^2*diff(G(r, y), y, y)^2 + 6*(Lambda^5*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2 - Lambda^4*r^4*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x)*diff(A(x), x) - (3*Lambda^6*r^8*A(x)^2*diff(F(r, x), x)^2 + 4*Lambda^4*r^4*diff(G(r, y), y)^2 - 4*Lambda^3*r^4*diff(G(r, y), y, y))*diff(A(x), x)^2 - (Lambda^4*r^8*A(x)*diff(A(x), x)^2 + 2*(Lambda^4*r^4*diff(G(r, y), y)^2 - Lambda^3*r^4*diff(G(r, y), y, y))*A(x))*diff(A(x), x, x))*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y)) - 3*(Lambda^5*r^8*A(x)^2*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 2*Lambda^3*r^4*A(x)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y)^3 - (6*Lambda^3*r^4*diff(A(x), x)^3*diff(F(r, x), x) - Lambda^2*r^4*A(x)*diff(A(x), x, x)^2 - (13*Lambda^4*r^4*diff(F(r, x), x)^2 - 4*Lambda^3*r^4*diff(F(r, x), x, x))*A(x)*diff(A(x), x)^2 - 8*((Lambda^4*diff(F(r, x), x)^2 - Lambda^3*diff(F(r, x), x, x))*diff(G(r, y), y)^2 - (Lambda^3*diff(F(r, x), x)^2 - Lambda^2*diff(F(r, x), x, x))*diff(G(r, y), y, y))*A(x) + 6*(2*Lambda^3*diff(F(r, x), x)*diff(G(r, y), y)^2 - 2*Lambda^2*diff(F(r, x), x)*diff(G(r, y), y, y) + (Lambda^5*r^4*diff(F(r, x), x)^3 - Lambda^4*r^4*diff(F(r, x), x)*diff(F(r, x), x, x))*A(x)^2)*diff(A(x), x) + 2*(3*Lambda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - Lambda^2*r^4*diff(A(x), x)^2 - 2*Lambda^2*diff(G(r, y), y)^2 - (Lambda^4*r^4*diff(F(r, x), x)^2 - Lambda^3*r^4*diff(F(r, x), x, x))*A(x)^2 + 2*Lambda*diff(G(r, y), y, y))*diff(A(x), x, x))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) + (3*Lambda^6*r^8*A(x)^2*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y)^2 + (3*Lambda^6*r^8*A(x)^3*diff(F(r, x), x)^2 - 3*Lambda^5*r^8*A(x)^2*diff(A(x), x)*diff(F(r, x), x) + 2*Lambda^4*r^8*A(x)*diff(A(x), x)^2 + Lambda^4*r^8*A(x)^2*diff(A(x), x, x) + (13*Lambda^4*r^4*diff(G(r, y), y)^2 - 4*Lambda^3*r^4*diff(G(r, y), y, y))*A(x))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) - (6*Lambda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - 2*Lambda^2*r^4*A(x)*diff(A(x), x, x) - 9*Lambda^2*diff(G(r, y), y)^2 - 4*(Lambda^4*r^4*diff(F(r, x), x)^2 - Lambda^3*r^4*diff(F(r, x), x, x))*A(x)^2)*e^(2*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y)^2 + (Lambda^4*r^8*A(x)^2*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y)) + Lambda^2*r^4*A(x)*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) + e^(2*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y, y)^2 + (9*Lambda^2*diff(A(x), x)^2*diff(F(r, x), x)^2 + 4*(Lambda^4*diff(F(r, x), x)^4 - 2*Lambda^3*diff(F(r, x), x)^2*diff(F(r, x), x, x) + Lambda^2*diff(F(r, x), x, x)^2)*A(x)^2 - 12*(Lambda^3*diff(F(r, x), x)^3 - Lambda^2*diff(F(r, x), x)*diff(F(r, x), x, x))*A(x)*diff(A(x), x) - 2*(3*Lambda*diff(A(x), x)*diff(F(r, x), x) - 2*(Lambda^2*diff(F(r, x), x)^2 - Lambda*diff(F(r, x), x, x))*A(x))*diff(A(x), x, x) + diff(A(x), x, x)^2)*e^(2*Lambda^2*r^4*A(x)*B(y)) - 3*((Lambda^5*r^8*A(x)*diff(A(x), x)^2*diff(G(r, y), y) + 2*(Lambda^5*r^4*diff(G(r, y), y)^3 - Lambda^4*r^4*diff(G(r, y), y)*diff(G(r, y), y, y))*A(x))*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y)) - 2*(3*Lambda^4*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x)*diff(G(r, y), y) - Lambda^3*r^4*diff(A(x), x)^2*diff(G(r, y), y) - Lambda^3*r^4*A(x)*diff(A(x), x, x)*diff(G(r, y), y) - 2*Lambda^3*diff(G(r, y), y)^3 - (Lambda^5*r^4*diff(F(r, x), x)^2 - Lambda^4*r^4*diff(F(r, x), x, x))*A(x)^2*diff(G(r, y), y) + 2*Lambda^2*diff(G(r, y), y)*diff(G(r, y), y, y))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) - 2*(3*Lambda^2*diff(A(x), x)*diff(F(r, x), x)*diff(G(r, y), y) - 2*(Lambda^3*diff(F(r, x), x)^2 - Lambda^2*diff(F(r, x), x, x))*A(x)*diff(G(r, y), y) - Lambda*diff(A(x), x, x)*diff(G(r, y), y))*e^(2*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y) + ((Lambda^4*r^8*A(x)*diff(A(x), x)^2 + 2*Lambda^4*r^8*A(x)^2*diff(A(x), x, x) + 2 ...
# -1/3456*(2*Lambda^6*r^12*A(x)^3*e^(3*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^6 + 9*(Lambda^8*r^12*A(x)*diff(A(x), x)^4*diff(G(r, y), y)^2 + 2*Lambda^8*r^12*A(x)^2*diff(A(x), x)^2*diff(A(x), x, x)*diff(G(r, y), y)^2 + 2*(Lambda^8*r^8*diff(G(r, y), y)^4 - Lambda^7*r^8*diff(G(r, y), y)^2*diff(G(r, y), y, y))*A(x)*diff(A(x), x)^2)*B(y)^4*e^(3*Lambda^2*r^4*A(x)*B(y)) - 9*(Lambda^7*r^12*A(x)^3*B(y)*e^(3*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 2*Lambda^5*r^8*A(x)^2*e^(3*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y)^5 - (9*Lambda^7*r^12*A(x)*diff(A(x), x)^5*diff(F(r, x), x) - 2*Lambda^6*r^12*diff(A(x), x)^6 + 2*Lambda^6*r^12*A(x)^3*diff(A(x), x, x)^3 - 16*Lambda^6*diff(G(r, y), y)^6 + 48*Lambda^5*diff(G(r, y), y)^4*diff(G(r, y), y, y) - 48*Lambda^4*diff(G(r, y), y)^2*diff(G(r, y), y, y)^2 + 16*Lambda^3*diff(G(r, y), y, y)^3 + 9*(7*Lambda^7*r^8*diff(F(r, x), x)*diff(G(r, y), y)^2 - 4*Lambda^6*r^8*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x)*diff(A(x), x)^3 - 3*(3*Lambda^8*r^12*A(x)^2*diff(F(r, x), x)^2 + 4*Lambda^6*r^8*diff(G(r, y), y)^2 - 4*Lambda^5*r^8*diff(G(r, y), y, y))*diff(A(x), x)^4 + 36*(Lambda^7*r^4*diff(F(r, x), x)*diff(G(r, y), y)^4 - 2*Lambda^6*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2*diff(G(r, y), y, y) + Lambda^5*r^4*diff(F(r, x), x)*diff(G(r, y), y, y)^2)*A(x)*diff(A(x), x) - 6*(4*Lambda^6*r^4*diff(G(r, y), y)^4 - 8*Lambda^5*r^4*diff(G(r, y), y)^2*diff(G(r, y), y, y) + 4*Lambda^4*r^4*diff(G(r, y), y, y)^2 - 3*(Lambda^7*r^8*diff(F(r, x), x)^2*diff(G(r, y), y, y) - (2*Lambda^8*r^8*diff(F(r, x), x)^2 - Lambda^7*r^8*diff(F(r, x), x, x))*diff(G(r, y), y)^2)*A(x)^2)*diff(A(x), x)^2 + 3*(Lambda^6*r^12*A(x)^2*diff(A(x), x)^2 + 2*(Lambda^6*r^8*diff(G(r, y), y)^2 - Lambda^5*r^8*diff(G(r, y), y, y))*A(x)^2)*diff(A(x), x, x)^2 + 3*(6*Lambda^7*r^12*A(x)^2*diff(A(x), x)^3*diff(F(r, x), x) - Lambda^6*r^12*A(x)*diff(A(x), x)^4 + 12*(Lambda^7*r^8*diff(F(r, x), x)*diff(G(r, y), y)^2 - Lambda^6*r^8*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x)^2*diff(A(x), x) - (6*Lambda^8*r^12*A(x)^3*diff(F(r, x), x)^2 + (7*Lambda^6*r^8*diff(G(r, y), y)^2 - 4*Lambda^5*r^8*diff(G(r, y), y, y))*A(x))*diff(A(x), x)^2 - 4*(Lambda^6*r^4*diff(G(r, y), y)^4 - 2*Lambda^5*r^4*diff(G(r, y), y)^2*diff(G(r, y), y, y) + Lambda^4*r^4*diff(G(r, y), y, y)^2)*A(x))*diff(A(x), x, x))*B(y)^3*e^(3*Lambda^2*r^4*A(x)*B(y)) + 3*(3*Lambda^8*r^12*A(x)^3*B(y)^2*e^(3*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y)^2 + (3*Lambda^8*r^12*A(x)^4*diff(F(r, x), x)^2 - 3*Lambda^7*r^12*A(x)^3*diff(A(x), x)*diff(F(r, x), x) + 2*Lambda^6*r^12*A(x)^2*diff(A(x), x)^2 + Lambda^6*r^12*A(x)^3*diff(A(x), x, x) + 2*(11*Lambda^6*r^8*diff(G(r, y), y)^2 - 2*Lambda^5*r^8*diff(G(r, y), y, y))*A(x)^2)*B(y)*e^(3*Lambda^2*r^4*A(x)*B(y)) - 2*(3*Lambda^5*r^8*A(x)^2*diff(A(x), x)*diff(F(r, x), x) - Lambda^4*r^8*A(x)^2*diff(A(x), x, x) - 9*Lambda^4*r^4*A(x)*diff(G(r, y), y)^2 - 2*(Lambda^6*r^8*diff(F(r, x), x)^2 - Lambda^5*r^8*diff(F(r, x), x, x))*A(x)^3)*e^(3*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y)^4 - 3*(6*Lambda^5*r^8*diff(A(x), x)^5*diff(F(r, x), x) + Lambda^4*r^8*A(x)^2*diff(A(x), x, x)^3 - 2*(11*Lambda^6*r^8*diff(F(r, x), x)^2 - 2*Lambda^5*r^8*diff(F(r, x), x, x))*A(x)*diff(A(x), x)^4 + 3*(8*Lambda^5*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2 - 8*Lambda^4*r^4*diff(F(r, x), x)*diff(G(r, y), y, y) + (7*Lambda^7*r^8*diff(F(r, x), x)^3 - 4*Lambda^6*r^8*diff(F(r, x), x)*diff(F(r, x), x, x))*A(x)^2)*diff(A(x), x)^3 - 2*(3*(Lambda^8*r^8*diff(F(r, x), x)^4 - Lambda^7*r^8*diff(F(r, x), x)^2*diff(F(r, x), x, x))*A(x)^3 + 2*((13*Lambda^6*r^4*diff(F(r, x), x)^2 - 4*Lambda^5*r^4*diff(F(r, x), x, x))*diff(G(r, y), y)^2 - (13*Lambda^5*r^4*diff(F(r, x), x)^2 - 4*Lambda^4*r^4*diff(F(r, x), x, x))*diff(G(r, y), y, y))*A(x))*diff(A(x), x)^2 + (3*Lambda^5*r^8*A(x)^2*diff(A(x), x)*diff(F(r, x), x) - 2*Lambda^4*r^8*A(x)*diff(A(x), x)^2 + 2*(Lambda^6*r^8*diff(F(r, x), x)^2 - Lambda^5*r^8*diff(F(r, x), x, x))*A(x)^3 - 4*(Lambda^4*r^4*diff(G(r, y), y)^2 - Lambda^3*r^4*diff(G(r, y), y, y))*A(x))*diff(A(x), x, x)^2 - 16*((Lambda^6*diff ...
# 0
# 1/192*(Lambda^4*r^8*A(x)^2*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^4 - (2*Lambda^5*r^8*A(x)*diff(A(x), x)^3*diff(F(r, x), x) - Lambda^4*r^8*diff(A(x), x)^4 - 4*Lambda^4*diff(G(r, y), y)^4 + 8*Lambda^3*diff(G(r, y), y)^2*diff(G(r, y), y, y) - 4*Lambda^2*diff(G(r, y), y, y)^2 + 4*(Lambda^5*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2 - Lambda^4*r^4*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x)*diff(A(x), x) - 4*(Lambda^4*r^4*diff(G(r, y), y)^2 - Lambda^3*r^4*diff(G(r, y), y, y))*diff(A(x), x)^2 + 2*(2*Lambda^5*r^8*A(x)^2*diff(A(x), x)*diff(F(r, x), x) - Lambda^4*r^8*A(x)*diff(A(x), x)^2 - 2*(Lambda^4*r^4*diff(G(r, y), y)^2 - Lambda^3*r^4*diff(G(r, y), y, y))*A(x))*diff(A(x), x, x))*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y)) - 2*(Lambda^5*r^8*A(x)^2*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 3*Lambda^3*r^4*A(x)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y)^3 - 2*(3*Lambda^3*r^4*diff(A(x), x)^3*diff(F(r, x), x) - Lambda^2*r^4*A(x)*diff(A(x), x, x)^2 - (5*Lambda^4*r^4*diff(F(r, x), x)^2 - 2*Lambda^3*r^4*diff(F(r, x), x, x))*A(x)*diff(A(x), x)^2 - 4*((Lambda^4*diff(F(r, x), x)^2 - Lambda^3*diff(F(r, x), x, x))*diff(G(r, y), y)^2 - (Lambda^3*diff(F(r, x), x)^2 - Lambda^2*diff(F(r, x), x, x))*diff(G(r, y), y, y))*A(x) + 2*(3*Lambda^3*diff(F(r, x), x)*diff(G(r, y), y)^2 - 3*Lambda^2*diff(F(r, x), x)*diff(G(r, y), y, y) + (Lambda^5*r^4*diff(F(r, x), x)^3 - Lambda^4*r^4*diff(F(r, x), x)*diff(F(r, x), x, x))*A(x)^2)*diff(A(x), x) + (4*Lambda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - Lambda^2*r^4*diff(A(x), x)^2 - 2*Lambda^2*diff(G(r, y), y)^2 - 2*(Lambda^4*r^4*diff(F(r, x), x)^2 - Lambda^3*r^4*diff(F(r, x), x, x))*A(x)^2 + 2*Lambda*diff(G(r, y), y, y))*diff(A(x), x, x))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) - (2*(Lambda^5*r^8*A(x)^2*diff(A(x), x)*diff(F(r, x), x) - Lambda^4*r^8*A(x)*diff(A(x), x)^2 - Lambda^4*r^8*A(x)^2*diff(A(x), x, x) - (5*Lambda^4*r^4*diff(G(r, y), y)^2 - 2*Lambda^3*r^4*diff(G(r, y), y, y))*A(x))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) + (6*Lambda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - 2*Lambda^2*r^4*A(x)*diff(A(x), x, x) - 9*Lambda^2*diff(G(r, y), y)^2 - 4*(Lambda^4*r^4*diff(F(r, x), x)^2 - Lambda^3*r^4*diff(F(r, x), x, x))*A(x)^2)*e^(2*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y)^2 + (2*Lambda^2*r^4*A(x)*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) + e^(2*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y, y)^2 - 2*(-I*Lambda^5*r^8*A(x)^2*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^3*diff(F(r, x), x) + (I*Lambda^5*r^8*diff(A(x), x)^3*diff(G(r, y), y) + 2*I*Lambda^5*r^8*A(x)*diff(A(x), x)*diff(A(x), x, x)*diff(G(r, y), y) + 2*(I*Lambda^5*r^4*diff(G(r, y), y)^3 - I*Lambda^4*r^4*diff(G(r, y), y)*diff(G(r, y), y, y))*diff(A(x), x))*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y)) + (-3*I*Lambda^4*r^4*diff(A(x), x)^2*diff(F(r, x), x)*diff(G(r, y), y) + I*Lambda^3*r^4*diff(A(x), x)*diff(A(x), x, x)*diff(G(r, y), y) + 2*(I*Lambda^5*r^4*diff(F(r, x), x)^2 - I*Lambda^4*r^4*diff(F(r, x), x, x))*A(x)*diff(A(x), x)*diff(G(r, y), y))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) + (I*Lambda^5*r^8*A(x)*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y) + 3*I*Lambda^4*r^4*A(x)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(F(r, x), x)*diff(G(r, y), y))*diff(B(y), y)^2 + ((-I*Lambda^5*r^8*A(x)*diff(A(x), x)^2*diff(F(r, x), x) - 2*I*Lambda^5*r^8*A(x)^2*diff(A(x), x, x)*diff(F(r, x), x) - 3*I*Lambda^4*r^4*diff(A(x), x)*diff(G(r, y), y)^2 + 2*(-I*Lambda^5*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2 + I*Lambda^4*r^4*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x))*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y)) + (3*I*Lambda^4*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x)^2 - I*Lambda^3*r^4*A(x)*diff(A(x), x, x)*diff(F(r, x), x) + 2*(-I*Lambda^5*r^4*diff(F(r, x), x)^3 + I*Lambda^4*r^4*diff(F(r, x), x)*diff(F(r, x), x, x))*A(x)^2)*e^(2*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y) + (2*I*Lambda^5*r^8*A(x)*B(y)^2*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y) + I*Lambda^3*r^4*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y) + (-2*I*Lambda^5*r^8*A(x)^2*B(y)*e^(2*Lambda^2*r^4*A(x)*B(y))*diff ...
# 1/1024*(4*Lambda^12*r^12*A(x)^2*B(y)^6*e^(4*Lambda^2*r^4*A(x)*B(y))*diff(A(x), x)^4*diff(G(r, y), y)^4 + Lambda^9*r^12*A(x)^4*B(y)*e^(4*Lambda^2*r^4*A(x)*B(y))*diff(B(y), y)^7*diff(G(r, y), y) - (Lambda^10*r^12*A(x)*diff(A(x), x)^6*diff(G(r, y), y)^2 + 4*Lambda^10*r^12*A(x)^3*diff(A(x), x)^2*diff(A(x), x, x)^2*diff(G(r, y), y)^2 + 4*(Lambda^10*r^8*diff(G(r, y), y)^4 - Lambda^9*r^8*diff(G(r, y), y)^2*diff(G(r, y), y, y))*A(x)*diff(A(x), x)^4 + 4*(Lambda^10*r^4*diff(G(r, y), y)^6 - 2*Lambda^9*r^4*diff(G(r, y), y)^4*diff(G(r, y), y, y) + Lambda^8*r^4*diff(G(r, y), y)^2*diff(G(r, y), y, y)^2)*A(x)*diff(A(x), x)^2 + 4*(Lambda^10*r^12*A(x)^2*diff(A(x), x)^4*diff(G(r, y), y)^2 + 2*(Lambda^10*r^8*diff(G(r, y), y)^4 - Lambda^9*r^8*diff(G(r, y), y)^2*diff(G(r, y), y, y))*A(x)^2*diff(A(x), x)^2)*diff(A(x), x, x))*B(y)^5*e^(4*Lambda^2*r^4*A(x)*B(y)) - (5*Lambda^10*r^12*A(x)^4*B(y)^2*e^(4*Lambda^2*r^4*A(x)*B(y))*diff(G(r, y), y)^2 + (Lambda^10*r^12*A(x)^5*diff(F(r, x), x)^2 - Lambda^9*r^12*A(x)^4*diff(A(x), x)*diff(F(r, x), x) - Lambda^8*r^12*A(x)^4*diff(A(x), x, x) + 9*Lambda^8*r^8*A(x)^3*diff(G(r, y), y)^2)*B(y)*e^(4*Lambda^2*r^4*A(x)*B(y)))*diff(B(y), y)^6 - (5*Lambda^10*r^12*A(x)^2*diff(A(x), x)^6*diff(F(r, x), x)^2 - Lambda^9*r^12*A(x)*diff(A(x), x)^7*diff(F(r, x), x) - 2*(4*Lambda^11*r^12*A(x)^3*diff(F(r, x), x)^3 + 3*(2*Lambda^9*r^8*diff(F(r, x), x)*diff(G(r, y), y)^2 - Lambda^8*r^8*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x))*diff(A(x), x)^5 + 4*(5*Lambda^8*r^4*diff(F(r, x), x)^2*diff(G(r, y), y, y)^2 + (7*Lambda^10*r^4*diff(F(r, x), x)^2 - 2*Lambda^9*r^4*diff(F(r, x), x, x))*diff(G(r, y), y)^4 - 2*(6*Lambda^9*r^4*diff(F(r, x), x)^2 - Lambda^8*r^4*diff(F(r, x), x, x))*diff(G(r, y), y)^2*diff(G(r, y), y, y))*A(x)^2*diff(A(x), x)^2 + 4*(Lambda^12*r^12*A(x)^4*diff(F(r, x), x)^4 - (5*Lambda^9*r^8*diff(F(r, x), x)^2*diff(G(r, y), y, y) - (6*Lambda^10*r^8*diff(F(r, x), x)^2 - Lambda^9*r^8*diff(F(r, x), x, x))*diff(G(r, y), y)^2)*A(x)^2)*diff(A(x), x)^4 - 4*(4*(Lambda^11*r^8*diff(F(r, x), x)^3*diff(G(r, y), y)^2 - Lambda^10*r^8*diff(F(r, x), x)^3*diff(G(r, y), y, y))*A(x)^3 + 3*(2*Lambda^9*r^4*diff(F(r, x), x)*diff(G(r, y), y)^4 - 3*Lambda^8*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2*diff(G(r, y), y, y) + Lambda^7*r^4*diff(F(r, x), x)*diff(G(r, y), y, y)^2)*A(x))*diff(A(x), x)^3 - 8*(Lambda^9*diff(F(r, x), x)*diff(G(r, y), y)^6 - 3*Lambda^8*diff(F(r, x), x)*diff(G(r, y), y)^4*diff(G(r, y), y, y) + 3*Lambda^7*diff(F(r, x), x)*diff(G(r, y), y)^2*diff(G(r, y), y, y)^2 - Lambda^6*diff(F(r, x), x)*diff(G(r, y), y, y)^3)*A(x)*diff(A(x), x) + (4*Lambda^9*r^12*A(x)^3*diff(A(x), x)^3*diff(F(r, x), x) - Lambda^8*r^12*A(x)^2*diff(A(x), x)^4 + 8*(Lambda^9*r^8*diff(F(r, x), x)*diff(G(r, y), y)^2 - Lambda^8*r^8*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x)^3*diff(A(x), x) - 4*(Lambda^8*r^4*diff(G(r, y), y)^4 - 2*Lambda^7*r^4*diff(G(r, y), y)^2*diff(G(r, y), y, y) + Lambda^6*r^4*diff(G(r, y), y, y)^2)*A(x)^2 - 4*(Lambda^10*r^12*A(x)^4*diff(F(r, x), x)^2 - Lambda^7*r^8*A(x)^2*diff(G(r, y), y, y))*diff(A(x), x)^2)*diff(A(x), x, x)^2 + (4*Lambda^9*r^12*A(x)^2*diff(A(x), x)^5*diff(F(r, x), x) - Lambda^8*r^12*A(x)*diff(A(x), x)^6 + 4*(Lambda^9*r^8*diff(F(r, x), x)*diff(G(r, y), y)^2 - 4*Lambda^8*r^8*diff(F(r, x), x)*diff(G(r, y), y, y))*A(x)^2*diff(A(x), x)^3 - 2*(2*Lambda^10*r^12*A(x)^3*diff(F(r, x), x)^2 + (2*Lambda^8*r^8*diff(G(r, y), y)^2 - 3*Lambda^7*r^8*diff(G(r, y), y, y))*A(x))*diff(A(x), x)^4 + 16*(Lambda^9*r^4*diff(F(r, x), x)*diff(G(r, y), y)^4 - 2*Lambda^8*r^4*diff(F(r, x), x)*diff(G(r, y), y)^2*diff(G(r, y), y, y) + Lambda^7*r^4*diff(F(r, x), x)*diff(G(r, y), y, y)^2)*A(x)^2*diff(A(x), x) - 4*(2*(Lambda^9*r^8*diff(F(r, x), x, x)*diff(G(r, y), y)^2 - Lambda^9*r^8*diff(F(r, x), x)^2*diff(G(r, y), y, y))*A(x)^3 + (2*Lambda^8*r^4*diff(G(r, y), y)^4 - 5*Lambda^7*r^4*diff(G(r, y), y)^2*diff(G(r, y), y, y) + 3*Lambda^6*r^4*diff(G(r, y), y, y)^2)*A(x))*diff(A(x), x)^2 - 8*(Lambda^8*diff(G(r, y), y)^6 - 3*Lambda^7*diff(G(r, y), y)^4*diff(G(r, y), y, y) + 3*Lamb ...
# False

# %%
met.Petrov_fromWeyl()
met.Petrov_frominvariants()
# Out:
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# Calculating Petrov Type...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 2
#       1 met.Petrov_fromWeyl()
# ----> 2 met.Petrov_frominvariants()
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:1010, in NewmanPenrose.Petrov_frominvariants(self)
#    1008 II=NewmanPenrose.simplify_fullfull(self.PetrovinvINP.expr())
#    1009 KK=NewmanPenrose.simplify_fullfull(self.PetrovinvKNP.expr())
# -> 1010 NN=NewmanPenrose.simplify_fullfull(self.PetrovinvNNP.expr())
#    1011 IIJJterm=NewmanPenrose.simplify_fullfull((II**_sage_const_3 -_sage_const_27 *JJ**_sage_const_2 ))
#    1012 if IIJJterm==_sage_const_0 :
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:536, in NewmanPenrose.simplify_fullfull(x)
#     534 def simplify_fullfull(x):
#     535     #This routine is used at some points in the functions
# --> 536     return x.expand().canonicalize_radical().simplify_rectform().simplify_full()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:10870, in sage.symbolic.expression.Expression.simplify_rectform (build/cythonized/sage/symbolic/expression.cpp:109798)()
#   10868     True
#   10869 """
# > 10870 simplified_expr = self.rectform()
#   10871
#   10872 if complexity_measure is None:
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:10508, in sage.symbolic.expression.Expression.rectform (build/cythonized/sage/symbolic/expression.cpp:107029)()
#   10506         0.0
#   10507     """
# > 10508     return self.maxima_methods().rectform()
#   10509
#   10510 def unhold(self, exclude=None):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/maxima_wrapper.py:31, in MaximaFunctionElementWrapper.__call__(self, *args, **kwds)
#      18 def __call__(self, *args, **kwds):
#      19     """
#      20     Return a Sage expression instead of a Maxima pexpect interface element.
#      21
#    (...)     29         Symbolic Ring
#      30     """
# ---> 31     return super().__call__(*args, **kwds).sage()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:1123, in InterfaceElement.sage(self, *args, **kwds)
#    1104 def sage(self, *args, **kwds):
#    1105     """
#    1106     Attempt to return a Sage version of this object.
#    1107
#    (...)   1121         [0 0]
#    1122     """
# -> 1123     return self._sage_(*args, **kwds)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_abstract.py:1229, in MaximaAbstractElement._sage_(self)
#    1176 """
#    1177 Attempt to make a native Sage object out of this Maxima object.
#    1178 This is useful for automatic coercions in addition to other
#    (...)   1226     (True, False)
#    1227 """
#    1228 import sage.calculus.calculus as calculus
# -> 1229 return calculus.symbolic_expression_from_maxima_string(self.name(),
#    1230         maxima=self.parent())
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/calculus/calculus.py:2502, in symbolic_expression_from_maxima_string(x, equals_sub, maxima)
#    2497 maxima.set('_tmp_', x)
#    2499 # This is inefficient since it so rarely is needed:
#    2500 #r = maxima._eval_line('listofvars(_tmp_);')[1:-1]
# -> 2502 s = maxima._eval_line('_tmp_;')
#    2504 # We don't actually implement a parser for maxima expressions.
#    2505 # Instead we simply transform the string until it is a valid
#    2506 # sagemath expression and parse that.
#    (...)   2510 # literal -- but string literals should *never* ever be part of a
#    2511 # symbolic expression.
#    2512 s = s.replace("'","")
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:475, in MaximaLib._eval_line(self, line, locals, reformat, **kwds)
#     473         line = line[ind_semi + 1:]
#     474     if statement:
# --> 475         result = ((result + '\n') if result else '') + max_to_string(maxima_eval("#$%s$" % statement))
#     476 else:
#     477     statement = line[:ind_dollar]
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:315, in max_to_string(s)
#     298 def max_to_string(s):
#     299     r"""
#     300     Return the Maxima string corresponding to this ECL object.
#     301
#    (...)    313         'cos(_SAGE_VAR_x)'
#     314     """
# --> 315     return maxprint(s).python()[1:-1]
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:12202)()
#     826     """
#     827     lispargs = EclObject(list(args))
# --> 828     return ecl_wrap(ecl_safe_apply(self.obj, (<EclObject>lispargs).obj))
#     829
#     830 def __richcmp__(left, right, int op):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:356, in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:9706)()
#     354         raise KeyboardInterrupt("ECL says: {}".format(message))
#     355     else:
# --> 356         raise RuntimeError("ECL says: {}".format(message))
#     357 else:
#     358     return ret
#
# RuntimeError: ECL says: Memory limit reached. Please jump to an outer pointer, quit program and enlarge the
# memory limits before executing the program again.

# %%
def fitEq(expr):
    expanded_expr = expr.expand()

    latex_expr = latex(expanded_expr)

    return latex_expr
var('z')
met.type_A_transformation(z)
met.type_B_transformation(z)
met.type_C_transformation(z)

# Yardımcı fonksiyonlar
def compare_expressions(orig, trans):
    """Dönüşümleri karşılaştır"""
    if trans == 0:
        return "0"
    try:
        if bool(trans == orig):
            return None
    except:
        if str(trans) == str(orig):
            return None
    return str(latex(fitEq(trans)))

def write_transformation_section(fout, coeffs, title):
    """Dönüşüm bölümünü yaz"""
    fout.write(f"\n\\textit{{{title}:}}\n\n")
    
    for symbol, orig, trans in coeffs:
        result = compare_expressions(orig, trans)
        if result is None:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {symbol}\n\\end{{dmath}}\n\n")
        else:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {result}\n\\end{{dmath}}\n\n")

def write_transformations(fout, met, transform_type):
    """Tüm dönüşümleri yaz"""
    tr_suffix = f"_tr{transform_type}"
    
    fout.write(f"\n\\newpage\n\\underline{{{transform_type} Type transformations:}}\n")
    
    # Spin coefficients
    spin_coeffs = [
        ('\\rho', met.rhoNP.expr(), getattr(met, f'rhoNP{tr_suffix}')),
        ('\\sigma', met.sigmaNP.expr(), getattr(met, f'sigmaNP{tr_suffix}')),
        ('\\kappa', met.kappaNP.expr(), getattr(met, f'kappaNP{tr_suffix}')),
        ('\\mu', met.muNP.expr(), getattr(met, f'muNP{tr_suffix}')),
        ('\\lambda', met.lambdaNP.expr(), getattr(met, f'lambdaNP{tr_suffix}')),
        ('\\nu', met.nuNP.expr(), getattr(met, f'nuNP{tr_suffix}')),
        ('\\alpha', met.alphaNP.expr(), getattr(met, f'alphaNP{tr_suffix}')),
        ('\\beta', met.betaNP.expr(), getattr(met, f'betaNP{tr_suffix}')),
        ('\\tau', met.tauNP.expr(), getattr(met, f'tauNP{tr_suffix}')),
        ('\\pi', met.piNP.expr(), getattr(met, f'piNP{tr_suffix}')),
        ('\\epsilon', met.epsilonNP.expr(), getattr(met, f'epsilonNP{tr_suffix}')),
        ('\\gamma', met.gammaNP.expr(), getattr(met, f'gammaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, spin_coeffs, "Spin coefficients")
    
    # Weyl components
    weyl_comps = [
        ('\\Psi_0', met.Psi0NP.expr(), getattr(met, f'Psi0NP{tr_suffix}')),
        ('\\Psi_1', met.Psi1NP.expr(), getattr(met, f'Psi1NP{tr_suffix}')),
        ('\\Psi_2', met.Psi2NP.expr(), getattr(met, f'Psi2NP{tr_suffix}')),
        ('\\Psi_3', met.Psi3NP.expr(), getattr(met, f'Psi3NP{tr_suffix}')),
        ('\\Psi_4', met.Psi4NP.expr(), getattr(met, f'Psi4NP{tr_suffix}'))
    ]
    write_transformation_section(fout, weyl_comps, "Weyl components")
    
    # Ricci components
    ricci_comps = [
        ('\\Phi_{00}', met.Phi00NP.expr(), getattr(met, f'Phi00NP{tr_suffix}')),
        ('\\Phi_{01}', met.Phi01NP.expr(), getattr(met, f'Phi01NP{tr_suffix}')),
        ('\\Phi_{02}', met.Phi02NP.expr(), getattr(met, f'Phi02NP{tr_suffix}')),
        ('\\Phi_{10}', met.Phi10NP.expr(), getattr(met, f'Phi10NP{tr_suffix}')),
        ('\\Phi_{11}', met.Phi11NP.expr(), getattr(met, f'Phi11NP{tr_suffix}')),
        ('\\Phi_{12}', met.Phi12NP.expr(), getattr(met, f'Phi12NP{tr_suffix}')),
        ('\\Phi_{20}', met.Phi20NP.expr(), getattr(met, f'Phi20NP{tr_suffix}')),
        ('\\Phi_{21}', met.Phi21NP.expr(), getattr(met, f'Phi21NP{tr_suffix}')),
        ('\\Phi_{22}', met.Phi22NP.expr(), getattr(met, f'Phi22NP{tr_suffix}'))
    ]
    write_transformation_section(fout, ricci_comps, "Ricci components")

z# Ana latex dosyası için dönüşüm bölümlerini yazan fonksiyon
def write_all_transformations(fout, met):
    for transform_type in ['A', 'B', 'C']:
        write_transformations(fout, met, transform_type)

# %%
# Latex formatında rapor dosyası oluşturmak için bu kodu kullanabilirsiniz.
# (Dosyanin adini uygun sekilde degistirmeyi unutmayin.)
fout = open('17.26.tex',"w")
tmpstr=r'''\documentclass[landscape]{article}
%\documentclass[11pt,a4paper,reqno]{amsart}
%%%%%%%%%%%%%%%%%%%%%%
\usepackage[fleqn]{amsmath} %Denklemleri sola daya
\usepackage{amssymb}
\usepackage{authblk}
\usepackage{caption}
\usepackage{cite}
\usepackage{xcolor}
\usepackage{color}
\usepackage{float}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{mdframed}
\usepackage{hyperref}
\usepackage{textcomp}
\usepackage{epstopdf}
\usepackage{subcaption}
\usepackage{lscape}
\usepackage{breqn}
%\usepackage{soul}
%%%%%%%%%%%%%%%%%%%%%%
\setlength\parindent{0pt}
\setlength{\parskip}{5pt}
\geometry{left=20mm,right=20mm,top=30mm,bottom=20mm}
\hyphenation{Schwarz-schild}
%%%%%%%%%%%%%%%%%%%%%%
\newcommand{\etalchar}[1]{$^{#1}$}
\newcommand\hl[1]{%
	\bgroup
	\hskip0pt\color{red!80!black}%
	#1%
	\egroup
}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\begin{document}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\textbf{Newman-Penrose Formalism Calculations for}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{metric:} 

\textit{Name:} Stephani et al., Equation (17.26)

\textit{Alias:} Stephanietal\_17\_26

\textit{Reference(s):} \cite{stefani}

\textit{Line element:} 

\begin{dmath}'''
fout.write(tmpstr)


fout.write("ds^2 " + str(latex(met.g.display()))[2:])
fout.write(r"\end{dmath}")


fout.write(r"\textit{Coordinates:} "+str(latex(MyCoordinates[:])))
tmpstr=r'''
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{Null tetrad components: }

\textit{Covariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}

\textit{Contravariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}


\newpage
\textbf{Directional derivatives: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"D&=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\Delta&=" + str(latex(fitEq( met.DeltanNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\delta&=" + str(latex(fitEq( met.deltamNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\overline{\delta}&=" + str(latex(fitEq( met.deltambarNP(f).expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Spin coefficients: }

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\rho&="+str(latex(fitEq(met.rhoNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\sigma&="+str(latex(fitEq(met.sigmaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\kappa&="+str(latex(fitEq(met.kappaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\mu&="+str(latex(fitEq(met.muNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\lambda&="+str(latex(met.lambdaNP.expr()))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\nu&="+str(latex(fitEq(met.nuNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\alpha&="+str(latex(fitEq(met.alphaNP.expr()))))

tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\beta&="+str(latex(fitEq(met.betaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\tau&="+str(latex(fitEq(met.tauNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\pi&="+str(latex(fitEq(met.piNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\epsilon&="+str(latex(fitEq(met.epsilonNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\gamma&="+str(latex(fitEq(met.gammaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage

\textbf{Relations between spin coefficients: }


%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Ricci tensor components: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{00}&="+str(latex(fitEq(met.Phi00NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{01}&="+str(latex(fitEq(met.Phi01NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{02}&="+str(latex(fitEq(met.Phi02NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{10}&="+str(latex(fitEq(met.Phi10NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{11}&="+str(latex(fitEq(met.Phi11NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{12}&="+str(latex(fitEq(met.Phi12NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{20}&="+str(latex(fitEq(met.Phi20NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{21}&="+str(latex(fitEq(met.Phi21NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{22}&="+str(latex(fitEq(met.Phi22NP.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Weyl tensor components: }
\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_0&="+str(latex(fitEq(met.Psi0NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_1&="+str(latex(fitEq(met.Psi1NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_2&="+str(latex(fitEq(met.Psi2NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_3&="+str(latex(fitEq(met.Psi3NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_4&="+str(latex(fitEq(met.Psi4NP.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Newman-Penrose equations: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"NP1&="+str(latex(fitEq(met.NPeq1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP2&="+str(latex(fitEq(met.NPeq2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP3&="+str(latex(fitEq(met.NPeq3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP4&="+str(latex(fitEq(met.NPeq4.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP5&="+str(latex(fitEq(met.NPeq5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP6&="+str(latex(fitEq(met.NPeq6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP7&="+str(latex(fitEq(met.NPeq7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP8&="+str(latex(fitEq(met.NPeq8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP9&="+str(latex(fitEq(met.NPeq9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP10&="+str(latex(fitEq(met.NPeq10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP11&="+str(latex(fitEq(met.NPeq11.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP12&="+str(latex(fitEq(met.NPeq12.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP13&="+str(latex(fitEq(met.NPeq13.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP14&="+str(latex(fitEq(met.NPeq14.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP15&="+str(latex(fitEq(met.NPeq15.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP16&="+str(latex(fitEq(met.NPeq16.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP17&="+str(latex(fitEq(met.NPeq17.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP18&="+str(latex(fitEq(met.NPeq18.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Bianchi identities: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI1&="+str(latex(fitEq(met.BI1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI2&="+str(latex(fitEq(met.BI2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI3&="+str(latex(fitEq(met.BI3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI4&="+str(latex(fitEq(met.BI4.expr())))+r' \\ '),
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI5&="+str(latex(fitEq(met.BI5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI6&="+str(latex(fitEq(met.BI6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI7&="+str(latex(fitEq(met.BI7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI8&="+str(latex(fitEq(met.BI8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI9&="+str(latex(fitEq(met.BI9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI10&="+str(latex(fitEq(met.BI10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI11&="+str(latex(fitEq(met.BI11.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


\newpage
\textbf{Petrov classification:} \\
\vspace{2cm}
\textit{Petrov class: I} 
\vspace{2cm}


'''
fout.write(tmpstr)
write_all_transformations(fout, met)
tmpstr = r'''

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\begin{thebibliography}{99}

\bibitem{stefani}
 H. Stephani, D. Kramer, M. MacCallum, C. Hoenselaers, and E. Herlt, Exact Solutions of Einstein’s Field Equations. Cambridge Monographs on Mathematical Physics, Cambridge University Press, 2009.
\end{thebibliography}
\begin{mdframed}
\textbf{Calculated by:}

\textit{Name: } Tuba Önen

\textit{E-mail: } onen20@itu.edu.tr

\textit{Date: } 02.12.2025
\end{mdframed}
\end{document}
'''
fout.write(tmpstr)
fout.close()

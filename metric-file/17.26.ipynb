# %%
reset()

from SageNP import NewmanPenrose

########################################################
# Define 4-dim. the manifold:
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
########################################################
MyCoordinates.<t,z,x,y> = MyManifold.chart(r't z x y')
###################################################
# Define the metric functions
var('lamda', latex_name='\lambda')
var('m,r')

def noargs(name):
    return lambda *args: name
    
F = function('F',imag_part_func=0,print_latex_func=noargs('F'))(r,x)
G = function('G',imag_part_func=0,print_latex_func=noargs('G'))(r,y)
A = function('A',imag_part_func=0,print_latex_func=noargs('A'))(x)
B = function('B',imag_part_func=0,print_latex_func=noargs('B'))(y)

metric_functions = [
    (r"F", A*r^2+m*x),
    (r"G", B*r^2+m*y),
    (r"A", 1-x^2-m*x^3),
    (r"B", y^2-m*y^3-1)]

#var('\lambda')
########################################################
# Parametre belirleyin: (tetradlarınızın tipine göre aşağıdaki kısmı tanımlayın.)
tetrad_type = 'covariant'  # 'covariant' ya da 'contravariant' olabilir.
###################################################
# Enter null tetrad elements
# These vectors define the Static Spherical spacetime
lvec=[sqrt(1/2)*(e^(lamda*(F-G))*B)^(1/2)*r, -sqrt(1/2)*(e^(lamda*(G-F))*A)^(1/2)*r, 0, 0]
nvec=[sqrt(1/2)*(e^(lamda*(F-G))*B)^(1/2)*r, sqrt(1/2)*(e^(lamda*(G-F))*A)^(1/2)*r, 0, 0]
mvec=[0, 0, sqrt(1/2)*r*(1/sqrt(A))*(e^(lamda*(F+G))*e^(-lamda^2*r^4*A*B))^(1/2), sqrt(1/2)*r*I*(1/sqrt(B))*(e^(lamda*(F+G))*e^(-lamda^2*r^4*A*B))^(1/2)]
mbarvec=[0, 0, sqrt(1/2)*r*(1/sqrt(A))*(e^(lamda*(F+G))*e^(-lamda^2*r^4*A*B))^(1/2), -sqrt(1/2)*r*I*(1/sqrt(B))*(e^(lamda*(F+G))*e^(-lamda^2*r^4*A*B))^(1/2)]
########################################################
# Define the object "met" of the class "SageNP":
met=NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
########################################################

f=MyManifold.scalar_field(function('f')(*MyCoordinates))
met.calculate_spincoefficients()
met.calculate_Weyl()
met.calculate_Ricci()
met.calculate_NPeq()
met.calculate_Bianchi()
met.Petrov_fromWeyl()

met.show_spincoefficients()
met.show_Weyl()
met.show_Ricci()
met.show_NPeq()
met.show_Bianchi()
# Out:
# 'The metric:'
# g = -r^2*B(y)*e^(lamda*F(r, x) - lamda*G(r, y)) dt⊗dt + r^2*A(x)*e^(-lamda*F(r, x) + lamda*G(r, y)) dz⊗dz + r^2*e^(-lamda^2*r^4*A(x)*B(y) + lamda*F(r, x) + lamda*G(r, y))/A(x) dx⊗dx + r^2*e^(-lamda^2*r^4*A(x)*B(y) + lamda*F(r, x) + lamda*G(r, y))/B(y) dy⊗dy
# Calculating spin coefficients...
# Calculating Weyl components...
# Calculating Ricci components...
# Calculating NP equations...
# Calculating Bianchi identities...
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# 'kappaNP=' -1/8*((2*sqrt(2)*lamda*A(x)*diff(F(r, x), x) - sqrt(2)*diff(A(x), x))*sqrt(B(y))*e^(1/2*lamda^2*r^4*A(x)*B(y)) - (2*I*sqrt(2)*lamda*B(y)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y) - I*sqrt(2)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(B(y), y))*sqrt(A(x)))*e^(-1/2*lamda*F(r, x) - 1/2*lamda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'tauNP=' -1/8*sqrt(2)*(sqrt(B(y))*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(A(x), x) + I*sqrt(A(x))*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(B(y), y))*e^(-1/2*lamda*F(r, x) - 1/2*lamda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'sigmaNP=' 0
# 'rhoNP=' 0
# 'piNP=' 1/8*sqrt(2)*(sqrt(B(y))*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(A(x), x) - I*sqrt(A(x))*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(B(y), y))*e^(-1/2*lamda*F(r, x) - 1/2*lamda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'nuNP=' 1/8*((2*sqrt(2)*lamda*A(x)*diff(F(r, x), x) - sqrt(2)*diff(A(x), x))*sqrt(B(y))*e^(1/2*lamda^2*r^4*A(x)*B(y)) - (-2*I*sqrt(2)*lamda*B(y)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + I*sqrt(2)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(B(y), y))*sqrt(A(x)))*e^(-1/2*lamda*F(r, x) - 1/2*lamda*G(r, y))/(r*sqrt(A(x))*sqrt(B(y)))
# 'muNP=' 0
# 'lambdaNP=' 0
# 'epsilonNP=' 0
# 'gammaNP=' 0
# 'betaNP=' -1/8*sqrt(2)*((lamda^2*r^4*B(y)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(A(x), x) - lamda*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(F(r, x), x))*sqrt(A(x)) + (I*lamda^2*r^4*A(x)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(B(y), y) - I*lamda*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*sqrt(B(y)))*e^(-1/2*lamda*F(r, x) - 1/2*lamda*G(r, y))/r
# 'alphaNP=' 1/8*sqrt(2)*((lamda^2*r^4*B(y)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(A(x), x) - lamda*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(F(r, x), x))*sqrt(A(x)) - (I*lamda^2*r^4*A(x)*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(B(y), y) - I*lamda*e^(1/2*lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*sqrt(B(y)))*e^(-1/2*lamda*F(r, x) - 1/2*lamda*G(r, y))/r
# 'Psi0NP=' -1/8*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - (2*lamda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - lamda^2*r^4*diff(A(x), x)^2 - 2*lamda^2*diff(G(r, y), y)^2 + 2*lamda*diff(G(r, y), y, y))*B(y)*e^(lamda^2*r^4*A(x)*B(y)) + 2*(-I*lamda^3*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(F(r, x), x) + I*lamda^3*r^4*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (3*lamda*diff(A(x), x)*diff(F(r, x), x) - 2*(lamda^2*diff(F(r, x), x)^2 - lamda*diff(F(r, x), x, x))*A(x) - diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) - (2*lamda^3*r^4*A(x)*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 3*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y) + e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Psi1NP=' 0
# 'Psi2NP=' -1/24*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - 3*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) + (lamda^2*r^4*diff(A(x), x)^2 + 2*lamda^2*r^4*A(x)*diff(A(x), x, x) + 2*lamda^2*diff(G(r, y), y)^2 - 2*lamda*diff(G(r, y), y, y))*B(y)*e^(lamda^2*r^4*A(x)*B(y)) - (3*lamda*diff(A(x), x)*diff(F(r, x), x) - 2*(lamda^2*diff(F(r, x), x)^2 - lamda*diff(F(r, x), x, x))*A(x) - diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) + (2*lamda^2*r^4*A(x)*B(y)*e^(lamda^2*r^4*A(x)*B(y)) + e^(lamda^2*r^4*A(x)*B(y)))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Psi3NP=' 0
# 'Psi4NP=' -1/8*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - (2*lamda^3*r^4*A(x)*diff(A(x), x)*diff(F(r, x), x) - lamda^2*r^4*diff(A(x), x)^2 - 2*lamda^2*diff(G(r, y), y)^2 + 2*lamda*diff(G(r, y), y, y))*B(y)*e^(lamda^2*r^4*A(x)*B(y)) - 2*(-I*lamda^3*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(F(r, x), x) + I*lamda^3*r^4*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (3*lamda*diff(A(x), x)*diff(F(r, x), x) - 2*(lamda^2*diff(F(r, x), x)^2 - lamda*diff(F(r, x), x, x))*A(x) - diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) - (2*lamda^3*r^4*A(x)*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y) + 3*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y))*diff(B(y), y) + e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Phi00NP=' -1/8*(2*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) + 2*lamda*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y, y) - (2*lamda*diff(A(x), x)*diff(F(r, x), x) + 2*lamda*A(x)*diff(F(r, x), x, x) - diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) - e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 1/8*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - 2*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) - (lamda^2*r^4*diff(A(x), x)^2 - lamda^2*diff(G(r, y), y)^2)*B(y)*e^(lamda^2*r^4*A(x)*B(y)) + 2*(-I*lamda^2*r^4*e^(lamda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(B(y), y) + I*lamda^2*e^(lamda^2*r^4*A(x)*B(y))*diff(F(r, x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (lamda^2*A(x)*diff(F(r, x), x)^2 - 2*lamda*diff(A(x), x)*diff(F(r, x), x) + diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) + e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Phi20NP=' 1/8*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 - 2*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) - (lamda^2*r^4*diff(A(x), x)^2 - lamda^2*diff(G(r, y), y)^2)*B(y)*e^(lamda^2*r^4*A(x)*B(y)) - 2*(-I*lamda^2*r^4*e^(lamda^2*r^4*A(x)*B(y))*diff(A(x), x)*diff(B(y), y) + I*lamda^2*e^(lamda^2*r^4*A(x)*B(y))*diff(F(r, x), x)*diff(G(r, y), y))*sqrt(A(x))*sqrt(B(y)) - (lamda^2*A(x)*diff(F(r, x), x)^2 - 2*lamda*diff(A(x), x)*diff(F(r, x), x) + diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) + e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Phi11NP=' 1/16*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 + 2*lamda^2*r^4*A(x)*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y) - (lamda^2*diff(F(r, x), x)^2 + 2*lamda*diff(F(r, x), x, x))*A(x)*e^(lamda^2*r^4*A(x)*B(y)) + (lamda^2*r^4*diff(A(x), x)^2 + 2*lamda^2*r^4*A(x)*diff(A(x), x, x) - lamda^2*diff(G(r, y), y)^2 - 2*lamda*diff(G(r, y), y, y))*B(y)*e^(lamda^2*r^4*A(x)*B(y)))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'Phi12NP=' 0
# 'Phi21NP=' 0
# 'Phi22NP=' -1/8*(2*lamda*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)*diff(G(r, y), y) + 2*lamda*B(y)*e^(lamda^2*r^4*A(x)*B(y))*diff(G(r, y), y, y) - (2*lamda*diff(A(x), x)*diff(F(r, x), x) + 2*lamda*A(x)*diff(F(r, x), x, x) - diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) - e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'LambdaNP=' 1/48*(lamda^2*r^4*A(x)*e^(lamda^2*r^4*A(x)*B(y))*diff(B(y), y)^2 + (lamda^2*r^4*diff(A(x), x)^2 + 2*lamda^2*r^4*A(x)*diff(A(x), x, x) - lamda^2*diff(G(r, y), y)^2 - 2*lamda*diff(G(r, y), y, y))*B(y)*e^(lamda^2*r^4*A(x)*B(y)) - ((lamda^2*diff(F(r, x), x)^2 + 2*lamda*diff(F(r, x), x, x))*A(x) + 2*diff(A(x), x, x))*e^(lamda^2*r^4*A(x)*B(y)) + 2*(lamda^2*r^4*A(x)*B(y)*e^(lamda^2*r^4*A(x)*B(y)) - e^(lamda^2*r^4*A(x)*B(y)))*diff(B(y), y, y))*e^(-lamda*F(r, x) - lamda*G(r, y))/r^2
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def write_dmath(fout, lhs, rhs):
    fout.write("\\begin{dmath*}\n")
    fout.write(f"{lhs} = {rhs}\n")
    fout.write("\\end{dmath*}\n\n")

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")

# %%
from pathlib import Path
fout = open('17.26.tex', "w")
metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if petrov is None:
    try:
        met.Petrov_fromWeyl()
        petrov = met.petrovtype
    except Exception:
        petrov = "Unknown"
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')



fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# tex dosyasi olusturuldu.

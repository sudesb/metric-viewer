# %%
reset()

from SageNP import NewmanPenrose

#########################################################################################################
# Define 4-dim. the manifold:
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
#########################################################################################################
MyCoordinates.<u,v,x,y> = MyManifold.chart(r'u v x y')
#########################################################################################################
#f fonksiyonu derivative operatörleri hesaplamak için kullanılıyor.(bu satırı değiştirmeyin!)
f=MyManifold.scalar_field(function('f')(*MyCoordinates))
#########################################################################################################
# Parametre belirleyin: (tetradlarınızın tipine göre aşağıdaki kısmı tanımlayın.)
tetrad_type = 'covariant'  # 'covariant' ya da 'contravariant' olabilir.
#########################################################################################################

var('l epsilon')

epsilon=-1

def noargs(name):
    return lambda *args: name
# Define the metric functions
P = function("P", print_latex_func=noargs('P'))(x,y)
b_x = function("b_x", imag_part_func = 0)(u,x,y)
b_y = function("b_y", imag_part_func = 0)(u,x,y)
K = function("K",print_latex_func=noargs('K'))(u)
k = function("k",print_latex_func=noargs('k'))(u)
H = function("H", print_latex_func=noargs('H'))(u,x,y)
A = function("A",print_latex_func=noargs('A'))(v,x,y)

metric_functions=[("K(u)",K),("H(u,x,y)",H)]

k=1+epsilon^2*K
A=(b_x^2+b_y^2)*2/(k^2*(1+epsilon*(x^2+y^2))^2)-2*(epsilon*k^2*v^2+l*v+H)
P=2/(k^2*(1+epsilon*(x^2+y^2)))

assume(K>0)

#########################################################################################################
# Null Terad Elemanlarını Girin :
lvec = [1,0, 0, 0] 
nvec = [A/2,1, -b_x*P, -b_y*P] 
mvec = [0, 0, sqrt(P/2), I*sqrt(P/2)]
mbarvec = [0, 0,sqrt(P/2), -I*sqrt(P/2)]

#########################################################################################################

# Define the object "metric" of the class "SageNP":
met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
#########################################################################################################
# Out:
# 'The metric:'
# g = -2*(((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v^2 - (l*K(u)^2 + 2*l*K(u) + l)*v - (K(u)^2 + 2*K(u) + 1)*H(u, x, y))*x^4 + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v^2 - (l*K(u)^2 + 2*l*K(u) + l)*v - (K(u)^2 + 2*K(u) + 1)*H(u, x, y))*y^4 + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v^2 - 2*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v^2 - (l*K(u)^2 + 2*l*K(u) + l)*v - (K(u)^2 + 2*K(u) + 1)*H(u, x, y))*x^2 - 2*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v^2 - ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v^2 - (l*K(u)^2 + 2*l*K(u) + l)*v - (K(u)^2 + 2*K(u) + 1)*H(u, x, y))*x^2 - (l*K(u)^2 + 2*l*K(u) + l)*v - (K(u)^2 + 2*K(u) + 1)*H(u, x, y))*y^2 - (l*K(u)^2 + 2*l*K(u) + l)*v - (K(u)^2 + 2*K(u) + 1)*H(u, x, y) + b_x(u, x, y)^2 + b_y(u, x, y)^2)/((K(u)^2 + 2*K(u) + 1)*x^4 + (K(u)^2 + 2*K(u) + 1)*y^4 - 2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*((K(u)^2 + 2*K(u) + 1)*x^2 - K(u)^2 - 2*K(u) - 1)*y^2 + K(u)^2 + 2*K(u) + 1) du⊗du - du⊗dv - 2*b_x(u, x, y)/((K(u)^2 + 2*K(u) + 1)*x^2 + (K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1) du⊗dx - 2*b_y(u, x, y)/((K(u)^2 + 2*K(u) + 1)*x^2 + (K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1) du⊗dy - dv⊗du - 2*b_x(u, x, y)/((K(u)^2 + 2*K(u) + 1)*x^2 + (K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1) dx⊗du - 2/((K(u)^2 + 2*K(u) + 1)*x^2 + (K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1) dx⊗dx - 2*b_y(u, x, y)/((K(u)^2 + 2*K(u) + 1)*x^2 + (K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1) dy⊗du - 2/((K(u)^2 + 2*K(u) + 1)*x^2 + (K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1) dy⊗dy

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()

met.calculate_Weyl()
met.show_Weyl()
met.calculate_Ricci()
met.show_Ricci()



met.Petrov_fromWeyl()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' 0
# 'tauNP=' 0
# 'sigmaNP=' 0
# 'rhoNP=' 0
# 'piNP=' 0
# 'nuNP=' 1/2*(((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), y))*x^6 + ((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), y))*y^6 + (4*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*b_x(u, x, y) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*b_y(u, x, y))*v - 2*(l*K(u) + l)*b_x(u, x, y) + 2*(I*l*K(u) + I*l)*b_y(u, x, y) - 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + 3*(I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), y) - 4*(b_x(u, x, y) - I*b_y(u, x, y))*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u) + 2*(-I*K(u) - I)*diff(b_y(u, x, y), u))*x^4 + (3*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y))*x^2 + 4*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*b_x(u, x, y) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*b_y(u, x, y))*v - 2*(l*K(u) + l)*b_x(u, x, y) + 2*(I*l*K(u) + I*l)*b_y(u, x, y) - 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + 3*(I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), y) - 4*(b_x(u, x, y) - I*b_y(u, x, y))*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u) + 2*(-I*K(u) - I)*diff(b_y(u, x, y), u))*y^4 - (2*(K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x) - 2*(I*K(u) + I)*b_x(u, x, y)*diff(b_x(u, x, y), y) + 2*(K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x) - 2*(I*K(u) + I)*b_y(u, x, y)*diff(b_y(u, x, y), y) + 8*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*b_x(u, x, y) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*b_y(u, x, y))*v - 4*(l*K(u) + l)*b_x(u, x, y) - 4*(-I*l*K(u) - I*l)*b_y(u, x, y) - 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) - 3*(-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y) - 8*(b_x(u, x, y) - I*b_y(u, x, y))*diff(K(u), u) + 4*(K(u) + 1)*diff(b_x(u, x, y), u) - 4*(I*K(u) + I)*diff(b_y(u, x, y), u))*x^2 + (3*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y))*x^4 + 2*(4*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*b_x(u, x, y) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*b_y(u, x, y))*v - 2*(l*K(u) + l)*b_x(u, x, y) + 2*(I*l*K(u) + I*l)*b_y(u, x, y) - 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + 3*(I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), y) - 4*(b_x(u, x, y) - I*b_y(u, x, y))*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u) + 2*(-I*K(u) - I)*diff(b_y(u, x, y), u))*x^2 - 2*(K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x) + 2*(I*K(u) + I)*b_x(u, x, y)*diff(b_x(u, x, y), y) - 2*(K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x) + 2*(I*K(u) + I)*b_y(u, x, y)*diff(b_y(u, x, y), y) - 8*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*b_x(u, x, y) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*b_y(u, x, y))*v + 4*(l*K(u) + l)*b_x(u, x, y) + 4*(-I*l*K(u) - I*l)*b_y(u, x, y) + 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + 3*(-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y) + 8*(b_x(u, x, y) - I*b_y(u, x, y))*diff(K(u), u) - 4*(K(u) + 1)*diff(b_x(u, x, y), u) + 4*(I*K(u) + I)*diff(b_y(u, x, y), u))*y^2 + 2*(K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x) + 2*(-I*K(u) - I)*b_x(u, x, y)*diff(b_x(u, x, y), y) + 2*(K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x) + 2*(-I*K(u) - I)*b_y(u, x, y)*diff(b_y(u, x, y), y) + 4*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*b_x(u, x, y) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*b_y(u, x, y))*v + 4*((K(u) + 1)*b_x(u, x, y)^2 + (K(u) + 1)*b_y(u, x, y)^2)*x + 4*((-I*K(u) - I)*b_x(u, x, y)^2 + (-I*K(u) - I)*b_y(u, x, y)^2)*y - 2*(l*K(u) + l)*b_x(u, x, y) + 2*(I*l*K(u) + I*l)*b_y(u, x, y) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) - (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y) - 4*(b_x(u, x, y) - I*b_y(u, x, y))*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u) + 2*(-I*K(u) - I)*diff(b_y(u, x, y), u))/((x^4*(K(u) + 1)*abs(K(u) + 1) + y^4*(K(u) + 1)*abs(K(u) + 1) - 2*x^2*(K(u) + 1)*abs(K(u) + 1) + 2*(x^2*(K(u) + 1)*abs(K(u) + 1) - (K(u) + 1)*abs(K(u) + 1))*y^2 + (K(u) + 1)*abs(K(u) + 1))*sqrt(abs(x^2 ...
# 'muNP=' -1/2*(((-I*K(u) - I)*diff(b_x(u, x, y), y) + (I*K(u) + I)*diff(b_y(u, x, y), x) + 2*diff(K(u), u))*x^2 + ((-I*K(u) - I)*diff(b_x(u, x, y), y) + (I*K(u) + I)*diff(b_y(u, x, y), x) + 2*diff(K(u), u))*y^2 - 2*y*(-I*K(u) - I)*b_x(u, x, y) - 2*x*(I*K(u) + I)*b_y(u, x, y) + (I*K(u) + I)*diff(b_x(u, x, y), y) + (-I*K(u) - I)*diff(b_y(u, x, y), x) - 2*diff(K(u), u))/((K(u) + 1)*abs(x^2 + y^2 - 1))
# 'lambdaNP=' 0
# 'epsilonNP=' 0
# 'gammaNP=' -1/4*(((-I*K(u) - I)*diff(b_x(u, x, y), y) + (I*K(u) + I)*diff(b_y(u, x, y), x) + 2*diff(K(u), u))*x^2 + ((-I*K(u) - I)*diff(b_x(u, x, y), y) + (I*K(u) + I)*diff(b_y(u, x, y), x) + 2*diff(K(u), u))*y^2 - 2*y*(-I*K(u) - I)*b_x(u, x, y) - 2*x*(I*K(u) + I)*b_y(u, x, y) + 2*(2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*v - l*K(u) - l + diff(K(u), u))*abs(x^2 + y^2 - 1) + (I*K(u) + I)*diff(b_x(u, x, y), y) + (-I*K(u) - I)*diff(b_y(u, x, y), x) - 2*diff(K(u), u))/((K(u) + 1)*abs(x^2 + y^2 - 1))
# 'betaNP=' 1/4*((K(u)^2 + 2*K(u) + 1)*x + (I*K(u)^2 + 2*I*K(u) + I)*y)/(sqrt(abs(x^2 + y^2 - 1))*abs(K(u) + 1))
# 'alphaNP=' -1/4*((K(u)^2 + 2*K(u) + 1)*x - (I*K(u)^2 + 2*I*K(u) + I)*y)/(sqrt(abs(x^2 + y^2 - 1))*abs(K(u) + 1))
# Calculating Weyl components...
# 'Psi0NP=' 0
# 'Psi1NP=' 0
# 'Psi2NP=' -1/6*(2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*(K(u)^2 + 2*K(u) + 1)*y^2 - 3*K(u)^2 - 6*K(u) - 3)/abs(x^2 + y^2 - 1)
# 'Psi3NP=' -1/8*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^4 - 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^3 + 2*(5*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 3*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) - (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) - (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - 2*(((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + ((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 3*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 5*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^2 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 2*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + 2*((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y - 10*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 10*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))/((x^2*abs(K(u) + 1) + y^2*abs(K(u) + 1) - abs(K(u) + 1))*sqrt(abs(x^2 + y^2 - 1)))
# 'Psi4NP=' -1/4*(((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + 2*(-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), x, y) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*x^8 + ((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + 2*(-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), x, y) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*y^8 + 2*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y))*x^7 + 2*((-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), x) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y))*y^7 + 2*(2*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(b_x(u, x, y), y) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(b_y(u, x, y), x) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v - 2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + 4*(I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), x, y) + 2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) + (K(u) + 1)*diff(b_x(u, x, y), u, x) + (-I*K(u) - I)*diff(b_x(u, x, y), u, y) - (l*K(u) + l + 2*diff(K(u), u))*diff(b_x(u, x, y), x) + (I*l*K(u) + I*l + 2*I*diff(K(u), u))*diff(b_x(u, x, y), y) + (-I*K(u) - I)*diff(b_y(u, x, y), u, x) - (K(u) + 1)*diff(b_y(u, x, y), u, y) + (I*l*K(u) + I*l + 2*I*diff(K(u), u))*diff(b_y(u, x, y), x) + (l*K(u) + l + 2*diff(K(u), u))*diff(b_y(u, x, y), y))*x^6 + 2*(2*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + 2*(-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), x, y) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*x^2 + 2*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(b_x(u, x, y), y) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(b_y(u, x, y), x) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v + ((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) + (-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), y))*x - 2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + 4*(I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), x, y) + 2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) + (K(u) + 1)*diff(b_x(u, x, y), u, x) + (-I*K(u) - I)*diff(b_x(u, x, y), u, y) - (l*K(u) + l + 2*diff(K(u), u))*diff(b_x(u, x, y), x) + (I*l*K(u) + I*l + 2*I*diff(K(u), u))*diff(b_x(u, x, y), y) + (-I*K(u) - I)*diff(b_y(u, x, y), u, x) - (K(u) + 1)*diff(b_y(u, x, y), u, y) + (I*l*K(u) + I*l + 2*I*diff(K(u), u))*diff(b_y(u, x, y), x) + (l*K(u) + l + 2*diff(K(u), u))*diff(b_y(u, x, y), y))*y^6 - 6*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), y))*x^5 + 6*(((-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), x) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y))*x^2 + (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(H(u, x, y), x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y))*y^5 - 2*(4*(K(u) + 1)*b_x(u, x, y)^2 - 8*(I*K(u) + I)*b_x(u, x, y)*b_y(u, x, y) - 4*(K(u) + 1)*b_y(u, x, y)^2 + (K(u) + 1)*diff(b_x(u, x, y), x)^2 + (K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x, x) - 2*(I*K(u) + I)*b_x(u, x, y)*diff(b_x(u, x, y), x, y) - (K(u) + 1)*diff(b_x(u, x, y), y)^2 - (K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), y, y) + (K(u) + 1)*diff(b_y(u, x, y), x)^2 + (K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x, x) - 2*(I*K(u) + I)*b_y(u, x, y)*diff(b_y(u, x, y), x, y) - (K(u) + 1)*diff(b_y(u, x, y), y)^2 - (K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), y, y) + 6*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(b_x(u, x, y), y) - (I*K(u)^3 + 3*I*K(u)^2 + 3*I*K(u) + I)*diff(b_y(u, x, y), x) - (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v - 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) - 6*(-I*K(u)^3 - 3*I*K(u)^2 - 3*I*K(u) - I)*diff(H(u, x, y), x, y) + 3*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) + 3*(K(u)  ...
# Calculating Ricci components...
# 'Phi00NP=' 0
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 0
# 'Phi20NP=' 0
# 'Phi11NP=' -1/8*(2*(K(u)^2 + 2*K(u) + 1)*x^4 + 2*(K(u)^2 + 2*K(u) + 1)*y^4 - 3*(K(u)^2 + 2*K(u) + 1)*x^2 + (4*(K(u)^2 + 2*K(u) + 1)*x^2 - 3*K(u)^2 - 6*K(u) - 3)*y^2 + K(u)^2 - (2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*(K(u)^2 + 2*K(u) + 1)*y^2 - K(u)^2 - 2*K(u) - 1)*abs(x^2 + y^2 - 1) + 2*K(u) + 1)/((x^2 + y^2 - 1)*abs(x^2 + y^2 - 1))
# 'Phi12NP=' -1/8*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^4 - 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^3 + 2*(3*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 5*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) - (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) - (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - 2*(((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + ((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 5*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^2 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 2*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + 2*((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y - 6*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 6*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))/((x^2*abs(K(u) + 1) + y^2*abs(K(u) + 1) - abs(K(u) + 1))*sqrt(abs(x^2 + y^2 - 1)))
# 'Phi21NP=' 1/8*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^4 - 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^3 - 2*(3*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 5*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - 2*(((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + ((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x + 5*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^2 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 2*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + 2*((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y + 6*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 6*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))/((x^2*abs(K(u) + 1) + y^2*abs(K(u) + 1) - abs(K(u) + 1))*sqrt(abs(x^2 + y^2 - 1)))
# 'Phi22NP=' 1/4*(((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y))*x^8 + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y))*y^8 + ((K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y)^2 - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x)^2 + 4*(2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(K(u), u) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_y(u, x, y), y))*v - 4*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) - 4*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y) - 4*(l*K(u) + l)*diff(K(u), u) - 8*diff(K(u), u)^2 + 4*(K(u) + 1)*diff(K(u), u, u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), u, x) - 2*(l*K(u)^2 + 2*l*K(u) + 2*(K(u) + 1)*diff(K(u), u) + l)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), u, y) - 2*(l*K(u)^2 + 2*l*K(u) + 2*(K(u) + 1)*diff(K(u), u) + l)*diff(b_y(u, x, y), y))*x^6 + (4*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y))*x^2 + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y)^2 - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x)^2 + 4*(2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(K(u), u) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_y(u, x, y), y))*v - 4*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) - 4*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y) - 4*(l*K(u) + l)*diff(K(u), u) - 8*diff(K(u), u)^2 + 4*(K(u) + 1)*diff(K(u), u, u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), u, x) - 2*(l*K(u)^2 + 2*l*K(u) + 2*(K(u) + 1)*diff(K(u), u) + l)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), u, y) - 2*(l*K(u)^2 + 2*l*K(u) + 2*(K(u) + 1)*diff(K(u), u) + l)*diff(b_y(u, x, y), y))*y^6 - 4*(2*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v*b_x(u, x, y) - 2*(K(u) + 1)*b_x(u, x, y)*diff(K(u), u) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y)*diff(b_x(u, x, y), y) + (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x) - (l*K(u)^2 + 2*l*K(u) + l)*b_x(u, x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), u))*x^5 - 4*(2*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*v*b_y(u, x, y) - 2*(K(u) + 1)*b_y(u, x, y)*diff(K(u), u) + (K(u)^2 + 2*K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), y) - (K(u)^2 + 2*K(u) + 1)*b_x(u, x, y)*diff(b_y(u, x, y), x) - (l*K(u)^2 + 2*l*K(u) + l)*b_y(u, x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), u))*y^5 - (8*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y)^2 + 4*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y)^2 + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x)^2 + 2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x, x) + 5*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y)^2 + 2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), y, y) - 6*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y)*diff(b_y(u, x, y), x) + 5*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x)^2 + 2*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x, x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y)^2 + 2*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), y, y) + 12*(2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(K(u), u) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_y(u, x, y), y))*v - 6*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) - 6*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y) - 12*(l*K(u) + l)*diff(K(u), u) - 24*diff(K(u), u)^2 + 12*(K(u) + 1)*diff(K(u), u, u) + 6*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), u, x) - 6*(l*K(u)^2 + 2*l*K(u) + 2*(K(u) + 1)*diff(K(u), u) + l)*diff(b_x(u, x, y), x) + 6*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y),  ...
# 'LambdaNP=' -1/12*(2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*(K(u)^2 + 2*K(u) + 1)*y^2 - 3*K(u)^2 - 6*K(u) - 3)/(x^2 + y^2 - 1)
# Calculating Petrov Type...
# Petrov Type II
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.

# %%
met.calculate_NPeq()
met.show_NPeq()

met.calculate_Bianchi()
met.show_Bianchi()
# Out:
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' -1/24*(14*(K(u)^2 + 2*K(u) + 1)*x^4 + 14*(K(u)^2 + 2*K(u) + 1)*y^4 - 29*(K(u)^2 + 2*K(u) + 1)*x^2 + (28*(K(u)^2 + 2*K(u) + 1)*x^2 - 29*K(u)^2 - 58*K(u) - 29)*y^2 + 15*K(u)^2 + (14*(K(u)^2 + 2*K(u) + 1)*x^2 + 14*(K(u)^2 + 2*K(u) + 1)*y^2 - 15*K(u)^2 - 30*K(u) - 15)*abs(x^2 + y^2 - 1) + 30*K(u) + 15)/((x^2 + y^2 - 1)*abs(x^2 + y^2 - 1))
# 'NPeq7=' 0
# 'NPeq8=' -1/6*(2*(K(u)^2 + 2*K(u) + 1)*x^4 + 2*(K(u)^2 + 2*K(u) + 1)*y^4 - 5*(K(u)^2 + 2*K(u) + 1)*x^2 + (4*(K(u)^2 + 2*K(u) + 1)*x^2 - 5*K(u)^2 - 10*K(u) - 5)*y^2 + 3*K(u)^2 + (2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*(K(u)^2 + 2*K(u) + 1)*y^2 - 3*K(u)^2 - 6*K(u) - 3)*abs(x^2 + y^2 - 1) + 6*K(u) + 3)/((x^2 + y^2 - 1)*abs(x^2 + y^2 - 1))
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 1/24*(2*(K(u)^2 + 2*K(u) + 1)*x^4 + 2*(K(u)^2 + 2*K(u) + 1)*y^4 + (K(u)^2 + 2*K(u) + 1)*x^2 + (4*(K(u)^2 + 2*K(u) + 1)*x^2 + K(u)^2 + 2*K(u) + 1)*y^2 - 3*K(u)^2 + (2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*(K(u)^2 + 2*K(u) + 1)*y^2 + 3*K(u)^2 + 6*K(u) + 3)*abs(x^2 + y^2 - 1) - 6*K(u) - 3)/((x^2 + y^2 - 1)*abs(x^2 + y^2 - 1))
# 'NPeq13=' 1/4*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^6 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^6 - 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^5 - 2*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^5 + (2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 2*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) - 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) - 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 - (3*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x + 2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 2*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^4 - 4*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 - 4*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + ((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^3 - (4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - (3*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + 4*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 + 6*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + 4*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x + 4*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^2 - 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 2*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^4 + 2*((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x^3 + 2*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + 2*((-I*K(u)^2 - 2*I*K(u) - I)*b_x(u, x, y) + (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y + (((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y ...
# 'NPeq14=' 1/4*(((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*x^10 + ((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*y^10 + (4*(2*(K(u)^2 + 2*K(u) + 1)*diff(K(u), u) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) - 4*l*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u, x) - 2*(l*K(u) + l + 2*diff(K(u), u))*diff(b_x(u, x, y), x) - 6*I*diff(K(u), u)*diff(b_x(u, x, y), y) + 2*(K(u) + 1)*diff(b_y(u, x, y), u, y) + 6*I*diff(K(u), u)*diff(b_y(u, x, y), x) - 2*(l*K(u) + l + 2*diff(K(u), u))*diff(b_y(u, x, y), y) + 4*diff(K(u), u, u))*x^8 + (5*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*x^2 + 4*(2*(K(u)^2 + 2*K(u) + 1)*diff(K(u), u) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) - 4*l*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u, x) - 2*(l*K(u) + l + 2*diff(K(u), u))*diff(b_x(u, x, y), x) - 6*I*diff(K(u), u)*diff(b_x(u, x, y), y) + 2*(K(u) + 1)*diff(b_y(u, x, y), u, y) + 6*I*diff(K(u), u)*diff(b_y(u, x, y), x) - 2*(l*K(u) + l + 2*diff(K(u), u))*diff(b_y(u, x, y), y) + 4*diff(K(u), u, u))*y^8 - 4*(2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*v*b_x(u, x, y) - (l*K(u) + l)*b_x(u, x, y) - (2*b_x(u, x, y) - 3*I*b_y(u, x, y))*diff(K(u), u) + (K(u) + 1)*diff(b_x(u, x, y), u))*x^7 - 4*(2*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*v*b_y(u, x, y) - (l*K(u) + l)*b_y(u, x, y) + (-3*I*b_x(u, x, y) - 2*b_y(u, x, y))*diff(K(u), u) + (K(u) + 1)*diff(b_y(u, x, y), u))*y^7 - 2*(4*(K(u) + 1)*b_x(u, x, y)^2 + 4*(K(u) + 1)*b_y(u, x, y)^2 + (K(u) + 1)*diff(b_x(u, x, y), x)^2 + (K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x, x) + (K(u) + 1)*diff(b_x(u, x, y), y)^2 + (K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), y, y) + (K(u) + 1)*diff(b_y(u, x, y), x)^2 + (K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), x, x) + (K(u) + 1)*diff(b_y(u, x, y), y)^2 + (K(u) + 1)*b_y(u, x, y)*diff(b_y(u, x, y), y, y) + 8*(2*(K(u)^2 + 2*K(u) + 1)*diff(K(u), u) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) - 8*l*diff(K(u), u) + 4*(K(u) + 1)*diff(b_x(u, x, y), u, x) - 4*(l*K(u) + l + 2*diff(K(u), u))*diff(b_x(u, x, y), x) - 12*I*diff(K(u), u)*diff(b_x(u, x, y), y) + 4*(K(u) + 1)*diff(b_y(u, x, y), u, y) + 12*I*diff(K(u), u)*diff(b_y(u, x, y), x) - 4*(l*K(u) + l + 2*diff(K(u), u))*diff(b_y(u, x, y), y) + 8*diff(K(u), u, u))*x^6 + 2*(5*((K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y))*x^4 + 2*(4*(2*(K(u)^2 + 2*K(u) + 1)*diff(K(u), u) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_x(u, x, y), x) + (K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(b_y(u, x, y), y))*v - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), x, x) - 5*(K(u)^3 + 3*K(u)^2 + 3*K(u) + 1)*diff(H(u, x, y), y, y) - 4*l*diff(K(u), u) + 2*(K(u) + 1)*diff(b_x(u, x, y), u, x) - 2*(l*K(u) + l + 2*diff(K(u), u))*diff(b_x(u, x, y), x) - 6*I*diff(K(u), u)*diff(b_x(u, x, y), y) + 2*(K(u) + 1)*diff(b_y(u, x, y), u, y) + 6*I*diff(K(u), u)*diff(b_y(u, x, y), x) - 2*(l*K(u) + l + 2*diff(K(u), u))*diff(b_y(u, x, y), y) + 4*diff(K(u), u, u))*x^2 - 4*(K(u) + 1)*b_x(u, x, y)^2 - 4*(K(u) + 1)*b_y(u, x, y)^2 - (K(u) + 1)*diff(b_x(u, x, y), x)^2 - (K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), x, x) - (K(u) + 1)*diff(b_x(u, x, y), y)^2 - (K(u) + 1)*b_x(u, x, y)*diff(b_x(u, x, y), y, y) - (K(u) + 1)*diff(b_y(u, x, y), x)^2 - (K(u) + 1)*b_y(u, x, y)*di ...
# 'NPeq15=' -1/8*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^6 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^6 - ((K(u) + 1)*conjugate(diff(K(u), u)) - (4*K(u) - conjugate(K(u)) + 3)*diff(K(u), u) + 2*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^5 + ((-I*K(u) - I)*conjugate(diff(K(u), u)) + (4*I*K(u) - I*conjugate(K(u)) + 3*I)*diff(K(u), u) - 2*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^5 - (2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 2*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 - (3*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + ((K(u) + 1)*conjugate(diff(K(u), u)) - (4*K(u) - conjugate(K(u)) + 3)*diff(K(u), u) + 2*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 2*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^4 + 2*((K(u) + 1)*conjugate(diff(K(u), u)) - (4*K(u) - conjugate(K(u)) + 3)*diff(K(u), u) - 2*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 - 2*(((I*K(u) + I)*conjugate(diff(K(u), u)) + (-4*I*K(u) + I*conjugate(K(u)) - 3*I)*diff(K(u), u) + 2*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + 2*((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (-I*K(u) - I)*conjugate(diff(K(u), u)) + (4*I*K(u) - I*conjugate(K(u)) + 3*I)*diff(K(u), u) + 2*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^3 + (4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) - 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - (3*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + 2*((K(u) + 1)*conjugate(diff(K(u), u)) - (4*K(u) - conjugate(K(u)) + 3)*diff(K(u), u) + 2*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 + 6*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - 2*((K(u) + 1)*conjugate(diff(K(u), u)) - (4*K(u) - conjugate(K(u)) + 3)*diff(K(u), u) - 2*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x + 4*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^2 - ((K(u) + 1)*conjugate(diff(K(u), u)) - (4*K(u) - conjugate(K(u)) + 3)*diff(K(u), u) + 2*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 2*(K(u)^2 + 2* ...
# 'NPeq16=' 0
# 'NPeq17=' 1/6*(2*(K(u)^2 + 2*K(u) + 1)*x^4 + 2*(K(u)^2 + 2*K(u) + 1)*y^4 - 5*(K(u)^2 + 2*K(u) + 1)*x^2 + (4*(K(u)^2 + 2*K(u) + 1)*x^2 - 5*K(u)^2 - 10*K(u) - 5)*y^2 + 3*K(u)^2 + (2*(K(u)^2 + 2*K(u) + 1)*x^2 + 2*(K(u)^2 + 2*K(u) + 1)*y^2 - 3*K(u)^2 - 6*K(u) - 3)*abs(x^2 + y^2 - 1) + 6*K(u) + 3)/((x^2 + y^2 - 1)*abs(x^2 + y^2 - 1))
# 'NPeq18=' 1/8*(((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^6 + ((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^6 - 2*((K(u) + 1)*diff(K(u), u) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^5 - 2*((-I*K(u) - I)*diff(K(u), u) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^5 + (2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 2*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) - 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) - 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 - (3*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 + 2*((K(u) + 1)*diff(K(u), u) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x + 2*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 2*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^4 + 4*((K(u) + 1)*diff(K(u), u) - (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 - 4*(((-I*K(u) - I)*diff(K(u), u) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + ((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (I*K(u) + I)*diff(K(u), u) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*y^3 - (4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - (3*((I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^4 + 4*((K(u) + 1)*diff(K(u), u) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^3 + 6*((-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x, y) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*x^2 - 4*((K(u) + 1)*diff(K(u), u) - (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x + 4*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y) + 3*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x, y) + 3*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x, x) - 3*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x, y))*y^2 - 2*((K(u) + 1)*diff(K(u), u) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x - 2*(((-I*K(u) - I)*diff(K(u), u) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^4 + 2*((I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x^3 + 2*((I*K(u) + I)*diff(K(u), u) + (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y))*x^2 + 2*((-I*K(u)^2 - 2*I*K(u) - I)*b_x(u, x, y) + (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x + (-I*K(u) - I)*diff(K(u), u) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), x) - (K(u)^2 + 2*K( ...
# Calculating Bianchi identities...
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 1/8*(((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x, x) - (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), x, x, y) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, y, y) - (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), y, y, y))*x^12 + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x, x) - (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), x, x, y) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, y, y) - (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), y, y, y))*y^12 + 2*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y))*x^11 + 2*((-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(H(u, x, y), x, x) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(H(u, x, y), y, y))*y^11 + 2*(4*(I*K(u) + I)*diff(K(u), u)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x, y)*diff(b_x(u, x, y), y) + 2*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(b_y(u, x, y), x, x) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(b_y(u, x, y), y, y))*v - (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x) - 3*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x, x) + 3*(I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), x, x, y) - 3*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, y, y) + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), y) + 3*(I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), y, y, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), u, x, x) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), u, y, y) - (l*K(u)^2 + 2*l*K(u) + 2*(K(u) + 1)*diff(K(u), u) + l)*diff(b_x(u, x, y), x, x) - (l*K(u)^2 + 2*l*K(u) - 2*(K(u) + 1)*diff(K(u), u) - (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + l)*diff(b_x(u, x, y), y, y) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), u, x, x) + (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), u, y, y) - ((K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x, y) - (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), y, y))*diff(b_y(u, x, y), x) + (I*l*K(u)^2 + 2*I*l*K(u) + 2*(-I*K(u) - I)*diff(K(u), u) - (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), y) + (K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), x) + I*l)*diff(b_y(u, x, y), x, x) - (4*(K(u) + 1)*diff(K(u), u) - (I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), y) - (-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x))*diff(b_y(u, x, y), x, y) + (I*l*K(u)^2 + 2*I*l*K(u) + 2*(I*K(u) + I)*diff(K(u), u) + I*l)*diff(b_y(u, x, y), y, y))*x^10 + 2*(3*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x, x) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(H(u, x, y), x, x, y) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, y, y) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(H(u, x, y), y, y, y))*x^2 + 4*(I*K(u) + I)*diff(K(u), u)*diff(b_x(u, x, y), x, y) + (K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x, y)*diff(b_x(u, x, y), y) + 2*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(b_x(u, x, y), y, y) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(b_y(u, x, y), x, x) + (-I*K(u)^4 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*diff(b_y(u, x, y), y, y))*v + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x) + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), y, y))*x - (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x) - 3*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H(u, x, y), x, x, x) + 3*(I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*diff(H(u, x, y), x, x, y) - 3*(K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*diff(H( ...
# 'BI5=' 0
# 'BI6=' -1/24*(2*(2*(K(u) + 1)*diff(K(u), u) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 9*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 9*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^6 + 2*(2*(K(u) + 1)*diff(K(u), u) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 9*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 9*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^6 + 12*(4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y))*x^5 + 12*(3*(I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + 4*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*y^5 - (26*(K(u) + 1)*diff(K(u), u) - 72*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) - 57*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), y) - 57*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - 72*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^4 + (6*(2*(K(u) + 1)*diff(K(u), u) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 9*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 9*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^2 + 12*(4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y))*x - 26*(K(u) + 1)*diff(K(u), u) + 72*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 57*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), y) + 57*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) + 72*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^4 - 6*(16*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 13*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y))*x^3 + 6*(4*(3*(I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + 4*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x^2 + 13*(-I*K(u)^2 - 2*I*K(u) - I)*b_x(u, x, y) - 16*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*y^3 + 4*(10*(K(u) + 1)*diff(K(u), u) - 18*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 15*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 15*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 18*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^2 + 2*(3*(2*(K(u) + 1)*diff(K(u), u) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 9*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 9*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^4 + 12*(4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y))*x^3 - (26*(K(u) + 1)*diff(K(u), u) - 72*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) - 57*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_x(u, x, y), y) - 57*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_y(u, x, y), x) - 72*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^2 - 3*(16*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) - 13*(I*K(u)^2 + 2*I*K(u) + I)*b_y(u, x, y))*x + 20*(K(u) + 1)*diff(K(u), u) - 36*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 30*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 30*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 36*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^2 + 6*(8*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 7*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y))*x + 6*(2*(3*(I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + 4*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x^4 + (13*(-I*K(u)^2 - 2*I*K(u) - I)*b_x(u, x, y) - 16*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*x^2 + 7*(I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + 8*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*y + (2*(2*(K(u) + 1)*diff(K(u), u) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 9*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 9*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^4 + 2*(2*(K(u) + 1)*diff(K(u), u) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 9*(-I*K(u)^2 - 2*I*K(u) - I)*diff(b_x(u, x, y), y) + 9*(I*K(u)^2 + 2*I*K(u) + I)*diff(b_y(u, x, y), x) - 12*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^4 + 12*(4*(K(u)^2 + 2*K(u) + 1)*b_x(u, x, y) + 3*(-I*K(u)^2 - 2*I*K(u) - I)*b_y(u, x, y))*x^3 + 12*(3*(I*K(u)^2 + 2*I*K(u) + I)*b_x(u, x, y) + 4*(K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*y^3 - (22*(K(u) + 1)*diff(K(u), u) - 48*(K(u)^2 + 2*K(u) + 1)*diff(b_x( ...
# 'BI7=' 1/6*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x^3 + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x*y^2 - (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*y^3 - (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x - (-I*K(u)^4 + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*x^2 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*y + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x - (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*y)*abs(x^2 + y^2 - 1))/((x^4*abs(K(u) + 1) + y^4*abs(K(u) + 1) + 2*(x^2*abs(K(u) + 1) - abs(K(u) + 1))*y^2 - 2*x^2*abs(K(u) + 1) + abs(K(u) + 1))*sqrt(abs(x^2 + y^2 - 1)))
# 'BI8=' 1/6*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x^3 + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x*y^2 + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*y^3 - (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x + (-I*K(u)^4 + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*x^2 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*y + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*y)*abs(x^2 + y^2 - 1))/((x^4*abs(K(u) + 1) + y^4*abs(K(u) + 1) + 2*(x^2*abs(K(u) + 1) - abs(K(u) + 1))*y^2 - 2*x^2*abs(K(u) + 1) + abs(K(u) + 1))*sqrt(abs(x^2 + y^2 - 1)))
# 'BI9=' 0
# 'BI10=' -1/8*((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x^3 + (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x*y^2 + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*y^3 - (K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x + (-I*K(u)^4 + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*x^2 - 4*I*K(u)^3 - 6*I*K(u)^2 - 4*I*K(u) - I)*y + ((K(u)^4 + 4*K(u)^3 + 6*K(u)^2 + 4*K(u) + 1)*x + (I*K(u)^4 + 4*I*K(u)^3 + 6*I*K(u)^2 + 4*I*K(u) + I)*y)*abs(x^2 + y^2 - 1))/((x^4*abs(K(u) + 1) + y^4*abs(K(u) + 1) + 2*(x^2*abs(K(u) + 1) - abs(K(u) + 1))*y^2 - 2*x^2*abs(K(u) + 1) + abs(K(u) + 1))*sqrt(abs(x^2 + y^2 - 1)))
# 'BI11=' 1/4*(2*((K(u) + 1)*diff(K(u), u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^4 + 2*((K(u) + 1)*diff(K(u), u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^4 - 8*(K(u)^2 + 2*K(u) + 1)*x^3*b_x(u, x, y) - 8*(K(u)^2 + 2*K(u) + 1)*y^3*b_y(u, x, y) - (3*(K(u) + 1)*diff(K(u), u) + 8*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 8*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^2 + (4*((K(u) + 1)*diff(K(u), u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^2 - 8*(K(u)^2 + 2*K(u) + 1)*x*b_x(u, x, y) - 3*(K(u) + 1)*diff(K(u), u) - 8*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) - 8*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^2 + 8*(K(u)^2 + 2*K(u) + 1)*x*b_x(u, x, y) - 8*((K(u)^2 + 2*K(u) + 1)*x^2*b_y(u, x, y) - (K(u)^2 + 2*K(u) + 1)*b_y(u, x, y))*y + (2*((K(u) + 1)*diff(K(u), u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*x^2 + 2*((K(u) + 1)*diff(K(u), u) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 2*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*y^2 - 8*(K(u)^2 + 2*K(u) + 1)*x*b_x(u, x, y) - 8*(K(u)^2 + 2*K(u) + 1)*y*b_y(u, x, y) - (K(u) + 1)*diff(K(u), u) - 4*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) - 4*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))*abs(x^2 + y^2 - 1) + (K(u) + 1)*diff(K(u), u) + 4*(K(u)^2 + 2*K(u) + 1)*diff(b_x(u, x, y), x) + 4*(K(u)^2 + 2*K(u) + 1)*diff(b_y(u, x, y), y))/((x^2 + y^2 - 1)*abs(x^2 + y^2 - 1))

# %%
met.petrovtype='II'

# %%
from pathlib import Path
fout = open('35.30_e-1.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def latex_write(fout, lhs, rhs_expr):
    """
    Uzun LaTeX ifadelerini \\frac sinirlarinda keserek yazar.
    Kisa ifadeler (<5500 karakter) dogrudan yazilir.
    Uzun ifadeler uygun bir \\frac noktasindan kesilip {} \\dots ile bitirilir.
    """
    my_expression = str(rhs_expr)

    if len(my_expression) < 5500:
        fout.write(r"\begin{dmath*}" + "\n")
        fout.write(lhs + " = " + my_expression + "\n")
        fout.write(r"\end{dmath*}" + "\n\n")
    else:
        count_oparan = 0
        count_cparan = 0
        last_frac_locations = []
        for i in range(min(5000, len(my_expression))):
            if my_expression[i] == "{":
                count_oparan += 1
            elif my_expression[i] == "}":
                count_cparan += 1
            if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                last_frac_locations.append(i)

        if len(last_frac_locations) > 2:
            fout.write(r"\begin{dmath*}" + "\n")
            fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
            fout.write(r"\end{dmath*}" + "\n\n")
        else:
            i = 5000
            while i < min(200000, len(my_expression)):
                if my_expression[i] == "{":
                    count_oparan += 1
                elif my_expression[i] == "}":
                    count_cparan += 1
                if len(my_expression) <= i + 5:
                    # Ifade tamamen taranabildi, hepsini yaz
                    fout.write(r"\begin{dmath*}" + "\n")
                    fout.write(lhs + " = " + my_expression + "\n")
                    fout.write(r"\end{dmath*}" + "\n\n")
                    return
                if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                    last_frac_locations.append(i)
                    if len(last_frac_locations) > 2:
                        break
                i += 1

            if not last_frac_locations or last_frac_locations[-1] == 0:
                # Uygun kesme noktasi bulunamadi, yine de yaz
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")
            else:
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")


def write_dmath(fout, lhs, rhs):
    """latex_write ile uzun ifade truncation destekli yazim."""
    latex_write(fout, lhs, rhs)

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# tex dosyasi olusturuldu.

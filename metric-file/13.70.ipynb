# %%
reset()
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<v, r, u, y> = MyManifold.chart(r'v r u y')
f = MyManifold.scalar_field(function('f')(*MyCoordinates))
tetrad_type = 'covariant'

var('delta, gamma, epsilon ,f1, w')
delta = 1
epsilon = 1

a = (sqrt(f) * w * u + r / sqrt(f)) / sqrt(2)

# b değeri
b = (sqrt(f) * w * u - r / sqrt(f)) / sqrt(2)

lvec = [sqrt(f/2),0,0,a]
nvec=[sqrt(f/2),0,0,b]

mvec=[0,exp(gamma)/sqrt(f*2),I*exp(gamma)/sqrt(f*2),0]
mbarvec=[0,exp(gamma)/sqrt(f*2),-I*exp(gamma)/sqrt(f*2),0]

met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
# Out:
# 'The metric:'
# g = -f(v, r, u, y) dv⊗dv - u*w*f(v, r, u, y) dv⊗dy + e^(2*gamma)/f(v, r, u, y) dr⊗dr + e^(2*gamma)/f(v, r, u, y) du⊗du - u*w*f(v, r, u, y) dy⊗dv - (u^2*w^2*f(v, r, u, y)^2 - r^2)/f(v, r, u, y) dy⊗dy

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' 1/4*sqrt(2)*(I*w*f(v, r, u, y)^2 - r*diff(f(v, r, u, y), r) - I*r*diff(f(v, r, u, y), u) + f(v, r, u, y))*e^(-gamma)/(r*sqrt(f(v, r, u, y)))
# 'tauNP=' -1/4*sqrt(2)*e^(-gamma)*sqrt(f(v, r, u, y))/r
# 'sigmaNP=' 0
# 'rhoNP=' -1/4*(sqrt(2)*u*w*f(v, r, u, y)*diff(f(v, r, u, y), v) + sqrt(2)*r*diff(f(v, r, u, y), v) - sqrt(2)*f(v, r, u, y)*diff(f(v, r, u, y), y))/(r*f(v, r, u, y)^(3/2))
# 'piNP=' 1/4*sqrt(2)*e^(-gamma)*sqrt(f(v, r, u, y))/r
# 'nuNP=' -1/4*sqrt(2)*(I*w*f(v, r, u, y)^2 - r*diff(f(v, r, u, y), r) + I*r*diff(f(v, r, u, y), u) + f(v, r, u, y))*e^(-gamma)/(r*sqrt(f(v, r, u, y)))
# 'muNP=' -1/4*(sqrt(2)*u*w*f(v, r, u, y)*diff(f(v, r, u, y), v) - sqrt(2)*r*diff(f(v, r, u, y), v) - sqrt(2)*f(v, r, u, y)*diff(f(v, r, u, y), y))/(r*f(v, r, u, y)^(3/2))
# 'lambdaNP=' 0
# 'epsilonNP=' -1/8*(sqrt(2)*u*w*f(v, r, u, y)*diff(f(v, r, u, y), v) - sqrt(2)*r*diff(f(v, r, u, y), v) - sqrt(2)*f(v, r, u, y)*diff(f(v, r, u, y), y))/(r*f(v, r, u, y)^(3/2))
# 'gammaNP=' -1/8*(sqrt(2)*u*w*f(v, r, u, y)*diff(f(v, r, u, y), v) + sqrt(2)*r*diff(f(v, r, u, y), v) - sqrt(2)*f(v, r, u, y)*diff(f(v, r, u, y), y))/(r*f(v, r, u, y)^(3/2))
# 'betaNP=' 1/8*sqrt(2)*(I*w*f(v, r, u, y)^2 - r*diff(f(v, r, u, y), r) - I*r*diff(f(v, r, u, y), u))*e^(-gamma)/(r*sqrt(f(v, r, u, y)))
# 'alphaNP=' -1/8*sqrt(2)*(I*w*f(v, r, u, y)^2 - r*diff(f(v, r, u, y), r) + I*r*diff(f(v, r, u, y), u))*e^(-gamma)/(r*sqrt(f(v, r, u, y)))

# %%
met.calculate_Weyl()
met.show_Weyl()
# Out:
# Calculating Weyl components...
# 'Psi0NP=' -1/4*(w^2*f(v, r, u, y)^3 - r^2*diff(f(v, r, u, y), r, r) - 2*I*r^2*diff(f(v, r, u, y), r, u) + r^2*diff(f(v, r, u, y), u, u) + (3*I*r*f(v, r, u, y)*diff(f(v, r, u, y), r) - 3*r*f(v, r, u, y)*diff(f(v, r, u, y), u) - I*f(v, r, u, y)^2)*w)*e^(-2*gamma)/r^2
# 'Psi1NP=' -1/8*(3*I*u*w^2*f(v, r, u, y)*diff(f(v, r, u, y), v) - (2*r*u*diff(f(v, r, u, y), v, r) + 2*I*r*u*diff(f(v, r, u, y), v, u) - (-I*r + 2*u)*diff(f(v, r, u, y), v) + 3*I*f(v, r, u, y)*diff(f(v, r, u, y), y))*w + 2*r*diff(f(v, r, u, y), r, y) + 2*I*r*diff(f(v, r, u, y), u, y) - 2*diff(f(v, r, u, y), y))*e^(-gamma)/r^2
# 'Psi2NP=' 1/12*((2*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, v) + f(v, r, u, y)^3)*w^2 - r^2*diff(f(v, r, u, y), r, r) - r^2*diff(f(v, r, u, y), u, u) - (4*u*e^(2*gamma)*diff(f(v, r, u, y), v, y) - 3*I*r*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*I*f(v, r, u, y)^2)*w + 2*r*diff(f(v, r, u, y), r) + 2*e^(2*gamma)*diff(f(v, r, u, y), y, y))*e^(-2*gamma)/r^2
# 'Psi3NP=' 1/8*(3*I*u*w^2*f(v, r, u, y)*diff(f(v, r, u, y), v) - (2*r*u*diff(f(v, r, u, y), v, r) - 2*I*r*u*diff(f(v, r, u, y), v, u) - (I*r + 2*u)*diff(f(v, r, u, y), v) + 3*I*f(v, r, u, y)*diff(f(v, r, u, y), y))*w + 2*r*diff(f(v, r, u, y), r, y) - 2*I*r*diff(f(v, r, u, y), u, y) - 2*diff(f(v, r, u, y), y))*e^(-gamma)/r^2
# 'Psi4NP=' -1/4*(w^2*f(v, r, u, y)^3 - r^2*diff(f(v, r, u, y), r, r) + 2*I*r^2*diff(f(v, r, u, y), r, u) + r^2*diff(f(v, r, u, y), u, u) + (3*I*r*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*r*f(v, r, u, y)*diff(f(v, r, u, y), u) - I*f(v, r, u, y)^2)*w)*e^(-2*gamma)/r^2

# %%
met.calculate_Ricci()
met.show_Ricci()
# Out:
# Calculating Ricci components...
# 'Phi00NP=' -1/8*(2*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) + 2*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), u)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), u, u) + 3*r^2*e^(2*gamma)*diff(f(v, r, u, y), v)^2 - 2*r^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, v) + 4*r*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, y) - 2*r*f(v, r, u, y)^3*diff(f(v, r, u, y), r) - 6*r*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y) + 3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), y)^2 - 2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), y, y) + (3*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2 - 2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v) - 2*f(v, r, u, y)^6)*w^2 + 2*(3*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)^2 - 2*r*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, v) + 2*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y) + 2*r*f(v, r, u, y)^4*diff(f(v, r, u, y), u) - 3*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y))*w)*e^(-2*gamma)/(r^2*f(v, r, u, y)^3)
# 'Phi01NP=' -1/8*(2*I*u*w^2*f(v, r, u, y)^3*diff(f(v, r, u, y), v) + 2*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + 2*I*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, u) + (-2*I*f(v, r, u, y)^3*diff(f(v, r, u, y), y) - (r*u*f(v, r, u, y)*diff(f(v, r, u, y), r) + I*r*u*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v))*w - 3*(r^2*diff(f(v, r, u, y), r) + I*r^2*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v) + (r*f(v, r, u, y)*diff(f(v, r, u, y), r) + I*r*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), y))*e^(-gamma)/(r^2*f(v, r, u, y)^2)
# 'Phi10NP=' 1/8*(2*I*u*w^2*f(v, r, u, y)^3*diff(f(v, r, u, y), v) - 2*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + 2*I*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, u) + (-2*I*f(v, r, u, y)^3*diff(f(v, r, u, y), y) + (r*u*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*r*u*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v))*w + 3*(r^2*diff(f(v, r, u, y), r) - I*r^2*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v) - (r*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*r*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), y))*e^(-gamma)/(r^2*f(v, r, u, y)^2)
# 'Phi02NP=' -1/8*(w^2*f(v, r, u, y)^4 + r^2*diff(f(v, r, u, y), r)^2 + 2*I*r^2*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), u) - r^2*diff(f(v, r, u, y), u)^2)*e^(-2*gamma)/(r^2*f(v, r, u, y))
# 'Phi20NP=' -1/8*(w^2*f(v, r, u, y)^4 + r^2*diff(f(v, r, u, y), r)^2 - 2*I*r^2*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), u) - r^2*diff(f(v, r, u, y), u)^2)*e^(-2*gamma)/(r^2*f(v, r, u, y))
# 'Phi11NP=' -1/16*(3*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) + 3*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), u)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), u, u) + 3*r^2*e^(2*gamma)*diff(f(v, r, u, y), v)^2 - 2*r^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, v) - 2*r*f(v, r, u, y)^3*diff(f(v, r, u, y), r) + e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), y)^2 - 2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), y, y) + (u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2 - 2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v) - f(v, r, u, y)^6)*w^2 + 2*(2*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y) - u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y))*w)*e^(-2*gamma)/(r^2*f(v, r, u, y)^3)
# 'Phi12NP=' -1/8*(2*I*u*w^2*f(v, r, u, y)^3*diff(f(v, r, u, y), v) + 2*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + 2*I*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, u) + (-2*I*f(v, r, u, y)^3*diff(f(v, r, u, y), y) + (r*u*f(v, r, u, y)*diff(f(v, r, u, y), r) + I*r*u*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v))*w - 3*(r^2*diff(f(v, r, u, y), r) + I*r^2*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v) - (r*f(v, r, u, y)*diff(f(v, r, u, y), r) + I*r*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), y))*e^(-gamma)/(r^2*f(v, r, u, y)^2)
# 'Phi21NP=' 1/8*(2*I*u*w^2*f(v, r, u, y)^3*diff(f(v, r, u, y), v) - 2*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + 2*I*r^2*f(v, r, u, y)*diff(f(v, r, u, y), v, u) + (-2*I*f(v, r, u, y)^3*diff(f(v, r, u, y), y) - (r*u*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*r*u*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v))*w + 3*(r^2*diff(f(v, r, u, y), r) - I*r^2*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v) + (r*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*r*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), y))*e^(-gamma)/(r^2*f(v, r, u, y)^2)
# 'Phi22NP=' -1/8*(2*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) + 2*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), u)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), u, u) + 3*r^2*e^(2*gamma)*diff(f(v, r, u, y), v)^2 - 2*r^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, v) - 4*r*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, y) - 2*r*f(v, r, u, y)^3*diff(f(v, r, u, y), r) + 6*r*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y) + 3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), y)^2 - 2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), y, y) + (3*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2 - 2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v) - 2*f(v, r, u, y)^6)*w^2 - 2*(3*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)^2 - 2*r*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, v) - 2*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y) + 2*r*f(v, r, u, y)^4*diff(f(v, r, u, y), u) + 3*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y))*w)*e^(-2*gamma)/(r^2*f(v, r, u, y)^3)
# 'LambdaNP=' -1/48*(3*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) + 3*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), u)^2 - 2*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), u, u) - 15*r^2*e^(2*gamma)*diff(f(v, r, u, y), v)^2 + 6*r^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, v) - 2*r*f(v, r, u, y)^3*diff(f(v, r, u, y), r) + 3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), y)^2 - 2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), y, y) + (3*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2 - 2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v) - f(v, r, u, y)^6)*w^2 + 2*(2*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y) - 3*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y))*w)*e^(-2*gamma)/(r^2*f(v, r, u, y)^3)

# %%
met.calculate_NPeq()
met.show_NPeq()
# Out:
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0

# %%
met.calculate_Bianchi()
met.show_Bianchi()
# Out:
# Calculating Bianchi identities...
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
met.Petrov_fromWeyl()
# Out:
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.

# %%
met.calculate_PetrovinvINP()
met.calculate_PetrovinvJNP()
met.calculate_PetrovinvKNP()
met.calculate_PetrovinvLNP()
met.calculate_PetrovinvNNP()

show(met.PetrovinvINP.expr())
show(met.PetrovinvJNP.expr())
show(met.PetrovinvKNP.expr())
show(met.PetrovinvLNP.expr())
show(met.PetrovinvNNP.expr())
a=met.PetrovinvINP.expr()
b=met.PetrovinvJNP.expr()
show(bool(a^3==27*b^2))
# Out:
# 1/48*(4*r^4*diff(f(v, r, u, y), r, r)^2 + 12*r^4*diff(f(v, r, u, y), r, u)^2 + 4*r^4*diff(f(v, r, u, y), u, u)^2 - (27*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2 - 4*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v) - 4*u^4*e^(4*gamma)*diff(f(v, r, u, y), v, v)^2 - 4*f(v, r, u, y)^6)*w^4 - 4*r^3*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), r, r) + 12*r^2*e^(2*gamma)*diff(f(v, r, u, y), r, y)^2 + 12*r^2*e^(2*gamma)*diff(f(v, r, u, y), u, y)^2 - 2*(18*I*r*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, r) - 18*I*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)^2 + 4*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y) - 12*I*r*f(v, r, u, y)^4*diff(f(v, r, u, y), r) - 27*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y) + 6*I*f(v, r, u, y)^5 + 2*(-3*I*r*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*I*u^2*e^(2*gamma)*f(v, r, u, y)^2 + 4*u^3*e^(4*gamma)*diff(f(v, r, u, y), v, y))*diff(f(v, r, u, y), v, v))*w^3 + 4*r^2*diff(f(v, r, u, y), r)^2 - 24*r*e^(2*gamma)*diff(f(v, r, u, y), r, y)*diff(f(v, r, u, y), y) + (12*r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, r)^2 + 12*r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, u)^2 - 36*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 - 8*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) - 27*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), u)^2 + 4*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), u, u) + 16*u^2*e^(4*gamma)*diff(f(v, r, u, y), v, y)^2 + 40*r*f(v, r, u, y)^3*diff(f(v, r, u, y), r) - 27*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), y)^2 - 12*f(v, r, u, y)^4 + 3*(r^2*e^(2*gamma) + 4*u^2*e^(2*gamma))*diff(f(v, r, u, y), v)^2 - 12*(2*r*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, r) - r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, u) - 3*I*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r, y))*diff(f(v, r, u, y), v) - 4*(r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), r, r) + r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), u, u) - 2*r*u^2*e^(2*gamma)*diff(f(v, r, u, y), r))*diff(f(v, r, u, y), v, v) - 24*(I*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*u*e^(2*gamma)*f(v, r, u, y)^2)*diff(f(v, r, u, y), v, y) - 36*(-I*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + 2*I*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v))*diff(f(v, r, u, y), y) + 4*(e^(2*gamma)*f(v, r, u, y)^3 + 2*u^2*e^(4*gamma)*diff(f(v, r, u, y), v, v))*diff(f(v, r, u, y), y, y))*w^2 + 12*e^(2*gamma)*diff(f(v, r, u, y), y)^2 + 4*e^(4*gamma)*diff(f(v, r, u, y), y, y)^2 - 4*(6*r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), r, y) + 9*I*r^3*f(v, r, u, y)*diff(f(v, r, u, y), r, u)*diff(f(v, r, u, y), u) - 3*I*r^3*f(v, r, u, y)*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), u, u) + 6*r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, u)*diff(f(v, r, u, y), u, y) - 3*I*r^2*f(v, r, u, y)*diff(f(v, r, u, y), r)^2 + 3*I*r*f(v, r, u, y)^2*diff(f(v, r, u, y), r) - 9*I*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), y)^2 - 3*(2*r*u*e^(2*gamma)*diff(f(v, r, u, y), r, y) - r^2*e^(2*gamma)*diff(f(v, r, u, y), u, y))*diff(f(v, r, u, y), v) - 2*(r^2*u*e^(2*gamma)*diff(f(v, r, u, y), r, r) + r^2*u*e^(2*gamma)*diff(f(v, r, u, y), u, u) - 2*r*u*e^(2*gamma)*diff(f(v, r, u, y), r))*diff(f(v, r, u, y), v, y) + 3*(2*I*r^3*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*r^2*f(v, r, u, y)^2)*diff(f(v, r, u, y), r, r) - 3*(2*r*u*e^(2*gamma)*diff(f(v, r, u, y), v, r) - 3*I*r*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r, y) - 2*u*e^(2*gamma)*diff(f(v, r, u, y), v))*diff(f(v, r, u, y), y) + (-3*I*r*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*I*e^(2*gamma)*f(v, r, u, y)^2 + 4*u*e^(4*gamma)*diff(f(v, r, u, y), v, y))*diff(f(v, r, u, y), y, y))*w - 4*(r^4*diff(f(v, r, u, y), r, r) + r^3*diff(f(v, r, u, y), r))*diff(f(v, r, u, y), u, u) - 4*(r^2*e^(2*gamma)*diff(f(v, r, u, y), r, r) + r^2*e^(2*gamma)*diff(f(v, r, u, y), u, u) - 2*r*e^(2*gamma)*diff(f(v, r, u, y), r))*diff(f(v, r, u, y), y, y))*e^(-4*gamma)/r^4
# -1/1728*(8*r^6*diff(f(v, r, u, y), r, r)^3 + 8*r^6*diff(f(v, r, u, y), u, u)^3 - 12*r^5*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), r, r)^2 - 72*r^5*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), r, u)^2 + 216*r^4*e^(2*gamma)*diff(f(v, r, u, y), r, u)*diff(f(v, r, u, y), r, y)*diff(f(v, r, u, y), u, y) + (81*u^2*e^(2*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), v)^2 + 12*u^4*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v)^2 + 8*u^6*e^(6*gamma)*diff(f(v, r, u, y), v, v)^3 - 8*f(v, r, u, y)^9 - 3*(4*u^2*e^(2*gamma)*f(v, r, u, y)^6 + 27*u^4*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2)*diff(f(v, r, u, y), v, v))*w^6 + 36*r^3*e^(2*gamma)*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), r, y)^2 - 3*(-36*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, r) + 24*I*r*f(v, r, u, y)^7*diff(f(v, r, u, y), r) - 12*I*f(v, r, u, y)^8 + 9*(-9*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), r) + 4*I*u^2*e^(2*gamma)*f(v, r, u, y)^4)*diff(f(v, r, u, y), v)^2 + 4*(-3*I*r*u^4*e^(4*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*I*u^4*e^(4*gamma)*f(v, r, u, y)^2 + 4*u^5*e^(6*gamma)*diff(f(v, r, u, y), v, y))*diff(f(v, r, u, y), v, v)^2 + 4*(9*I*r*u^4*e^(4*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, r) + 6*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), r) - 9*I*u^4*e^(4*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v)^2 + 4*u^3*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y))*diff(f(v, r, u, y), v, v) - 2*(4*u*e^(2*gamma)*f(v, r, u, y)^6 + 27*u^3*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2)*diff(f(v, r, u, y), v, y) + 54*(u*e^(2*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), v) - u^3*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, v))*diff(f(v, r, u, y), y))*w^5 + 8*r^3*diff(f(v, r, u, y), r)^3 - 3*(12*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, r)^2 - 24*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, u)^2 - 72*r^2*f(v, r, u, y)^5*diff(f(v, r, u, y), r)^2 - 8*r^2*f(v, r, u, y)^6*diff(f(v, r, u, y), r, r) - 27*r^2*f(v, r, u, y)^5*diff(f(v, r, u, y), u)^2 + 4*r^2*f(v, r, u, y)^6*diff(f(v, r, u, y), u, u) - 16*u^2*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y)^2 + 76*r*f(v, r, u, y)^6*diff(f(v, r, u, y), r) - 12*f(v, r, u, y)^7 + 3*(9*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), r, r) - 18*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), u, u) - 27*r*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), r) + 27*r^2*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), u) - 2*(r^2*e^(2*gamma) - 2*u^2*e^(2*gamma))*f(v, r, u, y)^3)*diff(f(v, r, u, y), v)^2 + 4*(r^2*u^4*e^(4*gamma)*diff(f(v, r, u, y), r, r) + r^2*u^4*e^(4*gamma)*diff(f(v, r, u, y), u, u) - 2*r*u^4*e^(4*gamma)*diff(f(v, r, u, y), r))*diff(f(v, r, u, y), v, v)^2 - 27*(e^(2*gamma)*f(v, r, u, y)^5 - u^2*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, v))*diff(f(v, r, u, y), y)^2 + 6*(6*I*r*u*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), r, y) + 2*(9*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), r) - 2*r*u^2*e^(2*gamma)*f(v, r, u, y)^3)*diff(f(v, r, u, y), v, r) + (27*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), u) - 4*r^2*u*e^(2*gamma)*f(v, r, u, y)^3)*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v) - (12*r^2*u^4*e^(4*gamma)*diff(f(v, r, u, y), v, r)^2 + 12*r^2*u^4*e^(4*gamma)*diff(f(v, r, u, y), v, u)^2 + 36*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 + 8*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) + 54*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), u)^2 - 16*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), u, u) + 8*r*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), r) - 12*u^2*e^(2*gamma)*f(v, r, u, y)^4 + 32*u^4*e^(6*gamma)*diff(f(v, r, u, y), v, y)^2 + 3*(r^2*u^2*e^(4*gamma) + 4*u^4*e^(4*gamma))*diff(f(v, r, u, y), v)^2 - 12*(2*r*u^4*e^(4*gamma)*diff(f(v, r, u, y), v, r) - r^2*u^3*e^(4*gamma)*diff(f(v, r, u, y), v, u) - 3*I*r*u^3*e^(4*gamma)*f(v, r, u, y)*dif ...
# -1/256*(8*r^5*diff(f(v, r, u, y), r, y)*diff(f(v, r, u, y), u, u)^2 + 3*(9*I*u^3*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v)^3 - 4*I*u^3*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, v))*w^6 - 8*r^3*e^(2*gamma)*diff(f(v, r, u, y), r, y)^3 + 24*r^3*e^(2*gamma)*diff(f(v, r, u, y), r, y)*diff(f(v, r, u, y), u, y)^2 - 8*I*r^3*e^(2*gamma)*diff(f(v, r, u, y), u, y)^3 - (8*I*r*u*f(v, r, u, y)^6*diff(f(v, r, u, y), v, u) - 24*I*u^2*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, y) - 27*(I*r*u^2*e^(2*gamma) + 2*u^3*e^(2*gamma))*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^3 + 54*(r*u^3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, r) - I*r*u^3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v)^2 - 2*(9*I*r*u*f(v, r, u, y)^5*diff(f(v, r, u, y), u) + 2*(-I*r - 3*u)*f(v, r, u, y)^6)*diff(f(v, r, u, y), v) - 4*(2*r*u^3*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, r) - 2*I*r*u^3*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, u) + (9*r*u^3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), r) - 9*I*r*u^3*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), u) + (-I*r*u^2*e^(2*gamma) - 5*u^3*e^(2*gamma))*f(v, r, u, y)^3)*diff(f(v, r, u, y), v))*diff(f(v, r, u, y), v, v) - 3*(-27*I*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v)^2 + 4*I*u^2*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v, v))*diff(f(v, r, u, y), y))*w^5 - (12*r^2*u*f(v, r, u, y)^4*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), u) + 8*I*r*u*f(v, r, u, y)^5*diff(f(v, r, u, y), v, r) - 8*I*r*f(v, r, u, y)^6*diff(f(v, r, u, y), u, y) - 81*I*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y)^2 + 12*I*u*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y, y) - 9*(I*r^2*u*e^(2*gamma) + 4*r*u^2*e^(2*gamma) - 4*I*u^3*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), v)^3 - 18*(3*r*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), r, y) - 3*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), u, y) - 2*(r^2*u^2*e^(2*gamma) - 2*I*r*u^3*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + 2*(I*r^2*u^2*e^(2*gamma) + 2*r*u^3*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v)^2 - 2*(-18*I*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, r)^2 - 36*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), v, u) + 18*I*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, u)^2 - 6*r^2*u*f(v, r, u, y)^4*diff(f(v, r, u, y), r, u) + 27*I*r^2*u*f(v, r, u, y)^3*diff(f(v, r, u, y), u)^2 + 6*I*r^2*u*f(v, r, u, y)^4*diff(f(v, r, u, y), u, u) - 2*(3*r - 5*I*u)*f(v, r, u, y)^5 + 12*(r^2 - 2*I*r*u)*f(v, r, u, y)^4*diff(f(v, r, u, y), r) - 3*(9*r^2*u*f(v, r, u, y)^3*diff(f(v, r, u, y), r) - (-3*I*r^2 - r*u)*f(v, r, u, y)^4)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v) - 4*(6*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), u) - 2*r*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), r, y) + 2*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), u, y) + (3*I*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r, r) + 6*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r, u) - 3*I*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), u, u) - (r*u^2*e^(2*gamma) - 2*I*u^3*e^(2*gamma))*f(v, r, u, y)^2 + 3*(r^2*u^2*e^(2*gamma) - 2*I*r*u^3*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*(-I*r^2*u^2*e^(2*gamma) - 2*r*u^3*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), u))*diff(f(v, r, u, y), v) + 2*(3*I*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) - I*r*u^3*e^(2*gamma)*f(v, r, u, y)^2)*diff(f(v, r, u, y), v, r) + 2*(3*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) - 3*I*r^2*u^3*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), u) - r*u^3*e^(2*gamma)*f(v, r, u, y)^2)*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v, v) - 12*(4*r^2*u*f(v, r, u, y)^4*diff(f(v, r, u, y), r) - 3*I*r^2*u*f(v, r, u, y)^4*diff(f(v, r, u, y), u) - 2*r*u*f(v, r, u, y)^5)*di ...
# -1/192*(4*r^4*diff(f(v, r, u, y), r, r)^2 - 4*r^4*diff(f(v, r, u, y), u, u)^2 - (27*u^2*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^2 - 8*u^2*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, v) - 4*f(v, r, u, y)^6)*w^4 + 16*I*r^3*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), r, u) + 12*r^2*e^(2*gamma)*diff(f(v, r, u, y), r, y)^2 - 24*I*r^2*e^(2*gamma)*diff(f(v, r, u, y), r, y)*diff(f(v, r, u, y), u, y) - 12*r^2*e^(2*gamma)*diff(f(v, r, u, y), u, y)^2 - 2*(8*u*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, y) - 12*I*r*f(v, r, u, y)^4*diff(f(v, r, u, y), r) - 6*r*f(v, r, u, y)^4*diff(f(v, r, u, y), u) - 27*u*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), y) + 8*I*f(v, r, u, y)^5 + 9*(r*u*e^(2*gamma) - 2*I*u^2*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), v)^2 + 18*(I*r*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, r) + r*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v) + 4*(-3*I*r*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) - 3*r*u^2*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), u) + I*u^2*e^(2*gamma)*f(v, r, u, y)^2)*diff(f(v, r, u, y), v, v))*w^3 + (12*r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, r)^2 - 24*I*r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), v, u) - 12*r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), v, u)^2 - 36*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r)^2 - 8*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, r) + 8*I*r^2*f(v, r, u, y)^3*diff(f(v, r, u, y), r, u) + 56*r*f(v, r, u, y)^3*diff(f(v, r, u, y), r) - 27*e^(2*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), y)^2 + 8*e^(2*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), y, y) - 12*f(v, r, u, y)^4 - 3*(r^2*e^(2*gamma) - 4*I*r*u*e^(2*gamma) - 4*u^2*e^(2*gamma))*diff(f(v, r, u, y), v)^2 - 12*(-3*I*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r, y) - 3*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), u, y) + (I*r^2*u*e^(2*gamma) + 2*r*u^2*e^(2*gamma))*diff(f(v, r, u, y), v, r) + (r^2*u*e^(2*gamma) - 2*I*r*u^2*e^(2*gamma))*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v) - 8*(r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), r, r) - 2*I*r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), r, u) - r^2*u^2*e^(2*gamma)*diff(f(v, r, u, y), u, u))*diff(f(v, r, u, y), v, v) - 16*(3*I*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), r) + 3*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), u) - I*u*e^(2*gamma)*f(v, r, u, y)^2)*diff(f(v, r, u, y), v, y) - 36*(-I*r^2*f(v, r, u, y)^2*diff(f(v, r, u, y), r) + I*r*f(v, r, u, y)^3)*diff(f(v, r, u, y), u) - 18*(-2*I*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, r) - 2*r*u*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), v, u) - (r*e^(2*gamma) - 4*I*u*e^(2*gamma))*f(v, r, u, y)*diff(f(v, r, u, y), v))*diff(f(v, r, u, y), y))*w^2 + 12*e^(2*gamma)*diff(f(v, r, u, y), y)^2 - 4*(6*r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), r, y) - 6*I*r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, u)*diff(f(v, r, u, y), r, y) - 6*I*r^2*f(v, r, u, y)*diff(f(v, r, u, y), r)^2 + 2*I*r*f(v, r, u, y)^2*diff(f(v, r, u, y), r) - 9*I*e^(2*gamma)*f(v, r, u, y)*diff(f(v, r, u, y), y)^2 + 3*((-I*r^2*e^(2*gamma) - 2*r*u*e^(2*gamma))*diff(f(v, r, u, y), r, y) - (r^2*e^(2*gamma) - 2*I*r*u*e^(2*gamma))*diff(f(v, r, u, y), u, y))*diff(f(v, r, u, y), v) - 4*(r^2*u*e^(2*gamma)*diff(f(v, r, u, y), r, r) - 2*I*r^2*u*e^(2*gamma)*diff(f(v, r, u, y), r, u) - r^2*u*e^(2*gamma)*diff(f(v, r, u, y), u, u))*diff(f(v, r, u, y), v, y) + 2*(3*I*r^3*f(v, r, u, y)*diff(f(v, r, u, y), r) - 2*I*r^2*f(v, r, u, y)^2)*diff(f(v, r, u, y), r, r) + 6*(r^3*f(v, r, u, y)*diff(f(v, r, u, y), r) - r^2*f(v, r, u, y)^2)*diff(f(v, r, u, y), r, u) + 3*(r^3*f(v, r, u, y)*diff(f(v, r, u, y), r, r) - 2*r^2*f(v, r, u, y)*diff(f(v, r, u, y), r))*diff(f(v, r, u, y), u) + (3*r^3*f(v, r, u, y)*diff(f(v, r, u, y), u) + 2*I*r^2*f(v, r, u, y)^2)*diff(f(v, r, u, y), u, u) + 6*(-I*r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, r) - r^2*u*e^(2*gamma)*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), u, y) - 3*(2*r*u*e^(2*gamma)*diff(f(v, r, u, ...
# 1/1024*(64*r^8*diff(f(v, r, u, y), r, u)^4 - 16*r^7*diff(f(v, r, u, y), r)*diff(f(v, r, u, y), r, r)^3 - 64*r^6*diff(f(v, r, u, y), r)^2*diff(f(v, r, u, y), r, u)^2 - (36*u^2*e^(2*gamma)*f(v, r, u, y)^8*diff(f(v, r, u, y), v)^2 - 243*u^4*e^(4*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v)^4 - 16*u^4*e^(4*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), v, v)^2 - 16*(u^2*e^(2*gamma)*f(v, r, u, y)^9 - 9*u^4*e^(4*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), v)^2)*diff(f(v, r, u, y), v, v))*w^8 + 48*r^4*e^(4*gamma)*diff(f(v, r, u, y), r, y)^4 + 192*I*r^4*e^(4*gamma)*diff(f(v, r, u, y), r, y)*diff(f(v, r, u, y), u, y)^3 + 48*r^4*e^(4*gamma)*diff(f(v, r, u, y), u, y)^4 - 4*(4*I*f(v, r, u, y)^11 - 81*(r*u^3*e^(4*gamma) - 2*I*u^4*e^(4*gamma))*f(v, r, u, y)^3*diff(f(v, r, u, y), v)^4 + 162*(-I*r*u^4*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, r) - r*u^4*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v)^3 + 6*(9*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), r) + (2*r*u*e^(2*gamma) - 11*I*u^2*e^(2*gamma))*f(v, r, u, y)^7)*diff(f(v, r, u, y), v)^2 + 8*(-3*I*r*u^4*e^(4*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), r) - 3*r*u^4*e^(4*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), u) + I*u^4*e^(4*gamma)*f(v, r, u, y)^5)*diff(f(v, r, u, y), v, v)^2 + 12*(I*r*u^2*e^(2*gamma)*f(v, r, u, y)^7*diff(f(v, r, u, y), v, r) + 2*r*u^2*e^(2*gamma)*f(v, r, u, y)^7*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v) + 4*(-9*I*r*u^2*e^(2*gamma)*f(v, r, u, y)^7*diff(f(v, r, u, y), r) - 6*r*u^2*e^(2*gamma)*f(v, r, u, y)^7*diff(f(v, r, u, y), u) + 5*I*u^2*e^(2*gamma)*f(v, r, u, y)^8 + 4*u^3*e^(4*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), v, y) + 3*(9*I*r*u^4*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), r) + 9*r*u^4*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), u) + (2*r*u^3*e^(4*gamma) - 7*I*u^4*e^(4*gamma))*f(v, r, u, y)^4)*diff(f(v, r, u, y), v)^2 + 12*(I*r*u^4*e^(4*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v, r) + r*u^4*e^(4*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v))*diff(f(v, r, u, y), v, v) + 8*(u*e^(2*gamma)*f(v, r, u, y)^9 - 9*u^3*e^(4*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), v)^2)*diff(f(v, r, u, y), v, y) - 9*(2*u*e^(2*gamma)*f(v, r, u, y)^8*diff(f(v, r, u, y), v) - 27*u^3*e^(4*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), v)^3 + 8*u^3*e^(4*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), v)*diff(f(v, r, u, y), v, v))*diff(f(v, r, u, y), y))*w^7 + 2*(8*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), v, r)^2 - 32*I*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), v, u) - 24*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), v, u)^2 + 18*r^2*f(v, r, u, y)^8*diff(f(v, r, u, y), u)^2 - 8*r^2*f(v, r, u, y)^9*diff(f(v, r, u, y), u, u) + 32*u^2*e^(4*gamma)*f(v, r, u, y)^6*diff(f(v, r, u, y), v, y)^2 + 80*r*f(v, r, u, y)^9*diff(f(v, r, u, y), r) - 48*I*r*f(v, r, u, y)^9*diff(f(v, r, u, y), u) - 32*f(v, r, u, y)^10 + 81*(r^2*u^2*e^(4*gamma) - 4*I*r*u^3*e^(4*gamma) - 4*u^4*e^(4*gamma))*f(v, r, u, y)^2*diff(f(v, r, u, y), v)^4 - 324*(I*r*u^3*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), r, y) + r*u^3*e^(4*gamma)*f(v, r, u, y)^3*diff(f(v, r, u, y), u, y) + (-I*r^2*u^3*e^(4*gamma) - 2*r*u^4*e^(4*gamma))*f(v, r, u, y)^2*diff(f(v, r, u, y), v, r) - (r^2*u^3*e^(4*gamma) - 2*I*r*u^4*e^(4*gamma))*f(v, r, u, y)^2*diff(f(v, r, u, y), v, u))*diff(f(v, r, u, y), v)^3 - 2*(162*r^2*u^4*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, r)^2 - 324*I*r^2*u^4*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, r)*diff(f(v, r, u, y), v, u) - 162*r^2*u^4*e^(4*gamma)*f(v, r, u, y)^2*diff(f(v, r, u, y), v, u)^2 - 81*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), r)^2 - 18*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), r, r) - 81*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^4*diff(f(v, r, u, y), u)^2 - 18*r^2*u^2*e^(2*gamma)*f(v, r, u, y)^5*diff(f(v, r, u, y), u, u) + (3*r^2*e^(2*gamma) - 56*I*r*u*e^(2*gamma) - 121*u^2*e^(2*gamma))*f(v, r, u, y)^6 + 18*(4*I*r^2*u*e^(2*gamma ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 14
#      12 a=met.PetrovinvINP.expr()
#      13 b=met.PetrovinvJNP.expr()
# ---> 14 show(bool(a**Integer(3)==Integer(27)*b**Integer(2)))
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:3508, in sage.symbolic.expression.Expression.__bool__ (build/cythonized/sage/symbolic/expression.cpp:67888)()
#    3506 from sage.symbolic.relation import check_relation_maxima
#    3507 if self.variables():
# -> 3508     return check_relation_maxima(self)
#    3509 else:
#    3510     return False
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/relation.py:498, in check_relation_maxima(relation)
#     496 if relation.operator() == operator.eq:  # operator is equality
#     497     try:
# --> 498         s = m.parent()._eval_line('is (equal(%s,%s))' % (repr(m.lhs()),
#     499                                                          repr(m.rhs())))
#     500     except TypeError:
#     501         raise ValueError("unable to evaluate the predicate '%s'" % repr(relation))
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:475, in MaximaLib._eval_line(self, line, locals, reformat, **kwds)
#     473         line = line[ind_semi + 1:]
#     474     if statement:
# --> 475         result = ((result + '\n') if result else '') + max_to_string(maxima_eval("#$%s$" % statement))
#     476 else:
#     477     statement = line[:ind_dollar]
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:12202)()
#     826     """
#     827     lispargs = EclObject(list(args))
# --> 828     return ecl_wrap(ecl_safe_apply(self.obj, (<EclObject>lispargs).obj))
#     829
#     830 def __richcmp__(left, right, int op):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:356, in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:9706)()
#     354         raise KeyboardInterrupt("ECL says: {}".format(message))
#     355     else:
# --> 356         raise RuntimeError("ECL says: {}".format(message))
#     357 else:
#     358     return ret
#
# RuntimeError: ECL says: Memory limit reached. Please jump to an outer pointer, quit program and enlarge the
# memory limits before executing the program again.

# %%
def fitEq(expr):
    expanded_expr = expr.expand()

    latex_expr = latex(expanded_expr)

    return latex_expr

# Yardımcı fonksiyonlar
def compare_expressions(orig, trans):
    """Dönüşümleri karşılaştır"""
    if trans == 0:
        return "0"
    try:
        if bool(trans == orig):
            return None
    except:
        if str(trans) == str(orig):
            return None
    return str(latex(fitEq(trans)))

def write_transformation_section(fout, coeffs, title):
    """Dönüşüm bölümünü yaz"""
    fout.write(f"\n\\textit{{{title}:}}\n\n")
    
    for symbol, orig, trans in coeffs:
        result = compare_expressions(orig, trans)
        if result is None:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {symbol}\n\\end{{dmath}}\n\n")
        else:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {result}\n\\end{{dmath}}\n\n")

def write_transformations(fout, met, transform_type):
    """Tüm dönüşümleri yaz"""
    tr_suffix = f"_tr{transform_type}"
    
    fout.write(f"\n\\newpage\n\\underline{{{transform_type} Type transformations:}}\n")
    
    # Spin coefficients
    spin_coeffs = [
        ('\\rho', met.rhoNP.expr(), getattr(met, f'rhoNP{tr_suffix}')),
        ('\\sigma', met.sigmaNP.expr(), getattr(met, f'sigmaNP{tr_suffix}')),
        ('\\kappa', met.kappaNP.expr(), getattr(met, f'kappaNP{tr_suffix}')),
        ('\\mu', met.muNP.expr(), getattr(met, f'muNP{tr_suffix}')),
        ('\\lambda', met.lambdaNP.expr(), getattr(met, f'lambdaNP{tr_suffix}')),
        ('\\nu', met.nuNP.expr(), getattr(met, f'nuNP{tr_suffix}')),
        ('\\alpha', met.alphaNP.expr(), getattr(met, f'alphaNP{tr_suffix}')),
        ('\\beta', met.betaNP.expr(), getattr(met, f'betaNP{tr_suffix}')),
        ('\\tau', met.tauNP.expr(), getattr(met, f'tauNP{tr_suffix}')),
        ('\\pi', met.piNP.expr(), getattr(met, f'piNP{tr_suffix}')),
        ('\\epsilon', met.epsilonNP.expr(), getattr(met, f'epsilonNP{tr_suffix}')),
        ('\\gamma', met.gammaNP.expr(), getattr(met, f'gammaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, spin_coeffs, "Spin coefficients")
    
    # Weyl components
    weyl_comps = [
        ('\\Psi_0', met.Psi0NP.expr(), getattr(met, f'Psi0NP{tr_suffix}')),
        ('\\Psi_1', met.Psi1NP.expr(), getattr(met, f'Psi1NP{tr_suffix}')),
        ('\\Psi_2', met.Psi2NP.expr(), getattr(met, f'Psi2NP{tr_suffix}')),
        ('\\Psi_3', met.Psi3NP.expr(), getattr(met, f'Psi3NP{tr_suffix}')),
        ('\\Psi_4', met.Psi4NP.expr(), getattr(met, f'Psi4NP{tr_suffix}'))
    ]
    write_transformation_section(fout, weyl_comps, "Weyl components")
    
    # Ricci components
    ricci_comps = [
        ('\\Phi_{00}', met.Phi00NP.expr(), getattr(met, f'Phi00NP{tr_suffix}')),
        ('\\Phi_{01}', met.Phi01NP.expr(), getattr(met, f'Phi01NP{tr_suffix}')),
        ('\\Phi_{02}', met.Phi02NP.expr(), getattr(met, f'Phi02NP{tr_suffix}')),
        ('\\Phi_{10}', met.Phi10NP.expr(), getattr(met, f'Phi10NP{tr_suffix}')),
        ('\\Phi_{11}', met.Phi11NP.expr(), getattr(met, f'Phi11NP{tr_suffix}')),
        ('\\Phi_{12}', met.Phi12NP.expr(), getattr(met, f'Phi12NP{tr_suffix}')),
        ('\\Phi_{20}', met.Phi20NP.expr(), getattr(met, f'Phi20NP{tr_suffix}')),
        ('\\Phi_{21}', met.Phi21NP.expr(), getattr(met, f'Phi21NP{tr_suffix}')),
        ('\\Phi_{22}', met.Phi22NP.expr(), getattr(met, f'Phi22NP{tr_suffix}'))
    ]
    write_transformation_section(fout, ricci_comps, "Ricci components")

# %%
# Latex formatında rapor dosyası oluşturmak için bu kodu kullanabilirsiniz.
# (Dosyanin adini uygun sekilde degistirmeyi unutmayin.)
fout = open('13.70.tex',"w")
tmpstr=r'''\documentclass[landscape]{article}
%\documentclass[11pt,a4paper,reqno]{amsart}
%%%%%%%%%%%%%%%%%%%%%%
\usepackage[fleqn]{amsmath} %Denklemleri sola daya
\usepackage{amssymb}
\usepackage{authblk}
\usepackage{caption}
\usepackage{cite}
\usepackage{xcolor}
\usepackage{color}
\usepackage{float}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{mdframed}
\usepackage{hyperref}
\usepackage{textcomp}
\usepackage{epstopdf}
\usepackage{subcaption}
\usepackage{lscape}
\usepackage{breqn}
%\usepackage{soul}
%%%%%%%%%%%%%%%%%%%%%%
\setlength\parindent{0pt}
\setlength{\parskip}{5pt}
\geometry{left=20mm,right=20mm,top=30mm,bottom=20mm}
\hyphenation{Schwarz-schild}
%%%%%%%%%%%%%%%%%%%%%%
\newcommand{\etalchar}[1]{$^{#1}$}
\newcommand\hl[1]{%
	\bgroup
	\hskip0pt\color{red!80!black}%
	#1%
	\egroup
}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\begin{document}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\textbf{Newman-Penrose Formalism Calculations for}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{metric:} 

\textit{Name:} Stephani et al., Equation (13.70)

\textit{Alias:} Stephanietal\_13\_70

\textit{Reference(s):} \cite{stefani}

\textit{Line element:} 

\begin{dmath}'''
fout.write(tmpstr)


fout.write("ds^2 " + str(latex(met.g.display()))[2:])
fout.write(r"\end{dmath}")


fout.write(r"\textit{Coordinates:} "+str(latex(MyCoordinates[:])))
tmpstr=r'''
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{Null tetrad components: }

\textit{Covariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}

\textit{Contravariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}


\newpage
\textbf{Directional derivatives: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"D&=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\Delta&=" + str(latex(fitEq( met.DeltanNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\delta&=" + str(latex(fitEq( met.deltamNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\overline{\delta}&=" + str(latex(fitEq( met.deltambarNP(f).expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Spin coefficients: }

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\rho&="+str(latex(fitEq(met.rhoNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\sigma&="+str(latex(fitEq(met.sigmaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\kappa&="+str(latex(fitEq(met.kappaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\mu&="+str(latex(fitEq(met.muNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\lambda&="+str(latex(met.lambdaNP.expr()))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\nu&="+str(latex(fitEq(met.nuNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\alpha&="+str(latex(fitEq(met.alphaNP.expr()))))

tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\beta&="+str(latex(fitEq(met.betaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\tau&="+str(latex(fitEq(met.tauNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\pi&="+str(latex(fitEq(met.piNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\epsilon&="+str(latex(fitEq(met.epsilonNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\gamma&="+str(latex(fitEq(met.gammaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage

\textbf{Relations between spin coefficients: }


%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Ricci tensor components: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{00}&="+str(latex(fitEq(met.Phi00NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{01}&="+str(latex(fitEq(met.Phi01NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{02}&="+str(latex(fitEq(met.Phi02NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{10}&="+str(latex(fitEq(met.Phi10NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{11}&="+str(latex(fitEq(met.Phi11NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{12}&="+str(latex(fitEq(met.Phi12NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{20}&="+str(latex(fitEq(met.Phi20NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{21}&="+str(latex(fitEq(met.Phi21NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{22}&="+str(latex(fitEq(met.Phi22NP.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Weyl tensor components: }
\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_0&="+str(latex(fitEq(met.Psi0NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_1&="+str(latex(fitEq(met.Psi1NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_2&="+str(latex(fitEq(met.Psi2NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_3&="+str(latex(fitEq(met.Psi3NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_4&="+str(latex(fitEq(met.Psi4NP.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Newman-Penrose equations: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"NP1&="+str(latex(fitEq(met.NPeq1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP2&="+str(latex(fitEq(met.NPeq2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP3&="+str(latex(fitEq(met.NPeq3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP4&="+str(latex(fitEq(met.NPeq4.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP5&="+str(latex(fitEq(met.NPeq5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP6&="+str(latex(fitEq(met.NPeq6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP7&="+str(latex(fitEq(met.NPeq7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP8&="+str(latex(fitEq(met.NPeq8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP9&="+str(latex(fitEq(met.NPeq9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP10&="+str(latex(fitEq(met.NPeq10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP11&="+str(latex(fitEq(met.NPeq11.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP12&="+str(latex(fitEq(met.NPeq12.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP13&="+str(latex(fitEq(met.NPeq13.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP14&="+str(latex(fitEq(met.NPeq14.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP15&="+str(latex(fitEq(met.NPeq15.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP16&="+str(latex(fitEq(met.NPeq16.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP17&="+str(latex(fitEq(met.NPeq17.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP18&="+str(latex(fitEq(met.NPeq18.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Bianchi identities: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI1&="+str(latex(fitEq(met.BI1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI2&="+str(latex(fitEq(met.BI2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI3&="+str(latex(fitEq(met.BI3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI4&="+str(latex(fitEq(met.BI4.expr())))+r' \\ '),
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI5&="+str(latex(fitEq(met.BI5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI6&="+str(latex(fitEq(met.BI6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI7&="+str(latex(fitEq(met.BI7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI8&="+str(latex(fitEq(met.BI8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI9&="+str(latex(fitEq(met.BI9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI10&="+str(latex(fitEq(met.BI10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI11&="+str(latex(fitEq(met.BI11.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


\newpage
\textbf{Petrov classification:} \\
\vspace{2cm}
\textit{Petrov class: III} 
\vspace{2cm}




%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\begin{thebibliography}{99}

\bibitem{stefani}
 H. Stephani, D. Kramer, M. MacCallum, C. Hoenselaers, and E. Herlt, Exact Solutions of Einstein’s Field Equations. Cambridge Monographs on Mathematical Physics, Cambridge University Press, 2009.
\end{thebibliography}
\begin{mdframed}
\textbf{Calculated by:}

\textit{Name: Şimal Serdaroğlu} 

\textit{E-mail: } 
\textit{Date: } 29.12.2025
\end{mdframed}
\end{document}
'''
fout.write(tmpstr)
fout.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 151
#     142 tmpstr=r'''
#     143 \end{dmath}
#     144
#    (...)    148
#     149 \begin{dmath}'''
#     150 fout.write(tmpstr)
# --> 151 fout.write(r"D&=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
#     152 tmpstr=r'''
#     153 \end{dmath}
#     154
#     155 \begin{dmath}'''
#     156 fout.write(tmpstr)
#
# File ~/Library/SageMath-10-6/lib/python3.12/site-packages/SageNP/SageNP.py:862, in NewmanPenrose.DlNP(self, X)
#     860     return _sage_const_0
#     861 else:
# --> 862     return self.lupNP['^i']*self.nab(X)['_i']
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/manifolds/differentiable/affine_connection.py:1508, in AffineConnection.__call__(self, tensor)
#    1506 from sage.manifolds.differentiable.tensorfield_paral import TensorFieldParal
#    1507 from sage.tensor.modules.format_utilities import format_unop_latex
# -> 1508 dom_resu = self._domain.intersection(tensor._domain)
#    1509 tensor_r = tensor.restrict(dom_resu)
#    1510 if tensor_r._tensor_type == (0,0):  # scalar field case
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:11829)()
#     493         AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'...
#     494     """
# --> 495     return self.getattr_from_category(name)
#     496
#     497 cdef getattr_from_category(self, name):
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:508, in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:11939)()
#     506     else:
#     507         cls = P._abstract_element_class
# --> 508     return getattr_from_other_class(self, cls, name)
#     509
#     510 def __dir__(self):
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/cpython/getattr.pyx:363, in sage.cpython.getattr.getattr_from_other_class (build/cythonized/sage/cpython/getattr.c:4458)()
#     361     dummy_error_message.cls = type(self)
#     362     dummy_error_message.name = name
# --> 363     raise AttributeError(dummy_error_message)
#     364 attribute = <object>attr
#     365 # Check for a descriptor (__get__ in Python)
#
# AttributeError: 'sage.symbolic.expression.Expression' object has no attribute '_domain'

# %%
reset()
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<x,y,z,t> = MyManifold.chart(r'x y z t')

tetrad_type = 'covariant'  

var('M epsilon', domain = "real")

epsilon=-1

def noargs(name):
    return lambda *args: name

m = function('m',imag_part_func=0,print_latex_func=noargs('m'))(t,z)
n = function('n',imag_part_func=0,print_latex_func=noargs('n'))(t,z)
l = function('l',imag_part_func=0,print_latex_func=noargs('l'))(t,z)
M = function('M',imag_part_func=0,print_latex_func=noargs('M'))(t,z)

C1=sqrt(epsilon*n)
C2=-m/sqrt(epsilon*n)
C3=(m^2)/(epsilon*n)+l
C4=e^(M)

assume(n>0)
assume(epsilon*l*n+m^2>0)

lvec=[C1/sqrt(2),C2/sqrt(2)+sqrt(C3)/sqrt(2),0,0]
nvec=[C1/sqrt(2),C2/sqrt(2)-sqrt(C3)/sqrt(2),0,0]
mvec=[ 0,0, sqrt(C4)/sqrt(2),  I*sqrt(C4*epsilon)/sqrt(2)]
mbarvec=[0,0, sqrt(C4)/sqrt(2), -I*sqrt(C4*epsilon)/sqrt(2)]

met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))
# Out:
# 'The metric:'
# g = n(t, z) dx⊗dx + m(t, z) dx⊗dy + m(t, z) dy⊗dx + l(t, z) dy⊗dy + e^(M(t, z)) dz⊗dz - e^(M(t, z)) dt⊗dt

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()

met.calculate_Weyl()
met.show_Weyl()
met.calculate_Ricci()
met.show_Ricci()
met.calculate_NPeq()
met.show_NPeq()

met.calculate_Bianchi()
met.show_Bianchi()

met.Petrov_fromWeyl()

def subs_abs(a):
    a_new = a.subs({abs(n) : n, conjugate(n) : n, real_part(n) : n, imag_part(n) : 0,
                    abs(m) : m, conjugate(m) : m, real_part(m) : m, imag_part(m) : 0,
                    abs(l) : l, conjugate(l) : l, real_part(l) : l, imag_part(l) : 0,
                    abs(epsilon * l * n + m^2) : epsilon * l * n + m^2, conjugate(epsilon * l * n + m^2) : epsilon * l * n + m^2,
                    real_part(epsilon * l * n + m^2) : epsilon * l * n + m^2, imag_part(epsilon * l * n + m^2) : 0,
                    conjugate(n.diff(t)) : n.diff(t), real_part(n.diff(t)) : n.diff(t), imag_part(n.diff(t)) : 0,
                    conjugate(n.diff(z)) : n.diff(z), real_part(n.diff(z)) : n.diff(z), imag_part(n.diff(z)) : 0,
                    conjugate(m.diff(t)) : m.diff(t), real_part(m.diff(t)) : m.diff(t), imag_part(m.diff(t)) : 0,
                    conjugate(m.diff(z)) : m.diff(z), real_part(m.diff(z)) : m.diff(z), imag_part(m.diff(z)) : 0,
                    conjugate(l.diff(t)) : l.diff(t), real_part(l.diff(t)) : l.diff(t), imag_part(l.diff(t)) : 0,
                    conjugate(l.diff(z)) : l.diff(z), real_part(l.diff(z)) : l.diff(z), imag_part(l.diff(z)) : 0})
    a_new = a_new.expand().simplify_full()
    return a_new

funcs = [met.kappaNP.expr(), met.kappabarNP.expr(), met.tauNP.expr(), met.taubarNP.expr(), met.sigmaNP.expr(), met.sigmabarNP.expr(), 
         met.rhoNP.expr(), met.rhobarNP.expr(), met.piNP.expr(), met.pibarNP.expr(), met.nuNP.expr(), met.nubarNP.expr(), 
         met.muNP.expr(), met.mubarNP.expr(), met.lambdaNP.expr(), met.lambdabarNP.expr(), met.epsilonNP.expr(), 
         met.epsilonbarNP.expr(), met.gammaNP.expr(), met.gammabarNP.expr(), met.betaNP.expr(), met.betabarNP.expr(), 
         met.alphaNP.expr(), met.alphabarNP.expr(), met.Psi0NP.expr(), met.Psi1NP.expr(), met.Psi2NP.expr(), met.Psi3NP.expr(), 
         met.Psi4NP.expr(), met.Phi00NP.expr(), met.Phi01NP.expr(), met.Phi10NP.expr(), met.Phi02NP.expr(), met.Phi20NP.expr(), 
         met.Phi11NP.expr(), met.Phi12NP.expr(), met.Phi21NP.expr(), met.Phi22NP.expr(), met.LambdaNP.expr(), met.NPeq1.expr(), 
         met.NPeq2.expr(), met.NPeq3.expr(), met.NPeq4.expr(),met.NPeq5.expr(), met.NPeq6.expr(), met.NPeq7.expr(), met.NPeq8.expr(), 
         met.NPeq9.expr(), met.NPeq10.expr(), met.NPeq11.expr(), met.NPeq12.expr(), met.NPeq13.expr(), met.NPeq14.expr(),
         met.NPeq15.expr(), met.NPeq16.expr(), met.NPeq17.expr(), met.NPeq18.expr(), met.BI1.expr(), met.BI2.expr(), met.BI3.expr(), 
         met.BI4.expr(), met.BI5.expr(), met.BI6.expr(), met.BI7.expr(),met.BI8.expr(), met.BI9.expr(), met.BI10.expr(), met.BI11.expr()]
for i in range(len(funcs)):
    funcs[i] = subs_abs(funcs[i])
# Out:
# Calculating spin coefficients...
# 'kappaNP=' -1/8*(sqrt(2)*e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z) - 2*sqrt(2)*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(m(t, z), z) + (2*sqrt(2)*e^(1/2*M(t, z))*m(t, z)^2 - sqrt(2)*e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(n(t, z), z) + 2*(sqrt(2)*e^(1/2*M(t, z))*n(t, z)*diff(m(t, z), z) - sqrt(2)*e^(1/2*M(t, z))*m(t, z)*diff(n(t, z), z) - (I*sqrt(2)*n(t, z)*diff(m(t, z), t) - I*sqrt(2)*m(t, z)*diff(n(t, z), t))*sqrt(-e^(M(t, z))))*sqrt(m(t, z)^2 - l(t, z)*n(t, z)) + (-I*sqrt(2)*n(t, z)^2*diff(l(t, z), t) + 2*I*sqrt(2)*m(t, z)*n(t, z)*diff(m(t, z), t) + (-2*I*sqrt(2)*m(t, z)^2 + I*sqrt(2)*l(t, z)*n(t, z))*diff(n(t, z), t))*sqrt(-e^(M(t, z))))/(e^(M(t, z))*m(t, z)^2*n(t, z) - e^(M(t, z))*l(t, z)*n(t, z)^2)
# 'tauNP=' 1/8*(sqrt(2)*e^(1/2*M(t, z))*n(t, z)*diff(l(t, z), z) - 2*sqrt(2)*e^(1/2*M(t, z))*m(t, z)*diff(m(t, z), z) + sqrt(2)*e^(1/2*M(t, z))*l(t, z)*diff(n(t, z), z) - (I*sqrt(2)*n(t, z)*diff(l(t, z), t) - 2*I*sqrt(2)*m(t, z)*diff(m(t, z), t) + I*sqrt(2)*l(t, z)*diff(n(t, z), t))*sqrt(-e^(M(t, z))))/(e^(M(t, z))*m(t, z)^2 - e^(M(t, z))*l(t, z)*n(t, z))
# 'sigmaNP=' 0
# 'rhoNP=' 0
# 'piNP=' -1/8*(sqrt(2)*e^(1/2*M(t, z))*n(t, z)*diff(l(t, z), z) - 2*sqrt(2)*e^(1/2*M(t, z))*m(t, z)*diff(m(t, z), z) + sqrt(2)*e^(1/2*M(t, z))*l(t, z)*diff(n(t, z), z) + (I*sqrt(2)*n(t, z)*diff(l(t, z), t) - 2*I*sqrt(2)*m(t, z)*diff(m(t, z), t) + I*sqrt(2)*l(t, z)*diff(n(t, z), t))*sqrt(-e^(M(t, z))))/(e^(M(t, z))*m(t, z)^2 - e^(M(t, z))*l(t, z)*n(t, z))
# 'nuNP=' 1/8*(sqrt(2)*e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z) - 2*sqrt(2)*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(m(t, z), z) + (2*sqrt(2)*e^(1/2*M(t, z))*m(t, z)^2 - sqrt(2)*e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(n(t, z), z) - 2*(sqrt(2)*e^(1/2*M(t, z))*n(t, z)*diff(m(t, z), z) - sqrt(2)*e^(1/2*M(t, z))*m(t, z)*diff(n(t, z), z) + (I*sqrt(2)*n(t, z)*diff(m(t, z), t) - I*sqrt(2)*m(t, z)*diff(n(t, z), t))*sqrt(-e^(M(t, z))))*sqrt(m(t, z)^2 - l(t, z)*n(t, z)) + (I*sqrt(2)*n(t, z)^2*diff(l(t, z), t) - 2*I*sqrt(2)*m(t, z)*n(t, z)*diff(m(t, z), t) + (2*I*sqrt(2)*m(t, z)^2 - I*sqrt(2)*l(t, z)*n(t, z))*diff(n(t, z), t))*sqrt(-e^(M(t, z))))/(e^(M(t, z))*m(t, z)^2*n(t, z) - e^(M(t, z))*l(t, z)*n(t, z)^2)
# 'muNP=' 0
# 'lambdaNP=' 0
# 'epsilonNP=' 0
# 'gammaNP=' 0
# 'betaNP=' -1/8*((I*sqrt(2)*m(t, z)^2*n(t, z) - I*sqrt(2)*l(t, z)*n(t, z)^2)*sqrt(-e^(M(t, z)))*diff(M(t, z), t) - (sqrt(2)*e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - sqrt(2)*e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), z) + (sqrt(2)*e^(1/2*M(t, z))*n(t, z)*diff(m(t, z), z) - sqrt(2)*e^(1/2*M(t, z))*m(t, z)*diff(n(t, z), z) + (-I*sqrt(2)*n(t, z)*diff(m(t, z), t) + I*sqrt(2)*m(t, z)*diff(n(t, z), t))*sqrt(-e^(M(t, z))))*sqrt(m(t, z)^2 - l(t, z)*n(t, z)))/(e^(M(t, z))*m(t, z)^2*n(t, z) - e^(M(t, z))*l(t, z)*n(t, z)^2)
# 'alphaNP=' 1/8*((-I*sqrt(2)*m(t, z)^2*n(t, z) + I*sqrt(2)*l(t, z)*n(t, z)^2)*sqrt(-e^(M(t, z)))*diff(M(t, z), t) - (sqrt(2)*e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - sqrt(2)*e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), z) - (sqrt(2)*e^(1/2*M(t, z))*n(t, z)*diff(m(t, z), z) - sqrt(2)*e^(1/2*M(t, z))*m(t, z)*diff(n(t, z), z) - (-I*sqrt(2)*n(t, z)*diff(m(t, z), t) + I*sqrt(2)*m(t, z)*diff(n(t, z), t))*sqrt(-e^(M(t, z))))*sqrt(m(t, z)^2 - l(t, z)*n(t, z)))/(e^(M(t, z))*m(t, z)^2*n(t, z) - e^(M(t, z))*l(t, z)*n(t, z)^2)
# Calculating Weyl components...
# 'Psi0NP=' 1/16*(e^(1/2*M(t, z))*n(t, z)^3*diff(l(t, z), t)^2 + e^(1/2*M(t, z))*n(t, z)^3*diff(l(t, z), z)^2 + 4*e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(m(t, z), t)^2 + 4*e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(m(t, z), z)^2 - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(M(t, z), t)*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(M(t, z), z)*diff(l(t, z), z) + (2*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), t)^2 + (2*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), z)^2 + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(l(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(l(t, z), z, z) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)^2*diff(l(t, z), t) - (e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(m(t, z), t) - 4*(e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), t, t) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)^2*diff(l(t, z), z) - (e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(M(t, z), z))*diff(m(t, z), z) - 4*(e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), z, z) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(l(t, z), t) - 2*e^(1/2*M(t, z))*m(t, z)^3*diff(m(t, z), t) - (2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(M(t, z), t))*diff(n(t, z), t) + 2*(2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(n(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(l(t, z), z) - 2*e^(1/2*M(t, z))*m(t, z)^3*diff(m(t, z), z) - (2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(M(t, z), z))*diff(n(t, z), z) + 2*(2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(n(t, z), z, z) - 2*(2*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(m(t, z), t)^2 + 2*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(m(t, z), z)^2 + e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(n(t, z), t)^2 + e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(n(t, z), z)^2 - (e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(m(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(m(t, z), t, t) - (e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), z))*diff(m(t, z), z) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(m(t, z), z, z) + (e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), t) - (2*e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), t))*diff(n(t, z), t) + 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), t, t) + (e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), z) - 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), z) - (2*e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), z))*diff(n(t, z), z) + 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), z, z) + ((I*n(t, z)^2*diff(l(t, z), z) + 2*(-I*m(t, z)^2*n(t, z) + I*l(t, z)*n(t, z)^2)*diff(M(t, z), z))*diff(m(t, z), t) + 4*(I*m(t, z)^2*n(t, z) - I*l(t, z)*n(t, z)^2)*diff(m(t, z), t, z) + (I*n(t, z)^2*diff(l(t, z), t) - 4*I*m(t, z)*n(t, z)*diff(m(t, z), t) + 2*(-I*m(t, z)^2*n(t, z) + I*l(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(m(t, z), z) + (-I*m(t, z)*n(t, z)*diff(l(t, z), z) + 2*(I*m(t, z)^3 - I*l(t, z)*m(t, z)*n(t, z))*diff ...
# 'Psi1NP=' 0
# 'Psi2NP=' -1/48*(e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), t)^2 - e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z)^2 - 4*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), t)*diff(m(t, z), t) + 4*e^(1/2*M(t, z))*m(t, z)^2*diff(m(t, z), t)^2 + 4*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), z)*diff(m(t, z), z) - 4*e^(1/2*M(t, z))*m(t, z)^2*diff(m(t, z), z)^2 + e^(1/2*M(t, z))*l(t, z)^2*diff(n(t, z), t)^2 - e^(1/2*M(t, z))*l(t, z)^2*diff(n(t, z), z)^2 - 6*(I*n(t, z)*diff(l(t, z), z)*diff(m(t, z), t) - I*n(t, z)*diff(l(t, z), t)*diff(m(t, z), z) + (-I*m(t, z)*diff(l(t, z), z) + I*l(t, z)*diff(m(t, z), z))*diff(n(t, z), t) + (I*m(t, z)*diff(l(t, z), t) - I*l(t, z)*diff(m(t, z), t))*diff(n(t, z), z))*sqrt(m(t, z)^2 - l(t, z)*n(t, z))*sqrt(-e^(M(t, z))) + 4*(e^(1/2*M(t, z))*m(t, z)^4 - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(M(t, z), t, t) - 4*(e^(1/2*M(t, z))*m(t, z)^4 - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(M(t, z), z, z) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(l(t, z), t, t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(l(t, z), z, z) - 4*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), t, t) + 4*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), z, z) + 2*(e^(1/2*M(t, z))*l(t, z)*n(t, z)*diff(l(t, z), t) - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(m(t, z), t))*diff(n(t, z), t) + 2*(e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), t, t) - 2*(e^(1/2*M(t, z))*l(t, z)*n(t, z)*diff(l(t, z), z) - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(m(t, z), z))*diff(n(t, z), z) - 2*(e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), z, z))/(e^(3/2*M(t, z))*m(t, z)^4 - 2*e^(3/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(3/2*M(t, z))*l(t, z)^2*n(t, z)^2)
# 'Psi3NP=' 0
# 'Psi4NP=' 1/16*(e^(1/2*M(t, z))*n(t, z)^3*diff(l(t, z), t)^2 + e^(1/2*M(t, z))*n(t, z)^3*diff(l(t, z), z)^2 + 4*e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(m(t, z), t)^2 + 4*e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(m(t, z), z)^2 - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(M(t, z), t)*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(M(t, z), z)*diff(l(t, z), z) + (2*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), t)^2 + (2*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), z)^2 + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(l(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)^2 - e^(1/2*M(t, z))*l(t, z)*n(t, z)^3)*diff(l(t, z), z, z) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)^2*diff(l(t, z), t) - (e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(m(t, z), t) - 4*(e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), t, t) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)^2*diff(l(t, z), z) - (e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(M(t, z), z))*diff(m(t, z), z) - 4*(e^(1/2*M(t, z))*m(t, z)^3*n(t, z) - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), z, z) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(l(t, z), t) - 2*e^(1/2*M(t, z))*m(t, z)^3*diff(m(t, z), t) - (2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(M(t, z), t))*diff(n(t, z), t) + 2*(2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(n(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z)*diff(l(t, z), z) - 2*e^(1/2*M(t, z))*m(t, z)^3*diff(m(t, z), z) - (2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(M(t, z), z))*diff(n(t, z), z) + 2*(2*e^(1/2*M(t, z))*m(t, z)^4 - 3*e^(1/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(1/2*M(t, z))*l(t, z)^2*n(t, z)^2)*diff(n(t, z), z, z) + 2*(2*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(m(t, z), t)^2 + 2*e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(m(t, z), z)^2 + e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(n(t, z), t)^2 + e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(n(t, z), z)^2 - (e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(m(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(m(t, z), t, t) - (e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), z))*diff(m(t, z), z) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(m(t, z), z, z) + (e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), t) - (2*e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), t))*diff(n(t, z), t) + 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), t, t) + (e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), z) - 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), z) - (2*e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), z))*diff(n(t, z), z) + 2*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), z, z) - ((I*n(t, z)^2*diff(l(t, z), z) + 2*(-I*m(t, z)^2*n(t, z) + I*l(t, z)*n(t, z)^2)*diff(M(t, z), z))*diff(m(t, z), t) + 4*(I*m(t, z)^2*n(t, z) - I*l(t, z)*n(t, z)^2)*diff(m(t, z), t, z) + (I*n(t, z)^2*diff(l(t, z), t) - 4*I*m(t, z)*n(t, z)*diff(m(t, z), t) + 2*(-I*m(t, z)^2*n(t, z) + I*l(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(m(t, z), z) + (-I*m(t, z)*n(t, z)*diff(l(t, z), z) + 2*(I*m(t, z)^3 - I*l(t, z)*m(t, z)*n(t, z))*diff ...
# Calculating Ricci components...
# 'Phi00NP=' -1/16*(n(t, z)^3*diff(l(t, z), t)^2 - n(t, z)^3*diff(l(t, z), z)^2 - 4*m(t, z)*n(t, z)^2*diff(l(t, z), t)*diff(m(t, z), t) + 4*m(t, z)^2*n(t, z)*diff(m(t, z), t)^2 + 4*m(t, z)*n(t, z)^2*diff(l(t, z), z)*diff(m(t, z), z) - 4*m(t, z)^2*n(t, z)*diff(m(t, z), z)^2 + (2*l(t, z)*m(t, z)^2 - l(t, z)^2*n(t, z))*diff(n(t, z), t)^2 - (2*l(t, z)*m(t, z)^2 - l(t, z)^2*n(t, z))*diff(n(t, z), z)^2 + 2*(m(t, z)^2*n(t, z)^2 - l(t, z)*n(t, z)^3)*diff(l(t, z), t, t) - 2*(m(t, z)^2*n(t, z)^2 - l(t, z)*n(t, z)^3)*diff(l(t, z), z, z) - 4*(m(t, z)^3*n(t, z) - l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), t, t) + 4*(m(t, z)^3*n(t, z) - l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), z, z) + 2*(m(t, z)^2*n(t, z)*diff(l(t, z), t) - 2*m(t, z)^3*diff(m(t, z), t))*diff(n(t, z), t) + 2*(2*m(t, z)^4 - 3*l(t, z)*m(t, z)^2*n(t, z) + l(t, z)^2*n(t, z)^2)*diff(n(t, z), t, t) - 2*(m(t, z)^2*n(t, z)*diff(l(t, z), z) - 2*m(t, z)^3*diff(m(t, z), z))*diff(n(t, z), z) - 2*(2*m(t, z)^4 - 3*l(t, z)*m(t, z)^2*n(t, z) + l(t, z)^2*n(t, z)^2)*diff(n(t, z), z, z) + 2*(n(t, z)^2*diff(l(t, z), t)*diff(m(t, z), t) - 2*m(t, z)*n(t, z)*diff(m(t, z), t)^2 - n(t, z)^2*diff(l(t, z), z)*diff(m(t, z), z) + 2*m(t, z)*n(t, z)*diff(m(t, z), z)^2 - l(t, z)*m(t, z)*diff(n(t, z), t)^2 + l(t, z)*m(t, z)*diff(n(t, z), z)^2 + 2*(m(t, z)^2*n(t, z) - l(t, z)*n(t, z)^2)*diff(m(t, z), t, t) - 2*(m(t, z)^2*n(t, z) - l(t, z)*n(t, z)^2)*diff(m(t, z), z, z) - (m(t, z)*n(t, z)*diff(l(t, z), t) - (2*m(t, z)^2 + l(t, z)*n(t, z))*diff(m(t, z), t))*diff(n(t, z), t) - 2*(m(t, z)^3 - l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), t, t) + (m(t, z)*n(t, z)*diff(l(t, z), z) - (2*m(t, z)^2 + l(t, z)*n(t, z))*diff(m(t, z), z))*diff(n(t, z), z) + 2*(m(t, z)^3 - l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), z, z))*sqrt(m(t, z)^2 - l(t, z)*n(t, z)))/(e^(M(t, z))*m(t, z)^4*n(t, z) - 2*e^(M(t, z))*l(t, z)*m(t, z)^2*n(t, z)^2 + e^(M(t, z))*l(t, z)^2*n(t, z)^3)
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 1/16*(e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), t)^2 + e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z)^2 + e^(1/2*M(t, z))*l(t, z)^2*diff(n(t, z), t)^2 + e^(1/2*M(t, z))*l(t, z)^2*diff(n(t, z), z)^2 - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), t)*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), z)*diff(l(t, z), z) + 2*(e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), t)^2 + 2*(e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), z)^2 + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(l(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(l(t, z), z, z) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), t) - (e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), t))*diff(m(t, z), t) - 4*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), t, t) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), z) - (e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), z))*diff(m(t, z), z) - 4*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), z, z) + 2*(e^(1/2*M(t, z))*m(t, z)^2*diff(l(t, z), t) - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(m(t, z), t) - (e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(M(t, z), t))*diff(n(t, z), t) + 2*(e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*diff(l(t, z), z) - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(m(t, z), z) - (e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(M(t, z), z))*diff(n(t, z), z) + 2*(e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), z, z) + 2*((I*m(t, z)^2*n(t, z) - I*l(t, z)*n(t, z)^2)*diff(M(t, z), z)*diff(l(t, z), t) + 2*(-I*m(t, z)^2*n(t, z) + I*l(t, z)*n(t, z)^2)*diff(l(t, z), t, z) + (-I*n(t, z)^2*diff(l(t, z), t) + (I*m(t, z)^2*n(t, z) - I*l(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(l(t, z), z) + 2*(I*m(t, z)*n(t, z)*diff(l(t, z), z) + (-I*m(t, z)^3 + I*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), z))*diff(m(t, z), t) + 4*(I*m(t, z)^3 - I*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), t, z) + 2*(I*m(t, z)*n(t, z)*diff(l(t, z), t) + (-I*m(t, z)^3 + I*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), t) + (-I*m(t, z)^2 - I*l(t, z)*n(t, z))*diff(m(t, z), t))*diff(m(t, z), z) + (-I*m(t, z)^2*diff(l(t, z), z) + 2*I*l(t, z)*m(t, z)*diff(m(t, z), z) + (I*l(t, z)*m(t, z)^2 - I*l(t, z)^2*n(t, z))*diff(M(t, z), z))*diff(n(t, z), t) + 2*(-I*l(t, z)*m(t, z)^2 + I*l(t, z)^2*n(t, z))*diff(n(t, z), t, z) + (-I*m(t, z)^2*diff(l(t, z), t) + 2*I*l(t, z)*m(t, z)*diff(m(t, z), t) - I*l(t, z)^2*diff(n(t, z), t) + (I*l(t, z)*m(t, z)^2 - I*l(t, z)^2*n(t, z))*diff(M(t, z), t))*diff(n(t, z), z))*sqrt(-e^(M(t, z))))/(e^(3/2*M(t, z))*m(t, z)^4 - 2*e^(3/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(3/2*M(t, z))*l(t, z)^2*n(t, z)^2)
# 'Phi20NP=' 1/16*(e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), t)^2 + e^(1/2*M(t, z))*n(t, z)^2*diff(l(t, z), z)^2 + e^(1/2*M(t, z))*l(t, z)^2*diff(n(t, z), t)^2 + e^(1/2*M(t, z))*l(t, z)^2*diff(n(t, z), z)^2 - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), t)*diff(l(t, z), t) - 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(M(t, z), z)*diff(l(t, z), z) + 2*(e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), t)^2 + 2*(e^(1/2*M(t, z))*m(t, z)^2 + e^(1/2*M(t, z))*l(t, z)*n(t, z))*diff(m(t, z), z)^2 + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(l(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*n(t, z) - e^(1/2*M(t, z))*l(t, z)*n(t, z)^2)*diff(l(t, z), z, z) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), t) - (e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), t))*diff(m(t, z), t) - 4*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), t, t) - 4*(e^(1/2*M(t, z))*m(t, z)*n(t, z)*diff(l(t, z), z) - (e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), z))*diff(m(t, z), z) - 4*(e^(1/2*M(t, z))*m(t, z)^3 - e^(1/2*M(t, z))*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), z, z) + 2*(e^(1/2*M(t, z))*m(t, z)^2*diff(l(t, z), t) - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(m(t, z), t) - (e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(M(t, z), t))*diff(n(t, z), t) + 2*(e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), t, t) + 2*(e^(1/2*M(t, z))*m(t, z)^2*diff(l(t, z), z) - 2*e^(1/2*M(t, z))*l(t, z)*m(t, z)*diff(m(t, z), z) - (e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(M(t, z), z))*diff(n(t, z), z) + 2*(e^(1/2*M(t, z))*l(t, z)*m(t, z)^2 - e^(1/2*M(t, z))*l(t, z)^2*n(t, z))*diff(n(t, z), z, z) - 2*((I*m(t, z)^2*n(t, z) - I*l(t, z)*n(t, z)^2)*diff(M(t, z), z)*diff(l(t, z), t) + 2*(-I*m(t, z)^2*n(t, z) + I*l(t, z)*n(t, z)^2)*diff(l(t, z), t, z) + (-I*n(t, z)^2*diff(l(t, z), t) + (I*m(t, z)^2*n(t, z) - I*l(t, z)*n(t, z)^2)*diff(M(t, z), t))*diff(l(t, z), z) + 2*(I*m(t, z)*n(t, z)*diff(l(t, z), z) + (-I*m(t, z)^3 + I*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), z))*diff(m(t, z), t) + 4*(I*m(t, z)^3 - I*l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), t, z) + 2*(I*m(t, z)*n(t, z)*diff(l(t, z), t) + (-I*m(t, z)^3 + I*l(t, z)*m(t, z)*n(t, z))*diff(M(t, z), t) + (-I*m(t, z)^2 - I*l(t, z)*n(t, z))*diff(m(t, z), t))*diff(m(t, z), z) + (-I*m(t, z)^2*diff(l(t, z), z) + 2*I*l(t, z)*m(t, z)*diff(m(t, z), z) + (I*l(t, z)*m(t, z)^2 - I*l(t, z)^2*n(t, z))*diff(M(t, z), z))*diff(n(t, z), t) + 2*(-I*l(t, z)*m(t, z)^2 + I*l(t, z)^2*n(t, z))*diff(n(t, z), t, z) + (-I*m(t, z)^2*diff(l(t, z), t) + 2*I*l(t, z)*m(t, z)*diff(m(t, z), t) - I*l(t, z)^2*diff(n(t, z), t) + (I*l(t, z)*m(t, z)^2 - I*l(t, z)^2*n(t, z))*diff(M(t, z), t))*diff(n(t, z), z))*sqrt(-e^(M(t, z))))/(e^(3/2*M(t, z))*m(t, z)^4 - 2*e^(3/2*M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(3/2*M(t, z))*l(t, z)^2*n(t, z)^2)
# 'Phi11NP=' 1/16*(2*(m(t, z)^2 - l(t, z)*n(t, z))*diff(M(t, z), t, t) - 2*(m(t, z)^2 - l(t, z)*n(t, z))*diff(M(t, z), z, z) - diff(m(t, z), t)^2 + diff(m(t, z), z)^2 + diff(l(t, z), t)*diff(n(t, z), t) - diff(l(t, z), z)*diff(n(t, z), z))/(e^(M(t, z))*m(t, z)^2 - e^(M(t, z))*l(t, z)*n(t, z))
# 'Phi12NP=' 0
# 'Phi21NP=' 0
# 'Phi22NP=' -1/16*(n(t, z)^3*diff(l(t, z), t)^2 - n(t, z)^3*diff(l(t, z), z)^2 - 4*m(t, z)*n(t, z)^2*diff(l(t, z), t)*diff(m(t, z), t) + 4*m(t, z)^2*n(t, z)*diff(m(t, z), t)^2 + 4*m(t, z)*n(t, z)^2*diff(l(t, z), z)*diff(m(t, z), z) - 4*m(t, z)^2*n(t, z)*diff(m(t, z), z)^2 + (2*l(t, z)*m(t, z)^2 - l(t, z)^2*n(t, z))*diff(n(t, z), t)^2 - (2*l(t, z)*m(t, z)^2 - l(t, z)^2*n(t, z))*diff(n(t, z), z)^2 + 2*(m(t, z)^2*n(t, z)^2 - l(t, z)*n(t, z)^3)*diff(l(t, z), t, t) - 2*(m(t, z)^2*n(t, z)^2 - l(t, z)*n(t, z)^3)*diff(l(t, z), z, z) - 4*(m(t, z)^3*n(t, z) - l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), t, t) + 4*(m(t, z)^3*n(t, z) - l(t, z)*m(t, z)*n(t, z)^2)*diff(m(t, z), z, z) + 2*(m(t, z)^2*n(t, z)*diff(l(t, z), t) - 2*m(t, z)^3*diff(m(t, z), t))*diff(n(t, z), t) + 2*(2*m(t, z)^4 - 3*l(t, z)*m(t, z)^2*n(t, z) + l(t, z)^2*n(t, z)^2)*diff(n(t, z), t, t) - 2*(m(t, z)^2*n(t, z)*diff(l(t, z), z) - 2*m(t, z)^3*diff(m(t, z), z))*diff(n(t, z), z) - 2*(2*m(t, z)^4 - 3*l(t, z)*m(t, z)^2*n(t, z) + l(t, z)^2*n(t, z)^2)*diff(n(t, z), z, z) - 2*(n(t, z)^2*diff(l(t, z), t)*diff(m(t, z), t) - 2*m(t, z)*n(t, z)*diff(m(t, z), t)^2 - n(t, z)^2*diff(l(t, z), z)*diff(m(t, z), z) + 2*m(t, z)*n(t, z)*diff(m(t, z), z)^2 - l(t, z)*m(t, z)*diff(n(t, z), t)^2 + l(t, z)*m(t, z)*diff(n(t, z), z)^2 + 2*(m(t, z)^2*n(t, z) - l(t, z)*n(t, z)^2)*diff(m(t, z), t, t) - 2*(m(t, z)^2*n(t, z) - l(t, z)*n(t, z)^2)*diff(m(t, z), z, z) - (m(t, z)*n(t, z)*diff(l(t, z), t) - (2*m(t, z)^2 + l(t, z)*n(t, z))*diff(m(t, z), t))*diff(n(t, z), t) - 2*(m(t, z)^3 - l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), t, t) + (m(t, z)*n(t, z)*diff(l(t, z), z) - (2*m(t, z)^2 + l(t, z)*n(t, z))*diff(m(t, z), z))*diff(n(t, z), z) + 2*(m(t, z)^3 - l(t, z)*m(t, z)*n(t, z))*diff(n(t, z), z, z))*sqrt(m(t, z)^2 - l(t, z)*n(t, z)))/(e^(M(t, z))*m(t, z)^4*n(t, z) - 2*e^(M(t, z))*l(t, z)*m(t, z)^2*n(t, z)^2 + e^(M(t, z))*l(t, z)^2*n(t, z)^3)
# 'LambdaNP=' -1/48*(n(t, z)^2*diff(l(t, z), t)^2 - n(t, z)^2*diff(l(t, z), z)^2 - 4*m(t, z)*n(t, z)*diff(l(t, z), t)*diff(m(t, z), t) + 4*m(t, z)*n(t, z)*diff(l(t, z), z)*diff(m(t, z), z) + l(t, z)^2*diff(n(t, z), t)^2 - l(t, z)^2*diff(n(t, z), z)^2 + (m(t, z)^2 + 3*l(t, z)*n(t, z))*diff(m(t, z), t)^2 - (m(t, z)^2 + 3*l(t, z)*n(t, z))*diff(m(t, z), z)^2 - 2*(m(t, z)^4 - 2*l(t, z)*m(t, z)^2*n(t, z) + l(t, z)^2*n(t, z)^2)*diff(M(t, z), t, t) + 2*(m(t, z)^4 - 2*l(t, z)*m(t, z)^2*n(t, z) + l(t, z)^2*n(t, z)^2)*diff(M(t, z), z, z) + 2*(m(t, z)^2*n(t, z) - l(t, z)*n(t, z)^2)*diff(l(t, z), t, t) - 2*(m(t, z)^2*n(t, z) - l(t, z)*n(t, z)^2)*diff(l(t, z), z, z) - 4*(m(t, z)^3 - l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), t, t) + 4*(m(t, z)^3 - l(t, z)*m(t, z)*n(t, z))*diff(m(t, z), z, z) - (4*l(t, z)*m(t, z)*diff(m(t, z), t) - (3*m(t, z)^2 - l(t, z)*n(t, z))*diff(l(t, z), t))*diff(n(t, z), t) + 2*(l(t, z)*m(t, z)^2 - l(t, z)^2*n(t, z))*diff(n(t, z), t, t) + (4*l(t, z)*m(t, z)*diff(m(t, z), z) - (3*m(t, z)^2 - l(t, z)*n(t, z))*diff(l(t, z), z))*diff(n(t, z), z) - 2*(l(t, z)*m(t, z)^2 - l(t, z)^2*n(t, z))*diff(n(t, z), z, z))/(e^(M(t, z))*m(t, z)^4 - 2*e^(M(t, z))*l(t, z)*m(t, z)^2*n(t, z) + e^(M(t, z))*l(t, z)^2*n(t, z)^2)
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# Calculating Bianchi identities...
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0
# Calculating Petrov Type...
# Petrov Type I

# %%
from pathlib import Path
fout = open('17.5_e-1.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def latex_write(fout, lhs, rhs_expr):
    """
    Uzun LaTeX ifadelerini \\frac sinirlarinda keserek yazar.
    Kisa ifadeler (<5500 karakter) dogrudan yazilir.
    Uzun ifadeler uygun bir \\frac noktasindan kesilip {} \\dots ile bitirilir.
    """
    my_expression = str(rhs_expr)

    if len(my_expression) < 5500:
        fout.write(r"\begin{dmath*}" + "\n")
        fout.write(lhs + " = " + my_expression + "\n")
        fout.write(r"\end{dmath*}" + "\n\n")
    else:
        count_oparan = 0
        count_cparan = 0
        last_frac_locations = []
        for i in range(min(5000, len(my_expression))):
            if my_expression[i] == "{":
                count_oparan += 1
            elif my_expression[i] == "}":
                count_cparan += 1
            if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                last_frac_locations.append(i)

        if len(last_frac_locations) > 2:
            fout.write(r"\begin{dmath*}" + "\n")
            fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
            fout.write(r"\end{dmath*}" + "\n\n")
        else:
            i = 5000
            while i < min(200000, len(my_expression)):
                if my_expression[i] == "{":
                    count_oparan += 1
                elif my_expression[i] == "}":
                    count_cparan += 1
                if len(my_expression) <= i + 5:
                    # Ifade tamamen taranabildi, hepsini yaz
                    fout.write(r"\begin{dmath*}" + "\n")
                    fout.write(lhs + " = " + my_expression + "\n")
                    fout.write(r"\end{dmath*}" + "\n\n")
                    return
                if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                    last_frac_locations.append(i)
                    if len(last_frac_locations) > 2:
                        break
                i += 1

            if not last_frac_locations or last_frac_locations[-1] == 0:
                # Uygun kesme noktasi bulunamadi, yine de yaz
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")
            else:
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")


def write_dmath(fout, lhs, rhs):
    """latex_write ile uzun ifade truncation destekli yazim."""
    latex_write(fout, lhs, rhs)

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# tex dosyasi olusturuldu.

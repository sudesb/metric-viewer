# %%
os.chdir('/mnt/c/Users/victu/Documents')
os.getcwd()

import os
print(os.getcwd())
# Out:
# /mnt/c/Users/victu/Documents

# %%
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<t,phi,rho,z> = MyManifold.chart(r't phi rho z')
tetrad_type = 'covariant'  
k=function('k')(rho,z)
A=function('A')(rho,z)
u=function('u')(rho,z)
I = sqrt(-1)
lvec = [(rho^(1/3))/sqrt(2),(-A*rho^(1/3)-rho^(2/3))/sqrt(2),0,0]   
nvec = [(rho^(1/3))/sqrt(2),(-A*rho^(1/3)+rho^(2/3))/sqrt(2),0,0]    
mvec = [0,0,((e^k)*rho^(-1/3))/(sqrt(2)),I*((e^k)*rho^(-1/3))/(sqrt(2))]
mbarvec = [0,0,((e^k)*rho^(-1/3))/(sqrt(2)),-I*((e^k)*rho^(-1/3))/(sqrt(2))]


met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))

met.calculate_spincoefficients()
met.calculate_Weyl()
met.calculate_Ricci()
met.calculate_NPeq()
met.calculate_Bianchi()
met.Petrov_fromWeyl()

met.show_spincoefficients()
met.show_Weyl()
met.show_Ricci()
met.show_NPeq()
met.show_Bianchi()
# Out:
# 'The metric:'
# g = -rho^(2/3) dt⊗dt + rho^(2/3)*A(rho, z) dt⊗dphi + rho^(2/3)*A(rho, z) dphi⊗dt + (-rho^(2/3)*A(rho, z)^2 + rho^(4/3)) dphi⊗dphi + e^(2*k(rho, z))/rho^(2/3) drho⊗drho + e^(2*k(rho, z))/rho^(2/3) dz⊗dz
# Calculating spin coefficients...
# Calculating Weyl components...
# Calculating Ricci components...
# Calculating NP equations...
# Calculating Bianchi identities...
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# 'kappaNP=' 1/12*sqrt(2)*(3*rho^(2/3)*(diff(A(rho, z), rho) + I*diff(A(rho, z), z)) + 1)*e^(-k(rho, z))/rho^(2/3)
# 'tauNP=' -1/4*sqrt(2)*e^(-k(rho, z))/rho^(2/3)
# 'sigmaNP=' 0
# 'rhoNP=' 0
# 'piNP=' 1/4*sqrt(2)*e^(-k(rho, z))/rho^(2/3)
# 'nuNP=' 1/12*sqrt(2)*(3*rho^(2/3)*(diff(A(rho, z), rho) - I*diff(A(rho, z), z)) - 1)*e^(-k(rho, z))/rho^(2/3)
# 'muNP=' 0
# 'lambdaNP=' 0
# 'epsilonNP=' 0
# 'gammaNP=' 0
# 'betaNP=' 1/24*(6*sqrt(2)*rho*diff(k(rho, z), rho) + 6*I*sqrt(2)*rho*diff(k(rho, z), z) + 3*(sqrt(2)*diff(A(rho, z), rho) + I*sqrt(2)*diff(A(rho, z), z))*rho^(2/3) - 2*sqrt(2))*e^(-k(rho, z))/rho^(2/3)
# 'alphaNP=' -1/24*(6*sqrt(2)*rho*diff(k(rho, z), rho) - 6*I*sqrt(2)*rho*diff(k(rho, z), z) - 3*(sqrt(2)*diff(A(rho, z), rho) - I*sqrt(2)*diff(A(rho, z), z))*rho^(2/3) - 2*sqrt(2))*e^(-k(rho, z))/rho^(2/3)
# 'Psi0NP=' 1/36*(6*rho*diff(k(rho, z), rho) + 6*I*rho*diff(k(rho, z), z) - 9*(rho*diff(A(rho, z), rho, rho) + 2*I*rho*diff(A(rho, z), rho, z) - rho*diff(A(rho, z), z, z) - 2*(rho*diff(A(rho, z), rho) + I*rho*diff(A(rho, z), z))*diff(k(rho, z), rho) - 2*(I*rho*diff(A(rho, z), rho) - rho*diff(A(rho, z), z))*diff(k(rho, z), z) + diff(A(rho, z), rho) + I*diff(A(rho, z), z))*rho^(2/3) + 9*(rho*diff(A(rho, z), rho)^2 + 2*I*rho*diff(A(rho, z), rho)*diff(A(rho, z), z) - rho*diff(A(rho, z), z)^2)*rho^(1/3) - 2)*e^(-2*k(rho, z))/rho^(4/3)
# 'Psi1NP=' 0
# 'Psi2NP=' 1/108*(18*rho^2*diff(k(rho, z), rho, rho) + 18*rho^2*diff(k(rho, z), z, z) - 9*I*rho^(2/3)*diff(A(rho, z), z) + 9*(rho*diff(A(rho, z), rho)^2 + rho*diff(A(rho, z), z)^2)*rho^(1/3) + 14)*e^(-2*k(rho, z))/rho^(4/3)
# 'Psi3NP=' 0
# 'Psi4NP=' 1/36*(6*rho*diff(k(rho, z), rho) - 6*I*rho*diff(k(rho, z), z) + 9*(rho*diff(A(rho, z), rho, rho) - 2*I*rho*diff(A(rho, z), rho, z) - rho*diff(A(rho, z), z, z) - 2*(rho*diff(A(rho, z), rho) - I*rho*diff(A(rho, z), z))*diff(k(rho, z), rho) - 2*(-I*rho*diff(A(rho, z), rho) - rho*diff(A(rho, z), z))*diff(k(rho, z), z) + diff(A(rho, z), rho) - I*diff(A(rho, z), z))*rho^(2/3) + 9*(rho*diff(A(rho, z), rho)^2 - 2*I*rho*diff(A(rho, z), rho)*diff(A(rho, z), z) - rho*diff(A(rho, z), z)^2)*rho^(1/3) - 2)*e^(-2*k(rho, z))/rho^(4/3)
# 'Phi00NP=' -1/12*(3*rho*diff(A(rho, z), rho, rho) + 3*rho*diff(A(rho, z), z, z) - 3*(diff(A(rho, z), rho)^2 + diff(A(rho, z), z)^2)*rho^(2/3) + diff(A(rho, z), rho))*e^(-2*k(rho, z))/rho^(2/3)
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 1/72*(36*rho*diff(k(rho, z), rho) + 36*I*rho*diff(k(rho, z), z) + 9*(rho*diff(A(rho, z), rho)^2 + 2*I*rho*diff(A(rho, z), rho)*diff(A(rho, z), z) - rho*diff(A(rho, z), z)^2)*rho^(1/3) - 4)*e^(-2*k(rho, z))/rho^(4/3)
# 'Phi20NP=' 1/72*(36*rho*diff(k(rho, z), rho) - 36*I*rho*diff(k(rho, z), z) + 9*(rho*diff(A(rho, z), rho)^2 - 2*I*rho*diff(A(rho, z), rho)*diff(A(rho, z), z) - rho*diff(A(rho, z), z)^2)*rho^(1/3) - 4)*e^(-2*k(rho, z))/rho^(4/3)
# 'Phi11NP=' -1/144*(36*rho^2*diff(k(rho, z), rho, rho) + 36*rho^2*diff(k(rho, z), z, z) - 9*(rho*diff(A(rho, z), rho)^2 + rho*diff(A(rho, z), z)^2)*rho^(1/3) + 4)*e^(-2*k(rho, z))/rho^(4/3)
# 'Phi12NP=' 0
# 'Phi21NP=' 0
# 'Phi22NP=' 1/12*(3*rho*diff(A(rho, z), rho, rho) + 3*rho*diff(A(rho, z), z, z) + 3*(diff(A(rho, z), rho)^2 + diff(A(rho, z), z)^2)*rho^(2/3) + diff(A(rho, z), rho))*e^(-2*k(rho, z))/rho^(2/3)
# 'LambdaNP=' -1/432*(36*rho^2*diff(k(rho, z), rho, rho) + 36*rho^2*diff(k(rho, z), z, z) - 9*(rho*diff(A(rho, z), rho)^2 + rho*diff(A(rho, z), z)^2)*rho^(1/3) + 4)*e^(-2*k(rho, z))/rho^(4/3)
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
met.calculate_PetrovinvINP()
met.calculate_PetrovinvJNP()
met.calculate_PetrovinvKNP()
met.calculate_PetrovinvLNP()
met.calculate_PetrovinvNNP()

show(met.PetrovinvINP.expr())
show(met.PetrovinvJNP.expr())
show(met.PetrovinvKNP.expr())
show(met.PetrovinvLNP.expr())
show(met.PetrovinvNNP.expr())
# Out:
# -1/3888*(972*I*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) - 972*I*rho^3*diff(A(rho, z), rho, z)*diff(A(rho, z), z)^2 + 972*I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z)*diff(A(rho, z), z, z) - 324*rho^4*diff(k(rho, z), rho, rho)^2 - 324*rho^4*diff(k(rho, z), z, z)^2 - 324*I*rho^2*diff(A(rho, z), z)^3 - 108*rho^2*diff(k(rho, z), rho)^2 - 108*rho^2*diff(k(rho, z), z)^2 - 504*rho^2*diff(k(rho, z), rho, rho) - 324*(3*I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) + I*rho^2*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) - 36*(-27*I*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), z) - 27*I*rho^3*diff(A(rho, z), z)^3 - 2*rho)*diff(k(rho, z), rho) - 972*(I*rho^3*diff(A(rho, z), rho)^3 + I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z)^2)*diff(k(rho, z), z) - 72*(9*rho^4*diff(k(rho, z), rho, rho) + 7*rho^2)*diff(k(rho, z), z, z) - 36*(9*rho^2*diff(A(rho, z), rho)^4 + 18*rho^2*diff(A(rho, z), rho)^2*diff(A(rho, z), z)^2 + 9*rho^2*diff(A(rho, z), z)^4 + 18*I*rho^2*diff(A(rho, z), z)*diff(k(rho, z), rho)^2 + 18*I*rho^2*diff(A(rho, z), z)*diff(k(rho, z), z)^2 - 9*I*rho^2*diff(A(rho, z), z)*diff(k(rho, z), rho, rho) - 9*I*rho^2*diff(A(rho, z), z)*diff(k(rho, z), z, z) + 6*I*rho*diff(A(rho, z), rho, z) + 3*(-6*I*rho^2*diff(A(rho, z), rho, z) - 5*I*rho*diff(A(rho, z), z))*diff(k(rho, z), rho) + 3*(3*I*rho^2*diff(A(rho, z), rho, rho) - 3*I*rho^2*diff(A(rho, z), z, z) + I*rho*diff(A(rho, z), rho))*diff(k(rho, z), z) - 4*I*diff(A(rho, z), z))*rho^(2/3) + 9*(27*rho^3*diff(A(rho, z), rho, rho)^2 + 108*rho^3*diff(A(rho, z), rho, z)^2 + 27*rho^3*diff(A(rho, z), z, z)^2 + 54*rho^2*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) + 108*rho^2*diff(A(rho, z), rho, z)*diff(A(rho, z), z) + 11*rho*diff(A(rho, z), rho)^2 - 4*rho*diff(A(rho, z), z)^2 + 108*(rho^3*diff(A(rho, z), rho)^2 + rho^3*diff(A(rho, z), z)^2)*diff(k(rho, z), rho)^2 + 108*(rho^3*diff(A(rho, z), rho)^2 + rho^3*diff(A(rho, z), z)^2)*diff(k(rho, z), z)^2 - 54*(rho^3*diff(A(rho, z), rho, rho) + rho^2*diff(A(rho, z), rho))*diff(A(rho, z), z, z) - 36*(3*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) + 6*rho^3*diff(A(rho, z), rho, z)*diff(A(rho, z), z) - 3*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z, z) + 4*rho^2*diff(A(rho, z), rho)^2 + 2*rho^2*diff(A(rho, z), z)^2)*diff(k(rho, z), rho) - 36*(rho^3*diff(A(rho, z), rho)^2 + rho^3*diff(A(rho, z), z)^2)*diff(k(rho, z), rho, rho) - 36*(6*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), rho, z) + 3*rho^3*diff(A(rho, z), z)*diff(A(rho, z), z, z) - (3*rho^3*diff(A(rho, z), rho, rho) - 2*rho^2*diff(A(rho, z), rho))*diff(A(rho, z), z))*diff(k(rho, z), z) - 36*(rho^3*diff(A(rho, z), rho)^2 + rho^3*diff(A(rho, z), z)^2)*diff(k(rho, z), z, z))*rho^(1/3) - 208)*e^(-4*k(rho, z))/rho^(8/3)
# 1/1259712*(5832*rho^4*diff(A(rho, z), rho)^6 + 17496*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), z)^4 + 5832*rho^4*diff(A(rho, z), z)^6 - 5832*rho^6*diff(k(rho, z), rho, rho)^3 - 5832*rho^6*diff(k(rho, z), z, z)^3 + 6561*I*rho^4*diff(A(rho, z), z)*diff(A(rho, z), z, z)^2 - 34992*I*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) - 13608*rho^4*diff(k(rho, z), rho, rho)^2 + 33048*I*rho^2*diff(A(rho, z), z)^3 + 2916*(6*rho^4*diff(A(rho, z), rho)^4 + 25*I*rho^3*diff(A(rho, z), rho, z))*diff(A(rho, z), z)^2 - 1458*(9*I*rho^4*diff(A(rho, z), rho, rho) + 37*I*rho^3*diff(A(rho, z), rho))*diff(A(rho, z), z)*diff(A(rho, z), z, z) - 324*(-135*I*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), z) - 135*I*rho^4*diff(A(rho, z), z)^3 - 14*rho^2)*diff(k(rho, z), rho)^2 - 324*(-135*I*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), z) - 135*I*rho^4*diff(A(rho, z), z)^3 - 18*rho^4*diff(k(rho, z), rho, rho) - 14*rho^2)*diff(k(rho, z), z)^2 - 1944*(9*rho^6*diff(k(rho, z), rho, rho) + 7*rho^4)*diff(k(rho, z), z, z)^2 - 243*(-27*I*rho^4*diff(A(rho, z), rho, rho)^2 - 108*I*rho^4*diff(A(rho, z), rho, z)^2 - 222*I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) - 163*I*rho^2*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) - 108*(162*I*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) + 648*I*rho^4*diff(A(rho, z), rho, z)*diff(A(rho, z), z)^2 - 243*I*rho^4*diff(A(rho, z), rho)*diff(A(rho, z), z)*diff(A(rho, z), z, z) + 675*I*rho^3*diff(A(rho, z), z)^3 + 27*(9*I*rho^4*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) + 31*I*rho^3*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) + 28*rho)*diff(k(rho, z), rho) - 216*(243*I*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) - 243*I*rho^5*diff(A(rho, z), rho, z)*diff(A(rho, z), z)^2 + 243*I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), z)*diff(A(rho, z), z, z) - 162*I*rho^4*diff(A(rho, z), z)^3 - 27*rho^4*diff(k(rho, z), rho)^2 + 46*rho^2 + 81*(-3*I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) - 2*I*rho^4*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) + 9*(27*I*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), z) + 27*I*rho^5*diff(A(rho, z), z)^3 + 2*rho^3)*diff(k(rho, z), rho))*diff(k(rho, z), rho, rho) - 8748*(-I*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho) + 6*I*rho^4*diff(A(rho, z), rho)*diff(A(rho, z), rho, z)*diff(A(rho, z), z) - 5*I*rho^3*diff(A(rho, z), rho)^3 + (-4*I*rho^4*diff(A(rho, z), rho, rho) - 3*I*rho^3*diff(A(rho, z), rho))*diff(A(rho, z), z)^2 + (I*rho^4*diff(A(rho, z), rho)^2 + 4*I*rho^4*diff(A(rho, z), z)^2)*diff(A(rho, z), z, z) + 6*(-I*rho^5*diff(A(rho, z), rho)^3 - I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), z)^2)*diff(k(rho, z), rho, rho))*diff(k(rho, z), z) - 216*(243*I*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) - 243*I*rho^5*diff(A(rho, z), rho, z)*diff(A(rho, z), z)^2 + 243*I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), z)*diff(A(rho, z), z, z) + 81*rho^6*diff(k(rho, z), rho, rho)^2 - 162*I*rho^4*diff(A(rho, z), z)^3 - 27*rho^4*diff(k(rho, z), rho)^2 - 27*rho^4*diff(k(rho, z), z)^2 + 126*rho^4*diff(k(rho, z), rho, rho) + 46*rho^2 + 81*(-3*I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) - 2*I*rho^4*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) + 9*(27*I*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), z) + 27*I*rho^5*diff(A(rho, z), z)^3 + 2*rho^3)*diff(k(rho, z), rho) + 243*(-I*rho^5*diff(A(rho, z), rho)^3 - I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), z)^2)*diff(k(rho, z), z))*diff(k(rho, z), z, z) - 27*(243*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho)^2 + 972*rho^4*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z)^2 + 486*rho^3*diff(A(rho, z), rho)^3*diff(A(rho, z), rho, rho) - 324*I*rho^4*diff(A(rho, z), z)*diff(k(rho, z), rho, rho)^2 - 324*I*rho^4*diff(A(rho, z), z)*diff(k(rho, z), z, z)^2 + 99*rho^2*diff(A(rho, z), rho)^4 - 684*rho^2*diff(A(rho, z), z)^4 + 9*(27*rho^4*diff(A(rho, z), rho, rho)^2 + 108*rho^4*diff(A(rho, z), rho, z)^2 - 54*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) - 65*rho^2*diff(A(rho, z), rho)^2)*diff(A(rho, z), z)^2 + 243*(rho^4*dif ...
# 0
# 1/3888*(81*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho) - 162*I*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) + 81*rho^2*diff(A(rho, z), rho)^3 - 162*I*rho^2*diff(A(rho, z), rho)^2*diff(A(rho, z), z) + 81*(rho^3*diff(A(rho, z), rho, rho) - 2*I*rho^3*diff(A(rho, z), rho, z) - rho^2*diff(A(rho, z), rho))*diff(A(rho, z), z)^2 - 81*(rho^3*diff(A(rho, z), rho)^2 + rho^3*diff(A(rho, z), z)^2)*diff(A(rho, z), z, z) - 6*(27*rho^3*diff(A(rho, z), rho)^3 - 27*I*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), z) + 27*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z)^2 - 27*I*rho^3*diff(A(rho, z), z)^3 - 14*rho)*diff(k(rho, z), rho) + 36*(3*rho^3*diff(k(rho, z), rho) - rho^2)*diff(k(rho, z), rho, rho) - 6*(-27*I*rho^3*diff(A(rho, z), rho)^3 - 27*rho^3*diff(A(rho, z), rho)^2*diff(A(rho, z), z) - 27*I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z)^2 - 27*rho^3*diff(A(rho, z), z)^3 + 18*I*rho^3*diff(k(rho, z), rho, rho) + 14*I*rho)*diff(k(rho, z), z) + 36*(3*rho^3*diff(k(rho, z), rho) - 3*I*rho^3*diff(k(rho, z), z) - rho^2)*diff(k(rho, z), z, z) + 9*(9*rho^2*diff(A(rho, z), rho)^4 - 18*I*rho^2*diff(A(rho, z), rho)*diff(A(rho, z), z)^3 - 9*rho^2*diff(A(rho, z), z)^4 + 14*rho*diff(A(rho, z), rho, rho) - 28*I*rho*diff(A(rho, z), rho, z) - 6*(3*I*rho^2*diff(A(rho, z), rho)^3 + 2*I)*diff(A(rho, z), z) - 14*rho*diff(A(rho, z), z, z) - 2*(14*rho*diff(A(rho, z), rho) - 11*I*rho*diff(A(rho, z), z))*diff(k(rho, z), rho) + 18*(rho^3*diff(A(rho, z), rho, rho) - 2*I*rho^3*diff(A(rho, z), rho, z) - rho^3*diff(A(rho, z), z, z) + rho^2*diff(A(rho, z), rho) - I*rho^2*diff(A(rho, z), z) - 2*(rho^3*diff(A(rho, z), rho) - I*rho^3*diff(A(rho, z), z))*diff(k(rho, z), rho))*diff(k(rho, z), rho, rho) - 2*(-14*I*rho*diff(A(rho, z), rho) - 11*rho*diff(A(rho, z), z) + 18*(-I*rho^3*diff(A(rho, z), rho) - rho^3*diff(A(rho, z), z))*diff(k(rho, z), rho, rho))*diff(k(rho, z), z) + 18*(rho^3*diff(A(rho, z), rho, rho) - 2*I*rho^3*diff(A(rho, z), rho, z) - rho^3*diff(A(rho, z), z, z) + rho^2*diff(A(rho, z), rho) - I*rho^2*diff(A(rho, z), z) - 2*(rho^3*diff(A(rho, z), rho) - I*rho^3*diff(A(rho, z), z))*diff(k(rho, z), rho) - 2*(-I*rho^3*diff(A(rho, z), rho) - rho^3*diff(A(rho, z), z))*diff(k(rho, z), z))*diff(k(rho, z), z, z) + 14*diff(A(rho, z), rho))*rho^(2/3) - 9*(-9*I*rho^2*diff(A(rho, z), z)*diff(A(rho, z), z, z) - 12*rho*diff(A(rho, z), rho)^2 + 25*rho*diff(A(rho, z), z)^2 + (9*I*rho^2*diff(A(rho, z), rho, rho) + 18*rho^2*diff(A(rho, z), rho, z) + 37*I*rho*diff(A(rho, z), rho))*diff(A(rho, z), z) - 6*(rho^2*diff(A(rho, z), rho)^2 + 3*I*rho^2*diff(A(rho, z), rho)*diff(A(rho, z), z) + 4*rho^2*diff(A(rho, z), z)^2)*diff(k(rho, z), rho) - 18*(rho^3*diff(A(rho, z), rho)^2 - 2*I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z) - rho^3*diff(A(rho, z), z)^2)*diff(k(rho, z), rho, rho) + 6*(I*rho^2*diff(A(rho, z), rho)^2 - 3*rho^2*diff(A(rho, z), rho)*diff(A(rho, z), z) + 4*I*rho^2*diff(A(rho, z), z)^2)*diff(k(rho, z), z) - 18*(rho^3*diff(A(rho, z), rho)^2 - 2*I*rho^3*diff(A(rho, z), rho)*diff(A(rho, z), z) - rho^3*diff(A(rho, z), z)^2)*diff(k(rho, z), z, z))*rho^(1/3) - 28)*e^(-4*k(rho, z))/rho^(8/3)
# 1/559872*(9963*rho^4*diff(A(rho, z), rho)^6 + 23328*rho^4*diff(A(rho, z), z)^6 - 972*rho^5*diff(A(rho, z), rho, rho)^3 + 15552*I*rho^5*diff(A(rho, z), rho, z)^3 + 972*rho^5*diff(A(rho, z), z, z)^3 + 2916*(6*I*rho^5*diff(A(rho, z), rho, rho) + 21*rho^5*diff(A(rho, z), rho, z) + 26*I*rho^4*diff(A(rho, z), rho))*diff(A(rho, z), z)^5 + 5940*rho^2*diff(A(rho, z), rho)^3 + 243*(9*rho^6*diff(A(rho, z), rho, rho)^2 + 180*rho^6*diff(A(rho, z), rho, z)^2 + 648*I*rho^5*diff(A(rho, z), rho)*diff(A(rho, z), rho, z) - 247*rho^4*diff(A(rho, z), rho)^2 + 18*(4*I*rho^6*diff(A(rho, z), rho, z) - 3*rho^5*diff(A(rho, z), rho))*diff(A(rho, z), rho, rho))*diff(A(rho, z), z)^4 - 432*(54*rho^6*diff(A(rho, z), rho)^3 + 162*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z)^2 - 108*I*rho^6*diff(A(rho, z), z)^3 + rho^4)*diff(k(rho, z), rho)^4 + 432*(54*rho^6*diff(A(rho, z), rho)^3 + 162*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z)^2 - 108*I*rho^6*diff(A(rho, z), z)^3 + rho^4)*diff(k(rho, z), z)^4 + 324*(81*I*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho)^2 + 324*I*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), rho, z)^2 + 216*I*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho) - 378*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) + 159*I*rho^4*diff(A(rho, z), rho)^3 + 52*I*rho^2)*diff(A(rho, z), z)^3 + 144*(243*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho) + 378*rho^5*diff(A(rho, z), rho)^3 - 432*I*rho^5*diff(A(rho, z), z)^3 + 4*rho^3 + 81*(3*rho^6*diff(A(rho, z), rho, rho) - 12*I*rho^6*diff(A(rho, z), rho, z) + 8*rho^5*diff(A(rho, z), rho))*diff(A(rho, z), z)^2 + 162*(6*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), rho, z) - I*rho^5*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) - 243*(rho^6*diff(A(rho, z), rho)^2 + rho^6*diff(A(rho, z), z)^2)*diff(A(rho, z), z, z))*diff(k(rho, z), rho)^3 - 288*(243*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) + 54*I*rho^5*diff(A(rho, z), rho)^3 + 108*rho^5*diff(A(rho, z), z)^3 + I*rho^3 - 81*(-3*I*rho^6*diff(A(rho, z), rho, rho) - 3*rho^6*diff(A(rho, z), rho, z) - I*rho^5*diff(A(rho, z), rho))*diff(A(rho, z), z)^2 - 81*(3*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho) - rho^5*diff(A(rho, z), rho)^2)*diff(A(rho, z), z) + 243*(rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z) - I*rho^6*diff(A(rho, z), z)^2)*diff(A(rho, z), z, z) - 3*(54*I*rho^6*diff(A(rho, z), rho)^3 + 162*I*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z)^2 + 108*rho^6*diff(A(rho, z), z)^3 + I*rho^4)*diff(k(rho, z), rho))*diff(k(rho, z), z)^3 + 729*(3*rho^6*diff(A(rho, z), rho)^4 - 4*rho^4*diff(A(rho, z), rho))*diff(A(rho, z), rho, rho)^2 + 2916*(15*rho^6*diff(A(rho, z), rho)^4 - 4*rho^4*diff(A(rho, z), rho))*diff(A(rho, z), rho, z)^2 - 54*(891*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho)^2 + 2268*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z)^2 + 1971*rho^4*diff(A(rho, z), rho)^4 + 784*rho^2*diff(A(rho, z), rho) - 6*(108*I*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) - 351*rho^5*diff(A(rho, z), rho)^3 - 88*rho^3)*diff(A(rho, z), rho, rho) - 12*(-54*I*rho^5*diff(A(rho, z), rho)^3 + 95*I*rho^3)*diff(A(rho, z), rho, z))*diff(A(rho, z), z)^2 + 243*(9*rho^6*diff(A(rho, z), rho)^4 - 198*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), z)^2 + 108*I*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z)^3 + 9*rho^6*diff(A(rho, z), z)^4 - 12*rho^5*diff(A(rho, z), rho, rho) - 12*rho^4*diff(A(rho, z), rho) + 4*(-27*I*rho^6*diff(A(rho, z), rho)^3 - 7*I*rho^4)*diff(A(rho, z), z))*diff(A(rho, z), z, z)^2 + 12*(729*rho^6*diff(A(rho, z), rho)^6 - 9477*rho^6*diff(A(rho, z), rho)^2*diff(A(rho, z), z)^4 + 11664*I*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z)^5 + 3645*rho^6*diff(A(rho, z), z)^6 - 1458*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), rho, rho)^2 - 5832*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), rho, z)^2 - 1458*rho^6*diff(A(rho, z), rho)*diff(A(rho, z), z, z)^2 - 4374*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, rho) + 1944*I*rho^5*diff(A(rho, z), rho)^2*diff(A(rho, z), rho, z) - 5076*rho^4*diff(A(rho, z), rho)^3 + 108*(54*I*rho ...

# %%
def fitEq(expr):
    expanded_expr = expr.expand()

    latex_expr = latex(expanded_expr)

    return latex_expr


# Yardımcı fonksiyonlar
def compare_expressions(orig, trans):
    """Dönüşümleri karşılaştır"""
    if trans == 0:
        return "0"
    try:
        if bool(trans == orig):
            return None
    except:
        if str(trans) == str(orig):
            return None
    return str(latex(fitEq(trans)))

def write_transformation_section(fout, coeffs, title):
    """Dönüşüm bölümünü yaz"""
    fout.write(f"\n\\textit{{{title}:}}\n\n")
    
    for symbol, orig, trans in coeffs:
        result = compare_expressions(orig, trans)
        if result is None:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {symbol}\n\\end{{dmath}}\n\n")
        else:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {result}\n\\end{{dmath}}\n\n")

def write_transformations(fout, met, transform_type):
    """Tüm dönüşümleri yaz"""
    tr_suffix = f"_tr{transform_type}"
    
    fout.write(f"\n\\newpage\n\\underline{{{transform_type} Type transformations:}}\n")
    
    # Spin coefficients
    spin_coeffs = [
        ('\\rho', met.rhoNP.expr(), getattr(met, f'rhoNP{tr_suffix}')),
        ('\\sigma', met.sigmaNP.expr(), getattr(met, f'sigmaNP{tr_suffix}')),
        ('\\kappa', met.kappaNP.expr(), getattr(met, f'kappaNP{tr_suffix}')),
        ('\\mu', met.muNP.expr(), getattr(met, f'muNP{tr_suffix}')),
        ('\\lambda', met.lambdaNP.expr(), getattr(met, f'lambdaNP{tr_suffix}')),
        ('\\nu', met.nuNP.expr(), getattr(met, f'nuNP{tr_suffix}')),
        ('\\alpha', met.alphaNP.expr(), getattr(met, f'alphaNP{tr_suffix}')),
        ('\\beta', met.betaNP.expr(), getattr(met, f'betaNP{tr_suffix}')),
        ('\\tau', met.tauNP.expr(), getattr(met, f'tauNP{tr_suffix}')),
        ('\\pi', met.piNP.expr(), getattr(met, f'piNP{tr_suffix}')),
        ('\\epsilon', met.epsilonNP.expr(), getattr(met, f'epsilonNP{tr_suffix}')),
        ('\\gamma', met.gammaNP.expr(), getattr(met, f'gammaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, spin_coeffs, "Spin coefficients")
    
    # Weyl components
    weyl_comps = [
        ('\\Psi_0', met.Psi0NP.expr(), getattr(met, f'Psi0NP{tr_suffix}')),
        ('\\Psi_1', met.Psi1NP.expr(), getattr(met, f'Psi1NP{tr_suffix}')),
        ('\\Psi_2', met.Psi2NP.expr(), getattr(met, f'Psi2NP{tr_suffix}')),
        ('\\Psi_3', met.Psi3NP.expr(), getattr(met, f'Psi3NP{tr_suffix}')),
        ('\\Psi_4', met.Psi4NP.expr(), getattr(met, f'Psi4NP{tr_suffix}'))
    ]
    write_transformation_section(fout, weyl_comps, "Weyl components")
    
    # Ricci components
    ricci_comps = [
        ('\\Phi_{00}', met.Phi00NP.expr(), getattr(met, f'Phi00NP{tr_suffix}')),
        ('\\Phi_{01}', met.Phi01NP.expr(), getattr(met, f'Phi01NP{tr_suffix}')),
        ('\\Phi_{02}', met.Phi02NP.expr(), getattr(met, f'Phi02NP{tr_suffix}')),
        ('\\Phi_{10}', met.Phi10NP.expr(), getattr(met, f'Phi10NP{tr_suffix}')),
        ('\\Phi_{11}', met.Phi11NP.expr(), getattr(met, f'Phi11NP{tr_suffix}')),
        ('\\Phi_{12}', met.Phi12NP.expr(), getattr(met, f'Phi12NP{tr_suffix}')),
        ('\\Phi_{20}', met.Phi20NP.expr(), getattr(met, f'Phi20NP{tr_suffix}')),
        ('\\Phi_{21}', met.Phi21NP.expr(), getattr(met, f'Phi21NP{tr_suffix}')),
        ('\\Phi_{22}', met.Phi22NP.expr(), getattr(met, f'Phi22NP{tr_suffix}')),
        ('\\Lambda', met.LambdaNP.expr(), getattr(met, f'LambdaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, ricci_comps, "Ricci components")

# %%
# Latex formatında rapor dosyası oluşturmak için bu kodu kullanabilirsiniz.
# (Dosyanin adini uygun sekilde degistirmeyi unutmayin.)
fout = open('21.35.tex',"w")
tmpstr=r'''\documentclass[landscape]{article}
%\documentclass[11pt,a4paper,reqno]{amsart}
%%%%%%%%%%%%%%%%%%%%%%
\usepackage[fleqn]{amsmath} %Denklemleri sola daya
\usepackage{amssymb}
\usepackage{authblk}
\usepackage{caption}
\usepackage{cite}
\usepackage{xcolor}
\usepackage{color}
\usepackage{float}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{mdframed}
\usepackage{hyperref}
\usepackage{textcomp}
\usepackage{epstopdf}
\usepackage{subcaption}
\usepackage{lscape}
\usepackage{breqn}
%\usepackage{soul}
%%%%%%%%%%%%%%%%%%%%%%
\setlength\parindent{0pt}
\setlength{\parskip}{5pt}
\geometry{left=20mm,right=20mm,top=30mm,bottom=20mm}
\hyphenation{Schwarz-schild}
%%%%%%%%%%%%%%%%%%%%%%
\newcommand{\etalchar}[1]{$^{#1}$}
\newcommand\hl[1]{%
	\bgroup
	\hskip0pt\color{red!80!black}%
	#1%
	\egroup
}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\begin{document}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\textbf{Newman-Penrose Formalism Calculations for}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{metric:21.35} 

\textit{Name:} Stephani et al., Equation (xx.xx)



\textit{Reference(s):} \cite{stefani}

\textit{Line element:} 

\begin{dmath}'''
fout.write(tmpstr)


fout.write("ds^2 " + str(latex(met.g.display()))[2:])
fout.write(r"\end{dmath}")


fout.write(r"\textit{Coordinates:} "+str(latex(MyCoordinates[:])))
tmpstr=r'''
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{Null tetrad components: }

\textit{Covariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l= " +r"\left("+str(latex(met.lNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n= " +r"\left("+str(latex(met.nNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m= " +r"\left("+str(latex(met.mNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}= " +r"\left("+str(latex(met.mbarNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}

\textit{Contravariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l= " +r"\left("+str(latex(met.lupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n= " +r"\left("+str(latex(met.nupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m= " +r"\left("+str(latex(met.mupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}= " +r"\left("+str(latex(met.mbarupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}


\newpage
\textbf{Directional derivatives: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"D=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\Delta=" + str(latex(fitEq( met.DeltanNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\delta=" + str(latex(fitEq( met.deltamNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\overline{\delta}=" + str(latex(fitEq( met.deltambarNP(f).expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Spin coefficients: }

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\rho="+str(latex(fitEq(met.rhoNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\sigma="+str(latex(fitEq(met.sigmaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\kappa="+str(latex(fitEq(met.kappaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\mu="+str(latex(fitEq(met.muNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}


\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\lambda="+str(latex(met.lambdaNP.expr()))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\nu="+str(latex(fitEq(met.nuNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\alpha="+str(latex(fitEq(met.alphaNP.expr()))))

tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\beta="+str(latex(fitEq(met.betaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\tau="+str(latex(fitEq(met.tauNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\pi="+str(latex(fitEq(met.piNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\epsilon="+str(latex(fitEq(met.epsilonNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\gamma="+str(latex(fitEq(met.gammaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage

\textbf{Relations between spin coefficients: }


%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Ricci tensor components: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{00}="+str(latex(fitEq(met.Phi00NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{01}="+str(latex(fitEq(met.Phi01NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{02}="+str(latex(fitEq(met.Phi02NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{10}="+str(latex(fitEq(met.Phi10NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{11}="+str(latex(fitEq(met.Phi11NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{12}="+str(latex(fitEq(met.Phi12NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{20}="+str(latex(fitEq(met.Phi20NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{21}="+str(latex(fitEq(met.Phi21NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{22}="+str(latex(fitEq(met.Phi22NP.expr()))))
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Lambda="+str(latex(fitEq(met.LambdaNP.expr()))))


tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Weyl tensor components: }
\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_0="+str(latex(fitEq(met.Psi0NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_1="+str(latex(fitEq(met.Psi1NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_2="+str(latex(fitEq(met.Psi2NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_3="+str(latex(fitEq(met.Psi3NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_4="+str(latex(fitEq(met.Psi4NP.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Newman-Penrose equations: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"NP1="+str(latex(fitEq(met.NPeq1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP2="+str(latex(fitEq(met.NPeq2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP3="+str(latex(fitEq(met.NPeq3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP4="+str(latex(fitEq(met.NPeq4.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP5="+str(latex(fitEq(met.NPeq5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP6="+str(latex(fitEq(met.NPeq6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP7="+str(latex(fitEq(met.NPeq7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP8="+str(latex(fitEq(met.NPeq8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP9="+str(latex(fitEq(met.NPeq9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP10="+str(latex(fitEq(met.NPeq10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP11="+str(latex(fitEq(met.NPeq11.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP12="+str(latex(fitEq(met.NPeq12.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP13="+str(latex(fitEq(met.NPeq13.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP14="+str(latex(fitEq(met.NPeq14.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP15="+str(latex(fitEq(met.NPeq15.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP16="+str(latex(fitEq(met.NPeq16.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP17="+str(latex(fitEq(met.NPeq17.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP18="+str(latex(fitEq(met.NPeq18.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Bianchi identities: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI1="+str(latex(fitEq(met.BI1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI2="+str(latex(fitEq(met.BI2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI3="+str(latex(fitEq(met.BI3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI4="+str(latex(fitEq(met.BI4.expr())))+r' \\ '),
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI5="+str(latex(fitEq(met.BI5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI6="+str(latex(fitEq(met.BI6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI7="+str(latex(fitEq(met.BI7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI8="+str(latex(fitEq(met.BI8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI9="+str(latex(fitEq(met.BI9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI10="+str(latex(fitEq(met.BI10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI11="+str(latex(fitEq(met.BI11.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


\newpage
\textbf{Petrov classification:} \\
\vspace{2cm}
\textit{Petrov class: '''
fout.write(tmpstr)
tmpstr = r'''} 
\vspace{2cm}



%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\begin{thebibliography}{99}

\bibitem{stefani}
 H. Stephani, D. Kramer, M. MacCallum, C. Hoenselaers, and E. Herlt, Exact Solutions of Einstein’s Field Equations. Cambridge Monographs on Mathematical Physics, Cambridge University Press, 2009.
\end{thebibliography}
\begin{mdframed}
\textbf{Calculated by:}

\textit{Name:Sezin Giravioğlu} 

\textit{E-mail: giravioglu21@itu.edu.tr}

\textit{Date: 26.11.2025}
\end{mdframed}
\end{document}
'''
fout.write(tmpstr)
fout.close()

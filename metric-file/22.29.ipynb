# %%
reset()
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<t,rho,y,phi> = MyManifold.chart(r't rho:\rho y phi:\phi')


tetrad_type = 'covariant' 
########################################################
# Functions of rho
h  = function('h')(rho)
E  = function('E')(rho)
w  = function('w')(rho)
b  = function('b')(rho)

sqrt2 = sqrt(2)
########################################################


lvec = [w/sqrt2, 0, 0, sqrt(E)/(sqrt2*h)]

nvec = [w/sqrt2, 0,0,-sqrt(E)/(sqrt2*h)]

mvec = [0,exp(-b/2)/(sqrt2*h*sqrt(E)), I/(sqrt2*h), I*rho/(sqrt2*h)]

mbarvec = [0, exp(-b/2)/(sqrt2*h*sqrt(E)), -I/(sqrt2*h), -I*rho/(sqrt2*h)]



met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))

met.calculate_spincoefficients()
met.calculate_Weyl()
met.calculate_Ricci()
met.calculate_NPeq()
met.calculate_Bianchi()
met.Petrov_fromWeyl()

met.show_spincoefficients()
met.show_Weyl()
met.show_Ricci()
met.show_NPeq()
met.show_Bianchi()




def fitEq(expr):
    expanded_expr = expr.expand()

    latex_expr = latex(expanded_expr)

    return latex_expr
# Out:
# 'The metric:'
# g = -w(rho)^2 dt⊗dt + e^(-b(rho))/(E(rho)*h(rho)^2) drho⊗drho + h(rho)^(-2) dy⊗dy + rho/h(rho)^2 dy⊗dphi + rho/h(rho)^2 dphi⊗dy + (rho^2 + E(rho))/h(rho)^2 dphi⊗dphi
# Calculating spin coefficients...
# Calculating Weyl components...
# Calculating Ricci components...
# Calculating NP equations...
# Calculating Bianchi identities...
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# 'kappaNP=' 1/8*sqrt(2)*(e^(1/2*b(rho))*h(rho)*w(rho)*diff(E(rho), rho) - 2*E(rho)*e^(1/2*b(rho))*w(rho)*diff(h(rho), rho) - 2*E(rho)*e^(1/2*b(rho))*h(rho)*diff(w(rho), rho))/(sqrt(E(rho))*w(rho))
# 'tauNP=' -1/8*sqrt(2)*(e^(1/2*b(rho))*h(rho)*w(rho)*diff(E(rho), rho) - 2*E(rho)*e^(1/2*b(rho))*w(rho)*diff(h(rho), rho) + 2*E(rho)*e^(1/2*b(rho))*h(rho)*diff(w(rho), rho))/(sqrt(E(rho))*w(rho))
# 'sigmaNP=' 1/4*I*sqrt(2)*e^(1/2*b(rho))*h(rho)
# 'rhoNP=' 0
# 'piNP=' 1/8*sqrt(2)*(e^(1/2*b(rho))*h(rho)*w(rho)*diff(E(rho), rho) - 2*E(rho)*e^(1/2*b(rho))*w(rho)*diff(h(rho), rho) + 2*E(rho)*e^(1/2*b(rho))*h(rho)*diff(w(rho), rho))/(sqrt(E(rho))*w(rho))
# 'nuNP=' -1/8*sqrt(2)*(e^(1/2*b(rho))*h(rho)*w(rho)*diff(E(rho), rho) - 2*E(rho)*e^(1/2*b(rho))*w(rho)*diff(h(rho), rho) - 2*E(rho)*e^(1/2*b(rho))*h(rho)*diff(w(rho), rho))/(sqrt(E(rho))*w(rho))
# 'muNP=' 0
# 'lambdaNP=' -1/4*I*sqrt(2)*e^(1/2*b(rho))*h(rho)
# 'epsilonNP=' -1/8*I*sqrt(2)*e^(1/2*b(rho))*h(rho)
# 'gammaNP=' 1/8*I*sqrt(2)*e^(1/2*b(rho))*h(rho)
# 'betaNP=' -1/4*sqrt(2)*sqrt(E(rho))*e^(1/2*b(rho))*diff(h(rho), rho)
# 'alphaNP=' 1/4*sqrt(2)*sqrt(E(rho))*e^(1/2*b(rho))*diff(h(rho), rho)
# 'Psi0NP=' -1/16*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 4*e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) - 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + e^b(rho)*h(rho)^2*diff(E(rho), rho) + 4*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Psi1NP=' -1/16*(-I*e^b(rho)*h(rho)^2*w(rho)*diff(b(rho), rho) + 2*I*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho) + 2*I*e^b(rho)*h(rho)^2*diff(w(rho), rho))*sqrt(E(rho))/w(rho)
# 'Psi2NP=' -1/48*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) + 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) + 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 4*e^b(rho)*h(rho)^2*w(rho) + 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) - e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) + 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) - e^b(rho)*h(rho)^2*diff(E(rho), rho) + 4*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Psi3NP=' -1/16*(-I*e^b(rho)*h(rho)^2*w(rho)*diff(b(rho), rho) + 2*I*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho) + 2*I*e^b(rho)*h(rho)^2*diff(w(rho), rho))*sqrt(E(rho))/w(rho)
# 'Psi4NP=' -1/16*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 4*e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) - 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + e^b(rho)*h(rho)^2*diff(E(rho), rho) + 4*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Phi00NP=' -1/16*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) + 8*E(rho)*e^b(rho)*w(rho)*diff(h(rho), rho)^2 - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 2*e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + 3*e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) - 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + e^b(rho)*h(rho)^2*diff(E(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Phi01NP=' -1/16*(I*e^b(rho)*h(rho)^2*w(rho)*diff(b(rho), rho) - 2*I*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho) + 2*I*e^b(rho)*h(rho)^2*diff(w(rho), rho))*sqrt(E(rho))/w(rho)
# 'Phi10NP=' 1/16*(I*e^b(rho)*h(rho)^2*w(rho)*diff(b(rho), rho) - 2*I*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho) + 2*I*e^b(rho)*h(rho)^2*diff(w(rho), rho))*sqrt(E(rho))/w(rho)
# 'Phi02NP=' -1/16*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) + 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 4*e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) + 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + e^b(rho)*h(rho)^2*diff(E(rho), rho) + 4*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Phi20NP=' -1/16*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) + 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 4*e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) + 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + e^b(rho)*h(rho)^2*diff(E(rho), rho) + 4*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Phi11NP=' -1/16*(4*E(rho)*e^b(rho)*w(rho)*diff(h(rho), rho)^2 - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) - e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) - 2*(e^b(rho)*h(rho)^2*diff(E(rho), rho) - 2*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'Phi12NP=' 1/16*(I*e^b(rho)*h(rho)^2*w(rho)*diff(b(rho), rho) - 2*I*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho) + 2*I*e^b(rho)*h(rho)^2*diff(w(rho), rho))*sqrt(E(rho))/w(rho)
# 'Phi21NP=' -1/16*(I*e^b(rho)*h(rho)^2*w(rho)*diff(b(rho), rho) - 2*I*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho) + 2*I*e^b(rho)*h(rho)^2*diff(w(rho), rho))*sqrt(E(rho))/w(rho)
# 'Phi22NP=' -1/16*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) + 8*E(rho)*e^b(rho)*w(rho)*diff(h(rho), rho)^2 - 4*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) - 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + 2*e^b(rho)*h(rho)^2*w(rho) - 2*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + 3*e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) - 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + e^b(rho)*h(rho)^2*diff(E(rho), rho))*diff(w(rho), rho))/w(rho)
# 'LambdaNP=' -1/48*(e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*w(rho)*diff(E(rho), rho, rho) + 12*E(rho)*e^b(rho)*w(rho)*diff(h(rho), rho)^2 - 8*E(rho)*e^b(rho)*h(rho)*w(rho)*diff(h(rho), rho, rho) + 4*E(rho)*e^b(rho)*h(rho)^2*diff(w(rho), rho, rho) + e^b(rho)*h(rho)^2*w(rho) - 4*(E(rho)*e^b(rho)*h(rho)*w(rho)*diff(b(rho), rho) + 2*e^b(rho)*h(rho)*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) + 2*(E(rho)*e^b(rho)*h(rho)^2*diff(b(rho), rho) + 2*e^b(rho)*h(rho)^2*diff(E(rho), rho) - 2*E(rho)*e^b(rho)*h(rho)*diff(h(rho), rho))*diff(w(rho), rho))/w(rho)
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
met.calculate_PetrovinvINP()
met.calculate_PetrovinvJNP()
met.calculate_PetrovinvKNP()
met.calculate_PetrovinvLNP()
met.calculate_PetrovinvNNP()

show(met.PetrovinvINP.expr())
show(met.PetrovinvJNP.expr())
show(met.PetrovinvKNP.expr())
show(met.PetrovinvLNP.expr())
show(met.PetrovinvNNP.expr())
a=met.PetrovinvINP.expr()
b=met.PetrovinvJNP.expr()
show(bool(a^3==27*b^2))
# Out:
# 1/192*(4*e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho, rho)^2 + 16*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(h(rho), rho, rho)^2 + 16*E(rho)^2*e^(2*b(rho))*h(rho)^4*diff(w(rho), rho, rho)^2 + 16*e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho, rho) + 16*e^(2*b(rho))*h(rho)^4*w(rho)^2 + (e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho)^2 + 3*E(rho)*e^(2*b(rho))*h(rho)^4*w(rho)^2)*diff(b(rho), rho)^2 + 4*(E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(b(rho), rho)^2 + E(rho)*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(E(rho), rho)*diff(b(rho), rho) + e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(E(rho), rho)^2 + 3*E(rho)*e^(2*b(rho))*h(rho)^2*w(rho)^2)*diff(h(rho), rho)^2 + 4*(E(rho)^2*e^(2*b(rho))*h(rho)^4*diff(b(rho), rho)^2 + E(rho)*e^(2*b(rho))*h(rho)^4*diff(E(rho), rho)*diff(b(rho), rho) + e^(2*b(rho))*h(rho)^4*diff(E(rho), rho)^2 + 16*E(rho)^2*e^(2*b(rho))*h(rho)^2*diff(h(rho), rho)^2 + 3*E(rho)*e^(2*b(rho))*h(rho)^4 + 4*(2*E(rho)^2*e^(2*b(rho))*h(rho)^3*diff(b(rho), rho) + E(rho)*e^(2*b(rho))*h(rho)^3*diff(E(rho), rho))*diff(h(rho), rho))*diff(w(rho), rho)^2 + 4*(e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho)*diff(E(rho), rho, rho) + 2*e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho))*diff(b(rho), rho) - 2*(E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho)*diff(b(rho), rho)^2 + 4*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho)*diff(E(rho), rho, rho) + 8*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho) + 2*(e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho)^2 + E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho, rho) + 5*E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2)*diff(b(rho), rho))*diff(h(rho), rho) - 4*(E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho)*diff(b(rho), rho) + 2*E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho, rho) + 4*E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2 - 2*(2*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(b(rho), rho) + E(rho)*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(E(rho), rho))*diff(h(rho), rho))*diff(h(rho), rho, rho) - 2*(E(rho)*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)*diff(b(rho), rho)^2 + 4*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)*diff(E(rho), rho, rho) + 8*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho) - 8*(2*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)*diff(b(rho), rho) + E(rho)*e^(2*b(rho))*h(rho)^2*w(rho)*diff(E(rho), rho))*diff(h(rho), rho)^2 + 2*(e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)^2 + E(rho)*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho, rho) + 5*E(rho)*e^(2*b(rho))*h(rho)^4*w(rho))*diff(b(rho), rho) - 4*(E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho)^2 + e^(2*b(rho))*h(rho)^3*w(rho)*diff(E(rho), rho)^2 - 2*E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)*diff(E(rho), rho, rho) - E(rho)*e^(2*b(rho))*h(rho)^3*w(rho))*diff(h(rho), rho) - 4*(2*E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho) + E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)*diff(E(rho), rho) + 8*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)*diff(h(rho), rho))*diff(h(rho), rho, rho))*diff(w(rho), rho) - 4*(E(rho)*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*E(rho)*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho, rho) - 8*E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(h(rho), rho, rho) + 4*E(rho)*e^(2*b(rho))*h(rho)^4*w(rho) - 2*(2*E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho) + E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)*diff(E(rho), rho))*diff(h(rho), rho) - 2*(2*E(rho)^2*e^(2*b(rho))*h(rho)^4*diff(b(rho), rho) + E(rho)*e^(2*b(rho))*h(rho)^4*diff(E(rho), rho) + 8*E(rho)^2*e^(2*b(rho))*h(rho)^3*diff(h(rho), rho))*diff(w(rho), rho))*diff(w(rho), rho, rho))/w(rho)^2
# -1/27648*(16*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho, rho)^3 + 128*E(rho)^3*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(h(rho), rho, rho)^3 + 128*E(rho)^3*e^(3*b(rho))*h(rho)^6*diff(w(rho), rho, rho)^3 + 96*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho, rho)^2 + 192*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho, rho) + 128*e^(3*b(rho))*h(rho)^6*w(rho)^3 + (2*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho)^3 + 9*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho))*diff(b(rho), rho)^3 + 8*(2*E(rho)^3*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(b(rho), rho)^3 + 3*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho)^2 - 2*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho)^3 - 9*E(rho)*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho) - 3*(E(rho)*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho)^2 + 6*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^3)*diff(b(rho), rho))*diff(h(rho), rho)^3 + 8*(2*E(rho)^3*e^(3*b(rho))*h(rho)^6*diff(b(rho), rho)^3 + 3*E(rho)^2*e^(3*b(rho))*h(rho)^6*diff(E(rho), rho)*diff(b(rho), rho)^2 - 2*e^(3*b(rho))*h(rho)^6*diff(E(rho), rho)^3 + 128*E(rho)^3*e^(3*b(rho))*h(rho)^3*diff(h(rho), rho)^3 - 9*E(rho)*e^(3*b(rho))*h(rho)^6*diff(E(rho), rho) + 48*(2*E(rho)^3*e^(3*b(rho))*h(rho)^4*diff(b(rho), rho) + E(rho)^2*e^(3*b(rho))*h(rho)^4*diff(E(rho), rho))*diff(h(rho), rho)^2 - 3*(E(rho)*e^(3*b(rho))*h(rho)^6*diff(E(rho), rho)^2 + 6*E(rho)^2*e^(3*b(rho))*h(rho)^6)*diff(b(rho), rho) + 12*(2*E(rho)^3*e^(3*b(rho))*h(rho)^5*diff(b(rho), rho)^2 + 2*E(rho)^2*e^(3*b(rho))*h(rho)^5*diff(E(rho), rho)*diff(b(rho), rho) - E(rho)*e^(3*b(rho))*h(rho)^5*diff(E(rho), rho)^2 - 6*E(rho)^2*e^(3*b(rho))*h(rho)^5)*diff(h(rho), rho))*diff(w(rho), rho)^3 + 6*(4*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho)^2 + 6*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^3 + (2*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(E(rho), rho)^2 + 3*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^3)*diff(E(rho), rho, rho))*diff(b(rho), rho)^2 - 12*(E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho)^3 - 8*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)^2 - 12*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3 - 2*(E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)^2 - E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho, rho) + 4*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3)*diff(b(rho), rho)^2 - 2*(2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)^2 + 3*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3)*diff(E(rho), rho, rho) - (2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)^3 + 4*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)*diff(E(rho), rho, rho) + 17*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho))*diff(b(rho), rho))*diff(h(rho), rho)^2 - 48*(E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho) + 2*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho, rho) + 4*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3 - 2*(2*E(rho)^3*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(b(rho), rho) + E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho))*diff(h(rho), rho))*diff(h(rho), rho, rho)^2 - 12*(E(rho)^2*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho)*diff(b(rho), rho)^3 - 8*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho)^2 - 12*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho) - 32*(2*E(rho)^3*e^(3*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho) + E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)*diff(E(rho), rho))*diff(h(rho), rho)^3 - 2*(E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho)^2 - E(rho)^2*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho, rho) + 4*E(rho)^2*e^(3*b(rho))*h(rho)^6*w(rho))*diff(b(rho), rho)^2 - 16*(2*E(rho)^3*e^(3*b(rho))*h(rho)^4*w(rho)*diff(b(rho), rho)^2 + E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) - E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)^2 - 2*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho, rho) - 10*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho))*diff(h(rho), rho)^2 - 2*(2*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho)^2 + 3*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho))*diff(E(rho), rho, rho) - (2*e^(3*b(rh ...
# -1/2048*(I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^3*diff(b(rho), rho)^3 - 8*(-I*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(b(rho), rho)^2 - I*E(rho)*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho) + I*E(rho)*e^(3*b(rho))*h(rho)^3*w(rho)^3)*diff(h(rho), rho)^3 - 8*(-I*E(rho)^2*e^(3*b(rho))*h(rho)^6*diff(b(rho), rho)^2 - I*E(rho)*e^(3*b(rho))*h(rho)^6*diff(E(rho), rho)*diff(b(rho), rho) - 16*I*E(rho)^2*e^(3*b(rho))*h(rho)^4*diff(h(rho), rho)^2 + I*E(rho)*e^(3*b(rho))*h(rho)^6 + 4*(-2*I*E(rho)^2*e^(3*b(rho))*h(rho)^5*diff(b(rho), rho) - I*E(rho)*e^(3*b(rho))*h(rho)^5*diff(E(rho), rho))*diff(h(rho), rho))*diff(w(rho), rho)^3 - 4*(I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(b(rho), rho)^3 + 2*I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho)^2 + (2*I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho, rho) + I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3)*diff(b(rho), rho))*diff(h(rho), rho)^2 - 16*(I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(b(rho), rho) - 2*I*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(h(rho), rho))*diff(h(rho), rho, rho)^2 - 4*(I*E(rho)^2*e^(3*b(rho))*h(rho)^6*w(rho)*diff(b(rho), rho)^3 + 2*I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho)*diff(b(rho), rho)^2 - 32*I*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)*diff(h(rho), rho)^3 + 16*(-I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)*diff(b(rho), rho) - I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho))*diff(h(rho), rho)^2 + (2*I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)*diff(E(rho), rho, rho) + I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho))*diff(b(rho), rho) + 2*(I*E(rho)^2*e^(3*b(rho))*h(rho)^5*w(rho)*diff(b(rho), rho)^2 + I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 4*I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)*diff(E(rho), rho, rho) + 11*I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho))*diff(h(rho), rho) + 4*(-2*I*E(rho)^2*e^(3*b(rho))*h(rho)^5*w(rho)*diff(b(rho), rho) - I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)*diff(E(rho), rho) - 8*I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)*diff(h(rho), rho))*diff(h(rho), rho, rho))*diff(w(rho), rho)^2 - 16*(I*E(rho)^2*e^(3*b(rho))*h(rho)^6*w(rho)*diff(b(rho), rho) - 2*I*E(rho)^2*e^(3*b(rho))*h(rho)^5*w(rho)*diff(h(rho), rho) - 2*I*E(rho)^2*e^(3*b(rho))*h(rho)^6*diff(w(rho), rho))*diff(w(rho), rho, rho)^2 - 2*(-I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho)^3 + (-2*I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)^3*diff(E(rho), rho, rho) - I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)^3)*diff(b(rho), rho)^2)*diff(h(rho), rho) - 4*(-I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho)^2 + 4*(-2*I*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(b(rho), rho) - I*E(rho)*e^(3*b(rho))*h(rho)^3*w(rho)^3*diff(E(rho), rho))*diff(h(rho), rho)^2 + 2*(-I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)^3*diff(E(rho), rho, rho) - 2*I*E(rho)*e^(3*b(rho))*h(rho)^5*w(rho)^3)*diff(b(rho), rho) + 4*(I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(b(rho), rho)^2 + I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho)*diff(b(rho), rho) + I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3*diff(E(rho), rho, rho) + 2*I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^3)*diff(h(rho), rho))*diff(h(rho), rho, rho) - 2*(-I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^2*diff(E(rho), rho)*diff(b(rho), rho)^3 - 16*I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^2*diff(h(rho), rho, rho)^2 + 16*(-2*I*E(rho)^2*e^(3*b(rho))*h(rho)^3*w(rho)^2*diff(b(rho), rho) - I*E(rho)*e^(3*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho))*diff(h(rho), rho)^3 + (-2*I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^2*diff(E(rho), rho, rho) - I*E(rho)*e^(3*b(rho))*h(rho)^6*w(rho)^2)*diff(b(rho), rho)^2 + 4*(I*E(rho)^2*e^(3*b(rho))*h(rho)^4*w(rho)^2*diff(b(rho), rho)^2 + I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho)*diff(b(rho), rho) + 4*I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho, rho) + 11*I*E(rho)*e^(3*b(rho))*h(rho)^4*w(rho)^2)*diff(h(rho), rho)^2 + 4*(I*E(rho)^2*e^(3*b(rho))*h(rho)^5*w(rho)^2*diff(b(rho), rho)^3 + I*E(rho)*e^(3*b(rho))*h(rho)^5* ...
# -1/768*(16*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(b(rho), rho)*diff(h(rho), rho)*diff(h(rho), rho, rho) - 4*e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho, rho)^2 + 16*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(h(rho), rho, rho)^2 + 16*E(rho)^2*e^(2*b(rho))*h(rho)^4*diff(w(rho), rho, rho)^2 - 16*e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho, rho) - 16*e^(2*b(rho))*h(rho)^4*w(rho)^2 - (e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho)^2 + 3*E(rho)*e^(2*b(rho))*h(rho)^4*w(rho)^2)*diff(b(rho), rho)^2 + 4*(E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(b(rho), rho)^2 - e^(2*b(rho))*h(rho)^2*w(rho)^2*diff(E(rho), rho)^2 - 3*E(rho)*e^(2*b(rho))*h(rho)^2*w(rho)^2)*diff(h(rho), rho)^2 + 4*(E(rho)^2*e^(2*b(rho))*h(rho)^4*diff(b(rho), rho)^2 + 8*E(rho)^2*e^(2*b(rho))*h(rho)^3*diff(b(rho), rho)*diff(h(rho), rho) - e^(2*b(rho))*h(rho)^4*diff(E(rho), rho)^2 + 16*E(rho)^2*e^(2*b(rho))*h(rho)^2*diff(h(rho), rho)^2 - 3*E(rho)*e^(2*b(rho))*h(rho)^4)*diff(w(rho), rho)^2 - 4*(e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho)*diff(E(rho), rho, rho) + 2*e^(2*b(rho))*h(rho)^4*w(rho)^2*diff(E(rho), rho))*diff(b(rho), rho) + 4*(2*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho)*diff(E(rho), rho, rho) + 4*e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho) + (e^(2*b(rho))*h(rho)^3*w(rho)^2*diff(E(rho), rho)^2 + 3*E(rho)*e^(2*b(rho))*h(rho)^3*w(rho)^2)*diff(b(rho), rho))*diff(h(rho), rho) + 4*(8*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)*diff(b(rho), rho)*diff(h(rho), rho)^2 + 2*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)*diff(E(rho), rho, rho) + 4*e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho) + (e^(2*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)^2 + 3*E(rho)*e^(2*b(rho))*h(rho)^4*w(rho))*diff(b(rho), rho) + 2*(E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho)^2 - e^(2*b(rho))*h(rho)^3*w(rho)*diff(E(rho), rho)^2 - 3*E(rho)*e^(2*b(rho))*h(rho)^3*w(rho))*diff(h(rho), rho) + 4*(E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho) + 4*E(rho)^2*e^(2*b(rho))*h(rho)^2*w(rho)*diff(h(rho), rho))*diff(h(rho), rho, rho))*diff(w(rho), rho) + 16*(E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(b(rho), rho)*diff(h(rho), rho) + 2*E(rho)^2*e^(2*b(rho))*h(rho)^3*w(rho)*diff(h(rho), rho, rho) + (E(rho)^2*e^(2*b(rho))*h(rho)^4*diff(b(rho), rho) + 4*E(rho)^2*e^(2*b(rho))*h(rho)^3*diff(h(rho), rho))*diff(w(rho), rho))*diff(w(rho), rho, rho))/w(rho)^2
# 1/16384*((E(rho)*e^(4*b(rho))*h(rho)^8*w(rho)^4*diff(E(rho), rho)^2 + 3*E(rho)^2*e^(4*b(rho))*h(rho)^8*w(rho)^4)*diff(b(rho), rho)^4 - 16*(E(rho)^3*e^(4*b(rho))*h(rho)^4*w(rho)^4*diff(E(rho), rho)*diff(b(rho), rho)^3 - E(rho)*e^(4*b(rho))*h(rho)^4*w(rho)^4*diff(E(rho), rho)^2 - 3*E(rho)^2*e^(4*b(rho))*h(rho)^4*w(rho)^4 + (2*E(rho)^2*e^(4*b(rho))*h(rho)^4*w(rho)^4*diff(E(rho), rho)^2 + 3*E(rho)^3*e^(4*b(rho))*h(rho)^4*w(rho)^4)*diff(b(rho), rho)^2 + (E(rho)*e^(4*b(rho))*h(rho)^4*w(rho)^4*diff(E(rho), rho)^3 + 2*E(rho)^2*e^(4*b(rho))*h(rho)^4*w(rho)^4*diff(E(rho), rho))*diff(b(rho), rho))*diff(h(rho), rho)^4 - 16*(E(rho)^3*e^(4*b(rho))*h(rho)^8*diff(E(rho), rho)*diff(b(rho), rho)^3 + 64*E(rho)^3*e^(4*b(rho))*h(rho)^5*diff(E(rho), rho)*diff(h(rho), rho)^3 - E(rho)*e^(4*b(rho))*h(rho)^8*diff(E(rho), rho)^2 - 3*E(rho)^2*e^(4*b(rho))*h(rho)^8 + (2*E(rho)^2*e^(4*b(rho))*h(rho)^8*diff(E(rho), rho)^2 + 3*E(rho)^3*e^(4*b(rho))*h(rho)^8)*diff(b(rho), rho)^2 + 16*(3*E(rho)^3*e^(4*b(rho))*h(rho)^6*diff(E(rho), rho)*diff(b(rho), rho) + 2*E(rho)^2*e^(4*b(rho))*h(rho)^6*diff(E(rho), rho)^2 + 3*E(rho)^3*e^(4*b(rho))*h(rho)^6)*diff(h(rho), rho)^2 + (E(rho)*e^(4*b(rho))*h(rho)^8*diff(E(rho), rho)^3 + 2*E(rho)^2*e^(4*b(rho))*h(rho)^8*diff(E(rho), rho))*diff(b(rho), rho) + 4*(3*E(rho)^3*e^(4*b(rho))*h(rho)^7*diff(E(rho), rho)*diff(b(rho), rho)^2 + E(rho)*e^(4*b(rho))*h(rho)^7*diff(E(rho), rho)^3 + 2*E(rho)^2*e^(4*b(rho))*h(rho)^7*diff(E(rho), rho) + 2*(2*E(rho)^2*e^(4*b(rho))*h(rho)^7*diff(E(rho), rho)^2 + 3*E(rho)^3*e^(4*b(rho))*h(rho)^7)*diff(b(rho), rho))*diff(h(rho), rho))*diff(w(rho), rho)^4 + 4*(E(rho)*e^(4*b(rho))*h(rho)^8*w(rho)^4*diff(E(rho), rho)*diff(E(rho), rho, rho) + 2*E(rho)*e^(4*b(rho))*h(rho)^8*w(rho)^4*diff(E(rho), rho))*diff(b(rho), rho)^3 + 8*(E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)*diff(b(rho), rho)^4 - 4*E(rho)*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)*diff(E(rho), rho, rho) - 8*E(rho)*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho) + 2*(2*E(rho)^2*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)^2 + E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho, rho) + 5*E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)^4)*diff(b(rho), rho)^3 + (3*E(rho)*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)^3 + 8*E(rho)^2*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)*diff(E(rho), rho, rho) + 22*E(rho)^2*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho))*diff(b(rho), rho)^2 + 2*(4*E(rho)*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)^2 - 2*E(rho)^2*e^(4*b(rho))*h(rho)^5*w(rho)^4 + (3*E(rho)*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)^2 + 2*E(rho)^2*e^(4*b(rho))*h(rho)^5*w(rho)^4)*diff(E(rho), rho, rho))*diff(b(rho), rho))*diff(h(rho), rho)^3 + 64*(E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho)*diff(b(rho), rho) + 2*E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)^4*diff(E(rho), rho, rho) - 2*E(rho)^3*e^(4*b(rho))*h(rho)^4*w(rho)^4*diff(E(rho), rho)*diff(h(rho), rho) + 4*E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)^4)*diff(h(rho), rho, rho)^3 + 8*(E(rho)^3*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho)*diff(b(rho), rho)^4 - 128*E(rho)^3*e^(4*b(rho))*h(rho)^4*w(rho)*diff(E(rho), rho)*diff(h(rho), rho)^4 - 4*E(rho)*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho)*diff(E(rho), rho, rho) - 8*E(rho)*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho) + 2*(2*E(rho)^2*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho)^2 + E(rho)^3*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho, rho) + 5*E(rho)^3*e^(4*b(rho))*h(rho)^8*w(rho))*diff(b(rho), rho)^3 - 64*(2*E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)*diff(E(rho), rho)*diff(b(rho), rho) + 2*E(rho)^2*e^(4*b(rho))*h(rho)^5*w(rho)*diff(E(rho), rho)^2 - 2*E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho)*diff(E(rho), rho, rho) - E(rho)^3*e^(4*b(rho))*h(rho)^5*w(rho))*diff(h(rho), rho)^3 + (3*E(rho)*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho)^3 + 8*E(rho)^2*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho)*diff(E(rho), rho, rho) + 22*E(rho)^2*e^(4*b(rho))*h(rho)^8*w(rho)*diff(E(rho), rho))*diff(b(rho), rho)^2 - 8*(3*E( ...
# False

# %%
fout = open('22_29.tex',"w")
tmpstr=r'''\documentclass[landscape]{article}
%\documentclass[11pt,a4paper,reqno]{amsart}
%%%%%%%%%%%%%%%%%%%%%%
\usepackage[fleqn]{amsmath} %Denklemleri sola daya
\usepackage{amssymb}
\usepackage{authblk}
\usepackage{caption}
\usepackage{cite}
\usepackage{xcolor}
\usepackage{color}
\usepackage{float}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{mdframed}
\usepackage{hyperref}
\usepackage{textcomp}
\usepackage{epstopdf}
\usepackage{subcaption}
\usepackage{lscape}
\usepackage{breqn}
%\usepackage{soul}
%%%%%%%%%%%%%%%%%%%%%%
\setlength\parindent{0pt}
\setlength{\parskip}{5pt}
\geometry{left=20mm,right=20mm,top=30mm,bottom=20mm}
\hyphenation{Schwarz-schild}
%%%%%%%%%%%%%%%%%%%%%%
\newcommand{\etalchar}[1]{$^{#1}$}
\newcommand\hl[1]{%
	\bgroup
	\hskip0pt\color{red!80!black}%
	#1%
	\egroup
}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\begin{document}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\textbf{Newman-Penrose Formalism Calculations for}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{metric:} 

\textit{Name:} Stephani et al., Equation (22.29)

\textit{Reference(s):} \cite{stefani}

\textit{Line element:} 

\begin{dmath}'''
fout.write(tmpstr)


fout.write("ds^2 " + str(latex(met.g.display()))[2:])
fout.write(r"\end{dmath}")


fout.write(r"\textit{Coordinates:} "+str(latex(MyCoordinates[:])))
tmpstr=r'''
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{Null tetrad components: }

\textit{Covariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}

\textit{Contravariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}


\newpage
\textbf{Directional derivatives: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"D&=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\Delta&=" + str(latex(fitEq( met.DeltanNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\delta&=" + str(latex(fitEq( met.deltamNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\overline{\delta}&=" + str(latex(fitEq( met.deltambarNP(f).expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Spin coefficients: }

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\rho&="+str(latex(fitEq(met.rhoNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\sigma&="+str(latex(fitEq(met.sigmaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\kappa&="+str(latex(fitEq(met.kappaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\mu&="+str(latex(fitEq(met.muNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\lambda&="+str(latex(met.lambdaNP.expr()))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\nu&="+str(latex(fitEq(met.nuNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\alpha&="+str(latex(fitEq(met.alphaNP.expr()))))

tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\beta&="+str(latex(fitEq(met.betaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\tau&="+str(latex(fitEq(met.tauNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\pi&="+str(latex(fitEq(met.piNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\epsilon&="+str(latex(fitEq(met.epsilonNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\gamma&="+str(latex(fitEq(met.gammaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage

\textbf{Relations between spin coefficients: }
\begin{dmath}
\text{$\kappa&= \nu&= 0$}
\end{dmath}
\begin{dmath}
\text{$\rho& + \Bar{\sigma}&= 0$}
\end{dmath}
\begin{dmath}
\text{$\alpha& - \Bar{\beta}&= 0$}
\end{dmath}
\begin{dmath}
\text{$\pi& - \Bar{\tau}&= 0$}
\end{dmath}


%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Ricci tensor components: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{00}&="+str(latex(fitEq(met.Phi00NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{01}&="+str(latex(fitEq(met.Phi01NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{02}&="+str(latex(fitEq(met.Phi02NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{10}&="+str(latex(fitEq(met.Phi10NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{11}&="+str(latex(fitEq(met.Phi11NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{12}&="+str(latex(fitEq(met.Phi12NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{20}&="+str(latex(fitEq(met.Phi20NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{21}&="+str(latex(fitEq(met.Phi21NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{22}="+str(latex(fitEq(met.Phi22NP.expr()))))
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Lambda="+str(latex(fitEq(met.LambdaNP.expr()))))


tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Weyl tensor components: }
\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_0&="+str(latex(fitEq(met.Psi0NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_1&="+str(latex(fitEq(met.Psi1NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_2&="+str(latex(fitEq(met.Psi2NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_3&="+str(latex(fitEq(met.Psi3NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_4&="+str(latex(fitEq(met.Psi4NP.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Newman-Penrose equations: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"NP1&="+str(latex(fitEq(met.NPeq1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP2&="+str(latex(fitEq(met.NPeq2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP3&="+str(latex(fitEq(met.NPeq3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP4&="+str(latex(fitEq(met.NPeq4.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP5&="+str(latex(fitEq(met.NPeq5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP6&="+str(latex(fitEq(met.NPeq6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP7&="+str(latex(fitEq(met.NPeq7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP8&="+str(latex(fitEq(met.NPeq8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP9&="+str(latex(fitEq(met.NPeq9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP10&="+str(latex(fitEq(met.NPeq10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP11&="+str(latex(fitEq(met.NPeq11.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP12&="+str(latex(fitEq(met.NPeq12.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP13&="+str(latex(fitEq(met.NPeq13.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP14&="+str(latex(fitEq(met.NPeq14.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP15&="+str(latex(fitEq(met.NPeq15.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP16&="+str(latex(fitEq(met.NPeq16.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP17&="+str(latex(fitEq(met.NPeq17.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP18&="+str(latex(fitEq(met.NPeq18.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Bianchi identities: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI1&="+str(latex(fitEq(met.BI1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI2&="+str(latex(fitEq(met.BI2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI3&="+str(latex(fitEq(met.BI3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI4&="+str(latex(fitEq(met.BI4.expr())))+r' \\ '),
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI5&="+str(latex(fitEq(met.BI5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI6&="+str(latex(fitEq(met.BI6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI7&="+str(latex(fitEq(met.BI7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI8&="+str(latex(fitEq(met.BI8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI9&="+str(latex(fitEq(met.BI9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI10&="+str(latex(fitEq(met.BI10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI11&="+str(latex(fitEq(met.BI11.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


\newpage
\textbf{Petrov classification:} \\
\vspace{2cm}
\textit{Petrov class: '''
fout.write(tmpstr)
tmpstr = r'''} 
\vspace{2cm}


'''
fout.write(tmpstr)
tmpstr = r'''

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\begin{thebibliography}{99}

\bibitem{stefani}
 H. Stephani, D. Kramer, M. MacCallum, C. Hoenselaers, and E. Herlt, Exact Solutions of Einstein’s Field Equations. Cambridge Monographs on Mathematical Physics, Cambridge University Press, 2009.
\end{thebibliography}
\begin{mdframed}
\textbf{Calculated by:}

\textit{Name: } Merve Yılmaz

\textit{E-mail: } yilmazmerv21@itu.edu.tr

\textit{Date: } 08.12.2025

\end{mdframed}
\end{document}
'''
fout.write(tmpstr)
fout.close()

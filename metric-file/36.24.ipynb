# %%
reset()
import sage.libs.ecl
sage.libs.ecl.ecl_eval("(ext:set-limit 'ext:heap-size 0)")
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<x_0,x_1,x_2,x_3> = MyManifold.chart(r't x y z')

tetrad_type = 'covariant'  
def noargs(name):
    return lambda *args: name

a = function("a", print_latex_func=noargs('a'))(x_1)
b = function("b", print_latex_func=noargs('b'))(x_1)
F = function("F", print_latex_func=noargs('F'))(x_0, x_1, x_2)
G = function("G", print_latex_func=noargs('G'))(x_0, x_1, x_2)

metric_functions=[("a(x)",a),("b(x)",b),("F(t,x,y)",F),("G(t,x,y)",G)]

lvec=[1/sqrt(2), a*(F + G)/sqrt(2), 0, 1/sqrt(2)]
nvec=[1/sqrt(2), a*(F + G)/sqrt(2), 0, -1/sqrt(2)]
mvec=[0, ((derivative(F,x_0) + derivative(G,x_0)) + I*sqrt(a*b)*(F-G))/sqrt(2), I/sqrt(2), 0]
mbarvec=[0, ((derivative(F,x_0) + derivative(G,x_0)) - I*sqrt(a*b)*(F-G))/sqrt(2), -I/sqrt(2), 0]


met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))
# Out:
# 'The metric:'
# g = -dt⊗dt - (F(t, x, y) + G(t, x, y))*a(x) dt⊗dx - (F(t, x, y) + G(t, x, y))*a(x) dx⊗dt + (-(F(t, x, y)^2 + 2*F(t, x, y)*G(t, x, y) + G(t, x, y)^2)*a(x)^2 + (F(t, x, y)^2 - 2*F(t, x, y)*G(t, x, y) + G(t, x, y)^2)*a(x)*b(x) + (d(F)/dt)^2 + 2*d(F)/dt*d(G)/dt + d(G)/dt^2) dx⊗dx + (F(t, x, y) - G(t, x, y))*sqrt(a(x))*sqrt(b(x)) dx⊗dy + (F(t, x, y) - G(t, x, y))*sqrt(a(x))*sqrt(b(x)) dy⊗dx + dy⊗dy + dz⊗dz

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()

met.calculate_Weyl()
met.show_Weyl()

met.calculate_Ricci()
met.show_Ricci()

met.calculate_NPeq()
met.show_NPeq()

met.calculate_Bianchi()
met.show_Bianchi()

met.Petrov_fromWeyl()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' 1/4*sqrt(2)*a(x)
# 'tauNP=' 1/4*sqrt(2)*a(x)
# 'sigmaNP=' -1/4*((-I*sqrt(2)*diff(F(t, x, y), t) + I*sqrt(2)*diff(G(t, x, y), t))*sqrt(a(x))*sqrt(b(x)) - sqrt(2)*diff(F(t, x, y), t, t) - sqrt(2)*diff(G(t, x, y), t, t))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'rhoNP=' 1/4*((I*sqrt(2)*diff(F(t, x, y), y) + I*sqrt(2)*diff(G(t, x, y), y))*a(x) + sqrt(2)*diff(F(t, x, y), t, t) + sqrt(2)*diff(G(t, x, y), t, t))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'piNP=' -1/4*sqrt(2)*a(x)
# 'nuNP=' -1/4*sqrt(2)*a(x)
# 'muNP=' 1/4*((I*sqrt(2)*diff(F(t, x, y), y) + I*sqrt(2)*diff(G(t, x, y), y))*a(x) - sqrt(2)*diff(F(t, x, y), t, t) - sqrt(2)*diff(G(t, x, y), t, t))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'lambdaNP=' -1/4*((-I*sqrt(2)*diff(F(t, x, y), t) + I*sqrt(2)*diff(G(t, x, y), t))*sqrt(a(x))*sqrt(b(x)) + sqrt(2)*diff(F(t, x, y), t, t) + sqrt(2)*diff(G(t, x, y), t, t))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'epsilonNP=' 1/8*((I*sqrt(2)*diff(F(t, x, y), y) + I*sqrt(2)*diff(G(t, x, y), y))*a(x) + (-I*sqrt(2)*diff(F(t, x, y), t) + I*sqrt(2)*diff(G(t, x, y), t))*sqrt(a(x))*sqrt(b(x)))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'gammaNP=' 1/8*((I*sqrt(2)*diff(F(t, x, y), y) + I*sqrt(2)*diff(G(t, x, y), y))*a(x) + (-I*sqrt(2)*diff(F(t, x, y), t) + I*sqrt(2)*diff(G(t, x, y), t))*sqrt(a(x))*sqrt(b(x)))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'betaNP=' -1/4*((sqrt(2)*diff(F(t, x, y), y) - sqrt(2)*diff(G(t, x, y), y))*sqrt(a(x))*sqrt(b(x)) - I*sqrt(2)*diff(F(t, x, y), t, y) - I*sqrt(2)*diff(G(t, x, y), t, y))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# 'alphaNP=' 1/4*((sqrt(2)*diff(F(t, x, y), y) - sqrt(2)*diff(G(t, x, y), y))*sqrt(a(x))*sqrt(b(x)) + I*sqrt(2)*diff(F(t, x, y), t, y) + I*sqrt(2)*diff(G(t, x, y), t, y))/(diff(F(t, x, y), t) + diff(G(t, x, y), t))
# Calculating Weyl components...
# 'Psi0NP=' 1/4*((diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)^2 - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)*b(x) + (I*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - I*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + I*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (I*diff(F(t, x, y), t) + I*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (-I*diff(F(t, x, y), t, t) - I*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x) - 2*((diff(F(t, x, y), y)*diff(G(t, x, y), t) - diff(F(t, x, y), t)*diff(G(t, x, y), y))*a(x) + I*diff(F(t, x, y), t, t)*diff(G(t, x, y), t) - I*diff(F(t, x, y), t)*diff(G(t, x, y), t, t))*sqrt(a(x))*sqrt(b(x)) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - diff(F(t, x, y), t, t, t)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, t, t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(a(x), x))/(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)
# 'Psi1NP=' -1/16*((-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*b(x)*diff(a(x), x) + (-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*a(x)*diff(b(x), x) - 2*(((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + 4*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*I*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 + 2*(-I*diff(F(t, x, y), t)^2*diff(F(t, x, y), y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t)^2 - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), y))*a(x)*b(x) - 2*I*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, y) - 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t) - 2*I*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t)^2 + (diff(F(t, x, y), t)^2*diff(F(t, x, y), y, y) + diff(F(t, x, y), y, y)*diff(G(t, x, y), t)^2 - I*diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - I*diff(F(t, x, y), t, x))*diff(F(t, x, y), y) - (diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + I*diff(F(t, x, y), x, y))*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - I*diff(F(t, x, y), t, x) - I*diff(G(t, x, y), t, x))*diff(G(t, x, y), y) + (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), y, y))*a(x) + 2*(-I*diff(F(t, x, y), t)^2 - 2*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, y) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), y))*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + 2*(I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, t) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + (2*(-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + ((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + ((I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)^2 + 2*(diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + I*diff(F(t, x, y), t, x))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, t) - I*diff(F(t, x, y), t)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y) + (diff(F(t, ...
# 'Psi2NP=' -1/12*((diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*b(x)*diff(a(x), x) + (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)*diff(b(x), x) + ((diff(F(t, x, y), t)^3 + 2*diff(F(t, x, y), t)*diff(F(t, x, y), y)^2 + 3*diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3 + 2*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y)^2 + (3*diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), y)^2)*diff(G(t, x, y), t) + 4*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)^2 - (diff(F(t, x, y), t)^3 - 2*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + 2*diff(F(t, x, y), t)*diff(F(t, x, y), y)^2 + 2*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) - diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3 - 2*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + 2*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y)^2 - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), y)^2 - 2*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + 2*((F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t, y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (F(t, x, y) - G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) - 2*((F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t) + (F(t, x, y) - G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)*b(x) - diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, t) - 2*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y, y) - (diff(F(t, x, y), t, t, t) + 2*diff(F(t, x, y), t, y, y))*diff(G(t, x, y), t)^2 - 2*(diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) + 2*diff(F(t, x, y), t)*diff(F(t, x, y), t, y, y))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, t) - 2*(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y, y) - (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - (F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) - diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 - (F(t, x, y) + G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + ((F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) - ((F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t) + (F(t, x, y) + G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (diff(F(t, x, y), t)^2 + (F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, t) + diff(F(t, x, y), t)*diff(G(t, x, y), t) + (F(t, x, y) + G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 - (diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - diff(F(t, x, y), t, x)*diff(F(t, x, y), y) + diff(F(t, x, y), x, y)*diff(G(t, x, y), t) - diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), x, y) + (diff(F(t, x, y), t, x) + diff(G(t, x, y), t, x))*diff(G(t, x, y), y))*a(x))*b(x))/((diff(F(t, x, y), t)^3 + 3*diff(F(t, x, y), t)^2*diff(G(t, x, y), t) + 3*diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3)*sqrt(a(x))*sqrt(b(x)))
# 'Psi3NP=' 1/16*((-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*b(x)*diff(a(x), x) + (-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*a(x)*diff(b(x), x) - 2*(((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + 4*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*I*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 + 2*(-I*diff(F(t, x, y), t)^2*diff(F(t, x, y), y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t)^2 - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), y))*a(x)*b(x) - 2*I*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, y) - 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t) - 2*I*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t)^2 - (diff(F(t, x, y), t)^2*diff(F(t, x, y), y, y) + diff(F(t, x, y), y, y)*diff(G(t, x, y), t)^2 + I*diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + I*diff(F(t, x, y), t, x))*diff(F(t, x, y), y) - (diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) - I*diff(F(t, x, y), x, y))*diff(G(t, x, y), t) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + I*diff(F(t, x, y), t, x) + I*diff(G(t, x, y), t, x))*diff(G(t, x, y), y) + (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), y, y))*a(x) + 2*(-I*diff(F(t, x, y), t)^2 - 2*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, y) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), y))*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + 2*(I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, t) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + (2*(-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + ((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + ((I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)^2 - 2*(diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - diff(F(t, x, y), t, t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), t, x))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, t) + I*diff(F(t, x, y), t)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y) + (diff(F(t,  ...
# 'Psi4NP=' 1/4*((diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)^2 - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)*b(x) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + I*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t, t) + I*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x) - 2*((diff(F(t, x, y), y)*diff(G(t, x, y), t) - diff(F(t, x, y), t)*diff(G(t, x, y), y))*a(x) - I*diff(F(t, x, y), t, t)*diff(G(t, x, y), t) + I*diff(F(t, x, y), t)*diff(G(t, x, y), t, t))*sqrt(a(x))*sqrt(b(x)) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - diff(F(t, x, y), t, t, t)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, t, t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(a(x), x))/(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)
# Calculating Ricci components...
# 'Phi00NP=' 1/8*((2*diff(F(t, x, y), t)^2 + diff(F(t, x, y), y)^2 + 4*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*diff(G(t, x, y), t)^2 + 2*diff(F(t, x, y), y)*diff(G(t, x, y), y) + diff(G(t, x, y), y)^2)*a(x)^2 + 2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)^(3/2)*sqrt(b(x)) - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)*b(x) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - 2*diff(F(t, x, y), t, t, t)*diff(G(t, x, y), t) - 2*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, t, t) - 2*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(a(x), x))/(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)
# 'Phi01NP=' 1/16*((-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*b(x)*diff(a(x), x) + (-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*a(x)*diff(b(x), x) - 2*(((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + 4*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*I*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 + 2*(-I*diff(F(t, x, y), t)^2*diff(F(t, x, y), y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t)^2 - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), y))*a(x)*b(x) - 2*I*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, y) - 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t) - 2*I*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t)^2 + (diff(F(t, x, y), t)^2*diff(F(t, x, y), y, y) + diff(F(t, x, y), y, y)*diff(G(t, x, y), t)^2 - I*diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - I*diff(F(t, x, y), t, x))*diff(F(t, x, y), y) - (diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + I*diff(F(t, x, y), x, y))*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - I*diff(F(t, x, y), t, x) - I*diff(G(t, x, y), t, x))*diff(G(t, x, y), y) + (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), y, y))*a(x) + 2*(-I*diff(F(t, x, y), t)^2 - 2*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, y) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), y))*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + 2*(I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, t) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + (2*(-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + ((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + ((I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)^2 + 2*(diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + I*diff(F(t, x, y), t, x))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, t) - I*diff(F(t, x, y), t)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y) + (diff(F(t, ...
# 'Phi10NP=' -1/16*((-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*b(x)*diff(a(x), x) + (-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*a(x)*diff(b(x), x) - 2*(((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + 4*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*I*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 + 2*(-I*diff(F(t, x, y), t)^2*diff(F(t, x, y), y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t)^2 - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), y))*a(x)*b(x) - 2*I*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, y) - 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t) - 2*I*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t)^2 - (diff(F(t, x, y), t)^2*diff(F(t, x, y), y, y) + diff(F(t, x, y), y, y)*diff(G(t, x, y), t)^2 + I*diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + I*diff(F(t, x, y), t, x))*diff(F(t, x, y), y) - (diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) - I*diff(F(t, x, y), x, y))*diff(G(t, x, y), t) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + I*diff(F(t, x, y), t, x) + I*diff(G(t, x, y), t, x))*diff(G(t, x, y), y) + (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), y, y))*a(x) + 2*(-I*diff(F(t, x, y), t)^2 - 2*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, y) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), y))*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + 2*(I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, t) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + (2*(-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + ((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + ((I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)^2 - 2*(diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - diff(F(t, x, y), t, t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), t, x))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, t) + I*diff(F(t, x, y), t)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y) + (diff(F(t ...
# 'Phi02NP=' -1/4*((diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)^2 - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)*b(x) + (I*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - I*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + I*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (I*diff(F(t, x, y), t) + I*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (-I*diff(F(t, x, y), t, t) - I*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x) - 2*((diff(F(t, x, y), y)*diff(G(t, x, y), t) - diff(F(t, x, y), t)*diff(G(t, x, y), y))*a(x) + I*diff(F(t, x, y), t, t)*diff(G(t, x, y), t) - I*diff(F(t, x, y), t)*diff(G(t, x, y), t, t))*sqrt(a(x))*sqrt(b(x)) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - diff(F(t, x, y), t, t, t)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, t, t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(a(x), x))/(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)
# 'Phi20NP=' -1/4*((diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)^2 - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)*b(x) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + I*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t, t) + I*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x) - 2*((diff(F(t, x, y), y)*diff(G(t, x, y), t) - diff(F(t, x, y), t)*diff(G(t, x, y), y))*a(x) - I*diff(F(t, x, y), t, t)*diff(G(t, x, y), t) + I*diff(F(t, x, y), t)*diff(G(t, x, y), t, t))*sqrt(a(x))*sqrt(b(x)) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - diff(F(t, x, y), t, t, t)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, t, t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(a(x), x))/(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)
# 'Phi11NP=' 1/16*(2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*b(x)*diff(a(x), x) + 2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)*diff(b(x), x) + (3*(diff(F(t, x, y), t)*diff(F(t, x, y), y)^2 + diff(F(t, x, y), y)^2*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y)^2 + 2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)^2 - (diff(F(t, x, y), t)^3 - 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + 4*diff(F(t, x, y), t)*diff(F(t, x, y), y)^2 + 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) - diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3 - 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + 4*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y)^2 - (diff(F(t, x, y), t)^2 - 4*diff(F(t, x, y), y)^2 - 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + 4*((F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t, y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (F(t, x, y) - G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) - 4*((F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t) + (F(t, x, y) - G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)*b(x) - 4*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y, y) - 8*diff(F(t, x, y), t)*diff(F(t, x, y), t, y, y)*diff(G(t, x, y), t) - 4*diff(F(t, x, y), t, y, y)*diff(G(t, x, y), t)^2 - 4*(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y, y))*sqrt(a(x))*sqrt(b(x)) - 2*((2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) - diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 - 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (diff(F(t, x, y), t)^2 - 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) - 2*((F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t) + (F(t, x, y) + G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (diff(F(t, x, y), t)^2 + 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, t) - diff(G(t, x, y), t)^2 + 2*(F(t, x, y) + G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 - 2*(diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - diff(F(t, x, y), t, x)*diff(F(t, x, y), y) + diff(F(t, x, y), x, y)*diff(G(t, x, y), t) - diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), x, y) + (diff(F(t, x, y), t, x) + diff(G(t, x, y), t, x))*diff(G(t, x, y), y))*a(x))*b(x))/((diff(F(t, x, y), t)^3 + 3*diff(F(t, x, y), t)^2*diff(G(t, x, y), t) + 3*diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3)*sqrt(a(x))*sqrt(b(x)))
# 'Phi12NP=' 1/16*((-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*b(x)*diff(a(x), x) + (-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*a(x)*diff(b(x), x) - 2*(((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + 4*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*I*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 + 2*(-I*diff(F(t, x, y), t)^2*diff(F(t, x, y), y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t)^2 - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), y))*a(x)*b(x) - 2*I*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, y) - 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t) - 2*I*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t)^2 + (diff(F(t, x, y), t)^2*diff(F(t, x, y), y, y) + diff(F(t, x, y), y, y)*diff(G(t, x, y), t)^2 - I*diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - I*diff(F(t, x, y), t, x))*diff(F(t, x, y), y) - (diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + I*diff(F(t, x, y), x, y))*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - I*diff(F(t, x, y), t, x) - I*diff(G(t, x, y), t, x))*diff(G(t, x, y), y) + (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), y, y))*a(x) + 2*(-I*diff(F(t, x, y), t)^2 - 2*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, y) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), y))*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + 2*(I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, t) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + (2*(-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + ((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + ((I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)^2 + 2*(diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + I*diff(F(t, x, y), t, x))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, t) - I*diff(F(t, x, y), t)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y) + (diff(F(t, ...
# 'Phi21NP=' -1/16*((-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*b(x)*diff(a(x), x) + (-I*diff(F(t, x, y), t)^2 + I*diff(G(t, x, y), t)^2)*a(x)*diff(b(x), x) - 2*(((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + 2*I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) + ((I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + (2*I*diff(F(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + 4*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*I*diff(G(t, x, y), t)^2 + (-I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 + 2*(-I*diff(F(t, x, y), t)^2*diff(F(t, x, y), y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + I*diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, y) + (I*diff(F(t, x, y), t)^2 - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), y))*a(x)*b(x) - 2*I*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, y) - 4*I*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t) - 2*I*diff(F(t, x, y), t, t, y)*diff(G(t, x, y), t)^2 - (diff(F(t, x, y), t)^2*diff(F(t, x, y), y, y) + diff(F(t, x, y), y, y)*diff(G(t, x, y), t)^2 + I*diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + I*diff(F(t, x, y), t, x))*diff(F(t, x, y), y) - (diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) - I*diff(F(t, x, y), x, y))*diff(G(t, x, y), t) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), x, y) - (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), t, y)*diff(G(t, x, y), t) + (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, y) + I*diff(F(t, x, y), t, x) + I*diff(G(t, x, y), t, x))*diff(G(t, x, y), y) + (diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), y, y))*a(x) + 2*(-I*diff(F(t, x, y), t)^2 - 2*I*diff(F(t, x, y), t)*diff(G(t, x, y), t) - I*diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, y) + (-I*diff(F(t, x, y), t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (-I*diff(F(t, x, y), t) - I*diff(G(t, x, y), t))*diff(G(t, x, y), y))*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*(((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) + 2*(I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t)*diff(G(t, x, y), t, t) + (-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) + (2*(-I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t, t) + (I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) + ((-I*F(t, x, y) + I*G(t, x, y))*diff(F(t, x, y), t, y) + (-I*F(t, x, y) + I*G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + ((I*F(t, x, y) - I*G(t, x, y))*diff(F(t, x, y), t) + (I*F(t, x, y) - I*G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)^2 - 2*(diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y) - diff(F(t, x, y), t)*diff(F(t, x, y), t, t)*diff(F(t, x, y), y) + (diff(F(t, x, y), t)*diff(F(t, x, y), t, y) - diff(F(t, x, y), t, t)*diff(F(t, x, y), y) - I*diff(F(t, x, y), t, x))*diff(G(t, x, y), t) - (diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), t, t) + I*diff(F(t, x, y), t)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y) + (diff(F(t ...
# 'Phi22NP=' 1/8*((2*diff(F(t, x, y), t)^2 + diff(F(t, x, y), y)^2 + 4*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 2*diff(G(t, x, y), t)^2 + 2*diff(F(t, x, y), y)*diff(G(t, x, y), y) + diff(G(t, x, y), y)^2)*a(x)^2 + 2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)^(3/2)*sqrt(b(x)) - (diff(F(t, x, y), t)^2 - 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*a(x)*b(x) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - 2*diff(F(t, x, y), t, t, t)*diff(G(t, x, y), t) - 2*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), t, t, t) - 2*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(a(x), x))/(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)
# 'LambdaNP=' 1/48*(2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*b(x)*diff(a(x), x) + 2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)*diff(b(x), x) - ((4*diff(F(t, x, y), t)^3 - diff(F(t, x, y), t)*diff(F(t, x, y), y)^2 + 12*diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + 4*diff(G(t, x, y), t)^3 - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y)^2 + (12*diff(F(t, x, y), t)^2 - diff(F(t, x, y), y)^2)*diff(G(t, x, y), t) - 2*(diff(F(t, x, y), t)*diff(F(t, x, y), y) + diff(F(t, x, y), y)*diff(G(t, x, y), t))*diff(G(t, x, y), y))*a(x)^2 - (diff(F(t, x, y), t)^3 + 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t, y)*diff(F(t, x, y), y) - 4*diff(F(t, x, y), t)*diff(F(t, x, y), y)^2 - 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), y, y) - diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3 + 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, y) - 4*(diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), y)^2 - (diff(F(t, x, y), t)^2 + 4*diff(F(t, x, y), y)^2 + 4*(F(t, x, y) - G(t, x, y))*diff(F(t, x, y), y, y))*diff(G(t, x, y), t) - 4*((F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t, y) - 2*diff(F(t, x, y), t)*diff(F(t, x, y), y) - 2*diff(F(t, x, y), y)*diff(G(t, x, y), t) + (F(t, x, y) - G(t, x, y))*diff(G(t, x, y), t, y))*diff(G(t, x, y), y) + 4*((F(t, x, y) - G(t, x, y))*diff(F(t, x, y), t) + (F(t, x, y) - G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), y, y))*a(x)*b(x) - 4*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, t, t) + 4*diff(F(t, x, y), t)^2*diff(F(t, x, y), t, y, y) - 4*(diff(F(t, x, y), t, t, t) - diff(F(t, x, y), t, y, y))*diff(G(t, x, y), t)^2 - 8*(diff(F(t, x, y), t)*diff(F(t, x, y), t, t, t) - diff(F(t, x, y), t)*diff(F(t, x, y), t, y, y))*diff(G(t, x, y), t) - 4*(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, t, t) + 4*(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(G(t, x, y), t, y, y) - 4*(diff(F(t, x, y), t)^2 + 2*diff(F(t, x, y), t)*diff(G(t, x, y), t) + diff(G(t, x, y), t)^2)*diff(a(x), x))*sqrt(a(x))*sqrt(b(x)) - 2*((2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t)*diff(F(t, x, y), t, y) + diff(F(t, x, y), y)*diff(G(t, x, y), t)^2 - 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), y)*diff(G(t, x, y), t, t) + (3*diff(F(t, x, y), t)^2 - 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, t))*diff(F(t, x, y), y) + 2*((F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, y) + 2*diff(F(t, x, y), t)*diff(F(t, x, y), y))*diff(G(t, x, y), t) - 2*((F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t) + (F(t, x, y) + G(t, x, y))*diff(G(t, x, y), t))*diff(G(t, x, y), t, y) - (diff(F(t, x, y), t)^2 - 2*(F(t, x, y) + G(t, x, y))*diff(F(t, x, y), t, t) + 4*diff(F(t, x, y), t)*diff(G(t, x, y), t) + 3*diff(G(t, x, y), t)^2 - 2*(F(t, x, y) + G(t, x, y))*diff(G(t, x, y), t, t))*diff(G(t, x, y), y))*a(x)^2 - 2*(diff(F(t, x, y), t)*diff(F(t, x, y), x, y) - diff(F(t, x, y), t, x)*diff(F(t, x, y), y) + diff(F(t, x, y), x, y)*diff(G(t, x, y), t) - diff(F(t, x, y), y)*diff(G(t, x, y), t, x) - (diff(F(t, x, y), t) + diff(G(t, x, y), t))*diff(G(t, x, y), x, y) + (diff(F(t, x, y), t, x) + diff(G(t, x, y), t, x))*diff(G(t, x, y), y))*a(x))*b(x))/((diff(F(t, x, y), t)^3 + 3*diff(F(t, x, y), t)^2*diff(G(t, x, y), t) + 3*diff(F(t, x, y), t)*diff(G(t, x, y), t)^2 + diff(G(t, x, y), t)^3)*sqrt(a(x))*sqrt(b(x)))
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# Calculating Bianchi identities...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#      10 met.calculate_NPeq()
#      11 met.show_NPeq()
# ---> 13 met.calculate_Bianchi()
#      14 met.show_Bianchi()
#      16 met.Petrov_fromWeyl()
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:925, in NewmanPenrose.calculate_Bianchi(self)
#     921 self.BI7=-self.DlNP(self.Psi3NP) + self.deltambarNP(self.Psi2NP) + self.DlNP(self.Phi21NP) -self.deltamNP(self.Phi20NP) + _sage_const_2 *self.deltambarNP(self.LambdaNP) - self.kappaNP*self.Psi4NP + _sage_const_2 *(self.rhoNP-self.epsilonNP)*self.Psi3NP + _sage_const_3 *self.piNP*self.Psi2NP - _sage_const_2 *self.lambdaNP*self.Psi1NP + (_sage_const_2 *self.alphabarNP-_sage_const_2 *self.betaNP - self.pibarNP)*self.Phi20NP - _sage_const_2 *(self.rhobarNP-self.epsilonNP)*self.Phi21NP - _sage_const_2 *self.piNP*self.Phi11NP + _sage_const_2 *self.muNP*self.Phi10NP + self.kappabarNP*self.Phi22NP
#     923 self.BI8=-self.DeltanNP(self.Psi1NP) + self.deltamNP(self.Psi2NP) + self.DeltanNP(self.Phi01NP) - self.deltambarNP(self.Phi02NP) + _sage_const_2 *self.deltamNP(self.LambdaNP) + self.nuNP*self.Psi0NP + _sage_const_2 *(self.gammaNP-self.muNP)*self.Psi1NP - _sage_const_3 *self.tauNP*self.Psi2NP + _sage_const_2 *self.sigmaNP*self.Psi3NP + (self.taubarNP - _sage_const_2 *self.betabarNP + _sage_const_2 *self.alphaNP)*self.Phi02NP + _sage_const_2 *(self.mubarNP - self.gammaNP)*self.Phi01NP + _sage_const_2 *self.tauNP*self.Phi11NP-_sage_const_2 *self.rhoNP*self.Phi12NP-self.nubarNP*self.Phi00NP
# --> 925 self.BI9=-self.DlNP(self.Phi11NP) + self.deltamNP(self.Phi10NP) + self.deltambarNP(self.Phi01NP) - self.DeltanNP(self.Phi00NP) - _sage_const_3 *self.DlNP(self.LambdaNP) + (_sage_const_2 *self.gammaNP - self.muNP + _sage_const_2 *self.gammabarNP - self.mubarNP)*self.Phi00NP + (self.piNP - _sage_const_2 *self.alphaNP - _sage_const_2 *self.taubarNP)*self.Phi01NP + (self.pibarNP - _sage_const_2 *self.alphabarNP - _sage_const_2 *self.tauNP)*self.Phi10NP + _sage_const_2 *(self.rhoNP+self.rhobarNP)*self.Phi11NP + self.sigmabarNP*self.Phi02NP + self.sigmaNP*self.Phi20NP - self.kappabarNP*self.Phi12NP - self.kappaNP*self.Phi21NP
#     927 self.BI10=-self.DlNP(self.Phi12NP) + self.deltamNP(self.Phi11NP) + self.deltambarNP(self.Phi02NP) - self.DeltanNP(self.Phi01NP) - _sage_const_3 *self.deltamNP(self.LambdaNP) + (-_sage_const_2 *self.alphaNP + _sage_const_2 *self.betabarNP + self.piNP - self.taubarNP)*self.Phi02NP + (self.rhobarNP + _sage_const_2 *self.rhoNP - _sage_const_2 *self.epsilonbarNP)*self.Phi12NP + _sage_const_2 *(self.pibarNP - self.tauNP)*self.Phi11NP + (_sage_const_2 *self.gammaNP - _sage_const_2 *self.mubarNP - self.muNP)*self.Phi01NP + self.nubarNP*self.Phi00NP - self.lambdabarNP*self.Phi10NP + self.sigmaNP*self.Phi21NP - self.kappaNP*self.Phi22NP
#     929 self.BI11=-self.DlNP(self.Phi22NP) + self.deltamNP(self.Phi21NP) + self.deltambarNP(self.Phi12NP) - self.DeltanNP(self.Phi11NP) - _sage_const_3 *self.DeltanNP(self.LambdaNP) + (self.rhoNP + self.rhobarNP - _sage_const_2 *self.epsilonNP - _sage_const_2 *self.epsilonbarNP)*self.Phi22NP + (_sage_const_2 *self.betabarNP + _sage_const_2 *self.piNP - self.taubarNP)*self.Phi12NP + (_sage_const_2 *self.betaNP + _sage_const_2 *self.pibarNP - self.tauNP)*self.Phi21NP - _sage_const_2 *(self.muNP+self.mubarNP)*self.Phi11NP + self.nuNP*self.Phi01NP + self.nubarNP*self.Phi10NP - self.lambdabarNP*self.Phi20NP - self.lambdaNP*self.Phi02NP
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:720, in NewmanPenrose.deltambarNP(self, X)
#     718     return _sage_const_0
#     719 else:
# --> 720     return self.mbarupNP['^i']*self.nab(X)['_i']
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/tensor/modules/tensor_with_indices.py:652, in TensorWithIndices.__mul__(self, other)
#     650 pos2 = [contraction_pairs[i][1] for i in range(ncontr)]
#     651 args = pos1 + [other._tensor] + pos2
# --> 652 return self._tensor.contract(*args)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/differentiable/tensorfield_paral.py:1806, in TensorFieldParal.contract(self, *args)
#    1733 r"""
#    1734 Contraction with another tensor field, on one or more indices.
#    1735
#    (...)   1802     for more examples.
#    1803 """
#    1804 # This is to ensure the call to the TensorField version instead of
#    1805 # the FreeModuleTensor one
# -> 1806 return TensorField.contract(self, *args)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/differentiable/tensorfield.py:3361, in TensorField.contract(self, *args)
#    3358 if ambient_dom_resu.is_manifestly_parallelizable():
#    3359     # call of the FreeModuleTensor version:
#    3360     args = pos1 + (other_r,) + pos2
# -> 3361     return FreeModuleTensor.contract(self_r, *args)
#    3362 com_dom = []
#    3363 for dom in self_r._restrictions:
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/tensor/modules/free_module_tensor.py:2795, in FreeModuleTensor.contract(self, *args)
#    2793     raise ValueError("no common basis for the contraction")
#    2794 args = pos1 + (other._components[basis],) + pos2
# -> 2795 cmp_res = self._components[basis].contract(*args)
#    2796 if self._tensor_rank + other._tensor_rank - 2*ncontr == 0:
#    2797     # Case of scalar output:
#    2798     return cmp_res
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/tensor/modules/comp.py:2222, in Components.contract(self, *args)
#    2220         res = 0
#    2221         for ind_s, ind_o in ind_pairs:
# -> 2222             res += self[[ind_s]] * other[[ind_o]]
#    2224     return res
#    2226 #
#    2227 # Positions of self and other indices in the result
#    2228 #  (None = the position is involved in a contraction and therefore
#    2229 #   does not appear in the final result)
#    2230 #
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:1224, in sage.structure.element.Element.__add__ (build/cythonized/sage/structure/element.c:20356)()
#    1222 cdef int cl = classify_elements(left, right)
#    1223 if HAVE_SAME_PARENT(cl):
# -> 1224     return (<Element>left)._add_(right)
#    1225 # Left and right are Sage elements => use coercion model
#    1226 if BOTH_ARE_ELEMENT(cl):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:2381, in sage.structure.element.ModuleElement._add_ (build/cythonized/sage/structure/element.c:25214)()
#    2379 Generic element of a module.
#    2380 """
# -> 2381 cpdef _add_(self, other):
#    2382     """
#    2383     Abstract addition method.
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/scalarfield.py:2677, in ScalarField._add_(self, other)
#    2674 result = type(self)(self.parent())
#    2675 for chart in com_charts:
#    2676     # ChartFunction addition:
# -> 2677     result._express[chart] = self._express[chart] + other._express[chart]
#    2678 if self._name is not None and other._name is not None:
#    2679     result._name = self._name + '+' + other._name
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:1224, in sage.structure.element.Element.__add__ (build/cythonized/sage/structure/element.c:20356)()
#    1222 cdef int cl = classify_elements(left, right)
#    1223 if HAVE_SAME_PARENT(cl):
# -> 1224     return (<Element>left)._add_(right)
#    1225 # Left and right are Sage elements => use coercion model
#    1226 if BOTH_ARE_ELEMENT(cl):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:2381, in sage.structure.element.ModuleElement._add_ (build/cythonized/sage/structure/element.c:25214)()
#    2379 Generic element of a module.
#    2380 """
# -> 2381 cpdef _add_(self, other):
#    2382     """
#    2383     Abstract addition method.
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/chart_func.py:1305, in ChartFunction._add_(self, other)
#    1303     res = other._simplify(self.expr() + other.expr())
#    1304 else:
# -> 1305     res = self._simplify(self.expr() + other.expr())
#    1306 if curr == 'SR' and res.is_trivial_zero():
#    1307     # NB: "if res == 0" would be too expensive (cf. #22859)
#    1308     return self.parent().zero()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/chart_func.py:410, in ChartFunction._simplify(self, expr)
#     389 def _simplify(self, expr):
#     390     """
#     391     Simplify the expression `expr` using `self._calc_method.simplify`.
#     392
#    (...)    408         2*x
#     409     """
# --> 410     res = self._calc_method.simplify(expr)
#     411     if self._expansion_symbol is not None and self._calc_method._current == 'SR':
#     412         res = res.series(self._expansion_symbol, self._order + 1).truncate()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/calculus_method.py:272, in CalculusMethod.simplify(self, expression, method)
#     270 if method is None:
#     271     method = self._current
# --> 272 return self._simplify_dict[method](expression)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/utilities.py:602, in simplify_chain_real(expr)
#     600 expr = expr.canonicalize_radical()
#     601 expr = expr.simplify_log('one')
# --> 602 expr = expr.simplify_rational()
#     603 expr = expr.simplify_trig()
#     604 return expr
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:11119, in sage.symbolic.expression.Expression.simplify_rational (build/cythonized/sage/symbolic/expression.cpp:111149)()
#   11117     ((x + 2)^2 + (x + 1)*x)/((x + 2)^2*(x + 1))
#   11118 """
# > 11119 self_m = self._maxima_()
#   11120 if algorithm == 'full':
#   11121     maxima_method = 'fullratsimp'
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:1217, in sage.symbolic.expression.Expression._maxima_ (build/cythonized/sage/symbolic/expression.cpp:51009)()
#    1215     # Maybe not such a great idea because the "default" interface is another one
#    1216     from sage.calculus.calculus import maxima
# -> 1217     return super()._interface_(maxima)
#    1218 else:
#    1219     return super()._interface_(session)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/sage_object.pyx:723, in sage.structure.sage_object.SageObject._interface_ (build/cythonized/sage/structure/sage_object.c:9257)()
#     721     except Exception:
#     722         raise NotImplementedError("coercion of object %s to %s not implemented" % (repr(self), I))
# --> 723 X = I(s)
#     724 if c:
#     725     try:
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:299, in Interface.__call__(self, x, name)
#     296         pass
#     298 if isinstance(x, str):
# --> 299     return cls(self, x, name=name)
#     300 try:
#     301     # Special methods do not and should not have an option to
#     302     # set the name directly, as the identifier assigned by the
#     303     # interface should stay consistent. An identifier with a
#     304     # user-assigned name might change its value, so we return a
#     305     # new element.
#     306     result = self._coerce_from_special_method(x)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:753, in InterfaceElement.__init__(self, parent, value, is_name, name)
#     751 else:
#     752     try:
# --> 753         self._name = parent._create(value, name=name)
#     754     except (TypeError, RuntimeError, ValueError) as x:
#     755         raise TypeError(x)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:624, in MaximaLib._create(self, value, name)
#     622         maxima_eval([[msetq], cadadr("#$%s$#$" % name), value])
#     623     else:
# --> 624         self.set(name, value)
#     625 except RuntimeError as error:
#     626     s = str(error)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:534, in MaximaLib.set(self, var, value)
#     532     raise TypeError
#     533 cmd = '%s : %s$' % (var, value.rstrip(';'))
# --> 534 self.eval(cmd)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:480, in MaximaLib._eval_line(self, line, locals, reformat, **kwds)
#     478         line = line[ind_dollar + 1:]
#     479         if statement:
# --> 480             maxima_eval("#$%s$" % statement)
#     481 if not reformat:
#     482     return result
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:12202)()
#     826     """
#     827     lispargs = EclObject(list(args))
# --> 828     return ecl_wrap(ecl_safe_apply(self.obj, (<EclObject>lispargs).obj))
#     829
#     830 def __richcmp__(left, right, int op):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:354, in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:9658)()
#     352 message = ecl_string_to_python(error)
#     353 if "Console interrupt" in message:
# --> 354     raise KeyboardInterrupt("ECL says: {}".format(message))
#     355 else:
#     356     raise RuntimeError("ECL says: {}".format(message))
#
# KeyboardInterrupt: ECL says: Console interrupt.

# %%
met.petrovtype='I'

# %%
from pathlib import Path
fout = open('36.24.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def latex_write(fout, lhs, rhs_expr):
    """
    Uzun LaTeX ifadelerini \\frac sinirlarinda keserek yazar.
    Kisa ifadeler (<5500 karakter) dogrudan yazilir.
    Uzun ifadeler uygun bir \\frac noktasindan kesilip {} \\dots ile bitirilir.
    """
    my_expression = str(rhs_expr)

    if len(my_expression) < 5500:
        fout.write(r"\begin{dmath*}" + "\n")
        fout.write(lhs + " = " + my_expression + "\n")
        fout.write(r"\end{dmath*}" + "\n\n")
    else:
        count_oparan = 0
        count_cparan = 0
        last_frac_locations = []
        for i in range(min(5000, len(my_expression))):
            if my_expression[i] == "{":
                count_oparan += 1
            elif my_expression[i] == "}":
                count_cparan += 1
            if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                last_frac_locations.append(i)

        if len(last_frac_locations) > 2:
            fout.write(r"\begin{dmath*}" + "\n")
            fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
            fout.write(r"\end{dmath*}" + "\n\n")
        else:
            i = 5000
            while i < min(200000, len(my_expression)):
                if my_expression[i] == "{":
                    count_oparan += 1
                elif my_expression[i] == "}":
                    count_cparan += 1
                if len(my_expression) <= i + 5:
                    # Ifade tamamen taranabildi, hepsini yaz
                    fout.write(r"\begin{dmath*}" + "\n")
                    fout.write(lhs + " = " + my_expression + "\n")
                    fout.write(r"\end{dmath*}" + "\n\n")
                    return
                if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                    last_frac_locations.append(i)
                    if len(last_frac_locations) > 2:
                        break
                i += 1

            if not last_frac_locations or last_frac_locations[-1] == 0:
                # Uygun kesme noktasi bulunamadi, yine de yaz
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")
            else:
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")


def write_dmath(fout, lhs, rhs):
    """latex_write ile uzun ifade truncation destekli yazim."""
    latex_write(fout, lhs, rhs)

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# tex dosyasi olusturuldu.

# %%
reset()

from SageNP import NewmanPenrose

########################################################
# Define 4-dim. the manifold:
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
########################################################
MyCoordinates.<t,z,r,phi> = MyManifold.chart(r't z r phi')
###################################################
# Define the metric functions
G_1 = function('G_1',imag_part_func=0)(z)
G_2 = function('G_2',imag_part_func=0)(z)
G_3 = function('G_3',imag_part_func=0)(z)
G_4 = function('G_4',imag_part_func=0)(z)
G_5 = function('G_5',imag_part_func=0)(z)
V = function('V',imag_part_func=0)(t,z,r,phi)
F = function('F',imag_part_func=0)(t)
var('epsilon')
#epsilon=-1,1
epsilon = -1
#V = G_1*integral(F^-1, t)+G_2+F*(G_3*r*cos(phi)+G_4*r*sin(phi)+epsilon*G_5*sqrt(1+epsilon*r^2))

assume(r-1>0)

########################################################
# Parametre belirleyin: (tetradlarınızın tipine göre aşağıdaki kısmı tanımlayın.)
tetrad_type = 'covariant'  # 'covariant' ya da 'contravariant' olabilir.
###################################################
# Enter null tetrad elements
# These vectors define the Static Spherical spacetime
lvec=[sqrt(1/2), -sqrt(1/2)*V, 0, 0]
nvec=[sqrt(1/2), sqrt(1/2)*V, 0, 0]
mvec=[0, 0, sqrt(1/2)*F*(1/sqrt(1+epsilon*r^2)), sqrt(1/2)*F*r*I]
mbarvec=[0, 0, sqrt(1/2)*F*(1/sqrt(1+epsilon*r^2)), -sqrt(1/2)*F*r*I]
########################################################
# Define the object "met" of the class "SageNP":
met=NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
########################################################
#f fonksiyonu derivative operatörleri hesaplamak için kullanılıyor.(bu satırı değiştirmeyin!)
f=MyManifold.scalar_field(function('f')(*MyCoordinates))
# Out:
# 'The metric:'
# g = -dt⊗dt + V(t, z, r, phi)^2 dz⊗dz - F(t)^2/(r^2 - 1) dr⊗dr + r^2*F(t)^2 dphi⊗dphi

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()

met.calculate_Weyl()
met.show_Weyl()
met.calculate_Ricci()
met.show_Ricci()
met.calculate_NPeq()
met.show_NPeq()

met.calculate_Bianchi()
met.show_Bianchi()

met.Petrov_fromWeyl()

met.petrovtype='I'
# Out:
# Calculating spin coefficients...
# 'kappaNP=' 1/4*(sqrt(2)*sqrt(r + 1)*sqrt(r - 1)*r*diff(V(t, z, r, phi), r) + I*sqrt(2)*diff(V(t, z, r, phi), phi))/(r*F(t)*V(t, z, r, phi))
# 'tauNP=' -1/4*(sqrt(2)*sqrt(r + 1)*sqrt(r - 1)*r*diff(V(t, z, r, phi), r) + I*sqrt(2)*diff(V(t, z, r, phi), phi))/(r*F(t)*V(t, z, r, phi))
# 'sigmaNP=' -1/2*sqrt(2)*diff(F(t), t)/F(t)
# 'rhoNP=' 0
# 'piNP=' 1/4*(sqrt(2)*sqrt(r + 1)*sqrt(r - 1)*r*diff(V(t, z, r, phi), r) - I*sqrt(2)*diff(V(t, z, r, phi), phi))/(r*F(t)*V(t, z, r, phi))
# 'nuNP=' -1/4*(sqrt(2)*sqrt(r + 1)*sqrt(r - 1)*r*diff(V(t, z, r, phi), r) - I*sqrt(2)*diff(V(t, z, r, phi), phi))/(r*F(t)*V(t, z, r, phi))
# 'muNP=' 0
# 'lambdaNP=' 1/2*sqrt(2)*diff(F(t), t)/F(t)
# 'epsilonNP=' -1/4*sqrt(2)*diff(V(t, z, r, phi), t)/V(t, z, r, phi)
# 'gammaNP=' 1/4*sqrt(2)*diff(V(t, z, r, phi), t)/V(t, z, r, phi)
# 'betaNP=' 0
# 'alphaNP=' 0
# Calculating Weyl components...
# 'Psi0NP=' -1/2*(I*r*diff(V(t, z, r, phi), r, phi) - I*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1)/(r^2*F(t)^2*V(t, z, r, phi))
# 'Psi1NP=' 1/4*((r*F(t)*diff(V(t, z, r, phi), t, r) - r*diff(F(t), t)*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) + I*F(t)*diff(V(t, z, r, phi), t, phi) - I*diff(F(t), t)*diff(V(t, z, r, phi), phi))/(r*F(t)^2*V(t, z, r, phi))
# 'Psi2NP=' 0
# 'Psi3NP=' 1/4*((r*F(t)*diff(V(t, z, r, phi), t, r) - r*diff(F(t), t)*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) - I*F(t)*diff(V(t, z, r, phi), t, phi) + I*diff(F(t), t)*diff(V(t, z, r, phi), phi))/(r*F(t)^2*V(t, z, r, phi))
# 'Psi4NP=' 1/2*(I*r*diff(V(t, z, r, phi), r, phi) - I*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1)/(r^2*F(t)^2*V(t, z, r, phi))
# Calculating Ricci components...
# 'Phi00NP=' -1/4*(2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - (2*r^3 - r)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*diff(V(t, z, r, phi), r, r) + diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'Phi01NP=' 1/4*((r*F(t)*diff(V(t, z, r, phi), t, r) - r*diff(F(t), t)*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) + I*F(t)*diff(V(t, z, r, phi), t, phi) - I*diff(F(t), t)*diff(V(t, z, r, phi), phi))/(r*F(t)^2*V(t, z, r, phi))
# 'Phi10NP=' 1/4*((r*F(t)*diff(V(t, z, r, phi), t, r) - r*diff(F(t), t)*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) - I*F(t)*diff(V(t, z, r, phi), t, phi) + I*diff(F(t), t)*diff(V(t, z, r, phi), phi))/(r*F(t)^2*V(t, z, r, phi))
# 'Phi02NP=' -1/4*(r^2*V(t, z, r, phi)*diff(F(t), t)^2 - r^2*F(t)^2*diff(V(t, z, r, phi), t, t) + r^2*V(t, z, r, phi) - 2*(-I*r*diff(V(t, z, r, phi), r, phi) + I*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1))/(r^2*F(t)^2*V(t, z, r, phi))
# 'Phi20NP=' -1/4*(r^2*V(t, z, r, phi)*diff(F(t), t)^2 - r^2*F(t)^2*diff(V(t, z, r, phi), t, t) + r^2*V(t, z, r, phi) + 2*(-I*r*diff(V(t, z, r, phi), r, phi) + I*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1))/(r^2*F(t)^2*V(t, z, r, phi))
# 'Phi11NP=' 1/8*(r^2*V(t, z, r, phi)*diff(F(t), t)^2 - r^2*F(t)^2*diff(V(t, z, r, phi), t, t) + r^2*V(t, z, r, phi) - r*diff(V(t, z, r, phi), r) - (r^4 - r^2)*diff(V(t, z, r, phi), r, r) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'Phi12NP=' 1/4*((r*F(t)*diff(V(t, z, r, phi), t, r) - r*diff(F(t), t)*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) + I*F(t)*diff(V(t, z, r, phi), t, phi) - I*diff(F(t), t)*diff(V(t, z, r, phi), phi))/(r*F(t)^2*V(t, z, r, phi))
# 'Phi21NP=' 1/4*((r*F(t)*diff(V(t, z, r, phi), t, r) - r*diff(F(t), t)*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) - I*F(t)*diff(V(t, z, r, phi), t, phi) + I*diff(F(t), t)*diff(V(t, z, r, phi), phi))/(r*F(t)^2*V(t, z, r, phi))
# 'Phi22NP=' -1/4*(2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - (2*r^3 - r)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*diff(V(t, z, r, phi), r, r) + diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'LambdaNP=' 1/12*(r^2*V(t, z, r, phi)*diff(F(t), t)^2 + 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) + r^2*F(t)^2*diff(V(t, z, r, phi), t, t) + r^2*V(t, z, r, phi) + (2*r^3 - r)*diff(V(t, z, r, phi), r) + (r^4 - r^2)*diff(V(t, z, r, phi), r, r) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# Calculating NP equations...
# 'NPeq1=' 1/4*(2*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) + (3*r^3 - r)*diff(V(t, z, r, phi), r) + 2*(r^4 - r^2)*diff(V(t, z, r, phi), r, r) - I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq2=' 1/4*(2*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) + r^3*diff(V(t, z, r, phi), r) + (r^4 - r^2)*diff(V(t, z, r, phi), r, r) + I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq3=' 0
# 'NPeq4=' -1/2*sqrt(r + 1)*sqrt(r - 1)*diff(F(t), t)*diff(V(t, z, r, phi), r)/(F(t)^2*V(t, z, r, phi))
# 'NPeq5=' -1/2*sqrt(r + 1)*sqrt(r - 1)*diff(F(t), t)*diff(V(t, z, r, phi), r)/(F(t)^2*V(t, z, r, phi))
# 'NPeq6=' 1/24*(r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 4*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 4*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) + 7*r^2*F(t)^2*diff(V(t, z, r, phi), t, t) + r^2*V(t, z, r, phi) - (4*r^3 + r)*diff(V(t, z, r, phi), r) - 5*(r^4 - r^2)*diff(V(t, z, r, phi), r, r) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq7=' -1/4*(3*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - r^2*F(t)^2*diff(V(t, z, r, phi), t, t) - r^3*diff(V(t, z, r, phi), r) + r^2*V(t, z, r, phi) - (r^4 - r^2)*diff(V(t, z, r, phi), r, r) + I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi) + diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq8=' -1/12*(4*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 4*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 4*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - 2*r^2*F(t)^2*diff(V(t, z, r, phi), t, t) - 2*r^2*V(t, z, r, phi) - (7*r^3 - 2*r)*diff(V(t, z, r, phi), r) - 5*(r^4 - r^2)*diff(V(t, z, r, phi), r, r) - 3*I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq9=' 0
# 'NPeq10=' -1/4*(2*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) + r^3*diff(V(t, z, r, phi), r) + (r^4 - r^2)*diff(V(t, z, r, phi), r, r) - I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq11=' 0
# 'NPeq12=' 1/24*(17*r^2*V(t, z, r, phi)*diff(F(t), t)^2 + 4*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 4*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - r^2*F(t)^2*diff(V(t, z, r, phi), t, t) + 5*r^2*V(t, z, r, phi) + (4*r^3 - 5*r)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*diff(V(t, z, r, phi), r, r) - 5*diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq13=' 0
# 'NPeq14=' 1/4*(2*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) + (3*r^3 - r)*diff(V(t, z, r, phi), r) + 2*(r^4 - r^2)*diff(V(t, z, r, phi), r, r) + I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq15=' -1/2*sqrt(r + 1)*sqrt(r - 1)*diff(F(t), t)*diff(V(t, z, r, phi), r)/(F(t)^2*V(t, z, r, phi))
# 'NPeq16=' -1/4*(3*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 2*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 2*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - r^2*F(t)^2*diff(V(t, z, r, phi), t, t) - r^3*diff(V(t, z, r, phi), r) + r^2*V(t, z, r, phi) - (r^4 - r^2)*diff(V(t, z, r, phi), r, r) - I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi) + diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq17=' 1/12*(4*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - 4*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) - 4*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t) - 2*r^2*F(t)^2*diff(V(t, z, r, phi), t, t) - 2*r^2*V(t, z, r, phi) - (7*r^3 - 2*r)*diff(V(t, z, r, phi), r) - 5*(r^4 - r^2)*diff(V(t, z, r, phi), r, r) + 3*I*sqrt(r + 1)*sqrt(r - 1)*diff(V(t, z, r, phi), phi) - diff(V(t, z, r, phi), phi, phi))/(r^2*F(t)^2*V(t, z, r, phi))
# 'NPeq18=' 1/2*sqrt(r + 1)*sqrt(r - 1)*diff(F(t), t)*diff(V(t, z, r, phi), r)/(F(t)^2*V(t, z, r, phi))
# Calculating Bianchi identities...
# 'BI1=' -1/8*sqrt(2)*(-4*I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, phi) + I*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), phi) - I*r^2*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), phi) - 3*(I*r^4 - I*r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, phi) - 3*I*r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi) + (I*r^3 - I*r)*diff(V(t, z, r, phi), r)*diff(V(t, z, r, phi), phi) + (r^3*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), r) + (r^4 - r^2)*diff(V(t, z, r, phi), r)^2 - (4*r^4 - r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r) - (r^5 - r^3)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, r) - r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi, phi) - (2*r^3*V(t, z, r, phi)*diff(F(t), t)^2 - r^3*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + (2*r^3 + r)*V(t, z, r, phi) + r*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) + (3*I*r^2*V(t, z, r, phi)*diff(F(t), t)^2 + I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + (-I*r^2 + 4*I)*V(t, z, r, phi))*diff(V(t, z, r, phi), phi) - I*diff(V(t, z, r, phi), phi)*diff(V(t, z, r, phi), phi, phi) + I*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi, phi))/(r^3*F(t)^3*V(t, z, r, phi)^2)
# 'BI2=' 1/8*sqrt(2)*(r^2*V(t, z, r, phi)^3*diff(F(t), t)^3 - 2*r^2*F(t)*V(t, z, r, phi)^2*diff(F(t), t)^2*diff(V(t, z, r, phi), t) + r^2*F(t)^3*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, t, t) + r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, z) + 2*r^3*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r) - r^2*F(t)^3*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), z) + r^2*V(t, z, r, phi)^3*diff(F(t), t) + 2*(r^4 - r^2)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r, r) - 2*(2*r^3 - r)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r) - 2*(r^4 - r^2)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, r) - 2*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi, phi) + 4*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi, phi) - 2*(-2*I*r*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, phi) - I*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi) + 3*I*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1) + (r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t) - r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t))*diff(V(t, z, r, phi), t, t))/(r^2*F(t)^3*V(t, z, r, phi)^3)
# 'BI3=' -1/8*sqrt(2)*(r^2*V(t, z, r, phi)^3*diff(F(t), t)^3 - 2*r^2*F(t)*V(t, z, r, phi)^2*diff(F(t), t)^2*diff(V(t, z, r, phi), t) + r^2*F(t)^3*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, t, t) - r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, z) + 2*r^3*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r) + r^2*F(t)^3*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), z) + r^2*V(t, z, r, phi)^3*diff(F(t), t) + 2*(r^4 - r^2)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r, r) - 2*(2*r^3 - r)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r) - 2*(r^4 - r^2)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, r) - 2*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi, phi) + 4*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi, phi) + 2*(-2*I*r*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, phi) - I*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi) + 3*I*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1) + (r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t) - r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t))*diff(V(t, z, r, phi), t, t))/(r^2*F(t)^3*V(t, z, r, phi)^3)
# 'BI4=' 1/8*sqrt(2)*(4*I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, phi) - I*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), phi) + I*r^2*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), phi) - 3*(-I*r^4 + I*r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, phi) + 3*I*r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi) + (-I*r^3 + I*r)*diff(V(t, z, r, phi), r)*diff(V(t, z, r, phi), phi) + (r^3*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), r) + (r^4 - r^2)*diff(V(t, z, r, phi), r)^2 - (4*r^4 - r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r) - (r^5 - r^3)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, r) - r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi, phi) - (2*r^3*V(t, z, r, phi)*diff(F(t), t)^2 - r^3*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + (2*r^3 + r)*V(t, z, r, phi) + r*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), r))*sqrt(r + 1)*sqrt(r - 1) + (-3*I*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + (I*r^2 - 4*I)*V(t, z, r, phi))*diff(V(t, z, r, phi), phi) + I*diff(V(t, z, r, phi), phi)*diff(V(t, z, r, phi), phi, phi) - I*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi, phi))/(r^3*F(t)^3*V(t, z, r, phi)^2)
# 'BI5=' -1/24*sqrt(2)*(r^2*V(t, z, r, phi)^3*diff(F(t), t)^3 - 6*r^2*F(t)*V(t, z, r, phi)^3*diff(F(t), t)*diff(F(t), t, t) + 2*r^2*F(t)^2*V(t, z, r, phi)^3*diff(F(t), t, t, t) - 2*r^2*F(t)^2*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t)^2 - 2*r^2*F(t)^3*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, t, t) - 2*r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, z) + 2*r^2*F(t)^2*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, z) + r^2*V(t, z, r, phi)^3*diff(F(t), t) - (16*r^3 - 5*r)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r) - 11*(r^4 - r^2)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r, r) + 2*(13*r^3 - 5*r)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r) + 16*(r^4 - r^2)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, r) - F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi, phi) + (2*r^3 - r)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r) + (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r, r) - 4*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi, phi) - F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, phi, phi) - 6*(2*I*r*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, phi) - I*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi) - I*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1) + (10*r^2*F(t)*V(t, z, r, phi)^2*diff(F(t), t)^2 + 2*r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t, t) - (2*r^3 - r)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r) + F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), t) - (7*r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t) - 2*r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t))*diff(V(t, z, r, phi), t, t) - (2*r^2*F(t)^2*diff(F(t), t)*diff(V(t, z, r, phi), t) - 2*r^2*F(t)^3*diff(V(t, z, r, phi), t, t) + (2*r^3 - r)*F(t)*diff(V(t, z, r, phi), r) + (r^4 - r^2)*F(t)*diff(V(t, z, r, phi), r, r) - F(t)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), z))/(r^2*F(t)^3*V(t, z, r, phi)^3)
# 'BI6=' -1/24*sqrt(2)*(r^2*V(t, z, r, phi)^3*diff(F(t), t)^3 - 6*r^2*F(t)*V(t, z, r, phi)^3*diff(F(t), t)*diff(F(t), t, t) + 2*r^2*F(t)^2*V(t, z, r, phi)^3*diff(F(t), t, t, t) - 2*r^2*F(t)^2*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t)^2 - 2*r^2*F(t)^3*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, t, t) + 2*r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, z) - 2*r^2*F(t)^2*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, z) + r^2*V(t, z, r, phi)^3*diff(F(t), t) - (16*r^3 - 5*r)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r) - 11*(r^4 - r^2)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r, r) + 2*(13*r^3 - 5*r)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r) + 16*(r^4 - r^2)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, r) - F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi, phi) - (2*r^3 - r)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r) - (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r, r) - 4*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi, phi) + F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, phi, phi) + 6*(2*I*r*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, phi) - I*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi) - I*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi))*sqrt(r + 1)*sqrt(r - 1) + (10*r^2*F(t)*V(t, z, r, phi)^2*diff(F(t), t)^2 + 2*r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t, t) - (2*r^3 - r)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r) + F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), t) - (7*r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t) - 2*r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t))*diff(V(t, z, r, phi), t, t) + (2*r^2*F(t)^2*diff(F(t), t)*diff(V(t, z, r, phi), t) - 2*r^2*F(t)^3*diff(V(t, z, r, phi), t, t) + (2*r^3 - r)*F(t)*diff(V(t, z, r, phi), r) + (r^4 - r^2)*F(t)*diff(V(t, z, r, phi), r, r) - F(t)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), z))/(r^2*F(t)^3*V(t, z, r, phi)^3)
# 'BI7=' 1/24*sqrt(2)*(-5*I*r^2*F(t)^2*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, phi) - 10*I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, phi) + I*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), phi) + 2*I*r^2*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), phi) - 8*(I*r^4 - I*r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, phi) - 2*(-I*r^3 + 5*I*r)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi) + (I*r^3 - 2*I*r)*diff(V(t, z, r, phi), r)*diff(V(t, z, r, phi), phi) + (-I*r^4 + I*r^2)*diff(V(t, z, r, phi), r, r)*diff(V(t, z, r, phi), phi) - (r^3*F(t)^2*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, r) + 2*r^3*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, r) + r^3*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), r) - r^3*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), r) + (r^4 - 2*r^2)*diff(V(t, z, r, phi), r)^2 - 2*(r^5 - r^3)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, r) - 4*r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi, phi) - (6*r^3*V(t, z, r, phi)*diff(F(t), t)^2 - 3*r^3*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*(2*r^3 + r)*V(t, z, r, phi) + 2*r*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), r) - (2*(4*r^4 - r^2)*V(t, z, r, phi) + (r^5 - r^3)*diff(V(t, z, r, phi), r))*diff(V(t, z, r, phi), r, r) + 2*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi))*sqrt(r + 1)*sqrt(r - 1) - 3*(-3*I*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + (I*r^2 - 4*I)*V(t, z, r, phi))*diff(V(t, z, r, phi), phi) - 2*I*diff(V(t, z, r, phi), phi)*diff(V(t, z, r, phi), phi, phi) + 2*I*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi, phi))/(r^3*F(t)^3*V(t, z, r, phi)^2)
# 'BI8=' 1/24*sqrt(2)*(5*I*r^2*F(t)^2*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, phi) + 10*I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, phi) - I*r^2*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), phi) - 2*I*r^2*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), phi) - 8*(-I*r^4 + I*r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, phi) - 2*(I*r^3 - 5*I*r)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi) + (-I*r^3 + 2*I*r)*diff(V(t, z, r, phi), r)*diff(V(t, z, r, phi), phi) + (I*r^4 - I*r^2)*diff(V(t, z, r, phi), r, r)*diff(V(t, z, r, phi), phi) - (r^3*F(t)^2*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, r) + 2*r^3*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, r) + r^3*F(t)*diff(F(t), t)*diff(V(t, z, r, phi), t)*diff(V(t, z, r, phi), r) - r^3*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), r) + (r^4 - 2*r^2)*diff(V(t, z, r, phi), r)^2 - 2*(r^5 - r^3)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, r) - 4*r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi, phi) - (6*r^3*V(t, z, r, phi)*diff(F(t), t)^2 - 3*r^3*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + 2*(2*r^3 + r)*V(t, z, r, phi) + 2*r*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), r) - (2*(4*r^4 - r^2)*V(t, z, r, phi) + (r^5 - r^3)*diff(V(t, z, r, phi), r))*diff(V(t, z, r, phi), r, r) + 2*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi))*sqrt(r + 1)*sqrt(r - 1) - 3*(3*I*r^2*V(t, z, r, phi)*diff(F(t), t)^2 + I*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t, t) + (-I*r^2 + 4*I)*V(t, z, r, phi))*diff(V(t, z, r, phi), phi) + 2*I*diff(V(t, z, r, phi), phi)*diff(V(t, z, r, phi), phi, phi) - 2*I*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi, phi))/(r^3*F(t)^3*V(t, z, r, phi)^2)
# 'BI9=' -1/16*sqrt(2)*(2*r^2*V(t, z, r, phi)^3*diff(F(t), t)^3 - 6*r^2*F(t)*V(t, z, r, phi)^3*diff(F(t), t)*diff(F(t), t, t) - r^2*F(t)^3*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, t, t) - r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, z) + 2*r^2*V(t, z, r, phi)^3*diff(F(t), t) - (12*r^3 - 5*r)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r) - 7*(r^4 - r^2)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r, r) + 10*(2*r^3 - r)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r) + 10*(r^4 - r^2)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, r) + F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi, phi) + r*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r) + (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r, r) - 6*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi, phi) + F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, phi, phi) + (8*r^2*F(t)*V(t, z, r, phi)^2*diff(F(t), t)^2 - r*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r) - F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), t) - (4*r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t) - r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t))*diff(V(t, z, r, phi), t, t) + (r^2*F(t)^3*diff(V(t, z, r, phi), t, t) - r*F(t)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*F(t)*diff(V(t, z, r, phi), r, r) - F(t)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), z))/(r^2*F(t)^3*V(t, z, r, phi)^3)
# 'BI10=' 1/16*(-I*sqrt(2)*r^2*F(t)^2*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, phi) - 8*I*sqrt(2)*r^2*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, phi) + I*sqrt(2)*r^2*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), phi) - 7*I*sqrt(2)*r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi) - I*sqrt(2)*r*diff(V(t, z, r, phi), r)*diff(V(t, z, r, phi), phi) - 7*(I*sqrt(2)*r^4 - I*sqrt(2)*r^2)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, phi) + (-I*sqrt(2)*r^4 + I*sqrt(2)*r^2)*diff(V(t, z, r, phi), r, r)*diff(V(t, z, r, phi), phi) - I*sqrt(2)*diff(V(t, z, r, phi), phi)*diff(V(t, z, r, phi), phi, phi) + I*sqrt(2)*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi, phi) + (3*sqrt(2)*r^3*F(t)^2*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, r) - 16*sqrt(2)*r^3*F(t)*V(t, z, r, phi)*diff(F(t), t)*diff(V(t, z, r, phi), t, r) + sqrt(2)*r^3*F(t)^2*diff(V(t, z, r, phi), t, t)*diff(V(t, z, r, phi), r) - sqrt(2)*r^2*diff(V(t, z, r, phi), r)^2 - 3*sqrt(2)*r*V(t, z, r, phi)*diff(V(t, z, r, phi), r, phi, phi) - 3*(sqrt(2)*r^5 - sqrt(2)*r^3)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r, r) + 2*sqrt(2)*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi) + (12*sqrt(2)*r^3*V(t, z, r, phi)*diff(F(t), t)^2 - sqrt(2)*r*diff(V(t, z, r, phi), phi, phi) - (4*sqrt(2)*r^3 + sqrt(2)*r)*V(t, z, r, phi))*diff(V(t, z, r, phi), r) - ((10*sqrt(2)*r^4 - sqrt(2)*r^2)*V(t, z, r, phi) + (sqrt(2)*r^5 - sqrt(2)*r^3)*diff(V(t, z, r, phi), r))*diff(V(t, z, r, phi), r, r))*sqrt(r + 1)*sqrt(r - 1) - 8*(-I*sqrt(2)*r^2*V(t, z, r, phi)*diff(F(t), t)^2 - I*sqrt(2)*V(t, z, r, phi))*diff(V(t, z, r, phi), phi))/(r^3*F(t)^3*V(t, z, r, phi)^2)
# 'BI11=' -1/16*sqrt(2)*(2*r^2*V(t, z, r, phi)^3*diff(F(t), t)^3 - 6*r^2*F(t)*V(t, z, r, phi)^3*diff(F(t), t)*diff(F(t), t, t) - r^2*F(t)^3*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, t, t) + r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t, t, z) + 2*r^2*V(t, z, r, phi)^3*diff(F(t), t) - (12*r^3 - 5*r)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r) - 7*(r^4 - r^2)*F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, r, r) + 10*(2*r^3 - r)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r) + 10*(r^4 - r^2)*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), r, r) + F(t)*V(t, z, r, phi)^2*diff(V(t, z, r, phi), t, phi, phi) - r*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r) - (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, r, r) - 6*V(t, z, r, phi)^2*diff(F(t), t)*diff(V(t, z, r, phi), phi, phi) - F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), z, phi, phi) + (8*r^2*F(t)*V(t, z, r, phi)^2*diff(F(t), t)^2 - r*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), r, r) - F(t)*V(t, z, r, phi)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), t) - (4*r^2*F(t)^2*V(t, z, r, phi)^2*diff(F(t), t) - r^2*F(t)^3*V(t, z, r, phi)*diff(V(t, z, r, phi), t))*diff(V(t, z, r, phi), t, t) - (r^2*F(t)^3*diff(V(t, z, r, phi), t, t) - r*F(t)*diff(V(t, z, r, phi), r) - (r^4 - r^2)*F(t)*diff(V(t, z, r, phi), r, r) - F(t)*diff(V(t, z, r, phi), phi, phi))*diff(V(t, z, r, phi), z))/(r^2*F(t)^3*V(t, z, r, phi)^3)
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.

# %%
from pathlib import Path
fout = open('37.51_2.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def write_dmath(fout, lhs, rhs):
    fout.write("\\begin{dmath*}\n")
    fout.write(f"{lhs} = {rhs}\n")
    fout.write("\\end{dmath*}\n\n")

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# tex dosyasi olusturuldu.

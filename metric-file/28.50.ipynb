# %%
os.chdir('/mnt/c/Users/victu/Documents')
os.getcwd()

import os
print(os.getcwd())
# Out:
# /mnt/c/Users/victu/Documents

# %%
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<u,r,x,y> = MyManifold.chart(r'u r x y')
tetrad_type = 'covariant'  
m=function('m')(u)
P=function('P')(u,x,y)
P_u = diff(P, u)
delta = P^2*diff(P,x)*diff(P,y)
A = delta*log(P) - r*P_u/P - m/r

q=function('q')(u)
fx=function('fx')(x,y)
fy=function('fy')(x,y)
var('k0')
B=k0 * q^4*(fx^2 + fy^2)/(2*r^2)
lvec=[1,0,0,0]
nvec=[A-B,1,0,0]
mvec=[0, 0, r/(sqrt(2)*P), I*r/(sqrt(2)*P)]
mbarvec=[0, 0, r/(sqrt(2)*P), -I*r/(sqrt(2)*P)]


met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))

met.calculate_spincoefficients()
met.calculate_Weyl()
met.calculate_Ricci()
met.calculate_NPeq()
met.calculate_Bianchi()
met.Petrov_fromWeyl()

met.show_spincoefficients()
met.show_Weyl()
met.show_Ricci()
met.show_NPeq()
met.show_Bianchi()
# Out:
# 'The metric:'
# g = (k0*P(u, x, y)*fx(x, y)^2*q(u)^4 + k0*P(u, x, y)*fy(x, y)^2*q(u)^4 - 2*r^2*P(u, x, y)^3*log(P(u, x, y))*d(P)/dx*d(P)/dy + 2*r^3*d(P)/du + 2*r*P(u, x, y)*m(u))/(r^2*P(u, x, y)) du⊗du - du⊗dr - dr⊗du + r^2/P(u, x, y)^2 dx⊗dx + r^2/P(u, x, y)^2 dy⊗dy
# Calculating spin coefficients...
# Calculating Weyl components...
# Calculating Ricci components...
# Calculating NP equations...
# Calculating Bianchi identities...
# Calculating Petrov Type...
# Petrov Type II
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# 'kappaNP=' 0
# 'tauNP=' 0
# 'sigmaNP=' 0
# 'rhoNP=' 1/r
# 'piNP=' 0
# 'nuNP=' 1/2*(sqrt(2)*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), x, y) - I*sqrt(2)*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y, y) - sqrt(2)*k0*P(u, x, y)^2*fx(x, y)*q(u)^4*diff(fx(x, y), x) + I*sqrt(2)*k0*P(u, x, y)^2*fx(x, y)*q(u)^4*diff(fx(x, y), y) - sqrt(2)*k0*P(u, x, y)^2*fy(x, y)*q(u)^4*diff(fy(x, y), x) + I*sqrt(2)*k0*P(u, x, y)^2*fy(x, y)*q(u)^4*diff(fy(x, y), y) - sqrt(2)*r^3*P(u, x, y)*diff(P(u, x, y), u, x) + I*sqrt(2)*r^3*P(u, x, y)*diff(P(u, x, y), u, y) + sqrt(2)*r^3*diff(P(u, x, y), u)*diff(P(u, x, y), x) + (-2*I*sqrt(2)*r^2*P(u, x, y)^3*log(P(u, x, y)) - I*sqrt(2)*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)*diff(P(u, x, y), y)^2 + (sqrt(2)*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, x) - I*sqrt(2)*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, y) - I*sqrt(2)*r^3*diff(P(u, x, y), u) + (2*sqrt(2)*r^2*P(u, x, y)^3*log(P(u, x, y)) + sqrt(2)*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)^2)*diff(P(u, x, y), y))/(r^3*P(u, x, y))
# 'muNP=' -1/2*(k0*fx(x, y)^2*q(u)^4 + k0*fy(x, y)^2*q(u)^4 - 2*r^2*P(u, x, y)^2*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y) + 2*r*m(u))/r^3
# 'lambdaNP=' 0
# 'epsilonNP=' 0
# 'gammaNP=' -1/2*(k0*P(u, x, y)*fx(x, y)^2*q(u)^4 + k0*P(u, x, y)*fy(x, y)^2*q(u)^4 - r^3*diff(P(u, x, y), u) + r*P(u, x, y)*m(u))/(r^3*P(u, x, y))
# 'betaNP=' -1/4*(sqrt(2)*diff(P(u, x, y), x) + I*sqrt(2)*diff(P(u, x, y), y))/r
# 'alphaNP=' 1/4*(sqrt(2)*diff(P(u, x, y), x) - I*sqrt(2)*diff(P(u, x, y), y))/r
# 'Psi0NP=' 0
# 'Psi1NP=' 0
# 'Psi2NP=' -1/6*(6*k0*fx(x, y)^2*q(u)^4 + 6*k0*fy(x, y)^2*q(u)^4 - 2*r^2*P(u, x, y)^2*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y) - r^2*diff(P(u, x, y), x)^2 + r^2*P(u, x, y)*diff(P(u, x, y), x, x) - r^2*diff(P(u, x, y), y)^2 + r^2*P(u, x, y)*diff(P(u, x, y), y, y) + 6*r*m(u))/r^4
# 'Psi3NP=' 1/2*(sqrt(2)*r^2*P(u, x, y)^3*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), x, y) - I*sqrt(2)*r^2*P(u, x, y)^3*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y, y) - 2*sqrt(2)*k0*P(u, x, y)*fx(x, y)*q(u)^4*diff(fx(x, y), x) + 2*I*sqrt(2)*k0*P(u, x, y)*fx(x, y)*q(u)^4*diff(fx(x, y), y) - 2*sqrt(2)*k0*P(u, x, y)*fy(x, y)*q(u)^4*diff(fy(x, y), x) + 2*I*sqrt(2)*k0*P(u, x, y)*fy(x, y)*q(u)^4*diff(fy(x, y), y) + (-2*I*sqrt(2)*r^2*P(u, x, y)^2*log(P(u, x, y)) - I*sqrt(2)*r^2*P(u, x, y)^2)*diff(P(u, x, y), x)*diff(P(u, x, y), y)^2 + (sqrt(2)*r^2*P(u, x, y)^3*log(P(u, x, y))*diff(P(u, x, y), x, x) - I*sqrt(2)*r^2*P(u, x, y)^3*log(P(u, x, y))*diff(P(u, x, y), x, y) + (2*sqrt(2)*r^2*P(u, x, y)^2*log(P(u, x, y)) + sqrt(2)*r^2*P(u, x, y)^2)*diff(P(u, x, y), x)^2)*diff(P(u, x, y), y))/r^4
# 'Psi4NP=' 1/2*(r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), x, x, y) - 2*I*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, y)^2 - 2*I*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), x, y, y) - r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y, y, y) - k0*P(u, x, y)^2*q(u)^4*diff(fx(x, y), x)^2 - k0*P(u, x, y)^2*fx(x, y)*q(u)^4*diff(fx(x, y), x, x) + 2*I*k0*P(u, x, y)^2*fx(x, y)*q(u)^4*diff(fx(x, y), x, y) + k0*P(u, x, y)^2*q(u)^4*diff(fx(x, y), y)^2 + k0*P(u, x, y)^2*fx(x, y)*q(u)^4*diff(fx(x, y), y, y) - k0*P(u, x, y)^2*q(u)^4*diff(fy(x, y), x)^2 - k0*P(u, x, y)^2*fy(x, y)*q(u)^4*diff(fy(x, y), x, x) + 2*I*k0*P(u, x, y)^2*fy(x, y)*q(u)^4*diff(fy(x, y), x, y) + k0*P(u, x, y)^2*q(u)^4*diff(fy(x, y), y)^2 + k0*P(u, x, y)^2*fy(x, y)*q(u)^4*diff(fy(x, y), y, y) - r^3*P(u, x, y)*diff(P(u, x, y), u, x, x) + 2*I*r^3*P(u, x, y)*diff(P(u, x, y), u, x, y) + r^3*P(u, x, y)*diff(P(u, x, y), u, y, y) - (6*r^2*P(u, x, y)^2*log(P(u, x, y)) + 5*r^2*P(u, x, y)^2)*diff(P(u, x, y), x)*diff(P(u, x, y), y)^3 - 2*((6*I*r^2*P(u, x, y)^2*log(P(u, x, y)) + 5*I*r^2*P(u, x, y)^2)*diff(P(u, x, y), x)^2 + (3*I*r^2*P(u, x, y)^3*log(P(u, x, y)) + I*r^2*P(u, x, y)^3)*diff(P(u, x, y), x, x) + (3*r^2*P(u, x, y)^3*log(P(u, x, y)) + r^2*P(u, x, y)^3)*diff(P(u, x, y), x, y))*diff(P(u, x, y), y)^2 - 2*(k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), x) - I*k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), y))*fx(x, y)*diff(fx(x, y), x) - 2*(k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), x) - I*k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), y))*fy(x, y)*diff(fy(x, y), x) + (2*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, y) + r^3*diff(P(u, x, y), u))*diff(P(u, x, y), x, x) - 2*(I*r^3*diff(P(u, x, y), u) - (3*r^2*P(u, x, y)^3*log(P(u, x, y)) + r^2*P(u, x, y)^3)*diff(P(u, x, y), x)^2)*diff(P(u, x, y), x, y) + (r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, x, x) - 2*I*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, x, y) - r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, y, y) + (6*r^2*P(u, x, y)^2*log(P(u, x, y)) + 5*r^2*P(u, x, y)^2)*diff(P(u, x, y), x)^3 + (8*r^2*P(u, x, y)^3*log(P(u, x, y)) + 3*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)*diff(P(u, x, y), x, x) - 2*(8*I*r^2*P(u, x, y)^3*log(P(u, x, y)) + 3*I*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)*diff(P(u, x, y), x, y))*diff(P(u, x, y), y) + (-2*I*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, x) - 2*r^2*P(u, x, y)^4*log(P(u, x, y))*diff(P(u, x, y), x, y) - r^3*diff(P(u, x, y), u) - 2*(3*I*r^2*P(u, x, y)^3*log(P(u, x, y)) + I*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)^2 - (8*r^2*P(u, x, y)^3*log(P(u, x, y)) + 3*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)*diff(P(u, x, y), y))*diff(P(u, x, y), y, y) - 2*(-I*k0*P(u, x, y)^2*q(u)^4*diff(fx(x, y), x) + (-I*k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), x) - k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), y))*fx(x, y))*diff(fx(x, y), y) - 2*(-I*k0*P(u, x, y)^2*q(u)^4*diff(fy(x, y), x) + (-I*k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), x) - k0*P(u, x, y)*q(u)^4*diff(P(u, x, y), y))*fy(x, y))*diff(fy(x, y), y))/r^4
# 'Phi00NP=' 0
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 0
# 'Phi20NP=' 0
# 'Phi11NP=' -1/4*(2*k0*fx(x, y)^2*q(u)^4 + 2*k0*fy(x, y)^2*q(u)^4 + 2*r^2*P(u, x, y)^2*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y) + r^2*diff(P(u, x, y), x)^2 - r^2*P(u, x, y)*diff(P(u, x, y), x, x) + r^2*diff(P(u, x, y), y)^2 - r^2*P(u, x, y)*diff(P(u, x, y), y, y))/r^4
# 'Phi12NP=' -1/2*(sqrt(2)*k0*P(u, x, y)*fx(x, y)*q(u)^4*diff(fx(x, y), x) + I*sqrt(2)*k0*P(u, x, y)*fx(x, y)*q(u)^4*diff(fx(x, y), y) + sqrt(2)*k0*P(u, x, y)*fy(x, y)*q(u)^4*diff(fy(x, y), x) + I*sqrt(2)*k0*P(u, x, y)*fy(x, y)*q(u)^4*diff(fy(x, y), y))/r^4
# 'Phi21NP=' -1/2*(sqrt(2)*k0*P(u, x, y)*fx(x, y)*q(u)^4*diff(fx(x, y), x) - I*sqrt(2)*k0*P(u, x, y)*fx(x, y)*q(u)^4*diff(fx(x, y), y) + sqrt(2)*k0*P(u, x, y)*fy(x, y)*q(u)^4*diff(fy(x, y), x) - I*sqrt(2)*k0*P(u, x, y)*fy(x, y)*q(u)^4*diff(fy(x, y), y))/r^4
# 'Phi22NP=' 1/2*(r^2*P(u, x, y)^5*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), x, x, y) + r^2*P(u, x, y)^5*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y, y, y) - k0*P(u, x, y)^3*q(u)^4*diff(fx(x, y), x)^2 - k0*P(u, x, y)^3*fx(x, y)*q(u)^4*diff(fx(x, y), x, x) - k0*P(u, x, y)^3*q(u)^4*diff(fx(x, y), y)^2 - k0*P(u, x, y)^3*fx(x, y)*q(u)^4*diff(fx(x, y), y, y) - k0*P(u, x, y)^3*q(u)^4*diff(fy(x, y), x)^2 - k0*P(u, x, y)^3*fy(x, y)*q(u)^4*diff(fy(x, y), x, x) - k0*P(u, x, y)^3*q(u)^4*diff(fy(x, y), y)^2 - k0*P(u, x, y)^3*fy(x, y)*q(u)^4*diff(fy(x, y), y, y) - r^3*P(u, x, y)^2*diff(P(u, x, y), u, x, x) - r^3*P(u, x, y)^2*diff(P(u, x, y), u, y, y) - 2*r^3*diff(P(u, x, y), u)*diff(P(u, x, y), x)^2 + (2*r^2*P(u, x, y)^3*log(P(u, x, y)) + 3*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)*diff(P(u, x, y), y)^3 + 6*r^2*m(u)*diff(P(u, x, y), u) + 2*(2*r^2*P(u, x, y)^4*log(P(u, x, y)) + r^2*P(u, x, y)^4)*diff(P(u, x, y), x)^2*diff(P(u, x, y), x, y) - 2*r^2*P(u, x, y)*diff(m(u), u) + 4*(k0*r*q(u)^4*diff(P(u, x, y), u) - k0*r*P(u, x, y)*q(u)^3*diff(q(u), u))*fx(x, y)^2 + 4*(k0*r*q(u)^4*diff(P(u, x, y), u) - k0*r*P(u, x, y)*q(u)^3*diff(q(u), u))*fy(x, y)^2 - 2*(r^3*diff(P(u, x, y), u) - (2*r^2*P(u, x, y)^4*log(P(u, x, y)) + r^2*P(u, x, y)^4)*diff(P(u, x, y), x, y))*diff(P(u, x, y), y)^2 + 2*(r^3*P(u, x, y)^3*log(P(u, x, y))*diff(P(u, x, y), u, y) + r^3*P(u, x, y)*diff(P(u, x, y), u, x))*diff(P(u, x, y), x) + (2*r^2*P(u, x, y)^5*log(P(u, x, y))*diff(P(u, x, y), x, y) + r^3*P(u, x, y)*diff(P(u, x, y), u))*diff(P(u, x, y), x, x) + (r^2*P(u, x, y)^5*log(P(u, x, y))*diff(P(u, x, y), x, x, x) + r^2*P(u, x, y)^5*log(P(u, x, y))*diff(P(u, x, y), x, y, y) + 2*r^3*P(u, x, y)^3*log(P(u, x, y))*diff(P(u, x, y), u, x) + 2*r^3*P(u, x, y)^2*diff(P(u, x, y), u)*diff(P(u, x, y), x) + 2*r^3*P(u, x, y)*diff(P(u, x, y), u, y) + (2*r^2*P(u, x, y)^3*log(P(u, x, y)) + 3*r^2*P(u, x, y)^3)*diff(P(u, x, y), x)^3 + 3*(2*r^2*P(u, x, y)^4*log(P(u, x, y)) + r^2*P(u, x, y)^4)*diff(P(u, x, y), x)*diff(P(u, x, y), x, x))*diff(P(u, x, y), y) + (2*r^2*P(u, x, y)^5*log(P(u, x, y))*diff(P(u, x, y), x, y) + r^3*P(u, x, y)*diff(P(u, x, y), u) + 3*(2*r^2*P(u, x, y)^4*log(P(u, x, y)) + r^2*P(u, x, y)^4)*diff(P(u, x, y), x)*diff(P(u, x, y), y))*diff(P(u, x, y), y, y))/(r^4*P(u, x, y))
# 'LambdaNP=' -1/12*(2*P(u, x, y)^2*log(P(u, x, y))*diff(P(u, x, y), x)*diff(P(u, x, y), y) + diff(P(u, x, y), x)^2 - P(u, x, y)*diff(P(u, x, y), x, x) + diff(P(u, x, y), y)^2 - P(u, x, y)*diff(P(u, x, y), y, y))/r^2
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
def fitEq(expr):
    expanded_expr = expr.expand()

    latex_expr = latex(expanded_expr)

    return latex_expr


# Yardımcı fonksiyonlar
def compare_expressions(orig, trans):
    """Dönüşümleri karşılaştır"""
    if trans == 0:
        return "0"
    try:
        if bool(trans == orig):
            return None
    except:
        if str(trans) == str(orig):
            return None
    return str(latex(fitEq(trans)))

def write_transformation_section(fout, coeffs, title):
    """Dönüşüm bölümünü yaz"""
    fout.write(f"\n\\textit{{{title}:}}\n\n")
    
    for symbol, orig, trans in coeffs:
        result = compare_expressions(orig, trans)
        if result is None:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {symbol}\n\\end{{dmath}}\n\n")
        else:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {result}\n\\end{{dmath}}\n\n")

def write_transformations(fout, met, transform_type):
    """Tüm dönüşümleri yaz"""
    tr_suffix = f"_tr{transform_type}"
    
    fout.write(f"\n\\newpage\n\\underline{{{transform_type} Type transformations:}}\n")
    
    # Spin coefficients
    spin_coeffs = [
        ('\\rho', met.rhoNP.expr(), getattr(met, f'rhoNP{tr_suffix}')),
        ('\\sigma', met.sigmaNP.expr(), getattr(met, f'sigmaNP{tr_suffix}')),
        ('\\kappa', met.kappaNP.expr(), getattr(met, f'kappaNP{tr_suffix}')),
        ('\\mu', met.muNP.expr(), getattr(met, f'muNP{tr_suffix}')),
        ('\\lambda', met.lambdaNP.expr(), getattr(met, f'lambdaNP{tr_suffix}')),
        ('\\nu', met.nuNP.expr(), getattr(met, f'nuNP{tr_suffix}')),
        ('\\alpha', met.alphaNP.expr(), getattr(met, f'alphaNP{tr_suffix}')),
        ('\\beta', met.betaNP.expr(), getattr(met, f'betaNP{tr_suffix}')),
        ('\\tau', met.tauNP.expr(), getattr(met, f'tauNP{tr_suffix}')),
        ('\\pi', met.piNP.expr(), getattr(met, f'piNP{tr_suffix}')),
        ('\\epsilon', met.epsilonNP.expr(), getattr(met, f'epsilonNP{tr_suffix}')),
        ('\\gamma', met.gammaNP.expr(), getattr(met, f'gammaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, spin_coeffs, "Spin coefficients")
    
    # Weyl components
    weyl_comps = [
        ('\\Psi_0', met.Psi0NP.expr(), getattr(met, f'Psi0NP{tr_suffix}')),
        ('\\Psi_1', met.Psi1NP.expr(), getattr(met, f'Psi1NP{tr_suffix}')),
        ('\\Psi_2', met.Psi2NP.expr(), getattr(met, f'Psi2NP{tr_suffix}')),
        ('\\Psi_3', met.Psi3NP.expr(), getattr(met, f'Psi3NP{tr_suffix}')),
        ('\\Psi_4', met.Psi4NP.expr(), getattr(met, f'Psi4NP{tr_suffix}'))
    ]
    write_transformation_section(fout, weyl_comps, "Weyl components")
    
    # Ricci components
    ricci_comps = [
        ('\\Phi_{00}', met.Phi00NP.expr(), getattr(met, f'Phi00NP{tr_suffix}')),
        ('\\Phi_{01}', met.Phi01NP.expr(), getattr(met, f'Phi01NP{tr_suffix}')),
        ('\\Phi_{02}', met.Phi02NP.expr(), getattr(met, f'Phi02NP{tr_suffix}')),
        ('\\Phi_{10}', met.Phi10NP.expr(), getattr(met, f'Phi10NP{tr_suffix}')),
        ('\\Phi_{11}', met.Phi11NP.expr(), getattr(met, f'Phi11NP{tr_suffix}')),
        ('\\Phi_{12}', met.Phi12NP.expr(), getattr(met, f'Phi12NP{tr_suffix}')),
        ('\\Phi_{20}', met.Phi20NP.expr(), getattr(met, f'Phi20NP{tr_suffix}')),
        ('\\Phi_{21}', met.Phi21NP.expr(), getattr(met, f'Phi21NP{tr_suffix}')),
        ('\\Phi_{22}', met.Phi22NP.expr(), getattr(met, f'Phi22NP{tr_suffix}')),
        ('\\Lambda', met.LambdaNP.expr(), getattr(met, f'LambdaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, ricci_comps, "Ricci components")

# %%
# Latex formatında rapor dosyası oluşturmak için bu kodu kullanabilirsiniz.
# (Dosyanin adini uygun sekilde degistirmeyi unutmayin.)
fout = open('28.50.tex',"w")
tmpstr=r'''\documentclass[landscape]{article}
%\documentclass[11pt,a4paper,reqno]{amsart}
%%%%%%%%%%%%%%%%%%%%%%
\usepackage[fleqn]{amsmath} %Denklemleri sola daya
\usepackage{amssymb}
\usepackage{authblk}
\usepackage{caption}
\usepackage{cite}
\usepackage{xcolor}
\usepackage{color}
\usepackage{float}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{mdframed}
\usepackage{hyperref}
\usepackage{textcomp}
\usepackage{epstopdf}
\usepackage{subcaption}
\usepackage{lscape}
\usepackage{breqn}
%\usepackage{soul}
%%%%%%%%%%%%%%%%%%%%%%
\setlength\parindent{0pt}
\setlength{\parskip}{5pt}
\geometry{left=20mm,right=20mm,top=30mm,bottom=20mm}
\hyphenation{Schwarz-schild}
%%%%%%%%%%%%%%%%%%%%%%
\newcommand{\etalchar}[1]{$^{#1}$}
\newcommand\hl[1]{%
	\bgroup
	\hskip0pt\color{red!80!black}%
	#1%
	\egroup
}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\begin{document}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\textbf{Newman-Penrose Formalism Calculations for}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{metric:28.50} 

\textit{Name:} Stephani et al., Equation (xx.xx)



\textit{Reference(s):} \cite{stefani}

\textit{Line element:} 

\begin{dmath}'''
fout.write(tmpstr)


fout.write("ds^2 " + str(latex(met.g.display()))[2:])
fout.write(r"\end{dmath}")


fout.write(r"\textit{Coordinates:} "+str(latex(MyCoordinates[:])))
tmpstr=r'''
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{Null tetrad components: }

\textit{Covariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l= " +r"\left("+str(latex(met.lNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n= " +r"\left("+str(latex(met.nNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m= " +r"\left("+str(latex(met.mNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}= " +r"\left("+str(latex(met.mbarNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}

\textit{Contravariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l= " +r"\left("+str(latex(met.lupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n= " +r"\left("+str(latex(met.nupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m= " +r"\left("+str(latex(met.mupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}= " +r"\left("+str(latex(met.mbarupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}


\newpage
\textbf{Directional derivatives: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"D=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\Delta=" + str(latex(fitEq( met.DeltanNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\delta=" + str(latex(fitEq( met.deltamNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\overline{\delta}=" + str(latex(fitEq( met.deltambarNP(f).expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Spin coefficients: }

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\rho="+str(latex(fitEq(met.rhoNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\sigma="+str(latex(fitEq(met.sigmaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\kappa="+str(latex(fitEq(met.kappaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\mu="+str(latex(fitEq(met.muNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}


\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\lambda="+str(latex(met.lambdaNP.expr()))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\nu="+str(latex(fitEq(met.nuNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\alpha="+str(latex(fitEq(met.alphaNP.expr()))))

tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\beta="+str(latex(fitEq(met.betaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\tau="+str(latex(fitEq(met.tauNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\pi="+str(latex(fitEq(met.piNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\epsilon="+str(latex(fitEq(met.epsilonNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\gamma="+str(latex(fitEq(met.gammaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage

\textbf{Relations between spin coefficients: }


%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Ricci tensor components: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{00}="+str(latex(fitEq(met.Phi00NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{01}="+str(latex(fitEq(met.Phi01NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{02}="+str(latex(fitEq(met.Phi02NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{10}="+str(latex(fitEq(met.Phi10NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{11}="+str(latex(fitEq(met.Phi11NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{12}="+str(latex(fitEq(met.Phi12NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{20}="+str(latex(fitEq(met.Phi20NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{21}="+str(latex(fitEq(met.Phi21NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{22}="+str(latex(fitEq(met.Phi22NP.expr()))))
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Lambda="+str(latex(fitEq(met.LambdaNP.expr()))))


tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Weyl tensor components: }
\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_0="+str(latex(fitEq(met.Psi0NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_1="+str(latex(fitEq(met.Psi1NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_2="+str(latex(fitEq(met.Psi2NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_3="+str(latex(fitEq(met.Psi3NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_4="+str(latex(fitEq(met.Psi4NP.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Newman-Penrose equations: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"NP1="+str(latex(fitEq(met.NPeq1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP2="+str(latex(fitEq(met.NPeq2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP3="+str(latex(fitEq(met.NPeq3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP4="+str(latex(fitEq(met.NPeq4.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP5="+str(latex(fitEq(met.NPeq5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP6="+str(latex(fitEq(met.NPeq6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP7="+str(latex(fitEq(met.NPeq7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP8="+str(latex(fitEq(met.NPeq8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP9="+str(latex(fitEq(met.NPeq9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP10="+str(latex(fitEq(met.NPeq10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP11="+str(latex(fitEq(met.NPeq11.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP12="+str(latex(fitEq(met.NPeq12.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP13="+str(latex(fitEq(met.NPeq13.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP14="+str(latex(fitEq(met.NPeq14.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP15="+str(latex(fitEq(met.NPeq15.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP16="+str(latex(fitEq(met.NPeq16.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP17="+str(latex(fitEq(met.NPeq17.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP18="+str(latex(fitEq(met.NPeq18.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Bianchi identities: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI1="+str(latex(fitEq(met.BI1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI2="+str(latex(fitEq(met.BI2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI3="+str(latex(fitEq(met.BI3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI4="+str(latex(fitEq(met.BI4.expr())))+r' \\ '),
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI5="+str(latex(fitEq(met.BI5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI6="+str(latex(fitEq(met.BI6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI7="+str(latex(fitEq(met.BI7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI8="+str(latex(fitEq(met.BI8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI9="+str(latex(fitEq(met.BI9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI10="+str(latex(fitEq(met.BI10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI11="+str(latex(fitEq(met.BI11.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


\newpage
\textbf{Petrov classification:} \\
\vspace{2cm}
\textit{Petrov class: '''
fout.write(tmpstr)
tmpstr = r'''} 
\vspace{2cm}



%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\begin{thebibliography}{99}

\bibitem{stefani}
 H. Stephani, D. Kramer, M. MacCallum, C. Hoenselaers, and E. Herlt, Exact Solutions of Einstein’s Field Equations. Cambridge Monographs on Mathematical Physics, Cambridge University Press, 2009.
\end{thebibliography}
\begin{mdframed}
\textbf{Calculated by:}

\textit{Name:Sezin Giravioğlu} 

\textit{E-mail: giravioglu21@itu.edu.tr}

\textit{Date: 26.11.2025}
\end{mdframed}
\end{document}
'''
fout.write(tmpstr)
fout.close()

# %%
reset()
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<x_0,x_1,x_2,x_3> = MyManifold.chart(r't x_1:\rho x_2:\varphi z')


tetrad_type = 'covariant'  

var('m_1 r_1 m_2 r_2 b_A b_1 b_2')

r = function("r", imag_part_func = 0)(x_1,x_3)
lamda = function('lamda',imag_part_func=0, latex_name = r"\lambda")(x_1, x_3)
U = function('U',imag_part_func=0,latex_name=r'\widetilde{U}')(x_1, x_3)


metric_functions=[(('U', -(m_1)/(r_1)-(m_2)/(r_2))),('r', x_1^2+(x_3-b_A)^2),('lamda',1/2*(-(m_1^2*x_1^2)/(r_1^4)-(m_2^2*x_1^2)/(r_2^4)+4*m_1*m_2*(x_1^2+(x_3-b_1)*(x_3-b_2))/(r_1*r_2*(b_1-b_2)^2)) )]

lvec=[e^(U)*sqrt(r + x_3)/sqrt(2), e^(lamda)/(2*sqrt(r)), 0, 0]
nvec=[e^(U)*sqrt(r + x_3)/sqrt(2), -e^(lamda)/(2*sqrt(r)), 0, 0]
mvec=[0, 0, e^(-U)*x_1/sqrt(r + x_3)/sqrt(2), I*e^(lamda)/(2*sqrt(r))]
mbarvec=[0, 0, e^(-U)*x_1/sqrt(r + x_3)/sqrt(2), -I*e^(lamda)/(2*sqrt(r))]



met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))
# Out:
# 'The metric:'
# g = (-z*e^(2*U(x_1, z)) - e^(2*U(x_1, z))*r(x_1, z)) dt⊗dt + 1/2*e^(2*lamda(x_1, z))/r(x_1, z) dx_1⊗dx_1 + x_1^2/(z*e^(2*U(x_1, z)) + e^(2*U(x_1, z))*r(x_1, z)) dx_2⊗dx_2 + 1/2*e^(2*lamda(x_1, z))/r(x_1, z) dz⊗dz
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:579, in NewmanPenrose.createmetric(self)
#     578 try:
# --> 579     self.lupNP=self.Man.tensor_field(_sage_const_1 ,_sage_const_0 ,self.lNPvecup)
#     580     self.nupNP=self.Man.tensor_field(_sage_const_1 ,_sage_const_0 ,self.nNPvecup)
#
# AttributeError: 'NewmanPenrose' object has no attribute 'lNPvecup'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      20 mvec=[Integer(0), Integer(0), e**(-U)*x_1/sqrt(r + x_3)/sqrt(Integer(2)), I*e**(lamda)/(Integer(2)*sqrt(r))]
#      21 mbarvec=[Integer(0), Integer(0), e**(-U)*x_1/sqrt(r + x_3)/sqrt(Integer(2)), -I*e**(lamda)/(Integer(2)*sqrt(r))]
# ---> 25 met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
#      26 f = MyManifold.scalar_field(function('f')(*MyCoordinates))
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:436, in NewmanPenrose.__init__(self, Man, CO, lvecaux, nvecaux, mvecaux, mbarvecaux, vectype)
#     434     self.mNPvec=mvecaux
#     435     self.mbarNPvec=mbarvecaux
# --> 436     self.createmetric()
#     437 #########################
#     438 elif vectype=='contravariant':
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:585, in NewmanPenrose.createmetric(self)
#     583 #########################
#     584 except:
# --> 585     self.lupNP=self.lNP.up(self.g)
#     586     self.nupNP=self.nNP.up(self.g)
#     587     self.mupNP=self.mNP.up(self.g)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/differentiable/tensorfield.py:3827, in TensorField.up(self, non_degenerate_form, pos)
#    3825     for p in range(n_con, self._tensor_rank):
#    3826         k = result._tensor_type[0]
# -> 3827         result = result.up(non_degenerate_form, k)
#    3828     return result
#    3830 if pos < n_con or pos > self._tensor_rank - 1:
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/differentiable/tensorfield.py:3839, in TensorField.up(self, non_degenerate_form, pos)
#    3836 from sage.manifolds.differentiable.symplectic_form import SymplecticForm
#    3838 if isinstance(non_degenerate_form, PseudoRiemannianMetric):
# -> 3839     return self.contract(pos, non_degenerate_form.inverse(), 1)
#    3840 elif isinstance(non_degenerate_form, SymplecticForm):
#    3841     return self.contract(pos, non_degenerate_form.poisson(), 1)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/differentiable/tensorfield_paral.py:1806, in TensorFieldParal.contract(self, *args)
#    1733 r"""
#    1734 Contraction with another tensor field, on one or more indices.
#    1735
#    (...)   1802     for more examples.
#    1803 """
#    1804 # This is to ensure the call to the TensorField version instead of
#    1805 # the FreeModuleTensor one
# -> 1806 return TensorField.contract(self, *args)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/differentiable/tensorfield.py:3361, in TensorField.contract(self, *args)
#    3358 if ambient_dom_resu.is_manifestly_parallelizable():
#    3359     # call of the FreeModuleTensor version:
#    3360     args = pos1 + (other_r,) + pos2
# -> 3361     return FreeModuleTensor.contract(self_r, *args)
#    3362 com_dom = []
#    3363 for dom in self_r._restrictions:
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/tensor/modules/free_module_tensor.py:2795, in FreeModuleTensor.contract(self, *args)
#    2793     raise ValueError("no common basis for the contraction")
#    2794 args = pos1 + (other._components[basis],) + pos2
# -> 2795 cmp_res = self._components[basis].contract(*args)
#    2796 if self._tensor_rank + other._tensor_rank - 2*ncontr == 0:
#    2797     # Case of scalar output:
#    2798     return cmp_res
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/tensor/modules/comp.py:2389, in Components.contract(self, *args)
#    2387                 ind_o[pos_o] = k
#    2388                 ic += 1
# -> 2389             sm += self[[ind_s]] * other[[ind_o]]
#    2390         res[[ind]] = sm
#    2392 return res
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:1510, in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:21602)()
#    1508 cdef int cl = classify_elements(left, right)
#    1509 if HAVE_SAME_PARENT(cl):
# -> 1510     return (<Element>left)._mul_(right)
#    1511 if BOTH_ARE_ELEMENT(cl):
#    1512     return coercion_model.bin_op(left, right, mul)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:1556, in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:21962)()
#    1554         raise bin_op_exception('*', self, other)
#    1555     else:
# -> 1556         return python_op(other)
#    1557
#    1558 cdef _mul_long(self, long n):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/scalarfield.py:2783, in ScalarField._mul_(self, other)
#    2780 result = type(self)(self.parent())
#    2781 for chart in com_charts:
#    2782     # ChartFunction multiplication:
# -> 2783     result._express[chart] = self._express[chart] * other._express[chart]
#    2784 result._name = format_mul_txt(self._name, '*', other._name)
#    2785 result._latex_name = format_mul_latex(self._latex_name, r' \cdot ',
#    2786                                       other._latex_name)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:1510, in sage.structure.element.Element.__mul__ (build/cythonized/sage/structure/element.c:21602)()
#    1508 cdef int cl = classify_elements(left, right)
#    1509 if HAVE_SAME_PARENT(cl):
# -> 1510     return (<Element>left)._mul_(right)
#    1511 if BOTH_ARE_ELEMENT(cl):
#    1512     return coercion_model.bin_op(left, right, mul)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/structure/element.pyx:1556, in sage.structure.element.Element._mul_ (build/cythonized/sage/structure/element.c:21962)()
#    1554         raise bin_op_exception('*', self, other)
#    1555     else:
# -> 1556         return python_op(other)
#    1557
#    1558 cdef _mul_long(self, long n):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/chart_func.py:1443, in ChartFunction._mul_(self, other)
#    1441     res = other._simplify(self.expr() * other.expr())
#    1442 else:
# -> 1443     res = self._simplify(self.expr() * other.expr())
#    1444 if curr == 'SR' and res.is_trivial_zero():
#    1445     # NB: "if res == 0" would be too expensive (cf. #22859)
#    1446     return self.parent().zero()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/chart_func.py:410, in ChartFunction._simplify(self, expr)
#     389 def _simplify(self, expr):
#     390     """
#     391     Simplify the expression `expr` using `self._calc_method.simplify`.
#     392
#    (...)    408         2*x
#     409     """
# --> 410     res = self._calc_method.simplify(expr)
#     411     if self._expansion_symbol is not None and self._calc_method._current == 'SR':
#     412         res = res.series(self._expansion_symbol, self._order + 1).truncate()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/calculus_method.py:272, in CalculusMethod.simplify(self, expression, method)
#     270 if method is None:
#     271     method = self._current
# --> 272 return self._simplify_dict[method](expression)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/manifolds/utilities.py:597, in simplify_chain_real(expr)
#     595 expr = expr.simplify_factorial()
#     596 expr = expr.simplify_trig()
# --> 597 expr = expr.simplify_rational()
#     598 expr = simplify_sqrt_real(expr)
#     599 expr = simplify_abs_trig(expr)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:11134, in sage.symbolic.expression.Expression.simplify_rational (build/cythonized/sage/symbolic/expression.cpp:111513)()
#   11132 else:
#   11133     cmd = "%s(%s)" % (maxima_method, self_m.str())
# > 11134 res = P(cmd)
#   11135 return self.parent()(res)
#   11136
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:299, in Interface.__call__(self, x, name)
#     296         pass
#     298 if isinstance(x, str):
# --> 299     return cls(self, x, name=name)
#     300 try:
#     301     # Special methods do not and should not have an option to
#     302     # set the name directly, as the identifier assigned by the
#     303     # interface should stay consistent. An identifier with a
#     304     # user-assigned name might change its value, so we return a
#     305     # new element.
#     306     result = self._coerce_from_special_method(x)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:753, in InterfaceElement.__init__(self, parent, value, is_name, name)
#     751 else:
#     752     try:
# --> 753         self._name = parent._create(value, name=name)
#     754     except (TypeError, RuntimeError, ValueError) as x:
#     755         raise TypeError(x)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:624, in MaximaLib._create(self, value, name)
#     622         maxima_eval([[msetq], cadadr("#$%s$#$" % name), value])
#     623     else:
# --> 624         self.set(name, value)
#     625 except RuntimeError as error:
#     626     s = str(error)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:534, in MaximaLib.set(self, var, value)
#     532     raise TypeError
#     533 cmd = '%s : %s$' % (var, value.rstrip(';'))
# --> 534 self.eval(cmd)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:480, in MaximaLib._eval_line(self, line, locals, reformat, **kwds)
#     478         line = line[ind_dollar + 1:]
#     479         if statement:
# --> 480             maxima_eval("#$%s$" % statement)
#     481 if not reformat:
#     482     return result
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:12202)()
#     826     """
#     827     lispargs = EclObject(list(args))
# --> 828     return ecl_wrap(ecl_safe_apply(self.obj, (<EclObject>lispargs).obj))
#     829
#     830 def __richcmp__(left, right, int op):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:354, in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:9658)()
#     352 message = ecl_string_to_python(error)
#     353 if "Console interrupt" in message:
# --> 354     raise KeyboardInterrupt("ECL says: {}".format(message))
#     355 else:
#     356     raise RuntimeError("ECL says: {}".format(message))
#
# KeyboardInterrupt: ECL says: Console interrupt.

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()

met.calculate_Weyl()
met.show_Weyl()
met.calculate_Ricci()
met.show_Ricci()
met.calculate_NPeq()
met.show_NPeq()

met.calculate_Bianchi()
met.show_Bianchi()

met.Petrov_fromWeyl()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' -1/4*(2*I*r(x_1, z)^2*diff(U(x_1, z), z) - 2*I*r(x_1, z)^2*diff(lamda(x_1, z), z) + (2*I*r(x_1, z)*diff(U(x_1, z), z) - 2*I*r(x_1, z)*diff(lamda(x_1, z), z) + I*diff(r(x_1, z), z))*z + 2*I*r(x_1, z)*diff(r(x_1, z), z) + I*r(x_1, z))/((z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'tauNP=' 1/4*(-2*I*r(x_1, z)^2*diff(U(x_1, z), z) - 2*I*r(x_1, z)^2*diff(lamda(x_1, z), z) + (-2*I*r(x_1, z)*diff(U(x_1, z), z) - 2*I*r(x_1, z)*diff(lamda(x_1, z), z) + I*diff(r(x_1, z), z))*z - I*r(x_1, z))/((z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'sigmaNP=' 1/4*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + (2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(lamda(x_1, z), x_1) - x_1*diff(r(x_1, z), x_1) - 2*r(x_1, z))*z - 2*r(x_1, z)^2)/((x_1*z*e^(lamda(x_1, z)) + x_1*e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'rhoNP=' 1/4*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1) + (2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 2*x_1*r(x_1, z)*diff(lamda(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1) - 2*r(x_1, z))*z - 2*r(x_1, z)^2)/((x_1*z*e^(lamda(x_1, z)) + x_1*e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'piNP=' 1/4*(-2*I*r(x_1, z)^2*diff(U(x_1, z), z) - 2*I*r(x_1, z)^2*diff(lamda(x_1, z), z) + (-2*I*r(x_1, z)*diff(U(x_1, z), z) - 2*I*r(x_1, z)*diff(lamda(x_1, z), z) + I*diff(r(x_1, z), z))*z - I*r(x_1, z))/((z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'nuNP=' -1/4*(2*I*r(x_1, z)^2*diff(U(x_1, z), z) - 2*I*r(x_1, z)^2*diff(lamda(x_1, z), z) + (2*I*r(x_1, z)*diff(U(x_1, z), z) - 2*I*r(x_1, z)*diff(lamda(x_1, z), z) + I*diff(r(x_1, z), z))*z + 2*I*r(x_1, z)*diff(r(x_1, z), z) + I*r(x_1, z))/((z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'muNP=' 1/4*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1) + (2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 2*x_1*r(x_1, z)*diff(lamda(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1) - 2*r(x_1, z))*z - 2*r(x_1, z)^2)/((x_1*z*e^(lamda(x_1, z)) + x_1*e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'lambdaNP=' 1/4*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + (2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(lamda(x_1, z), x_1) - x_1*diff(r(x_1, z), x_1) - 2*r(x_1, z))*z - 2*r(x_1, z)^2)/((x_1*z*e^(lamda(x_1, z)) + x_1*e^(lamda(x_1, z))*r(x_1, z))*sqrt(r(x_1, z)))
# 'epsilonNP=' 1/4*(2*z*diff(U(x_1, z), x_1) + 2*r(x_1, z)*diff(U(x_1, z), x_1) + diff(r(x_1, z), x_1))*sqrt(r(x_1, z))/(z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))
# 'gammaNP=' 1/4*(2*z*diff(U(x_1, z), x_1) + 2*r(x_1, z)*diff(U(x_1, z), x_1) + diff(r(x_1, z), x_1))*sqrt(r(x_1, z))/(z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))
# 'betaNP=' -1/4*(2*I*z*diff(U(x_1, z), z) + 2*I*r(x_1, z)*diff(U(x_1, z), z) + I*diff(r(x_1, z), z) + I)*sqrt(r(x_1, z))/(z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))
# 'alphaNP=' -1/4*(2*I*z*diff(U(x_1, z), z) + 2*I*r(x_1, z)*diff(U(x_1, z), z) + I*diff(r(x_1, z), z) + I)*sqrt(r(x_1, z))/(z*e^(lamda(x_1, z)) + e^(lamda(x_1, z))*r(x_1, z))
# Calculating Weyl components...
# 'Psi0NP=' -1/4*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^4*diff(U(x_1, z), z)^2 - 2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) - 6*r(x_1, z)^4*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + 2*x_1*r(x_1, z)^3*diff(r(x_1, z), z, z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 - 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)*diff(lamda(x_1, z), z) - 2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) + 2*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), z) - 6*r(x_1, z)^2*diff(U(x_1, z), x_1) - x_1*diff(r(x_1, z), x_1)^2 + x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) - x_1*diff(r(x_1, z), z)^2 + x_1*r(x_1, z)*diff(r(x_1, z), z, z) + 2*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - r(x_1, z)^2)*diff(lamda(x_1, z), x_1) - (2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - r(x_1, z))*diff(r(x_1, z), x_1))*z^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 + 8*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) - 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) - 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) - 12*r(x_1, z)^3*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 3*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 + x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) - x_1*r(x_1, z)*diff(r(x_1, z), z)^2 + 3*x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) + 4*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - r(x_1, z)^3)*diff(lamda(x_1, z), x_1) - 2*(4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + x_1*r(x_1, z)^2)*diff(lamda(x_1, z), z) + (2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) - r(x_1, z)^2)*diff(r(x_1, z), x_1) + (8*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z) + x_1*r(x_1, z))*diff(r(x_1, z), z))*z + 2*(2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1) - r(x_1, z)^4)*diff(lamda(x_1, z), x_1) - 2*(2*x_1*r(x_1, z)^4*diff(U(x_1, z), z) + x_1*r(x_1, z)^3)*diff(lamda(x_1, z), z) + 2*(x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) + x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1) - r(x_1, z)^3)*diff(r(x_1, z), x_1) + (6*x_1*r(x_1, z)^3*diff(U(x_1, z), z) - 2*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z) + x_1*r(x_1, z)^2)*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# 'Psi1NP=' -1/4*(4*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, z) + 2*I*r(x_1, z)^3*diff(U(x_1, z), z) + 2*I*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, z) + (-4*I*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(lamda(x_1, z), x_1) + 4*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1, z) + 2*I*x_1*diff(U(x_1, z), z)*diff(r(x_1, z), x_1) + 2*I*r(x_1, z)*diff(U(x_1, z), z) - 2*(2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - I*r(x_1, z))*diff(lamda(x_1, z), z) + (2*I*x_1*diff(U(x_1, z), x_1) - I)*diff(r(x_1, z), z))*z^2 + (8*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, z) + 4*I*r(x_1, z)^2*diff(U(x_1, z), z) + 2*I*x_1*r(x_1, z)*diff(r(x_1, z), x_1, z) - 2*(4*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + I*x_1*r(x_1, z))*diff(lamda(x_1, z), x_1) - 4*(2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - I*r(x_1, z)^2)*diff(lamda(x_1, z), z) + (4*I*x_1*r(x_1, z)*diff(U(x_1, z), z) - 2*I*x_1*r(x_1, z)*diff(lamda(x_1, z), z) + I*x_1)*diff(r(x_1, z), x_1) + (4*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 2*I*x_1*r(x_1, z)*diff(lamda(x_1, z), x_1) + 2*I*x_1*diff(r(x_1, z), x_1) - I*r(x_1, z))*diff(r(x_1, z), z) + I*r(x_1, z))*z + I*r(x_1, z)^2 - 2*(2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + I*x_1*r(x_1, z)^2)*diff(lamda(x_1, z), x_1) - 2*(2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - I*r(x_1, z)^3)*diff(lamda(x_1, z), z) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 2*I*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z) - I*x_1*r(x_1, z))*diff(r(x_1, z), x_1) - 2*(-I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Psi2NP=' 1/12*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^4*diff(U(x_1, z), z)^2 + 6*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) - 6*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) + 2*r(x_1, z)^4*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + 4*x_1*r(x_1, z)^3*diff(r(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), z, z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 + 12*x_1*r(x_1, z)^2*diff(U(x_1, z), z)*diff(lamda(x_1, z), z) + 6*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) - 6*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) - 6*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), z) + 2*r(x_1, z)^2*diff(U(x_1, z), x_1) - x_1*diff(r(x_1, z), x_1)^2 + x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) - x_1*diff(r(x_1, z), z)^2 + x_1*r(x_1, z)*diff(r(x_1, z), z, z) - 6*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - r(x_1, z)^2)*diff(lamda(x_1, z), x_1) + 3*(2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - r(x_1, z))*diff(r(x_1, z), x_1))*z^2 + 4*x_1*r(x_1, z)^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 + 8*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 + 12*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) - 12*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) - 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) - 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) + 4*r(x_1, z)^3*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 + 5*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) - 5*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) - 12*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - r(x_1, z)^3)*diff(lamda(x_1, z), x_1) + 6*(4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + x_1*r(x_1, z)^2)*diff(lamda(x_1, z), z) + (16*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 6*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) - 5*r(x_1, z)^2)*diff(r(x_1, z), x_1) - (8*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 6*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z) + 3*x_1*r(x_1, z))*diff(r(x_1, z), z))*z - 6*(2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1) - r(x_1, z)^4)*diff(lamda(x_1, z), x_1) + 6*(2*x_1*r(x_1, z)^4*diff(U(x_1, z), z) + x_1*r(x_1, z)^3)*diff(lamda(x_1, z), z) + 2*(5*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - 3*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1) - r(x_1, z)^3)*diff(r(x_1, z), x_1) - (2*x_1*r(x_1, z)^3*diff(U(x_1, z), z) - 6*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z) - 5*x_1*r(x_1, z)^2)*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# 'Psi3NP=' -1/4*(4*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, z) + 2*I*r(x_1, z)^3*diff(U(x_1, z), z) + 2*I*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, z) + (-4*I*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(lamda(x_1, z), x_1) + 4*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1, z) + 2*I*x_1*diff(U(x_1, z), z)*diff(r(x_1, z), x_1) + 2*I*r(x_1, z)*diff(U(x_1, z), z) - 2*(2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - I*r(x_1, z))*diff(lamda(x_1, z), z) + (2*I*x_1*diff(U(x_1, z), x_1) - I)*diff(r(x_1, z), z))*z^2 + (8*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, z) + 4*I*r(x_1, z)^2*diff(U(x_1, z), z) + 2*I*x_1*r(x_1, z)*diff(r(x_1, z), x_1, z) - 2*(4*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + I*x_1*r(x_1, z))*diff(lamda(x_1, z), x_1) - 4*(2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - I*r(x_1, z)^2)*diff(lamda(x_1, z), z) + (4*I*x_1*r(x_1, z)*diff(U(x_1, z), z) - 2*I*x_1*r(x_1, z)*diff(lamda(x_1, z), z) + I*x_1)*diff(r(x_1, z), x_1) + (4*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 2*I*x_1*r(x_1, z)*diff(lamda(x_1, z), x_1) + 2*I*x_1*diff(r(x_1, z), x_1) - I*r(x_1, z))*diff(r(x_1, z), z) + I*r(x_1, z))*z + I*r(x_1, z)^2 - 2*(2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + I*x_1*r(x_1, z)^2)*diff(lamda(x_1, z), x_1) - 2*(2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - I*r(x_1, z)^3)*diff(lamda(x_1, z), z) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 2*I*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z) - I*x_1*r(x_1, z))*diff(r(x_1, z), x_1) - 2*(-I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Psi4NP=' -1/4*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^4*diff(U(x_1, z), z)^2 - 2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) - 6*r(x_1, z)^4*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + 2*x_1*r(x_1, z)^3*diff(r(x_1, z), z, z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 - 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)*diff(lamda(x_1, z), z) - 2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) + 2*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), z) - 6*r(x_1, z)^2*diff(U(x_1, z), x_1) - x_1*diff(r(x_1, z), x_1)^2 + x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) - x_1*diff(r(x_1, z), z)^2 + x_1*r(x_1, z)*diff(r(x_1, z), z, z) + 2*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - r(x_1, z)^2)*diff(lamda(x_1, z), x_1) - (2*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - r(x_1, z))*diff(r(x_1, z), x_1))*z^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 + 8*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) - 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) - 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) - 12*r(x_1, z)^3*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 3*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 + x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) - x_1*r(x_1, z)*diff(r(x_1, z), z)^2 + 3*x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) + 4*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - r(x_1, z)^3)*diff(lamda(x_1, z), x_1) - 2*(4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + x_1*r(x_1, z)^2)*diff(lamda(x_1, z), z) + (2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1) - r(x_1, z)^2)*diff(r(x_1, z), x_1) + (8*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z) + x_1*r(x_1, z))*diff(r(x_1, z), z))*z + 2*(2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1) - r(x_1, z)^4)*diff(lamda(x_1, z), x_1) - 2*(2*x_1*r(x_1, z)^4*diff(U(x_1, z), z) + x_1*r(x_1, z)^3)*diff(lamda(x_1, z), z) + 2*(x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) + x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1) - r(x_1, z)^3)*diff(r(x_1, z), x_1) + (6*x_1*r(x_1, z)^3*diff(U(x_1, z), z) - 2*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z) + x_1*r(x_1, z)^2)*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# Calculating Ricci components...
# 'Phi00NP=' -1/4*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) - 6*r(x_1, z)^4*diff(U(x_1, z), x_1) - 2*r(x_1, z)^4*diff(lamda(x_1, z), x_1) + 3*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(r(x_1, z), z)^2 - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(r(x_1, z), z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) - 6*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) + x_1*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)*diff(r(x_1, z), z, z) + r(x_1, z)*diff(r(x_1, z), x_1))*z^2 + x_1*r(x_1, z)^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) - 12*r(x_1, z)^3*diff(U(x_1, z), x_1) - 4*r(x_1, z)^3*diff(lamda(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 - 3*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 - 3*x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - r(x_1, z)^2)*diff(r(x_1, z), x_1))*z + 2*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - r(x_1, z)^3)*diff(r(x_1, z), x_1))/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# 'Phi01NP=' -1/4*(2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*I*r(x_1, z)^3*diff(lamda(x_1, z), z) - (2*(-2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(U(x_1, z), z) + 2*I*r(x_1, z)*diff(lamda(x_1, z), z) - I*diff(r(x_1, z), z))*z^2 + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), x_1) + 2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 4*I*r(x_1, z)^2*diff(lamda(x_1, z), z) - 4*(-2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*r(x_1, z)^2)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(r(x_1, z), z) - I*r(x_1, z))*z - I*r(x_1, z)^2 - 2*(-2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) + I*r(x_1, z)^3)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + I*x_1*r(x_1, z))*diff(r(x_1, z), x_1) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*x_1*r(x_1, z)*diff(r(x_1, z), x_1))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Phi10NP=' 1/4*(2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*I*r(x_1, z)^3*diff(lamda(x_1, z), z) - (2*(-2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(U(x_1, z), z) + 2*I*r(x_1, z)*diff(lamda(x_1, z), z) - I*diff(r(x_1, z), z))*z^2 + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), x_1) + 2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 4*I*r(x_1, z)^2*diff(lamda(x_1, z), z) - 4*(-2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*r(x_1, z)^2)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(r(x_1, z), z) - I*r(x_1, z))*z - I*r(x_1, z)^2 - 2*(-2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) + I*r(x_1, z)^3)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + I*x_1*r(x_1, z))*diff(r(x_1, z), x_1) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*x_1*r(x_1, z)*diff(r(x_1, z), x_1))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Phi02NP=' 1/4*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), z)^2 + 2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z)*diff(r(x_1, z), z) + 2*r(x_1, z)^4*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + 2*r(x_1, z)^4*diff(lamda(x_1, z), x_1) + x_1*r(x_1, z)^2*diff(r(x_1, z), z)^2 + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) + 2*r(x_1, z)^2*diff(U(x_1, z), x_1) + 2*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) + x_1*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)*diff(r(x_1, z), z, z) - r(x_1, z)*diff(r(x_1, z), x_1))*z^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)*diff(r(x_1, z), z) + 4*r(x_1, z)^3*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + 4*r(x_1, z)^3*diff(lamda(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) - r(x_1, z)^2*diff(r(x_1, z), x_1))*z)/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# 'Phi20NP=' 1/4*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), z)^2 + 2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z)*diff(r(x_1, z), z) + 2*r(x_1, z)^4*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + 2*r(x_1, z)^4*diff(lamda(x_1, z), x_1) + x_1*r(x_1, z)^2*diff(r(x_1, z), z)^2 + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) + 2*r(x_1, z)^2*diff(U(x_1, z), x_1) + 2*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) + x_1*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)*diff(r(x_1, z), z, z) - r(x_1, z)*diff(r(x_1, z), x_1))*z^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)*diff(r(x_1, z), z) + 4*r(x_1, z)^3*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + 4*r(x_1, z)^3*diff(lamda(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) - r(x_1, z)^2*diff(r(x_1, z), x_1))*z)/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# 'Phi11NP=' 1/8*(4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) - 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z) - 4*r(x_1, z)^3*diff(lamda(x_1, z), x_1) - x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 + 2*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) - 3*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 + 2*x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) + 2*(2*x_1*r(x_1, z)*diff(U(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)*diff(U(x_1, z), z)^2 + 2*x_1*r(x_1, z)*diff(U(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)*diff(U(x_1, z), z, z) - 2*r(x_1, z)*diff(lamda(x_1, z), x_1) + diff(r(x_1, z), x_1))*z^2 + 2*(4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 - 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) - 2*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), z) - 2*x_1*r(x_1, z)*diff(U(x_1, z), z) - 4*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) + x_1*r(x_1, z)*diff(r(x_1, z), z, z) + 2*(x_1*r(x_1, z)*diff(U(x_1, z), x_1) + r(x_1, z))*diff(r(x_1, z), x_1))*z - 3*x_1*r(x_1, z) + 2*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + r(x_1, z)^2)*diff(r(x_1, z), x_1) - 2*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + 3*x_1*r(x_1, z))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Phi12NP=' 1/4*(2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*I*r(x_1, z)^3*diff(lamda(x_1, z), z) - (2*(-2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(U(x_1, z), z) + 2*I*r(x_1, z)*diff(lamda(x_1, z), z) - I*diff(r(x_1, z), z))*z^2 + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), x_1) + 2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 4*I*r(x_1, z)^2*diff(lamda(x_1, z), z) - 4*(-2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*r(x_1, z)^2)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(r(x_1, z), z) - I*r(x_1, z))*z - I*r(x_1, z)^2 - 2*(-2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) + I*r(x_1, z)^3)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + I*x_1*r(x_1, z))*diff(r(x_1, z), x_1) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*x_1*r(x_1, z)*diff(r(x_1, z), x_1))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Phi21NP=' -1/4*(2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*I*r(x_1, z)^3*diff(lamda(x_1, z), z) - (2*(-2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(U(x_1, z), z) + 2*I*r(x_1, z)*diff(lamda(x_1, z), z) - I*diff(r(x_1, z), z))*z^2 + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), z)*diff(r(x_1, z), x_1) + 2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) - 4*I*r(x_1, z)^2*diff(lamda(x_1, z), z) - 4*(-2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*r(x_1, z)^2)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)*diff(U(x_1, z), x_1) + I*r(x_1, z))*diff(r(x_1, z), z) - I*r(x_1, z))*z - I*r(x_1, z)^2 - 2*(-2*I*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) + I*r(x_1, z)^3)*diff(U(x_1, z), z) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + I*x_1*r(x_1, z))*diff(r(x_1, z), x_1) + (2*I*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) + I*x_1*r(x_1, z)*diff(r(x_1, z), x_1))*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z)) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z) + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^2)
# 'Phi22NP=' -1/4*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^4*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) - 6*r(x_1, z)^4*diff(U(x_1, z), x_1) - 2*r(x_1, z)^4*diff(lamda(x_1, z), x_1) + 3*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(r(x_1, z), z)^2 - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(r(x_1, z), z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1, x_1) - 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) - 6*r(x_1, z)^2*diff(U(x_1, z), x_1) - 2*r(x_1, z)^2*diff(lamda(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) + x_1*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)*diff(r(x_1, z), z, z) + r(x_1, z)*diff(r(x_1, z), x_1))*z^2 + x_1*r(x_1, z)^2 + (8*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1, x_1) - 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z, z) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) - 12*r(x_1, z)^3*diff(U(x_1, z), x_1) - 4*r(x_1, z)^3*diff(lamda(x_1, z), x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 - 3*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 - 3*x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) + (4*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - r(x_1, z)^2)*diff(r(x_1, z), x_1))*z + 2*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - r(x_1, z)^3)*diff(r(x_1, z), x_1))/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# 'LambdaNP=' -1/24*(4*x_1*r(x_1, z)^4*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^4*diff(U(x_1, z), z)^2 + 4*x_1*r(x_1, z)^4*diff(lamda(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^4*diff(lamda(x_1, z), z, z) - 4*r(x_1, z)^4*diff(U(x_1, z), x_1) + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + 3*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), x_1, x_1) + 3*x_1*r(x_1, z)^2*diff(r(x_1, z), z)^2 - 2*x_1*r(x_1, z)^3*diff(r(x_1, z), z, z) + 2*(2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1)^2 + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z)^2 + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)^2*diff(lamda(x_1, z), z, z) - 2*r(x_1, z)^2*diff(U(x_1, z), x_1) + x_1*diff(r(x_1, z), x_1)^2 - x_1*r(x_1, z)*diff(r(x_1, z), x_1, x_1) + x_1*diff(r(x_1, z), z)^2 - x_1*r(x_1, z)*diff(r(x_1, z), z, z))*z^2 + x_1*r(x_1, z)^2 + 2*(4*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1)^2 + 4*x_1*r(x_1, z)^3*diff(U(x_1, z), z)^2 + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), x_1, x_1) + 4*x_1*r(x_1, z)^3*diff(lamda(x_1, z), z, z) + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z)*diff(r(x_1, z), z) - 4*r(x_1, z)^3*diff(U(x_1, z), x_1) + 2*x_1*r(x_1, z)^2*diff(U(x_1, z), z) + 2*x_1*r(x_1, z)*diff(r(x_1, z), x_1)^2 - 2*x_1*r(x_1, z)^2*diff(r(x_1, z), x_1, x_1) + 2*x_1*r(x_1, z)*diff(r(x_1, z), z)^2 - 2*x_1*r(x_1, z)^2*diff(r(x_1, z), z, z) + (2*x_1*r(x_1, z)^2*diff(U(x_1, z), x_1) - r(x_1, z)^2)*diff(r(x_1, z), x_1))*z + 2*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), x_1) - r(x_1, z)^3)*diff(r(x_1, z), x_1) + 2*(2*x_1*r(x_1, z)^3*diff(U(x_1, z), z) + x_1*r(x_1, z)^2)*diff(r(x_1, z), z))/(x_1*z^2*e^(2*lamda(x_1, z))*r(x_1, z) + 2*x_1*z*e^(2*lamda(x_1, z))*r(x_1, z)^2 + x_1*e^(2*lamda(x_1, z))*r(x_1, z)^3)
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0
# Calculating Bianchi identities...
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0
# Calculating Petrov Type...
# Petrov Type I

# %%
met.petrovtype='I'

# %%
from pathlib import Path
fout = open('17.20.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def latex_write(fout, lhs, rhs_expr):
    """
    Uzun LaTeX ifadelerini \\frac sinirlarinda keserek yazar.
    Kisa ifadeler (<5500 karakter) dogrudan yazilir.
    Uzun ifadeler uygun bir \\frac noktasindan kesilip {} \\dots ile bitirilir.
    """
    my_expression = str(rhs_expr)

    if len(my_expression) < 5500:
        fout.write(r"\begin{dmath*}" + "\n")
        fout.write(lhs + " = " + my_expression + "\n")
        fout.write(r"\end{dmath*}" + "\n\n")
    else:
        count_oparan = 0
        count_cparan = 0
        last_frac_locations = []
        for i in range(min(5000, len(my_expression))):
            if my_expression[i] == "{":
                count_oparan += 1
            elif my_expression[i] == "}":
                count_cparan += 1
            if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                last_frac_locations.append(i)

        if len(last_frac_locations) > 2:
            fout.write(r"\begin{dmath*}" + "\n")
            fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
            fout.write(r"\end{dmath*}" + "\n\n")
        else:
            i = 5000
            while i < min(200000, len(my_expression)):
                if my_expression[i] == "{":
                    count_oparan += 1
                elif my_expression[i] == "}":
                    count_cparan += 1
                if len(my_expression) <= i + 5:
                    # Ifade tamamen taranabildi, hepsini yaz
                    fout.write(r"\begin{dmath*}" + "\n")
                    fout.write(lhs + " = " + my_expression + "\n")
                    fout.write(r"\end{dmath*}" + "\n\n")
                    return
                if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                    last_frac_locations.append(i)
                    if len(last_frac_locations) > 2:
                        break
                i += 1

            if not last_frac_locations or last_frac_locations[-1] == 0:
                # Uygun kesme noktasi bulunamadi, yine de yaz
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")
            else:
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")


def write_dmath(fout, lhs, rhs):
    """latex_write ile uzun ifade truncation destekli yazim."""
    latex_write(fout, lhs, rhs)

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# tex dosyasi olusturuldu.

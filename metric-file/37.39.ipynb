# %%
reset()

from SageNP import NewmanPenrose
#########################################################################################################
# Define 4-dim. the manifold:
MyManifold = Manifold(4, 'MyManifold', r'\mathcal{Man}')
#########################################################################################################
MyCoordinates.<t, r, th, phi> = MyManifold.chart(r't r th:\theta phi:\phi ')
#########################################################################################################
# f fonksiyonu derivative operatörleri hesaplamak için kullanılıyor. (bu satırı değiştirmeyin!)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))
#########################################################################################################
# Parametre belirleyin: (tetradlarınızın tipine göre aşağıdaki kısmı tanımlayın.)
tetrad_type = 'covariant'  # 'covariant' ya da 'contravariant' olabilir.
#########################################################################################################

var('C')

u_4 = function("u_4", imag_part_func = 0)(t,r,th,phi)
A = function("A", imag_part_func = 0)(t,r,th,phi)
f_1 = function("f_1", imag_part_func = 0)(t)
f_2 = function("f_2", imag_part_func = 0)(t)
f_3 = function("f_3", imag_part_func = 0)(t)
f_4 = function("f_4", imag_part_func = 0)(t)

A=1/(1-C^2*r^2)
#u_4=r*f_1*sin(th)*sin(phi)+r*f_2*sin(th)*cos(phi)+r*f_3*cos(th)+f_4*sqrt(1-C^2*r^2)-1/C

assume(C*r + 1 >0 and C*r - 1 >0)

# Null tetrad components:
lvec = [sqrt(1/2)*u_4, sqrt(A/2), 0, 0]
nvec = [sqrt(1/2)*u_4,-sqrt(A/2) , 0, 0]
mvec = [0, 0, r/sqrt(2), I*r*sin(th)/sqrt(2)]
mbarvec = [0, 0, r/sqrt(2), -I*r*sin(th)/sqrt(2)]

#########################################################################################################

# Define the object "metric" of the class "SageNP":
met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)

#########################################################################################################
# Out:
# 'The metric:'
# g = -u_4(t, r, th, phi)^2 dt⊗dt - 1/(C^2*r^2 - 1) dr⊗dr + r^2 dth⊗dth + r^2*sin(th)^2 dphi⊗dphi

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()

met.calculate_Weyl()
met.show_Weyl()
met.calculate_Ricci()
met.show_Ricci()

met.calculate_NPeq()
met.show_NPeq()

met.calculate_Bianchi()
met.show_Bianchi()

met.Petrov_fromWeyl()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' -1/4*(sqrt(2)*sin(th)*diff(u_4(t, r, th, phi), th) + I*sqrt(2)*diff(u_4(t, r, th, phi), phi))/(r*sin(th)*u_4(t, r, th, phi))
# 'tauNP=' -1/4*(sqrt(2)*sin(th)*diff(u_4(t, r, th, phi), th) + I*sqrt(2)*diff(u_4(t, r, th, phi), phi))/(r*sin(th)*u_4(t, r, th, phi))
# 'sigmaNP=' 0
# 'rhoNP=' 1/2*sqrt(2)*(C^2*r^2 - 1)/(sqrt(C*r + 1)*r*sqrt(abs(C*r - 1)))
# 'piNP=' 1/4*(sqrt(2)*sin(th)*diff(u_4(t, r, th, phi), th) - I*sqrt(2)*diff(u_4(t, r, th, phi), phi))/(r*sin(th)*u_4(t, r, th, phi))
# 'nuNP=' 1/4*(sqrt(2)*sin(th)*diff(u_4(t, r, th, phi), th) - I*sqrt(2)*diff(u_4(t, r, th, phi), phi))/(r*sin(th)*u_4(t, r, th, phi))
# 'muNP=' 1/2*sqrt(2)*(C^2*r^2 - 1)/(sqrt(C*r + 1)*r*sqrt(abs(C*r - 1)))
# 'lambdaNP=' 0
# 'epsilonNP=' -1/4*(2*(C^2*r^2 - 1)*abs(C*r - 1)*diff(u_4(t, r, th, phi), r) - (C^3*r^2 + C^2*r*abs(C*r - 1) - C^2*r)*u_4(t, r, th, phi))*sqrt(C*r + 1)*sqrt(abs(C*r - 1))/((sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + sqrt(2))*u_4(t, r, th, phi))
# 'gammaNP=' -1/4*(2*(C^2*r^2 - 1)*abs(C*r - 1)*diff(u_4(t, r, th, phi), r) - (C^3*r^2 + C^2*r*abs(C*r - 1) - C^2*r)*u_4(t, r, th, phi))*sqrt(C*r + 1)*sqrt(abs(C*r - 1))/((sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + sqrt(2))*u_4(t, r, th, phi))
# 'betaNP=' 1/4*sqrt(2)*cos(th)/(r*sin(th))
# 'alphaNP=' -1/4*sqrt(2)*cos(th)/(r*sin(th))
# Calculating Weyl components...
# 'Psi0NP=' -1/8*((C*r - abs(C*r - 1) - 1)*sin(th)^2*diff(u_4(t, r, th, phi), th, th) + 2*(-I*C*r + I*abs(C*r - 1) + I)*cos(th)*diff(u_4(t, r, th, phi), phi) - ((C*r - abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), th) - 2*(I*C*r - I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th, phi))*sin(th) - (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'Psi1NP=' 1/4*sqrt(C*r + 1)*(((C*r^2 - r)*diff(u_4(t, r, th, phi), r, th) - (C*r - 1)*diff(u_4(t, r, th, phi), th))*sin(th) - (-I*C*r^2 + I*r)*diff(u_4(t, r, th, phi), r, phi) - (I*C*r - I)*diff(u_4(t, r, th, phi), phi))/(r^2*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'Psi2NP=' 1/24*((C*r - abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + (2*(C*r^2 - r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), r) + 2*(C^3*r^5 - C^2*r^4 - C*r^3 + r^2 - (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'Psi3NP=' -1/4*sqrt(C*r + 1)*(((C*r^2 - r)*diff(u_4(t, r, th, phi), r, th) - (C*r - 1)*diff(u_4(t, r, th, phi), th))*sin(th) - (I*C*r^2 - I*r)*diff(u_4(t, r, th, phi), r, phi) - (-I*C*r + I)*diff(u_4(t, r, th, phi), phi))/(r^2*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'Psi4NP=' -1/8*((C*r - abs(C*r - 1) - 1)*sin(th)^2*diff(u_4(t, r, th, phi), th, th) + 2*(I*C*r - I*abs(C*r - 1) - I)*cos(th)*diff(u_4(t, r, th, phi), phi) - ((C*r - abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), th) - 2*(-I*C*r + I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th, phi))*sin(th) - (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# Calculating Ricci components...
# 'Phi00NP=' -1/8*((C*r - abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + ((C^3*r^3 - 3*C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) - (C^3*r^4 - C^2*r^3 - 2*C*r^2 - (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*diff(u_4(t, r, th, phi), r) + (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'Phi01NP=' 1/4*sqrt(C*r + 1)*(((C*r^2 - r)*diff(u_4(t, r, th, phi), r, th) - (C*r - 1)*diff(u_4(t, r, th, phi), th))*sin(th) - (-I*C*r^2 + I*r)*diff(u_4(t, r, th, phi), r, phi) - (I*C*r - I)*diff(u_4(t, r, th, phi), phi))/(r^2*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'Phi10NP=' 1/4*sqrt(C*r + 1)*(((C*r^2 - r)*diff(u_4(t, r, th, phi), r, th) - (C*r - 1)*diff(u_4(t, r, th, phi), th))*sin(th) - (I*C*r^2 - I*r)*diff(u_4(t, r, th, phi), r, phi) - (-I*C*r + I)*diff(u_4(t, r, th, phi), phi))/(r^2*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'Phi02NP=' -1/4*(sin(th)^2*diff(u_4(t, r, th, phi), th, th) - (cos(th)*diff(u_4(t, r, th, phi), th) - 2*I*diff(u_4(t, r, th, phi), th, phi))*sin(th) - 2*I*cos(th)*diff(u_4(t, r, th, phi), phi) - diff(u_4(t, r, th, phi), phi, phi))/(r^2*sin(th)^2*u_4(t, r, th, phi))
# 'Phi20NP=' -1/4*(sin(th)^2*diff(u_4(t, r, th, phi), th, th) - (cos(th)*diff(u_4(t, r, th, phi), th) + 2*I*diff(u_4(t, r, th, phi), th, phi))*sin(th) + 2*I*cos(th)*diff(u_4(t, r, th, phi), phi) - diff(u_4(t, r, th, phi), phi, phi))/(r^2*sin(th)^2*u_4(t, r, th, phi))
# 'Phi11NP=' 1/16*((C*r + abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + ((C^3*r^3 + 5*C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) - (C^3*r^4 - C^2*r^3 - 2*C*r^2 + (5*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*diff(u_4(t, r, th, phi), r) + (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 - 3*(C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'Phi12NP=' -1/4*sqrt(C*r + 1)*(((C*r^2 - r)*diff(u_4(t, r, th, phi), r, th) - (C*r - 1)*diff(u_4(t, r, th, phi), th))*sin(th) - (-I*C*r^2 + I*r)*diff(u_4(t, r, th, phi), r, phi) - (I*C*r - I)*diff(u_4(t, r, th, phi), phi))/(r^2*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'Phi21NP=' -1/4*sqrt(C*r + 1)*(((C*r^2 - r)*diff(u_4(t, r, th, phi), r, th) - (C*r - 1)*diff(u_4(t, r, th, phi), th))*sin(th) - (I*C*r^2 - I*r)*diff(u_4(t, r, th, phi), r, phi) - (-I*C*r + I)*diff(u_4(t, r, th, phi), phi))/(r^2*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'Phi22NP=' -1/8*((C*r - abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + ((C^3*r^3 - 3*C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) - (C^3*r^4 - C^2*r^3 - 2*C*r^2 - (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*diff(u_4(t, r, th, phi), r) + (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r - abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'LambdaNP=' 1/12*((3*C^2*r^2*u_4(t, r, th, phi) + (3*C^2*r^3 - 2*r)*diff(u_4(t, r, th, phi), r) + (C^2*r^4 - r^2)*diff(u_4(t, r, th, phi), r, r) - diff(u_4(t, r, th, phi), th, th))*sin(th)^2 - cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) - diff(u_4(t, r, th, phi), phi, phi))/(r^2*sin(th)^2*u_4(t, r, th, phi))
# Calculating NP equations...
# 'NPeq1=' -1/8*((C*r + abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) - (5*(C^3*r^3 + C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) - (3*C^3*r^4 - 3*C^2*r^3 - 2*C*r^2 + (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*diff(u_4(t, r, th, phi), r) - (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq2=' -1/8*((C*r + abs(C*r - 1) - 1)*sin(th)^2*diff(u_4(t, r, th, phi), th, th) - 2*(I*C*r + I*abs(C*r - 1) - I)*cos(th)*diff(u_4(t, r, th, phi), phi) - ((C*r + abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), th) + 2*(-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th, phi))*sin(th) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq3=' 1/4*((C^3*r + C^2*abs(C*r - 1) - C^2)*sin(th)*diff(u_4(t, r, th, phi), th) + (I*C^3*r + I*C^2*abs(C*r - 1) - I*C^2)*diff(u_4(t, r, th, phi), phi))*sqrt(C*r + 1)/((C^2*r^2 - 1)*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'NPeq4=' 1/8*((C^3*r + C^2*abs(C*r - 1) - C^2)*sin(th)*diff(u_4(t, r, th, phi), th) + (-I*C^3*r - I*C^2*abs(C*r - 1) + I*C^2)*diff(u_4(t, r, th, phi), phi))/(sqrt(C*r + 1)*(C*r - 1)*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'NPeq5=' 1/8*((C^3*r + C^2*abs(C*r - 1) - C^2)*sin(th)*diff(u_4(t, r, th, phi), th) + (I*C^3*r + I*C^2*abs(C*r - 1) - I*C^2)*diff(u_4(t, r, th, phi), phi))/(sqrt(C*r + 1)*(C*r - 1)*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'NPeq6=' 1/48*(5*(C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) - (3*(3*C^5*r^5 - 3*C^4*r^4 + 5*C^3*r^3 - 5*C^2*r^2 + (3*C^4*r^4 + 5*C^2*r^2)*abs(C*r - 1))*u_4(t, r, th, phi) + (3*C^5*r^6 - 3*C^4*r^5 - 13*C^3*r^4 + 13*C^2*r^3 + 10*C*r^2 + (3*C^4*r^5 - 13*C^2*r^3 + 10*r)*abs(C*r - 1) - 10*r)*diff(u_4(t, r, th, phi), r) + 17*(C^5*r^7 - C^4*r^6 - 2*C^3*r^5 + 2*C^2*r^4 + C*r^3 - r^2 + (C^4*r^6 - 2*C^2*r^4 + r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) - 5*(C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + 5*(C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*diff(u_4(t, r, th, phi), phi, phi))/((C^2*r^4 - r^2)*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq7=' 0
# 'NPeq8=' 1/24*((C*r + abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + (6*(C^3*r^3 + C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) + 2*(6*C^3*r^4 - 6*C^2*r^3 - 5*C*r^2 + (6*C^2*r^3 - 5*r)*abs(C*r - 1) + 5*r)*diff(u_4(t, r, th, phi), r) + 2*(C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq9=' -1/4*((C^3*r + C^2*abs(C*r - 1) - C^2)*sin(th)*diff(u_4(t, r, th, phi), th) + (-I*C^3*r - I*C^2*abs(C*r - 1) + I*C^2)*diff(u_4(t, r, th, phi), phi))*sqrt(C*r + 1)/((C^2*r^2 - 1)*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'NPeq10=' 1/8*((C*r + abs(C*r - 1) - 1)*sin(th)^2*diff(u_4(t, r, th, phi), th, th) - 2*(-I*C*r - I*abs(C*r - 1) + I)*cos(th)*diff(u_4(t, r, th, phi), phi) - ((C*r + abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), th) + 2*(I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th, phi))*sin(th) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq11=' 0
# 'NPeq12=' 1/48*((C*r + abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + (3*(9*C^3*r^3 - 9*C^2*r^2 - 8*C*r + (9*C^2*r^2 - 8)*abs(C*r - 1) + 8)*u_4(t, r, th, phi) - (3*C^3*r^4 - 3*C^2*r^3 - 2*C*r^2 + (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*diff(u_4(t, r, th, phi), r) - (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq13=' 0
# 'NPeq14=' -1/8*((C*r + abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) - (5*(C^3*r^3 + C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) - (3*C^3*r^4 - 3*C^2*r^3 - 2*C*r^2 + (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*diff(u_4(t, r, th, phi), r) - (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq15=' -1/8*((C^3*r + C^2*abs(C*r - 1) - C^2)*sin(th)*diff(u_4(t, r, th, phi), th) + (I*C^3*r + I*C^2*abs(C*r - 1) - I*C^2)*diff(u_4(t, r, th, phi), phi))/(sqrt(C*r + 1)*(C*r - 1)*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# 'NPeq16=' 0
# 'NPeq17=' -1/24*((C*r + abs(C*r - 1) - 1)*cos(th)*sin(th)*diff(u_4(t, r, th, phi), th) + (6*(C^3*r^3 + C^2*r^2*abs(C*r - 1) - C^2*r^2)*u_4(t, r, th, phi) + 2*(6*C^3*r^4 - 6*C^2*r^3 - 5*C*r^2 + (6*C^2*r^3 - 5*r)*abs(C*r - 1) + 5*r)*diff(u_4(t, r, th, phi), r) + 2*(C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r) + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))/(r^2*abs(C*r - 1)*sin(th)^2*u_4(t, r, th, phi))
# 'NPeq18=' 1/8*((C^3*r + C^2*abs(C*r - 1) - C^2)*sin(th)*diff(u_4(t, r, th, phi), th) + (-I*C^3*r - I*C^2*abs(C*r - 1) + I*C^2)*diff(u_4(t, r, th, phi), phi))/(sqrt(C*r + 1)*(C*r - 1)*sqrt(abs(C*r - 1))*sin(th)*u_4(t, r, th, phi))
# Calculating Bianchi identities...
# 'BI1=' -1/16*sqrt(2)*(((C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, th) + (3*C^3*r^4 - 3*C^2*r^3 - 2*C*r^2 + (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, th) - (2*(2*C^3*r^3 - 2*C^2*r^2 - C*r + (2*C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi) - (C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*sin(th)^3 - (C*r + abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), phi)^2 - ((C*r + abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), th)^2 - (I*C^3*r^5 - I*C^2*r^4 - I*C*r^3 + I*r^2 + (I*C^2*r^4 - I*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, phi) - (3*I*C^3*r^4 - 3*I*C^2*r^3 - 2*I*C*r^2 + (3*I*C^2*r^3 - 2*I*r)*abs(C*r - 1) + 2*I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, phi) - (I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, phi) + 2*(2*I*C^3*r^3 - 2*I*C^2*r^2 - I*C*r + (2*I*C^2*r^2 - I)*abs(C*r - 1) + I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi) - (I*C^3*r^4 - I*C^2*r^3 - I*C*r^2 + (I*C^2*r^3 - I*r)*abs(C*r - 1) + I*r)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi) - (-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th, th)*diff(u_4(t, r, th, phi), phi))*sin(th)^2 + ((-I*C*r - I*abs(C*r - 1) + I)*cos(th)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi) + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, phi)*diff(u_4(t, r, th, phi), phi) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi, phi))*sin(th))/(r^3*abs(C*r - 1)*sin(th)^3*u_4(t, r, th, phi)^2)
# 'BI2=' -1/16*sqrt(2)*(((C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi, phi) - (C^2*r^2 - 2*C*r + (C*r - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi, phi) + (C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi, phi) - ((C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, th) - ((C^2*r^2 - 2*C*r + (C*r - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2 - (C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + 2*((I*C^2*r^3 - 2*I*C*r^2 + (I*C*r^2 - I*r)*abs(C*r - 1) + I*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi) + (-I*C^2*r^2 + 2*I*C*r + (-I*C*r + I)*abs(C*r - 1) - I)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi) + (I*C^2*r^3 - 2*I*C*r^2 + (I*C*r^2 - I*r)*abs(C*r - 1) + I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi))*cos(th) + (2*(-I*C^2*r^3 + 2*I*C*r^2 + (-I*C*r^2 + I*r)*abs(C*r - 1) - I*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, phi) + 2*(I*C^2*r^2 - 2*I*C*r + (I*C*r - I)*abs(C*r - 1) + I)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), th, phi) + 2*(-I*C^2*r^3 + 2*I*C*r^2 + (-I*C*r^2 + I*r)*abs(C*r - 1) - I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), th, phi) + ((C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th) - ((C^2*r^2 - 2*C*r + (C*r - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2 - (C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*cos(th))*sin(th))*sqrt(C*r + 1) + (((C*r^2 + r*abs(C*r - 1) - r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, th) - (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 - (C*r^2 + r*abs(C*r - 1) - r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, phi, phi) + (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), phi, phi) + 2*((-I*C*r^2 - I*r*abs(C*r - 1) + I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, phi) + (I*C*r^2 + I*r*abs(C*r - 1) - I*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), phi))*cos(th) + (2*(I*C*r^2 + I*r*abs(C*r - 1) - I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, phi) + 2*(-I*C*r^2 - I*r*abs(C*r - 1) + I*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, phi) - ((C*r^2 + r*abs(C*r - 1) - r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th) - (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th))*cos(th))*sin(th))*sqrt(abs(C*r - 1)))/(r^3*abs(C*r - 1)^(3/2)*sin(th)^2*u_4(t, r, th, phi)^3)
# 'BI3=' -1/16*sqrt(2)*(((C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi, phi) - (C^2*r^2 - 2*C*r + (C*r - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi, phi) + (C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi, phi) - ((C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, th) - ((C^2*r^2 - 2*C*r + (C*r - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2 - (C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 - 2*((I*C^2*r^3 - 2*I*C*r^2 + (I*C*r^2 - I*r)*abs(C*r - 1) + I*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi) + (-I*C^2*r^2 + 2*I*C*r + (-I*C*r + I)*abs(C*r - 1) - I)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi) + (I*C^2*r^3 - 2*I*C*r^2 + (I*C*r^2 - I*r)*abs(C*r - 1) + I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi))*cos(th) - (2*(-I*C^2*r^3 + 2*I*C*r^2 + (-I*C*r^2 + I*r)*abs(C*r - 1) - I*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, phi) + 2*(I*C^2*r^2 - 2*I*C*r + (I*C*r - I)*abs(C*r - 1) + I)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), th, phi) + 2*(-I*C^2*r^3 + 2*I*C*r^2 + (-I*C*r^2 + I*r)*abs(C*r - 1) - I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), th, phi) - ((C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th) - ((C^2*r^2 - 2*C*r + (C*r - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2 - (C^2*r^3 - 2*C*r^2 + (C*r^2 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*cos(th))*sin(th))*sqrt(C*r + 1) - (((C*r^2 + r*abs(C*r - 1) - r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, th) - (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 - (C*r^2 + r*abs(C*r - 1) - r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, phi, phi) + (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), phi, phi) + 2*((I*C*r^2 + I*r*abs(C*r - 1) - I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, phi) + (-I*C*r^2 - I*r*abs(C*r - 1) + I*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), phi))*cos(th) + (2*(-I*C*r^2 - I*r*abs(C*r - 1) + I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, phi) + 2*(I*C*r^2 + I*r*abs(C*r - 1) - I*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, phi) - ((C*r^2 + r*abs(C*r - 1) - r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th) - (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th))*cos(th))*sin(th))*sqrt(abs(C*r - 1)))/(r^3*abs(C*r - 1)^(3/2)*sin(th)^2*u_4(t, r, th, phi)^3)
# 'BI4=' 1/16*sqrt(2)*(((C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, th) + (3*C^3*r^4 - 3*C^2*r^3 - 2*C*r^2 + (3*C^2*r^3 - 2*r)*abs(C*r - 1) + 2*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, th) - (2*(2*C^3*r^3 - 2*C^2*r^2 - C*r + (2*C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi) - (C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*sin(th)^3 - (C*r + abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), phi)^2 - ((C*r + abs(C*r - 1) - 1)*cos(th)*diff(u_4(t, r, th, phi), th)^2 - (-I*C^3*r^5 + I*C^2*r^4 + I*C*r^3 - I*r^2 + (-I*C^2*r^4 + I*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, phi) - (-3*I*C^3*r^4 + 3*I*C^2*r^3 + 2*I*C*r^2 + (-3*I*C^2*r^3 + 2*I*r)*abs(C*r - 1) - 2*I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, phi) - (-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, phi) + 2*(-2*I*C^3*r^3 + 2*I*C^2*r^2 + I*C*r + (-2*I*C^2*r^2 + I)*abs(C*r - 1) - I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi) - (-I*C^3*r^4 + I*C^2*r^3 + I*C*r^2 + (-I*C^2*r^3 + I*r)*abs(C*r - 1) - I*r)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi) - (I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th, th)*diff(u_4(t, r, th, phi), phi))*sin(th)^2 + ((I*C*r + I*abs(C*r - 1) - I)*cos(th)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi) + (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, phi)*diff(u_4(t, r, th, phi), phi) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi, phi))*sin(th))/(r^3*abs(C*r - 1)*sin(th)^3*u_4(t, r, th, phi)^2)
# 'BI5=' -1/48*(2*((sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th) - (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) - ((3*sqrt(2)*C^5*r^7 - 3*sqrt(2)*C^4*r^6 - 7*sqrt(2)*C^3*r^5 + 7*sqrt(2)*C^2*r^4 + 4*sqrt(2)*C*r^3 - 4*sqrt(2)*r^2 + (3*sqrt(2)*C^4*r^6 - 7*sqrt(2)*C^2*r^4 + 4*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r) - (sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r, r) - 2*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, th) + 2*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, th) - ((3*sqrt(2)*C^5*r^7 - 3*sqrt(2)*C^4*r^6 - 7*sqrt(2)*C^3*r^5 + 7*sqrt(2)*C^2*r^4 + 4*sqrt(2)*C*r^3 - 4*sqrt(2)*r^2 + (3*sqrt(2)*C^4*r^6 - 7*sqrt(2)*C^2*r^4 + 4*sqrt(2)*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r) - (sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r))*diff(u_4(t, r, th, phi), t))*sin(th)^2 + 2*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, phi, phi) - 2*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), phi, phi) - (4*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi, phi) + (sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi, phi) + 2*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi, phi) + (4*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th) + ((sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2 + 2*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) + (6*(2*sqrt(2)*C^5*r^5 - 2*sqrt(2)*C^4*r^4 - sqrt(2)*C^3*r^3 + sqrt(2)*C^2*r^2 + (2*sqrt(2)*C^4*r^4 - sqrt(2)*C^2*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^3 - (9*sqrt(2)*C^5*r^6 - 9*sqrt(2)*C^4*r^5 - 13*sqrt(2)*C^3*r^4 + 13*sqrt(2)*C^2*r^3 + 10*sqrt(2)*C*r^2 + (9*sqrt(2)*C^4*r^5 - 13*sqrt(2)*C^2*r^3 + 10*sqrt(2)*r)*abs(C*r - 1) - 10*sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r) - (3*sqrt(2)*C^5*r^7 - 3*sqrt(2)*C^4*r^6 - 7*sqrt(2)*C^3*r^5 + 7*sqrt(2)*C^2*r^4 + 4*sqrt(2)*C*r^3 - 4*sqrt(2)*r^2 + (3*sqrt(2)*C^4*r^6 - 7*sqrt(2)*C^2*r^4 + 4*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)^2 + 5*(sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, r, r) + 4*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi) ...
# 'BI6=' -1/24*(2*((C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th) - (C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) - ((3*C^5*r^7 - 3*C^4*r^6 - 7*C^3*r^5 + 7*C^2*r^4 + 4*C*r^3 - 4*r^2 + (3*C^4*r^6 - 7*C^2*r^4 + 4*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r) - (C^5*r^8 - C^4*r^7 - 2*C^3*r^6 + 2*C^2*r^5 + C*r^4 - r^3 + (C^4*r^7 - 2*C^2*r^5 + r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r, r) - 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, th) + 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, th) - ((3*C^5*r^7 - 3*C^4*r^6 - 7*C^3*r^5 + 7*C^2*r^4 + 4*C*r^3 - 4*r^2 + (3*C^4*r^6 - 7*C^2*r^4 + 4*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r) - (C^5*r^8 - C^4*r^7 - 2*C^3*r^6 + 2*C^2*r^5 + C*r^4 - r^3 + (C^4*r^7 - 2*C^2*r^5 + r^3)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r))*diff(u_4(t, r, th, phi), t))*sin(th)^2 + 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, phi, phi) - 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), phi, phi) + (4*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi, phi) + (C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi, phi) + 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi, phi) + (4*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th) + ((C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2 + 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) + (6*(2*C^5*r^5 - 2*C^4*r^4 - C^3*r^3 + C^2*r^2 + (2*C^4*r^4 - C^2*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^3 - (9*C^5*r^6 - 9*C^4*r^5 - 13*C^3*r^4 + 13*C^2*r^3 + 10*C*r^2 + (9*C^4*r^5 - 13*C^2*r^3 + 10*r)*abs(C*r - 1) - 10*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r) - (3*C^5*r^7 - 3*C^4*r^6 - 7*C^3*r^5 + 7*C^2*r^4 + 4*C*r^3 - 4*r^2 + (3*C^4*r^6 - 7*C^2*r^4 + 4*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)^2 + 5*(C^5*r^8 - C^4*r^7 - 2*C^3*r^6 + 2*C^2*r^5 + C*r^4 - r^3 + (C^4*r^7 - 2*C^2*r^5 + r^3)*abs(C*r - 1))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, r, r) + 4*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, th) + ((13*C^5*r^7 - 13*C^4*r^6 - 17*C^3*r^5 + 17*C^2*r^4 + 4*C*r^3 - 4*r^2 + (13*C^4*r^6 - 17*C^2*r^4 + 4*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^2 + (C^5*r^8 - C^4*r^7 - 2*C^3*r^6 + 2*C^2*r^5 + C*r^4 - r^3 + (C^4*r^7 - 2*C^2*r^5 + r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), r, r) + ((C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi)^2 + 2*(C^3*r^4 - C^2*r^3 - C*r^2 + (C^2*r^3 - r)*abs(C*r - 1) + r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th, th))*sin(th)^2)*sqrt(C*r + 1)*sqrt(abs(C*r - 1)))/((sqrt(2)*C^3*r^6 - sqrt(2)*C^2*r^5 - sqrt(2)*C*r^4 + sqrt(2)*r^3)*sin(th)^2*u_4(t, r, th, phi)^3)
# 'BI7=' 1/48*sqrt(2)*((2*(C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, th) + 2*(6*C^3*r^4 - 6*C^2*r^3 - 5*C*r^2 + (6*C^2*r^3 - 5*r)*abs(C*r - 1) + 5*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, th) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, th) + (C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th, th) - (12*(C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi) - (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), r) - (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r))*diff(u_4(t, r, th, phi), th))*sin(th)^3 - (2*(I*C^3*r^5 - I*C^2*r^4 - I*C*r^3 + I*r^2 + (I*C^2*r^4 - I*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, phi) + 2*(6*I*C^3*r^4 - 6*I*C^2*r^3 - 5*I*C*r^2 + (6*I*C^2*r^3 - 5*I*r)*abs(C*r - 1) + 5*I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, phi) - (-I*C*r - I*abs(C*r - 1) + I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th, phi) + 3*(-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, phi) + 12*(-I*C^3*r^3 + I*C^2*r^2 + I*C*r + (-I*C^2*r^2 + I)*abs(C*r - 1) - I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi) - (-I*C*r^2 - I*r*abs(C*r - 1) + I*r)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi) - (-I*C^3*r^5 + I*C^2*r^4 + I*C*r^3 - I*r^2 + (-I*C^2*r^4 + I*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r)*diff(u_4(t, r, th, phi), phi) + 2*(I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th, th)*diff(u_4(t, r, th, phi), phi) - (2*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th)^2 + (C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th))*cos(th))*sin(th)^2 + (I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), phi)*diff(u_4(t, r, th, phi), phi, phi) + (-I*C*r - I*abs(C*r - 1) + I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi, phi, phi) + (3*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi)^2 - 2*(C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi, phi))*cos(th) + ((C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, phi, phi) - 3*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, phi)*diff(u_4(t, r, th, phi), phi) + ((-I*C*r - I*abs(C*r - 1) + I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, phi) - 2*(I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi))*cos(th) - ((C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi) - 2*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))*diff(u_4(t, r, th, phi), th))*sin(th))/(r^3*abs(C*r - 1)*sin(th)^3*u_4(t, r, th, phi)^2)
# 'BI8=' 1/48*sqrt(2)*((2*(C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, th) + 2*(6*C^3*r^4 - 6*C^2*r^3 - 5*C*r^2 + (6*C^2*r^3 - 5*r)*abs(C*r - 1) + 5*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, th) - (C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, th) + (C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th, th) - (12*(C^3*r^3 - C^2*r^2 - C*r + (C^2*r^2 - 1)*abs(C*r - 1) + 1)*u_4(t, r, th, phi) - (C*r^2 + r*abs(C*r - 1) - r)*diff(u_4(t, r, th, phi), r) - (C^3*r^5 - C^2*r^4 - C*r^3 + r^2 + (C^2*r^4 - r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r))*diff(u_4(t, r, th, phi), th))*sin(th)^3 - (2*(-I*C^3*r^5 + I*C^2*r^4 + I*C*r^3 - I*r^2 + (-I*C^2*r^4 + I*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, phi) + 2*(-6*I*C^3*r^4 + 6*I*C^2*r^3 + 5*I*C*r^2 + (-6*I*C^2*r^3 + 5*I*r)*abs(C*r - 1) - 5*I*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, phi) - (I*C*r + I*abs(C*r - 1) - I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th, phi) + 3*(I*C*r + I*abs(C*r - 1) - I)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, phi) + 12*(I*C^3*r^3 - I*C^2*r^2 - I*C*r + (I*C^2*r^2 - I)*abs(C*r - 1) + I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi) - (I*C*r^2 + I*r*abs(C*r - 1) - I*r)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi) - (I*C^3*r^5 - I*C^2*r^4 - I*C*r^3 + I*r^2 + (I*C^2*r^4 - I*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r)*diff(u_4(t, r, th, phi), phi) + 2*(-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th, th)*diff(u_4(t, r, th, phi), phi) - (2*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th)^2 + (C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th))*cos(th))*sin(th)^2 + (-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), phi)*diff(u_4(t, r, th, phi), phi, phi) + (I*C*r + I*abs(C*r - 1) - I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi, phi, phi) + (3*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi)^2 - 2*(C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi, phi))*cos(th) + ((C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, phi, phi) - 3*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), th, phi)*diff(u_4(t, r, th, phi), phi) + ((I*C*r + I*abs(C*r - 1) - I)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, phi) - 2*(-I*C*r - I*abs(C*r - 1) + I)*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi))*cos(th) - ((C*r + abs(C*r - 1) - 1)*u_4(t, r, th, phi) - 2*(C*r + abs(C*r - 1) - 1)*diff(u_4(t, r, th, phi), phi, phi))*diff(u_4(t, r, th, phi), th))*sin(th))/(r^3*abs(C*r - 1)*sin(th)^3*u_4(t, r, th, phi)^2)
# 'BI9=' 1/32*((3*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi, phi) + 2*(sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi, phi) + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi, phi) + (3*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th) + (2*(sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2 + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) + (4*(3*sqrt(2)*C^5*r^5 - 3*sqrt(2)*C^4*r^4 - 2*sqrt(2)*C^3*r^3 + 2*sqrt(2)*C^2*r^2 + (3*sqrt(2)*C^4*r^4 - 2*sqrt(2)*C^2*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^3 - (11*sqrt(2)*C^5*r^6 - 11*sqrt(2)*C^4*r^5 - 17*sqrt(2)*C^3*r^4 + 17*sqrt(2)*C^2*r^3 + 10*sqrt(2)*C*r^2 + (11*sqrt(2)*C^4*r^5 - 17*sqrt(2)*C^2*r^3 + 10*sqrt(2)*r)*abs(C*r - 1) - 10*sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r) - (sqrt(2)*C^5*r^7 - sqrt(2)*C^4*r^6 - 3*sqrt(2)*C^3*r^5 + 3*sqrt(2)*C^2*r^4 + 2*sqrt(2)*C*r^3 - 2*sqrt(2)*r^2 + (sqrt(2)*C^4*r^6 - 3*sqrt(2)*C^2*r^4 + 2*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)^2 + 3*(sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, r, r) + 3*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, th) + ((7*sqrt(2)*C^5*r^7 - 7*sqrt(2)*C^4*r^6 - 9*sqrt(2)*C^3*r^5 + 9*sqrt(2)*C^2*r^4 + 2*sqrt(2)*C*r^3 - 2*sqrt(2)*r^2 + (7*sqrt(2)*C^4*r^6 - 9*sqrt(2)*C^2*r^4 + 2*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^2 + (sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), r, r) + (2*(sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2 + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th, th))*sin(th)^2)*sqrt(C*r + 1) - (((sqrt(2)*C^2*r^3 + (sqrt(2)*C*r^2 + sqrt(2)*r)*abs(C*r - 1) - sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th) - (sqrt(2)*C^2*r^3 + (sqrt(2)*C*r^2 + sqrt(2)*r)*abs(C*r - 1) - sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) - ((sqrt(2)*C^4*r^6 - 3*sqrt(2)*C^2*r^4 + 2*sqrt(2)*r^2 + (sqrt(2)*C^3*r^5 + sqrt(2)*C^2*r^4 - 2*sqrt(2)*C*r^3 - 2*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r) - (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3 + (sqrt(2)*C^3*r^6 + sqrt(2)*C^2*r^5 - sqrt(2)*C*r^4 - sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r, r) - (sqrt(2)*C^2*r^3 + (sqrt(2)*C*r^2 + sqrt(2)*r)*abs(C*r - 1) - sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, th) + (sqrt(2)*C^2*r^3 + (sqrt(2)*C*r^2 + sqrt(2)*r)*abs(C*r - 1) - sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, th) - ((sqrt(2)*C^4*r^6 - 3*sqrt(2)*C^2*r^4 + 2*sqrt(2)*r^2 + (sqrt(2)*C^3*r^5 + sqrt(2)*C^2*r^4 - 2*sqrt(2)*C*r^3 - 2*sqrt(2)*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r) - (sqrt(2)*C^4*r^7 - 2 ...
# 'BI10=' -1/32*((7*(sqrt(2)*C^3*r^5 - sqrt(2)*C^2*r^4 - sqrt(2)*C*r^3 + sqrt(2)*r^2 + (sqrt(2)*C^2*r^4 - sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, th) + (13*sqrt(2)*C^3*r^4 - 13*sqrt(2)*C^2*r^3 - 10*sqrt(2)*C*r^2 + (13*sqrt(2)*C^2*r^3 - 10*sqrt(2)*r)*abs(C*r - 1) + 10*sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, th) + (sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), th, th) - (sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th, th) - (4*(3*sqrt(2)*C^3*r^3 - 3*sqrt(2)*C^2*r^2 - 2*sqrt(2)*C*r + (3*sqrt(2)*C^2*r^2 - 2*sqrt(2))*abs(C*r - 1) + 2*sqrt(2))*u_4(t, r, th, phi) + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - 2*sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - 2*sqrt(2)*r)*abs(C*r - 1) + 2*sqrt(2)*r)*diff(u_4(t, r, th, phi), r) - (sqrt(2)*C^3*r^5 - sqrt(2)*C^2*r^4 - sqrt(2)*C*r^3 + sqrt(2)*r^2 + (sqrt(2)*C^2*r^4 - sqrt(2)*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r))*diff(u_4(t, r, th, phi), th))*sin(th)^3 + 2*(sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*cos(th)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi, phi) + (7*(I*sqrt(2)*C^3*r^5 - I*sqrt(2)*C^2*r^4 - I*sqrt(2)*C*r^3 + I*sqrt(2)*r^2 + (I*sqrt(2)*C^2*r^4 - I*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, r, phi) - (-13*I*sqrt(2)*C^3*r^4 + 13*I*sqrt(2)*C^2*r^3 + 10*I*sqrt(2)*C*r^2 + (-13*I*sqrt(2)*C^2*r^3 + 10*I*sqrt(2)*r)*abs(C*r - 1) - 10*I*sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r, phi) - (I*sqrt(2)*C*r + I*sqrt(2)*abs(C*r - 1) - I*sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th, phi) + 4*(-3*I*sqrt(2)*C^3*r^3 + 3*I*sqrt(2)*C^2*r^2 + 2*I*sqrt(2)*C*r + (-3*I*sqrt(2)*C^2*r^2 + 2*I*sqrt(2))*abs(C*r - 1) - 2*I*sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi) - (I*sqrt(2)*C^3*r^4 - I*sqrt(2)*C^2*r^3 - 2*I*sqrt(2)*C*r^2 + (I*sqrt(2)*C^2*r^3 - 2*I*sqrt(2)*r)*abs(C*r - 1) + 2*I*sqrt(2)*r)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi) - (-I*sqrt(2)*C^3*r^5 + I*sqrt(2)*C^2*r^4 + I*sqrt(2)*C*r^3 - I*sqrt(2)*r^2 + (-I*sqrt(2)*C^2*r^4 + I*sqrt(2)*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r)*diff(u_4(t, r, th, phi), phi) - (-I*sqrt(2)*C*r - I*sqrt(2)*abs(C*r - 1) + I*sqrt(2))*diff(u_4(t, r, th, phi), th, th)*diff(u_4(t, r, th, phi), phi) + ((sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*diff(u_4(t, r, th, phi), th)^2 - (sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, th))*cos(th))*sin(th)^2 - (-I*sqrt(2)*C*r - I*sqrt(2)*abs(C*r - 1) + I*sqrt(2))*diff(u_4(t, r, th, phi), phi)*diff(u_4(t, r, th, phi), phi, phi) - (I*sqrt(2)*C*r + I*sqrt(2)*abs(C*r - 1) - I*sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), phi, phi, phi) - ((sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, phi, phi) + ((I*sqrt(2)*C*r + I*sqrt(2)*abs(C*r - 1) - I*sqrt(2))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), th, phi) + (-I*sqrt(2)*C*r - I*sqrt(2)*abs(C*r - 1) + I*sqrt(2))*diff(u_4(t, r, th, phi), th)*diff(u_4(t, r, th, phi), phi))*cos(th) - ((sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*u_4(t, r, th, phi) + (sqrt(2)*C*r + sqrt(2)*abs(C*r - 1) - sqrt(2))*diff(u_4(t, r, th, phi), phi, phi))*diff(u_4(t, r, th, phi), th))*sin(th))/(r^3*abs(C*r - 1)*sin(th)^3*u_4(t, r, th, phi)^2)
# 'BI11=' -1/32*(3*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, phi, phi) + 2*(sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), phi, phi) + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)*diff(u_4(t, r, th, phi), phi, phi) + (3*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th) + (2*(sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2 + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) + (4*(3*sqrt(2)*C^5*r^5 - 3*sqrt(2)*C^4*r^4 - 2*sqrt(2)*C^3*r^3 + 2*sqrt(2)*C^2*r^2 + (3*sqrt(2)*C^4*r^4 - 2*sqrt(2)*C^2*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^3 - (11*sqrt(2)*C^5*r^6 - 11*sqrt(2)*C^4*r^5 - 17*sqrt(2)*C^3*r^4 + 17*sqrt(2)*C^2*r^3 + 10*sqrt(2)*C*r^2 + (11*sqrt(2)*C^4*r^5 - 17*sqrt(2)*C^2*r^3 + 10*sqrt(2)*r)*abs(C*r - 1) - 10*sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r) - (sqrt(2)*C^5*r^7 - sqrt(2)*C^4*r^6 - 3*sqrt(2)*C^3*r^5 + 3*sqrt(2)*C^2*r^4 + 2*sqrt(2)*C*r^3 - 2*sqrt(2)*r^2 + (sqrt(2)*C^4*r^6 - 3*sqrt(2)*C^2*r^4 + 2*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r)^2 + 3*(sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, r, r) + 3*(sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)^2*diff(u_4(t, r, th, phi), r, th, th) + ((7*sqrt(2)*C^5*r^7 - 7*sqrt(2)*C^4*r^6 - 9*sqrt(2)*C^3*r^5 + 9*sqrt(2)*C^2*r^4 + 2*sqrt(2)*C*r^3 - 2*sqrt(2)*r^2 + (7*sqrt(2)*C^4*r^6 - 9*sqrt(2)*C^2*r^4 + 2*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)^2 + (sqrt(2)*C^5*r^8 - sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^3*r^6 + 2*sqrt(2)*C^2*r^5 + sqrt(2)*C*r^4 - sqrt(2)*r^3 + (sqrt(2)*C^4*r^7 - 2*sqrt(2)*C^2*r^5 + sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), r, r) + (2*(sqrt(2)*C^3*r^3 - sqrt(2)*C^2*r^2 - sqrt(2)*C*r + (sqrt(2)*C^2*r^2 - sqrt(2))*abs(C*r - 1) + sqrt(2))*u_4(t, r, th, phi)^2 + (sqrt(2)*C^3*r^4 - sqrt(2)*C^2*r^3 - sqrt(2)*C*r^2 + (sqrt(2)*C^2*r^3 - sqrt(2)*r)*abs(C*r - 1) + sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), r))*diff(u_4(t, r, th, phi), th, th))*sin(th)^2 + (((sqrt(2)*C*r^2 + sqrt(2)*r*abs(C*r - 1) - sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th) - (sqrt(2)*C*r^2 + sqrt(2)*r*abs(C*r - 1) - sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th))*cos(th)*sin(th) - ((sqrt(2)*C^3*r^5 - sqrt(2)*C^2*r^4 - 2*sqrt(2)*C*r^3 + 2*sqrt(2)*r^2 + (sqrt(2)*C^2*r^4 - 2*sqrt(2)*r^2)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r) - (sqrt(2)*C^3*r^6 - sqrt(2)*C^2*r^5 - sqrt(2)*C*r^4 + sqrt(2)*r^3 + (sqrt(2)*C^2*r^5 - sqrt(2)*r^3)*abs(C*r - 1))*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, r, r) - (sqrt(2)*C*r^2 + sqrt(2)*r*abs(C*r - 1) - sqrt(2)*r)*u_4(t, r, th, phi)*diff(u_4(t, r, th, phi), t, th, th) + (sqrt(2)*C*r^2 + sqrt(2)*r*abs(C*r - 1) - sqrt(2)*r)*diff(u_4(t, r, th, phi), t)*diff(u_4(t, r, th, phi), th, th) - ((sqrt(2)*C^3*r^5 - sqrt(2)*C^2*r^4 - 2*sqrt(2)*C*r^3 + 2*sqrt(2)*r^2 + (sqrt(2)*C^2*r^4 - 2*sqrt(2)*r^2)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r) - (sqrt(2)*C^3*r^6 - sqrt(2)*C^2*r^5 - sqrt(2)*C*r^4 + sqrt(2)*r^3 + (sqrt(2)*C^2*r^5 - sqrt(2)*r^3)*abs(C*r - 1))*diff(u_4(t, r, th, phi), r, r))*diff(u_4(t, r, th, phi), t))* ...
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.

# %%
met.petrovtype='I'

# %%
from pathlib import Path
fout = open('37.39.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def write_dmath(fout, lhs, rhs):
    fout.write("\\begin{dmath*}\n")
    fout.write(f"{lhs} = {rhs}\n")
    fout.write("\\end{dmath*}\n\n")

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")
# Out:
# tex dosyasi olusturuldu.

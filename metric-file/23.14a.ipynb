# %%
reset()
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<t,x,y,z> = MyManifold.chart(r't x y z')


tetrad_type = 'covariant'  

var("n m", domain = "real")
G = function("G", imag_part_func = 0)(x)
P = function("P", imag_part_func = 0)(x)
H = function("H", imag_part_func = 0)(x)
T = function("T", imag_part_func = 0)(t)

assume(T>0)

lvec=[sqrt(T^(2*m)*G^(1-2*m)*P^(n))/sqrt(2), sqrt(T^(2*m)*G^(1-2*m)*P^(n))*H/sqrt(2), 0, 0]
nvec=[sqrt(T^(2*m)*G^(1-2*m)*P^(n))/sqrt(2), -sqrt(T^(2*m)*G^(1-2*m)*P^(n))*H/sqrt(2), 0, 0]
mvec=[0, 0, sqrt(T*G)*T^(n/2)*P^(1/2)/sqrt(2), I*sqrt(T*G)*T^(-n/2)*P^(-1/2)/sqrt(2)]
mbarvec=[0, 0, sqrt(T*G)*T^(n/2)*P^(1/2)/sqrt(2), -I*sqrt(T*G)*T^(-n/2)*P^(-1/2)/sqrt(2)]



met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
f = MyManifold.scalar_field(function('f')(*MyCoordinates))

met.calculate_spincoefficients()
met.calculate_Weyl()
met.calculate_Ricci()
met.calculate_NPeq()
met.calculate_Bianchi()
met.Petrov_fromWeyl()

met.show_spincoefficients()
met.show_Weyl()
met.show_Ricci()
met.show_NPeq()
met.show_Bianchi()


# def subs_abs(a):
#     a_new = a.subs({abs(T) : T, abs(T^(m)) : T^(m), abs(G) : G, abs(G^(m - 1/2)) : G^(m - 1/2), 
#                     abs(P^(n)) : P^(n), abs(P) : P, conjugate(T) : T, real_part(T) : T, imag_part(T) : 0,
#                     conjugate(G) : G, real_part(G) : G, imag_part(G) : 0, conjugate(P) : P, real_part(P) : P, imag_part(P) : 0,
#                     conjugate(T.diff(t)) : T.diff(t), real_part(T.diff(t)) : T.diff(t), imag_part(T.diff(t)) : 0, 
#                     conjugate(P.diff(x)) : P.diff(x), real_part(P.diff(x)) : P.diff(x), imag_part(P.diff(x)) : 0, 
#                     conjugate(G.diff(x)) : G.diff(x), real_part(G.diff(x)) : G.diff(x), imag_part(G.diff(x)) : 0})
#     a_new = a_new.expand().simplify_full()
#     return a_new

# funcs = [met.kappaNP.expr(), met.kappabarNP.expr(), met.tauNP.expr(), met.taubarNP.expr(), met.sigmaNP.expr(), met.sigmabarNP.expr(), 
#          met.rhoNP.expr(), met.rhobarNP.expr(), met.piNP.expr(), met.pibarNP.expr(), met.nuNP.expr(), met.nubarNP.expr(), 
#          met.muNP.expr(), met.mubarNP.expr(), met.lambdaNP.expr(), met.lambdabarNP.expr(), met.epsilonNP.expr(), 
#          met.epsilonbarNP.expr(), met.gammaNP.expr(), met.gammabarNP.expr(), met.betaNP.expr(), met.betabarNP.expr(), 
#          met.alphaNP.expr(), met.alphabarNP.expr(), met.Psi0NP.expr(), met.Psi1NP.expr(), met.Psi2NP.expr(), met.Psi3NP.expr(), 
#          met.Psi4NP.expr(), met.Phi00NP.expr(), met.Phi01NP.expr(), met.Phi10NP.expr(), met.Phi02NP.expr(), met.Phi20NP.expr(), 
#          met.Phi11NP.expr(), met.Phi12NP.expr(), met.Phi21NP.expr(), met.Phi22NP.expr(), met.LambdaNP.expr(), met.NPeq1.expr(), 
#          met.NPeq2.expr(), met.NPeq3.expr(), met.NPeq4.expr(),met.NPeq5.expr(), met.NPeq6.expr(), met.NPeq7.expr(), met.NPeq8.expr(), 
#          met.NPeq9.expr(), met.NPeq10.expr(), met.NPeq11.expr(), met.NPeq12.expr(), met.NPeq13.expr(), met.NPeq14.expr(),
#          met.NPeq15.expr(), met.NPeq16.expr(), met.NPeq17.expr(), met.NPeq18.expr(), met.BI1.expr(), met.BI2.expr(), met.BI3.expr(), 
#          met.BI4.expr(), met.BI5.expr(), met.BI6.expr(), met.BI7.expr(),met.BI8.expr(), met.BI9.expr(), met.BI10.expr(), met.BI11.expr()]
# for i in range(len(funcs)):
#     funcs[i] = subs_abs(funcs[i])
# Out:
# 'The metric:'
# g = -G(x)^(-2*m + 1)*P(x)^n*T(t)^(2*m) dt⊗dt + G(x)^(-2*m + 1)*P(x)^n*T(t)^(2*m)*H(x)^2 dx⊗dx + T(t)^(n + 1)*G(x)*P(x) dy⊗dy + T(t)^(-n + 1)*G(x)/P(x) dz⊗dz
# Calculating spin coefficients...
# Calculating Weyl components...
# Calculating Ricci components...
# Calculating NP equations...
# Calculating Bianchi identities...
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# 'kappaNP=' 0
# 'tauNP=' 0
# 'sigmaNP=' 1/4*(sqrt(2)*n*G(x)^(2*m)*abs(T(t))^m*H(x)*P(x)*diff(T(t), t) - sqrt(2)*G(x)^(2*m)*abs(T(t))^m*T(t)*diff(P(x), x))*T(t)^(-2*m - 1)*abs(G(x))^(-m + 1/2)/(sqrt(P(x)^n)*G(x)*H(x)*P(x))
# 'rhoNP=' -1/4*(sqrt(2)*G(x)^(2*m)*abs(T(t))^m*T(t)*diff(G(x), x) - sqrt(2)*G(x)^(2*m + 1)*abs(T(t))^m*H(x)*diff(T(t), t))*T(t)^(-2*m - 1)*abs(G(x))^(-m + 1/2)/(sqrt(P(x)^n)*G(x)^2*H(x))
# 'piNP=' 0
# 'nuNP=' 0
# 'muNP=' -1/4*(sqrt(2)*G(x)^(2*m)*abs(T(t))^m*T(t)*diff(G(x), x) + sqrt(2)*G(x)^(2*m + 1)*abs(T(t))^m*H(x)*diff(T(t), t))*T(t)^(-2*m - 1)*abs(G(x))^(-m + 1/2)/(sqrt(P(x)^n)*G(x)^2*H(x))
# 'lambdaNP=' -1/4*(sqrt(2)*n*G(x)^(2*m)*abs(T(t))^m*H(x)*P(x)*diff(T(t), t) + sqrt(2)*G(x)^(2*m)*abs(T(t))^m*T(t)*diff(P(x), x))*T(t)^(-2*m - 1)*abs(G(x))^(-m + 1/2)/(sqrt(P(x)^n)*G(x)*H(x)*P(x))
# 'epsilonNP=' -1/8*sqrt(2)*(2*m*G(x)^(2*m + 1)*T(t)^(2*m)*abs(G(x))^(2*m)*abs(T(t))^m*H(x)^2*P(x)*diff(T(t), t) + (2*m - 1)*G(x)^(2*m)*T(t)^(2*m + 1)*abs(G(x))^(2*m)*abs(T(t))^m*H(x)*P(x)*diff(G(x), x) - n*G(x)^(2*m + 1)*T(t)^(2*m + 1)*abs(G(x))^(2*m)*abs(T(t))^m*H(x)*diff(P(x), x) - (G(x)^(2*m + 1)*T(t)^(2*m + 1)*abs(G(x))^(2*m)*abs(T(t))^m*P(x) - G(x)^(4*m)*abs(T(t))^(3*m)*P(x)*T(t)*abs(G(x)))*diff(H(x), x))*sqrt(P(x)^n)*P(x)^(-n - 1)*T(t)^(-4*m - 1)*abs(G(x))^(-3*m + 1/2)/(G(x)^2*H(x)^2)
# 'gammaNP=' 1/8*sqrt(2)*(2*m*G(x)^(2*m + 1)*T(t)^(2*m)*abs(G(x))^(2*m)*abs(T(t))^m*H(x)^2*P(x)*diff(T(t), t) - (2*m - 1)*G(x)^(2*m)*T(t)^(2*m + 1)*abs(G(x))^(2*m)*abs(T(t))^m*H(x)*P(x)*diff(G(x), x) + n*G(x)^(2*m + 1)*T(t)^(2*m + 1)*abs(G(x))^(2*m)*abs(T(t))^m*H(x)*diff(P(x), x) + (G(x)^(2*m + 1)*T(t)^(2*m + 1)*abs(G(x))^(2*m)*abs(T(t))^m*P(x) - G(x)^(4*m)*abs(T(t))^(3*m)*P(x)*T(t)*abs(G(x)))*diff(H(x), x))*sqrt(P(x)^n)*P(x)^(-n - 1)*T(t)^(-4*m - 1)*abs(G(x))^(-3*m + 1/2)/(G(x)^2*H(x)^2)
# 'betaNP=' 0
# 'alphaNP=' 0
# 'Psi0NP=' 1/4*(2*m*n*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*T(t)*abs(G(x))*diff(G(x), x)*diff(T(t), t) + (n + 1)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x))*diff(P(x), x)^2 + (2*m*n*abs(T(t))^(2*m)*diff(T(t), t)^2 - n*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 1)*H(x)^3*P(x)^2*abs(G(x)) - G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(P(x), x, x) - (2*m*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(G(x), x) + (n^2 + 2*m - 1)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)^2*P(x)*T(t)*abs(G(x))*diff(T(t), t) - G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)*T(t)^2*abs(G(x))*diff(H(x), x))*diff(P(x), x))*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^3*H(x)^3)
# 'Psi1NP=' 0
# 'Psi2NP=' 1/12*(2*m*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x)^2 - 2*m*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x, x) + 2*m*G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x)*diff(H(x), x) - n*G(x)^(4*m + 2)*abs(T(t))^(2*m)*P(x)*T(t)^2*abs(G(x))*diff(H(x), x)*diff(P(x), x) - (n + 1)*G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x))*diff(P(x), x)^2 + n*G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(P(x), x, x) + ((n^2 + 2*m - 1)*abs(T(t))^(2*m)*diff(T(t), t)^2 - (2*m - 1)*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 2)*H(x)^3*P(x)^2*abs(G(x)))*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^4*H(x)^3)
# 'Psi3NP=' 0
# 'Psi4NP=' -1/4*(2*m*n*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*T(t)*abs(G(x))*diff(G(x), x)*diff(T(t), t) - (n + 1)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x))*diff(P(x), x)^2 - (2*m*n*abs(T(t))^(2*m)*diff(T(t), t)^2 - n*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 1)*H(x)^3*P(x)^2*abs(G(x)) + G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(P(x), x, x) + (2*m*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(G(x), x) - (n^2 + 2*m - 1)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)^2*P(x)*T(t)*abs(G(x))*diff(T(t), t) - G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)*T(t)^2*abs(G(x))*diff(H(x), x))*diff(P(x), x))*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^3*H(x)^3)
# 'Phi00NP=' -1/8*((4*m - 3)*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x)^2 - 2*n*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(G(x), x)*diff(P(x), x) + 2*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x, x) - 2*G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x)*diff(H(x), x) + ((n^2 - 4*m - 1)*abs(T(t))^(2*m)*diff(T(t), t)^2 + 2*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 2)*H(x)^3*P(x)^2*abs(G(x)) + G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x))*diff(P(x), x)^2)*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^4*H(x)^3)
# 'Phi01NP=' 0
# 'Phi10NP=' 0
# 'Phi02NP=' 1/4*(n*G(x)^(2*m + 1)*H(x)^3*P(x)^2*diff(T(t), t, t) + G(x)^(2*m + 1)*H(x)*T(t)*diff(P(x), x)^2 - G(x)^(2*m + 1)*H(x)*P(x)*T(t)*diff(P(x), x, x) - (G(x)^(2*m)*H(x)*P(x)*T(t)*diff(G(x), x) - G(x)^(2*m + 1)*P(x)*T(t)*diff(H(x), x))*diff(P(x), x))*P(x)^(-n - 2)*T(t)^(-2*m - 1)/(G(x)^2*H(x)^3)
# 'Phi20NP=' 1/4*(n*G(x)^(2*m + 1)*H(x)^3*P(x)^2*diff(T(t), t, t) + G(x)^(2*m + 1)*H(x)*T(t)*diff(P(x), x)^2 - G(x)^(2*m + 1)*H(x)*P(x)*T(t)*diff(P(x), x, x) - (G(x)^(2*m)*H(x)*P(x)*T(t)*diff(G(x), x) - G(x)^(2*m + 1)*P(x)*T(t)*diff(H(x), x))*diff(P(x), x))*P(x)^(-n - 2)*T(t)^(-2*m - 1)/(G(x)^2*H(x)^3)
# 'Phi11NP=' -1/32*(((n^2 - 4*m - 1)*T(t)^(2*m)*diff(T(t), t)^2 + 4*m*T(t)^(2*m + 1)*diff(T(t), t, t))*G(x)^(2*m + 3)*abs(G(x))^(2*m)*H(x)^3*P(x)^2 + ((n^2 - 4*m - 1)*abs(T(t))^(2*m)*diff(T(t), t)^2 + 4*m*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 2)*H(x)^3*P(x)^2*abs(G(x)) - ((4*m - 3)*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x)) + (4*m - 3)*G(x)^(2*m + 1)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x)*P(x)^2)*diff(G(x), x)^2 - 2*((2*m - 1)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)^2*T(t)^2*abs(G(x)) + (2*m - 1)*G(x)^(2*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*P(x)^2)*diff(G(x), x)*diff(H(x), x) + 2*(n*G(x)^(4*m + 2)*abs(T(t))^(2*m)*P(x)*T(t)^2*abs(G(x)) + n*G(x)^(2*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*P(x))*diff(H(x), x)*diff(P(x), x) + ((2*n - 1)*G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x)) + (2*n - 1)*G(x)^(2*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x))*diff(P(x), x)^2 + 2*((2*m - 1)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x)) + (2*m - 1)*G(x)^(2*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x)*P(x)^2)*diff(G(x), x, x) - 2*(n*G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x)) + n*G(x)^(2*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x)*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^4*H(x)^3)
# 'Phi12NP=' 0
# 'Phi21NP=' 0
# 'Phi22NP=' -1/8*((4*m - 3)*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x)^2 - 2*n*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(G(x), x)*diff(P(x), x) + 2*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x, x) - 2*G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)^2*T(t)^2*abs(G(x))*diff(G(x), x)*diff(H(x), x) + ((n^2 - 4*m - 1)*abs(T(t))^(2*m)*diff(T(t), t)^2 + 2*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 2)*H(x)^3*P(x)^2*abs(G(x)) + G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x))*diff(P(x), x)^2)*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^4*H(x)^3)
# 'LambdaNP=' -1/48*((4*m - 3)*G(x)^(2*m)*H(x)*P(x)^2*T(t)^2*diff(G(x), x)^2 - 2*(2*m - 3)*G(x)^(2*m + 1)*H(x)*P(x)^2*T(t)^2*diff(G(x), x, x) + 2*(2*m - 3)*G(x)^(2*m + 1)*P(x)^2*T(t)^2*diff(G(x), x)*diff(H(x), x) - ((n^2 - 4*m - 1)*diff(T(t), t)^2 + 4*(m + 1)*T(t)*diff(T(t), t, t))*G(x)^(2*m + 2)*H(x)^3*P(x)^2 - 2*n*G(x)^(2*m + 2)*P(x)*T(t)^2*diff(H(x), x)*diff(P(x), x) - (2*n - 1)*G(x)^(2*m + 2)*H(x)*T(t)^2*diff(P(x), x)^2 + 2*n*G(x)^(2*m + 2)*H(x)*P(x)*T(t)^2*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-2*m - 2)/(G(x)^3*H(x)^3)
# 'NPeq1=' 1/16*(2*(m*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (m*T(t)^(2*m)*conjugate(T(t)) - 2*m*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2)*G(x)^(4*m + 3)*abs(G(x))^(2*m)*H(x)^3 - ((2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*conjugate(G(x)) - 2*(2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x))*abs(G(x))^(2*m)*diff(G(x), x)^2 + ((2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*conjugate(G(x))*diff(T(t), t) - 2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*H(x)^2)*abs(G(x))^(2*m)*diff(G(x), x) + ((2*m - 1)*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*diff(T(t), t) - (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*diff(G(x), x))*conjugate(diff(G(x), x)) - 2*(G(x)^(6*m + 2)*abs(T(t))^(4*m)*H(x)*T(t)^2*abs(G(x))*diff(T(t), t) - G(x)^(4*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*diff(T(t), t) - (G(x)^(6*m + 1)*abs(T(t))^(4*m)*T(t)^3*abs(G(x)) - G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m))*diff(G(x), x))*diff(H(x), x))*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(P(x)^n*G(x)^3*H(x)^3)
# 'NPeq2=' 1/16*(2*(m*n*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (m*n*T(t)^(2*m)*conjugate(T(t)) - 2*m*n*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2)*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x) + ((2*m - 1)*n*G(x)^(4*m)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)*conjugate(G(x))*diff(T(t), t) - 2*(2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)*diff(T(t), t))*abs(G(x))^(2*m)*diff(G(x), x) + ((2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*P(x)*diff(T(t), t) - (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*diff(P(x), x))*conjugate(diff(G(x), x)) - 2*(n*G(x)^(6*m + 1)*abs(T(t))^(4*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(T(t), t) - n*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)*diff(T(t), t))*diff(H(x), x) - (2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - 2*m*T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^2 + ((2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*conjugate(G(x)) - 2*(2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x))*abs(G(x))^(2*m)*diff(G(x), x) - 2*(G(x)^(6*m + 1)*abs(T(t))^(4*m)*T(t)^3*abs(G(x)) - G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m))*diff(H(x), x))*diff(P(x), x))*P(x)^(-n - 1)*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(G(x)^2*H(x)^3)
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 1/96*((24*m^2*T(t)^(4*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (24*m^2*T(t)^(4*m)*conjugate(T(t)) - (48*m^2 - 5*n^2 + 20*m + 5)*T(t)^(4*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2 + 4*(5*m + 2)*T(t)^(4*m + 2)*abs(T(t))^(2*m)*diff(T(t), t, t))*G(x)^(4*m + 3)*abs(G(x))^(4*m)*H(x)^4*P(x)^2 - (5*(n^2 - 4*m - 1)*T(t)^(6*m + 1)*diff(T(t), t)^2 + 4*(5*m + 2)*T(t)^(6*m + 2)*diff(T(t), t, t))*G(x)^(2*m + 2)*abs(G(x))^(6*m + 1)*H(x)^4*P(x)^2 + (5*(4*m - 3)*G(x)^(2*m)*T(t)^(6*m + 3)*abs(G(x))^(6*m + 1)*H(x)^2*P(x)^2 - (6*(4*m^2 - 4*m + 1)*G(x)^(4*m)*T(t)^(4*m + 3)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*conjugate(G(x)) - (48*m^2 - 68*m + 27)*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(T(t))^(2*m)*H(x)^2*P(x)^2)*abs(G(x))^(4*m))*diff(G(x), x)^2 + 2*((10*m - 9)*G(x)^(2*m + 1)*T(t)^(6*m + 3)*abs(G(x))^(6*m + 1)*H(x)*P(x)^2 + (3*(2*m - 1)*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)^2*conjugate(G(x)) - (10*m - 9)*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)^2)*abs(G(x))^(4*m) - 3*(3*(2*m - 1)*G(x)^(6*m)*T(t)^(2*m + 3)*abs(T(t))^(4*m)*H(x)*P(x)^2*conjugate(G(x)) - 4*(2*m - 1)*G(x)^(6*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(4*m)*H(x)*P(x)^2)*abs(G(x))^(2*m + 1))*diff(G(x), x)*diff(H(x), x) - 12*(G(x)^(8*m + 3)*abs(T(t))^(6*m)*P(x)^2*T(t)^3 + 2*G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m + 1)*abs(T(t))^(4*m)*P(x)^2 - 3*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*P(x)^2)*diff(H(x), x)^2 + 5*((2*n - 1)*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)^2 - (2*n - 1)*G(x)^(2*m + 2)*T(t)^(6*m + 3)*abs(G(x))^(6*m + 1)*H(x)^2)*diff(P(x), x)^2 - 6*((4*m^2 - 4*m + 1)*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(G(x), x) - (2*m - 1)*n*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)^2*P(x)*diff(P(x), x) + (3*(2*m - 1)*G(x)^(6*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m + 1)*abs(T(t))^(4*m)*H(x)*P(x)^2 - (2*m - 1)*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2)*diff(H(x), x))*conjugate(diff(G(x), x)) + 2*((10*m - 9)*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2 - (10*m - 9)*G(x)^(2*m + 1)*T(t)^(6*m + 3)*abs(G(x))^(6*m + 1)*H(x)^2*P(x)^2)*diff(G(x), x, x) + 24*(G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m + 1)*abs(T(t))^(4*m)*H(x)*P(x)^2 - G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2)*diff(H(x), x, x) + 2*(3*((2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(T(t))^(2*m)*H(x)^2*P(x)*conjugate(G(x)) - 2*(2*m - 1)*n*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(T(t))^(2*m)*H(x)^2*P(x))*abs(G(x))^(4*m)*diff(G(x), x) + (6*n*G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m + 1)*abs(T(t))^(4*m)*H(x)*P(x) - n*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)*P(x) - 5*n*G(x)^(2*m + 2)*T(t)^(6*m + 3)*abs(G(x))^(6*m + 1)*H(x)*P(x))*diff(H(x), x))*diff(P(x), x) - 10*(n*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m)*abs(T(t))^(2*m)*H(x)^2*P(x) - n*G(x)^(2*m + 2)*T(t)^(6*m + 3)*abs(G(x))^(6*m + 1)*H(x)^2*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-8*m - 3)*abs(G(x))^(-6*m - 1)/(G(x)^3*H(x)^4)
# 'NPeq7=' 1/16*(4*n*G(x)^(2*m + 1)*T(t)^(4*m + 2)*abs(G(x))^(4*m + 1)*H(x)^3*P(x)^2*diff(T(t), t, t) - 2*(m*n*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (m*n*T(t)^(2*m)*conjugate(T(t)) - 2*m*n*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2 + 2*n*T(t)^(2*m + 2)*abs(T(t))^(2*m)*diff(T(t), t, t))*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x)^2 - ((2*m - 1)*n*G(x)^(4*m)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*conjugate(G(x))*diff(T(t), t) - 2*(2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(T(t), t))*abs(G(x))^(2*m)*diff(G(x), x) - 4*(G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x) - G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x))*diff(P(x), x)^2 - ((2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(T(t), t) + (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)*diff(P(x), x))*conjugate(diff(G(x), x)) - 2*(n*G(x)^(6*m + 1)*abs(T(t))^(4*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(T(t), t) - n*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*diff(T(t), t))*diff(H(x), x) - (2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - 2*m*T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^2*P(x) + (4*G(x)^(2*m)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x) + ((2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)*conjugate(G(x)) - 2*(2*m + 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x))*abs(G(x))^(2*m))*diff(G(x), x) + 2*(G(x)^(6*m + 1)*abs(T(t))^(4*m)*P(x)*T(t)^3*abs(G(x)) + G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*P(x) - 2*G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*P(x))*diff(H(x), x))*diff(P(x), x) + 4*(G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x) - G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(G(x)^2*H(x)^3)
# 'NPeq8=' -1/48*(2*(3*m*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (3*m*T(t)^(2*m)*conjugate(T(t)) + (n^2 - 10*m - 1)*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2 + 4*(m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*diff(T(t), t, t))*G(x)^(4*m + 3)*abs(G(x))^(2*m)*H(x)^3*P(x)^2 - 2*((n^2 - 4*m - 1)*T(t)^(4*m + 1)*diff(T(t), t)^2 + 4*(m + 1)*T(t)^(4*m + 2)*diff(T(t), t, t))*G(x)^(2*m + 2)*abs(G(x))^(4*m + 1)*H(x)^3*P(x)^2 + 3*((2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*conjugate(G(x))*diff(T(t), t) + 2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - (4*m - 1)*T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*H(x)^2*P(x)^2)*abs(G(x))^(2*m)*diff(G(x), x) + (2*(4*m - 3)*G(x)^(2*m)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x)^2 + (3*(2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)^2*conjugate(G(x)) - 4*(5*m - 3)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)^2)*abs(G(x))^(2*m))*diff(G(x), x)^2 + 4*(n*G(x)^(4*m + 3)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*P(x) - n*G(x)^(2*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*P(x))*diff(H(x), x)*diff(P(x), x) + 2*((2*n - 1)*G(x)^(4*m + 3)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x) - (2*n - 1)*G(x)^(2*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x))*diff(P(x), x)^2 + 3*((2*m - 1)*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(T(t), t) + (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*diff(G(x), x))*conjugate(diff(G(x), x)) + 4*((2*m - 3)*G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2 - (2*m - 3)*G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x)^2)*diff(G(x), x, x) + 2*(3*G(x)^(6*m + 2)*abs(T(t))^(4*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(T(t), t) - 3*G(x)^(4*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*diff(T(t), t) + (3*G(x)^(6*m + 1)*abs(T(t))^(4*m)*P(x)^2*T(t)^3*abs(G(x)) - (4*m - 3)*G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*P(x)^2 + 2*(2*m - 3)*G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*P(x)^2)*diff(G(x), x))*diff(H(x), x) - 4*(n*G(x)^(4*m + 3)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x) - n*G(x)^(2*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(G(x)^3*H(x)^3)
# 'NPeq9=' 0
# 'NPeq10=' -1/16*(2*(m*n*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (m*n*T(t)^(2*m)*conjugate(T(t)) - 2*m*n*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2)*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x) - ((2*m - 1)*n*G(x)^(4*m)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)*conjugate(G(x))*diff(T(t), t) - 2*(2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)*diff(T(t), t))*abs(G(x))^(2*m)*diff(G(x), x) - ((2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*P(x)*diff(T(t), t) + (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*diff(P(x), x))*conjugate(diff(G(x), x)) + 2*(n*G(x)^(6*m + 1)*abs(T(t))^(4*m)*H(x)*P(x)*T(t)^2*abs(G(x))*diff(T(t), t) - n*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)*diff(T(t), t))*diff(H(x), x) + (2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - 2*m*T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^2 - ((2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*conjugate(G(x)) - 2*(2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x))*abs(G(x))^(2*m)*diff(G(x), x) + 2*(G(x)^(6*m + 1)*abs(T(t))^(4*m)*T(t)^3*abs(G(x)) - G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m))*diff(H(x), x))*diff(P(x), x))*P(x)^(-n - 1)*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(G(x)^2*H(x)^3)
# 'NPeq11=' 0
# 'NPeq12=' -1/96*(((n^2 - 4*m - 1)*T(t)^(2*m)*diff(T(t), t)^2 + 4*(m - 2)*T(t)^(2*m + 1)*diff(T(t), t, t))*G(x)^(2*m + 3)*abs(G(x))^(2*m)*H(x)^3*P(x)^2 - ((n^2 - 4*m - 1)*abs(T(t))^(2*m)*diff(T(t), t)^2 + 4*(m - 2)*abs(T(t))^(2*m)*T(t)*diff(T(t), t, t))*G(x)^(4*m + 2)*H(x)^3*P(x)^2*abs(G(x)) + ((4*m - 3)*G(x)^(4*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x)) - (4*m - 3)*G(x)^(2*m + 1)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x)*P(x)^2)*diff(G(x), x)^2 + 2*((2*m + 3)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*P(x)^2*T(t)^2*abs(G(x)) - (2*m + 3)*G(x)^(2*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*P(x)^2)*diff(G(x), x)*diff(H(x), x) - 2*(n*G(x)^(4*m + 2)*abs(T(t))^(2*m)*P(x)*T(t)^2*abs(G(x)) - n*G(x)^(2*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*P(x))*diff(H(x), x)*diff(P(x), x) - ((2*n - 1)*G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*T(t)^2*abs(G(x)) - (2*n - 1)*G(x)^(2*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x))*diff(P(x), x)^2 - 2*((2*m + 3)*G(x)^(4*m + 1)*abs(T(t))^(2*m)*H(x)*P(x)^2*T(t)^2*abs(G(x)) - (2*m + 3)*G(x)^(2*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x)*P(x)^2)*diff(G(x), x, x) + 2*(n*G(x)^(4*m + 2)*abs(T(t))^(2*m)*H(x)*P(x)*T(t)^2*abs(G(x)) - n*G(x)^(2*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*H(x)*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-4*m - 2)/(abs(G(x))^(2*m)*G(x)^4*H(x)^3)
# 'NPeq13=' 0
# 'NPeq14=' 1/16*(2*(m*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (m*T(t)^(2*m)*conjugate(T(t)) - 2*m*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2)*G(x)^(4*m + 3)*abs(G(x))^(2*m)*H(x)^3 - ((2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*conjugate(G(x)) - 2*(2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x))*abs(G(x))^(2*m)*diff(G(x), x)^2 - ((2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*conjugate(G(x))*diff(T(t), t) - 2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*H(x)^2)*abs(G(x))^(2*m)*diff(G(x), x) - ((2*m - 1)*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*diff(T(t), t) + (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*diff(G(x), x))*conjugate(diff(G(x), x)) + 2*(G(x)^(6*m + 2)*abs(T(t))^(4*m)*H(x)*T(t)^2*abs(G(x))*diff(T(t), t) - G(x)^(4*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*diff(T(t), t) + (G(x)^(6*m + 1)*abs(T(t))^(4*m)*T(t)^3*abs(G(x)) - G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m))*diff(G(x), x))*diff(H(x), x))*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(P(x)^n*G(x)^3*H(x)^3)
# 'NPeq15=' 0
# 'NPeq16=' 1/16*(4*n*G(x)^(2*m + 1)*T(t)^(4*m + 2)*abs(G(x))^(4*m + 1)*H(x)^3*P(x)^2*diff(T(t), t, t) - 2*(m*n*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (m*n*T(t)^(2*m)*conjugate(T(t)) - 2*m*n*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2 + 2*n*T(t)^(2*m + 2)*abs(T(t))^(2*m)*diff(T(t), t, t))*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x)^2 + ((2*m - 1)*n*G(x)^(4*m)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*conjugate(G(x))*diff(T(t), t) - 2*(2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(T(t), t))*abs(G(x))^(2*m)*diff(G(x), x) - 4*(G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x) - G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x))*diff(P(x), x)^2 + ((2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(T(t), t) - (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)*diff(P(x), x))*conjugate(diff(G(x), x)) + 2*(n*G(x)^(6*m + 1)*abs(T(t))^(4*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(T(t), t) - n*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*diff(T(t), t))*diff(H(x), x) + (2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - 2*m*T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*abs(G(x))^(2*m)*H(x)^2*P(x) - (4*G(x)^(2*m)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x) + ((2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)*conjugate(G(x)) - 2*(2*m + 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x))*abs(G(x))^(2*m))*diff(G(x), x) - 2*(G(x)^(6*m + 1)*abs(T(t))^(4*m)*P(x)*T(t)^3*abs(G(x)) + G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*P(x) - 2*G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*P(x))*diff(H(x), x))*diff(P(x), x) + 4*(G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x) - G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(G(x)^2*H(x)^3)
# 'NPeq17=' 1/48*(2*(3*m*T(t)^(2*m + 1)*abs(T(t))^(2*m)*conjugate(diff(T(t), t))*diff(T(t), t) + (3*m*T(t)^(2*m)*conjugate(T(t)) + (n^2 - 10*m - 1)*T(t)^(2*m + 1))*abs(T(t))^(2*m)*diff(T(t), t)^2 + 4*(m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*diff(T(t), t, t))*G(x)^(4*m + 3)*abs(G(x))^(2*m)*H(x)^3*P(x)^2 - 2*((n^2 - 4*m - 1)*T(t)^(4*m + 1)*diff(T(t), t)^2 + 4*(m + 1)*T(t)^(4*m + 2)*diff(T(t), t, t))*G(x)^(2*m + 2)*abs(G(x))^(4*m + 1)*H(x)^3*P(x)^2 - 3*((2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 2)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*conjugate(G(x))*diff(T(t), t) + 2*(m*T(t)^(2*m + 2)*abs(T(t))^(2*m)*conjugate(diff(T(t), t)) + (m*T(t)^(2*m + 1)*conjugate(T(t)) - (4*m - 1)*T(t)^(2*m + 2))*abs(T(t))^(2*m)*diff(T(t), t))*G(x)^(4*m + 2)*H(x)^2*P(x)^2)*abs(G(x))^(2*m)*diff(G(x), x) + (2*(4*m - 3)*G(x)^(2*m)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x)^2 + (3*(2*m - 1)*G(x)^(4*m)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)^2*conjugate(G(x)) - 4*(5*m - 3)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(2*m)*H(x)*P(x)^2)*abs(G(x))^(2*m))*diff(G(x), x)^2 + 4*(n*G(x)^(4*m + 3)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*P(x) - n*G(x)^(2*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*P(x))*diff(H(x), x)*diff(P(x), x) + 2*((2*n - 1)*G(x)^(4*m + 3)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x) - (2*n - 1)*G(x)^(2*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x))*diff(P(x), x)^2 - 3*((2*m - 1)*G(x)^(4*m + 2)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)^2*P(x)^2*diff(T(t), t) - (2*m - 1)*G(x)^(4*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*diff(G(x), x))*conjugate(diff(G(x), x)) + 4*((2*m - 3)*G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2 - (2*m - 3)*G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x)^2)*diff(G(x), x, x) - 2*(3*G(x)^(6*m + 2)*abs(T(t))^(4*m)*H(x)*P(x)^2*T(t)^2*abs(G(x))*diff(T(t), t) - 3*G(x)^(4*m + 3)*T(t)^(2*m + 2)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x)^2*diff(T(t), t) - (3*G(x)^(6*m + 1)*abs(T(t))^(4*m)*P(x)^2*T(t)^3*abs(G(x)) - (4*m - 3)*G(x)^(4*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*P(x)^2 + 2*(2*m - 3)*G(x)^(2*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*P(x)^2)*diff(G(x), x))*diff(H(x), x) - 4*(n*G(x)^(4*m + 3)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(2*m)*H(x)*P(x) - n*G(x)^(2*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)*P(x))*diff(P(x), x, x))*P(x)^(-n - 2)*T(t)^(-6*m - 3)*abs(G(x))^(-4*m - 1)/(G(x)^3*H(x)^3)
# 'NPeq18=' 0
# 'BI1=' 0
# 'BI2=' 1/64*sqrt(2)*(((16*m^2*n*T(t)^(2*m)*conjugate(T(t)) + (n^3 - (32*m^2 + 4*m + 1)*n)*T(t)^(2*m + 1))*abs(T(t))^(3*m)*diff(T(t), t)^3 - 4*(2*m*n*T(t)^(2*m + 1)*conjugate(T(t)) - (9*m + 1)*n*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)*diff(T(t), t, t) - 8*n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t, t) + 8*(2*m^2*n*T(t)^(2*m + 1)*abs(T(t))^(3*m)*diff(T(t), t)^2 - m*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t, t))*conjugate(diff(T(t), t)))*G(x)^(6*m + 3)*abs(G(x))^(2*m)*H(x)^5*P(x)^3 - ((n^3 - (4*m + 1)*n)*T(t)^(4*m + 1)*abs(T(t))^m*diff(T(t), t)^3 + 4*(5*m + 1)*n*T(t)^(4*m + 2)*abs(T(t))^m*diff(T(t), t)*diff(T(t), t, t) - 8*n*T(t)^(4*m + 3)*abs(T(t))^m*diff(T(t), t, t, t))*G(x)^(4*m + 2)*abs(G(x))^(4*m + 1)*H(x)^5*P(x)^3 - 5*((2*n + 3)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2 - (2*n + 3)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2)*diff(P(x), x)^3 + ((4*m - 3)*n*G(x)^(4*m)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t) - (8*(2*m^2 - m)*n*G(x)^(6*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*conjugate(G(x))*diff(T(t), t) - (32*m^2 - 20*m + 3)*n*G(x)^(6*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*diff(T(t), t))*abs(G(x))^(2*m))*diff(G(x), x)^2 - ((2*n^2 + 16*m - n - 4)*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)*diff(T(t), t) - (8*(m*n + m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (8*(m*n + m)*T(t)^(2*m + 2)*conjugate(T(t)) - ((16*m + 1)*n - 2*n^2 + 4)*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 3)*abs(G(x))^(2*m)*H(x)^3*P(x) + 4*((4*m + 2*n + 1)*G(x)^(4*m + 1)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x) + (((2*m - 1)*n + 2*m - 1)*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)*conjugate(G(x)) - (4*m*n + 8*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x))*abs(G(x))^(2*m))*diff(G(x), x) + 2*(4*(n + 1)*G(x)^(8*m + 2)*abs(T(t))^(5*m)*H(x)*P(x)*T(t)^4*abs(G(x)) + (n + 8)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x) - (5*n + 12)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x))*diff(H(x), x))*diff(P(x), x)^2 - 4*(2*(2*m^2 - m)*n*G(x)^(6*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*diff(G(x), x)*diff(T(t), t) + (2*(2*m^2 - m)*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - (2*m - 1)*n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 2)*abs(G(x))^(2*m)*H(x)^4*P(x)^3 + ((2*m - 1)*n + 2*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)*diff(P(x), x)^2 - (2*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^2*diff(P(x), x, x) - (((2*m - 1)*n^2 + 4*m^2 - 4*m + 1)*G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^3*P(x)^2*diff(T(t), t) + 2*(2*m^2 - m)*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^2*diff(G(x), x) - (2*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^2*diff(H(x), x))*diff(P(x), x))*conjugate(diff(G(x), x)) - 4*((4*m - 1)*n*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^4*P(x)^3*diff(T(t), t, t) + ((2*(2*m^2 - m)*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - (2*m - 1)*n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 1)*H(x)^4*P(x)^3*conjugate(G(x)) - (4*m^2*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*conjugate(diff(T(t), t))*diff(T(t), t) + 4*(m^2*n*T(t)^(2*m + 1)*conjugate(T(t)) - m*n*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)^2 + n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 2)*H(x)^4*P(x)^3)*abs(G(x))^(2*m))*diff(G(x), x) + 2*((2*m - 1)*n*G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*diff(T(t), t) - (2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t))*diff(G(x), x, x) + 2*(4*(2*m*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t,  ...
# 'BI3=' -1/64*sqrt(2)*(((16*m^2*n*T(t)^(2*m)*conjugate(T(t)) + (n^3 - (32*m^2 + 4*m + 1)*n)*T(t)^(2*m + 1))*abs(T(t))^(3*m)*diff(T(t), t)^3 - 4*(2*m*n*T(t)^(2*m + 1)*conjugate(T(t)) - (9*m + 1)*n*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)*diff(T(t), t, t) - 8*n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t, t) + 8*(2*m^2*n*T(t)^(2*m + 1)*abs(T(t))^(3*m)*diff(T(t), t)^2 - m*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t, t))*conjugate(diff(T(t), t)))*G(x)^(6*m + 3)*abs(G(x))^(2*m)*H(x)^5*P(x)^3 - ((n^3 - (4*m + 1)*n)*T(t)^(4*m + 1)*abs(T(t))^m*diff(T(t), t)^3 + 4*(5*m + 1)*n*T(t)^(4*m + 2)*abs(T(t))^m*diff(T(t), t)*diff(T(t), t, t) - 8*n*T(t)^(4*m + 3)*abs(T(t))^m*diff(T(t), t, t, t))*G(x)^(4*m + 2)*abs(G(x))^(4*m + 1)*H(x)^5*P(x)^3 + 5*((2*n + 3)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2 - (2*n + 3)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2)*diff(P(x), x)^3 + ((4*m - 3)*n*G(x)^(4*m)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t) - (8*(2*m^2 - m)*n*G(x)^(6*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*conjugate(G(x))*diff(T(t), t) - (32*m^2 - 20*m + 3)*n*G(x)^(6*m + 1)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*diff(T(t), t))*abs(G(x))^(2*m))*diff(G(x), x)^2 - ((2*n^2 + 16*m - n - 4)*G(x)^(4*m + 2)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)*diff(T(t), t) - (8*(m*n + m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (8*(m*n + m)*T(t)^(2*m + 2)*conjugate(T(t)) - ((16*m + 1)*n - 2*n^2 + 4)*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 3)*abs(G(x))^(2*m)*H(x)^3*P(x) - 4*((4*m + 2*n + 1)*G(x)^(4*m + 1)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x) + (((2*m - 1)*n + 2*m - 1)*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)*conjugate(G(x)) - (4*m*n + 8*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x))*abs(G(x))^(2*m))*diff(G(x), x) - 2*(4*(n + 1)*G(x)^(8*m + 2)*abs(T(t))^(5*m)*H(x)*P(x)*T(t)^4*abs(G(x)) + (n + 8)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x) - (5*n + 12)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x))*diff(H(x), x))*diff(P(x), x)^2 - 4*(2*(2*m^2 - m)*n*G(x)^(6*m + 1)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*diff(G(x), x)*diff(T(t), t) - (2*(2*m^2 - m)*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - (2*m - 1)*n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 2)*abs(G(x))^(2*m)*H(x)^4*P(x)^3 - ((2*m - 1)*n + 2*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)*diff(P(x), x)^2 + (2*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^2*diff(P(x), x, x) - (((2*m - 1)*n^2 + 4*m^2 - 4*m + 1)*G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^3*P(x)^2*diff(T(t), t) - 2*(2*m^2 - m)*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^2*diff(G(x), x) + (2*m - 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^2*diff(H(x), x))*diff(P(x), x))*conjugate(diff(G(x), x)) + 4*((4*m - 1)*n*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^4*P(x)^3*diff(T(t), t, t) + ((2*(2*m^2 - m)*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - (2*m - 1)*n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 1)*H(x)^4*P(x)^3*conjugate(G(x)) - (4*m^2*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*conjugate(diff(T(t), t))*diff(T(t), t) + 4*(m^2*n*T(t)^(2*m + 1)*conjugate(T(t)) - m*n*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)^2 + n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 2)*H(x)^4*P(x)^3)*abs(G(x))^(2*m))*diff(G(x), x) + 2*((2*m - 1)*n*G(x)^(6*m + 2)*T(t)^(2*m + 3)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^3*P(x)^3*diff(T(t), t) - (2*m - 1)*n*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t))*diff(G(x), x, x) - 2*(4*(2*m*n*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - n*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, ...
# 'BI4=' 0
# 'BI5=' -1/192*sqrt(2)*(((4*(m*n^2 - 16*m^2 - m)*T(t)^(2*m)*conjugate(T(t)) - ((16*m + 11)*n^2 - 160*m^2 - 60*m - 11)*T(t)^(2*m + 1))*abs(T(t))^(3*m)*diff(T(t), t)^3 + 4*(4*(m^2 + m)*T(t)^(2*m + 1)*conjugate(T(t)) - (16*m^2 - 5*n^2 + 31*m + 6)*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)*diff(T(t), t, t) + 16*(m + 1)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t, t) + 4*((m*n^2 - 16*m^2 - m)*T(t)^(2*m + 1)*abs(T(t))^(3*m)*diff(T(t), t)^2 + 4*(m^2 + m)*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t, t))*conjugate(diff(T(t), t)))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^5*P(x)^3 + (((8*m + 11)*n^2 - 32*m^2 - 52*m - 11)*T(t)^(4*m + 1)*abs(T(t))^m*diff(T(t), t)^3 + 4*(8*m^2 - 5*n^2 + 23*m + 6)*T(t)^(4*m + 2)*abs(T(t))^m*diff(T(t), t)*diff(T(t), t, t) - 16*(m + 1)*T(t)^(4*m + 3)*abs(T(t))^m*diff(T(t), t, t, t))*G(x)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)^5*P(x)^3 - ((32*m^2 - 84*m + 45)*G(x)^(4*m)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x)^3 + (2*(32*m^2 - 34*m + 9)*G(x)^(6*m)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3*conjugate(G(x)) - (160*m^2 - 220*m + 81)*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3)*abs(G(x))^(2*m))*diff(G(x), x)^3 + 24*(G(x)^(8*m + 2)*abs(T(t))^(5*m)*P(x)^3*T(t)^4*abs(G(x)) - 2*(m - 1)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*P(x)^3 + (2*m - 3)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*P(x)^3)*diff(G(x), x)*diff(H(x), x)^2 + 4*((2*n^2 + 3*n - 5)*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2 - (2*n^2 + 3*n - 5)*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2)*diff(P(x), x)^3 - ((32*m^2 - 12*m - 9)*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t) - (4*(8*m^2 - 9*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (4*(8*m^2 - 9*m)*T(t)^(2*m + 2)*conjugate(T(t)) - (32*m^2 - 60*m + 9)*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x)^3)*diff(G(x), x)^2 + 8*((2*m - 3)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^3 - (2*m - 3)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x)^3)*diff(G(x), x)*diff(H(x), x, x) + ((2*(8*m - 3)*n - 8*m - 3)*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)*diff(T(t), t) + (4*(2*m*n + 5*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (4*(2*m*n + 5*m)*T(t)^(2*m + 2)*conjugate(T(t)) - (2*(16*m - 3)*n + 32*m - 3)*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^3*P(x) + ((2*(8*m - 7)*n - 8*m - 5)*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x) + (2*(2*(2*m - 1)*n - 2*m + 1)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)*conjugate(G(x)) - (2*(16*m - 11)*n - 16*m - 1)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x))*abs(G(x))^(2*m))*diff(G(x), x) - 4*(3*G(x)^(8*m + 3)*abs(T(t))^(5*m)*H(x)*P(x)*T(t)^4*abs(G(x)) - 2*(n^2 + 3*n - 1)*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x) + (2*n^2 + 6*n - 5)*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x))*diff(H(x), x))*diff(P(x), x)^2 - 2*((32*m^2 - 34*m + 9)*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^3*diff(G(x), x)^2 - 2*(4*m^2 - 8*m + 3)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^3*diff(G(x), x, x) + 2*(4*m^2 - 8*m + 3)*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^3*diff(G(x), x)*diff(H(x), x) + 2*(2*m - 1)*n*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)^2*diff(P(x), x, x) + ((5*(2*m - 1)*n^2 - 16*m^2 - 2*m + 5)*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t)^2 - 4*(2*m^2 - 5*m + 2)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t))*G(x)^(6*m + 3)*abs(G(x))^(2*m)*H(x)^4*P(x)^3 - (2*(2*m - 1)*n - 2*m + 1)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2*P(x)*diff(P(x), x)^2 - 2*(3*(2*m - 1)*n*G(x)^(6*m + 2)*T(t)^(2* ...
# 'BI6=' -1/192*(((4*(sqrt(2)*m*n^2 - 16*sqrt(2)*m^2 - sqrt(2)*m)*T(t)^(2*m)*conjugate(T(t)) - ((16*sqrt(2)*m + 11*sqrt(2))*n^2 - 160*sqrt(2)*m^2 - 60*sqrt(2)*m - 11*sqrt(2))*T(t)^(2*m + 1))*abs(T(t))^(3*m)*diff(T(t), t)^3 + 4*(4*(sqrt(2)*m^2 + sqrt(2)*m)*T(t)^(2*m + 1)*conjugate(T(t)) - (16*sqrt(2)*m^2 - 5*sqrt(2)*n^2 + 31*sqrt(2)*m + 6*sqrt(2))*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)*diff(T(t), t, t) + 16*(sqrt(2)*m + sqrt(2))*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t, t) + 4*((sqrt(2)*m*n^2 - 16*sqrt(2)*m^2 - sqrt(2)*m)*T(t)^(2*m + 1)*abs(T(t))^(3*m)*diff(T(t), t)^2 + 4*(sqrt(2)*m^2 + sqrt(2)*m)*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t, t))*conjugate(diff(T(t), t)))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^5*P(x)^3 + (((8*sqrt(2)*m + 11*sqrt(2))*n^2 - 32*sqrt(2)*m^2 - 52*sqrt(2)*m - 11*sqrt(2))*T(t)^(4*m + 1)*abs(T(t))^m*diff(T(t), t)^3 + 4*(8*sqrt(2)*m^2 - 5*sqrt(2)*n^2 + 23*sqrt(2)*m + 6*sqrt(2))*T(t)^(4*m + 2)*abs(T(t))^m*diff(T(t), t)*diff(T(t), t, t) - 16*(sqrt(2)*m + sqrt(2))*T(t)^(4*m + 3)*abs(T(t))^m*diff(T(t), t, t, t))*G(x)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)^5*P(x)^3 + ((32*sqrt(2)*m^2 - 84*sqrt(2)*m + 45*sqrt(2))*G(x)^(4*m)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x)^3 + (2*(32*sqrt(2)*m^2 - 34*sqrt(2)*m + 9*sqrt(2))*G(x)^(6*m)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3*conjugate(G(x)) - (160*sqrt(2)*m^2 - 220*sqrt(2)*m + 81*sqrt(2))*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3)*abs(G(x))^(2*m))*diff(G(x), x)^3 - 24*(sqrt(2)*G(x)^(8*m + 2)*abs(T(t))^(5*m)*P(x)^3*T(t)^4*abs(G(x)) - 2*(sqrt(2)*m - sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*P(x)^3 + (2*sqrt(2)*m - 3*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*P(x)^3)*diff(G(x), x)*diff(H(x), x)^2 - 4*((2*sqrt(2)*n^2 + 3*sqrt(2)*n - 5*sqrt(2))*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2 - (2*sqrt(2)*n^2 + 3*sqrt(2)*n - 5*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2)*diff(P(x), x)^3 - ((32*sqrt(2)*m^2 - 12*sqrt(2)*m - 9*sqrt(2))*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t) - (4*(8*sqrt(2)*m^2 - 9*sqrt(2)*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (4*(8*sqrt(2)*m^2 - 9*sqrt(2)*m)*T(t)^(2*m + 2)*conjugate(T(t)) - (32*sqrt(2)*m^2 - 60*sqrt(2)*m + 9*sqrt(2))*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x)^3)*diff(G(x), x)^2 - 8*((2*sqrt(2)*m - 3*sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^3 - (2*sqrt(2)*m - 3*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x)^3)*diff(G(x), x)*diff(H(x), x, x) + ((2*(8*sqrt(2)*m - 3*sqrt(2))*n - 8*sqrt(2)*m - 3*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)*diff(T(t), t) + (4*(2*sqrt(2)*m*n + 5*sqrt(2)*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (4*(2*sqrt(2)*m*n + 5*sqrt(2)*m)*T(t)^(2*m + 2)*conjugate(T(t)) - (2*(16*sqrt(2)*m - 3*sqrt(2))*n + 32*sqrt(2)*m - 3*sqrt(2))*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^3*P(x) - ((2*(8*sqrt(2)*m - 7*sqrt(2))*n - 8*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x) + (2*(2*(2*sqrt(2)*m - sqrt(2))*n - 2*sqrt(2)*m + sqrt(2))*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)*conjugate(G(x)) - (2*(16*sqrt(2)*m - 11*sqrt(2))*n - 16*sqrt(2)*m - sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x))*abs(G(x))^(2*m))*diff(G(x), x) + 4*(3*sqrt(2)*G(x)^(8*m + 3)*abs(T(t))^(5*m)*H(x)*P(x)*T(t)^4*abs(G(x)) - 2*(sqrt(2)*n^2 + 3*sqrt(2)*n - sqrt(2))*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x) + (2*sqrt(2)*n^2 + 6*sqrt(2)*n - 5*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x))*diff(H(x), x))*diff(P(x), x)^2 + 2*((32*sqrt(2)*m^2 - 34*sqrt(2)*m + 9*sqrt(2))*G(x)^(6*m + 1)*T(t)^(2*m  ...
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' -1/128*(2*((5*(sqrt(2)*m*n^2 - 4*sqrt(2)*m^2 - sqrt(2)*m)*T(t)^(2*m)*conjugate(T(t)) - 4*((3*sqrt(2)*m + sqrt(2))*n^2 - 12*sqrt(2)*m^2 - 7*sqrt(2)*m - sqrt(2))*T(t)^(2*m + 1))*abs(T(t))^(3*m)*diff(T(t), t)^3 + 2*(2*(sqrt(2)*m^2 + 2*sqrt(2)*m)*T(t)^(2*m + 1)*conjugate(T(t)) - (8*sqrt(2)*m^2 - 5*sqrt(2)*n^2 + 26*sqrt(2)*m + 5*sqrt(2))*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)*diff(T(t), t, t) + 4*(sqrt(2)*m + 2*sqrt(2))*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t, t) + (5*(sqrt(2)*m*n^2 - 4*sqrt(2)*m^2 - sqrt(2)*m)*T(t)^(2*m + 1)*abs(T(t))^(3*m)*diff(T(t), t)^2 + 4*(sqrt(2)*m^2 + 2*sqrt(2)*m)*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t, t))*conjugate(diff(T(t), t)))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^5*P(x)^3 + 4*(((sqrt(2)*m + 2*sqrt(2))*n^2 - 4*sqrt(2)*m^2 - 9*sqrt(2)*m - 2*sqrt(2))*T(t)^(4*m + 1)*abs(T(t))^m*diff(T(t), t)^3 + (4*sqrt(2)*m^2 - 5*sqrt(2)*n^2 + 18*sqrt(2)*m + 5*sqrt(2))*T(t)^(4*m + 2)*abs(T(t))^m*diff(T(t), t)*diff(T(t), t, t) - 2*(sqrt(2)*m + 2*sqrt(2))*T(t)^(4*m + 3)*abs(T(t))^m*diff(T(t), t, t, t))*G(x)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)^5*P(x)^3 - (2*(8*sqrt(2)*m^2 - 26*sqrt(2)*m + 15*sqrt(2))*G(x)^(4*m)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x)^3 + (5*(8*sqrt(2)*m^2 - 10*sqrt(2)*m + 3*sqrt(2))*G(x)^(6*m)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3*conjugate(G(x)) - 4*(24*sqrt(2)*m^2 - 38*sqrt(2)*m + 15*sqrt(2))*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3)*abs(G(x))^(2*m))*diff(G(x), x)^3 + 4*(4*sqrt(2)*G(x)^(8*m + 2)*abs(T(t))^(5*m)*P(x)^3*T(t)^4*abs(G(x)) - (6*sqrt(2)*m - 11*sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*P(x)^3 + 3*(2*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*P(x)^3)*diff(G(x), x)*diff(H(x), x)^2 + 2*((2*sqrt(2)*n^2 + 3*sqrt(2)*n - 10*sqrt(2))*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2 - (2*sqrt(2)*n^2 + 3*sqrt(2)*n - 10*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2)*diff(P(x), x)^3 - 2*(2*(4*sqrt(2)*m^2 + sqrt(2)*m - 3*sqrt(2))*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t) - (3*(4*sqrt(2)*m^2 - 3*sqrt(2)*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (3*(4*sqrt(2)*m^2 - 3*sqrt(2)*m)*T(t)^(2*m + 2)*conjugate(T(t)) - 2*(8*sqrt(2)*m^2 - 10*sqrt(2)*m + 3*sqrt(2))*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x)^3)*diff(G(x), x)^2 + 4*((2*sqrt(2)*m - 5*sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^3 - (2*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x)^3)*diff(G(x), x)*diff(H(x), x, x) + (4*(2*(sqrt(2)*m - sqrt(2))*n - sqrt(2)*m - sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)*diff(T(t), t) + 2*((2*sqrt(2)*m*n + 3*sqrt(2)*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + ((2*sqrt(2)*m*n + 3*sqrt(2)*m)*T(t)^(2*m + 2)*conjugate(T(t)) - 2*(2*(2*sqrt(2)*m - sqrt(2))*n + 2*sqrt(2)*m - sqrt(2))*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^3*P(x) + (2*(2*(2*sqrt(2)*m - 3*sqrt(2))*n - 2*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x) + ((2*(2*sqrt(2)*m - sqrt(2))*n - 10*sqrt(2)*m + 5*sqrt(2))*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)*conjugate(G(x)) - 8*(2*(sqrt(2)*m - sqrt(2))*n - 3*sqrt(2)*m)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x))*abs(G(x))^(2*m))*diff(G(x), x) - 4*(2*sqrt(2)*G(x)^(8*m + 3)*abs(T(t))^(5*m)*H(x)*P(x)*T(t)^4*abs(G(x)) - (sqrt(2)*n^2 + 3*sqrt(2)*n - 3*sqrt(2))*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x) + (sqrt(2)*n^2 + 3*sqrt(2)*n - 5*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x))*diff(H(x), x))*diff(P(x), x)^2 - (5*(8*sqrt(2)*m^2 - 10*sqrt(2)*m + 3*sqrt(2))*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T ...
# 'BI10=' 0
# 'BI11=' -1/128*(2*((5*(sqrt(2)*m*n^2 - 4*sqrt(2)*m^2 - sqrt(2)*m)*T(t)^(2*m)*conjugate(T(t)) - 4*((3*sqrt(2)*m + sqrt(2))*n^2 - 12*sqrt(2)*m^2 - 7*sqrt(2)*m - sqrt(2))*T(t)^(2*m + 1))*abs(T(t))^(3*m)*diff(T(t), t)^3 + 2*(2*(sqrt(2)*m^2 + 2*sqrt(2)*m)*T(t)^(2*m + 1)*conjugate(T(t)) - (8*sqrt(2)*m^2 - 5*sqrt(2)*n^2 + 26*sqrt(2)*m + 5*sqrt(2))*T(t)^(2*m + 2))*abs(T(t))^(3*m)*diff(T(t), t)*diff(T(t), t, t) + 4*(sqrt(2)*m + 2*sqrt(2))*T(t)^(2*m + 3)*abs(T(t))^(3*m)*diff(T(t), t, t, t) + (5*(sqrt(2)*m*n^2 - 4*sqrt(2)*m^2 - sqrt(2)*m)*T(t)^(2*m + 1)*abs(T(t))^(3*m)*diff(T(t), t)^2 + 4*(sqrt(2)*m^2 + 2*sqrt(2)*m)*T(t)^(2*m + 2)*abs(T(t))^(3*m)*diff(T(t), t, t))*conjugate(diff(T(t), t)))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^5*P(x)^3 + 4*(((sqrt(2)*m + 2*sqrt(2))*n^2 - 4*sqrt(2)*m^2 - 9*sqrt(2)*m - 2*sqrt(2))*T(t)^(4*m + 1)*abs(T(t))^m*diff(T(t), t)^3 + (4*sqrt(2)*m^2 - 5*sqrt(2)*n^2 + 18*sqrt(2)*m + 5*sqrt(2))*T(t)^(4*m + 2)*abs(T(t))^m*diff(T(t), t)*diff(T(t), t, t) - 2*(sqrt(2)*m + 2*sqrt(2))*T(t)^(4*m + 3)*abs(T(t))^m*diff(T(t), t, t, t))*G(x)^(4*m + 3)*abs(G(x))^(4*m + 1)*H(x)^5*P(x)^3 + (2*(8*sqrt(2)*m^2 - 26*sqrt(2)*m + 15*sqrt(2))*G(x)^(4*m)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x)^3 + (5*(8*sqrt(2)*m^2 - 10*sqrt(2)*m + 3*sqrt(2))*G(x)^(6*m)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3*conjugate(G(x)) - 4*(24*sqrt(2)*m^2 - 38*sqrt(2)*m + 15*sqrt(2))*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)^3)*abs(G(x))^(2*m))*diff(G(x), x)^3 - 4*(4*sqrt(2)*G(x)^(8*m + 2)*abs(T(t))^(5*m)*P(x)^3*T(t)^4*abs(G(x)) - (6*sqrt(2)*m - 11*sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*P(x)^3 + 3*(2*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*P(x)^3)*diff(G(x), x)*diff(H(x), x)^2 - 2*((2*sqrt(2)*n^2 + 3*sqrt(2)*n - 10*sqrt(2))*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)^2 - (2*sqrt(2)*n^2 + 3*sqrt(2)*n - 10*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2)*diff(P(x), x)^3 - 2*(2*(4*sqrt(2)*m^2 + sqrt(2)*m - 3*sqrt(2))*G(x)^(4*m + 1)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)^3*diff(T(t), t) - (3*(4*sqrt(2)*m^2 - 3*sqrt(2)*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + (3*(4*sqrt(2)*m^2 - 3*sqrt(2)*m)*T(t)^(2*m + 2)*conjugate(T(t)) - 2*(8*sqrt(2)*m^2 - 10*sqrt(2)*m + 3*sqrt(2))*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 2)*abs(G(x))^(2*m)*H(x)^3*P(x)^3)*diff(G(x), x)^2 - 4*((2*sqrt(2)*m - 5*sqrt(2))*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x)^3 - (2*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x)^3)*diff(G(x), x)*diff(H(x), x, x) + (4*(2*(sqrt(2)*m - sqrt(2))*n - sqrt(2)*m - sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 3)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^3*P(x)*diff(T(t), t) + 2*((2*sqrt(2)*m*n + 3*sqrt(2)*m)*T(t)^(2*m + 3)*abs(T(t))^(3*m)*conjugate(diff(T(t), t)) + ((2*sqrt(2)*m*n + 3*sqrt(2)*m)*T(t)^(2*m + 2)*conjugate(T(t)) - 2*(2*(2*sqrt(2)*m - sqrt(2))*n + 2*sqrt(2)*m - sqrt(2))*T(t)^(2*m + 3))*abs(T(t))^(3*m)*diff(T(t), t))*G(x)^(6*m + 4)*abs(G(x))^(2*m)*H(x)^3*P(x) - (2*(2*(2*sqrt(2)*m - 3*sqrt(2))*n - 2*sqrt(2)*m - 5*sqrt(2))*G(x)^(4*m + 2)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)^2*P(x) + ((2*(2*sqrt(2)*m - sqrt(2))*n - 10*sqrt(2)*m + 5*sqrt(2))*G(x)^(6*m + 2)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x)*conjugate(G(x)) - 8*(2*(sqrt(2)*m - sqrt(2))*n - 3*sqrt(2)*m)*G(x)^(6*m + 3)*T(t)^(2*m + 4)*abs(T(t))^(3*m)*H(x)^2*P(x))*abs(G(x))^(2*m))*diff(G(x), x) + 4*(2*sqrt(2)*G(x)^(8*m + 3)*abs(T(t))^(5*m)*H(x)*P(x)*T(t)^4*abs(G(x)) - (sqrt(2)*n^2 + 3*sqrt(2)*n - 3*sqrt(2))*G(x)^(6*m + 4)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs(T(t))^(3*m)*H(x)*P(x) + (sqrt(2)*n^2 + 3*sqrt(2)*n - 5*sqrt(2))*G(x)^(4*m + 3)*T(t)^(4*m + 4)*abs(G(x))^(4*m + 1)*abs(T(t))^m*H(x)*P(x))*diff(H(x), x))*diff(P(x), x)^2 + (5*(8*sqrt(2)*m^2 - 10*sqrt(2)*m + 3*sqrt(2))*G(x)^(6*m + 1)*T(t)^(2*m + 4)*abs(G(x))^(2*m)*abs( ...

# %%
from pathlib import Path
fout = open('23.14a.tex', "w")

def fitEq(expr):
    try:
        expr = expr.expand()
    except Exception:
        pass
    return latex(expr)
def safe_expr(x):
    return x.expr() if hasattr(x, "expr") else x

def is_zero_expr(expr):
    expr = safe_expr(expr)
    try:
        return bool(expr.simplify_full() == 0)
    except Exception:
        try:
            return str(expr) == "0"
        except Exception:
            return False

def clean_metric_latex(metric_display):
    metric_ltx = fitEq(metric_display)
    if metric_ltx.startswith("g = "):
        metric_ltx = metric_ltx[4:]
    elif metric_ltx.startswith("= "):
        metric_ltx = metric_ltx[2:]
    elif metric_ltx.startswith("="):
        metric_ltx = metric_ltx[1:]
    return metric_ltx.strip()

def directional_operator_latex(vector_field, coords):
    terms = []
    for i, coord in enumerate(coords):
        coeff = safe_expr(vector_field[i])
        if is_zero_expr(coeff):
            continue
        coeff_ltx = fitEq(coeff)
        coord_ltx = latex(coord)

        if coeff_ltx == "1":
            terms.append(r"\partial_{" + coord_ltx + "}")
        elif coeff_ltx == "-1":
            terms.append(r"-\partial_{" + coord_ltx + "}")
        else:
            terms.append(coeff_ltx + r"\,\partial_{" + coord_ltx + "}")

    if not terms:
        return "0"

    return " + ".join(terms).replace("+ -", "- ")

def latex_write(fout, lhs, rhs_expr):
    """
    Uzun LaTeX ifadelerini \\frac sinirlarinda keserek yazar.
    Kisa ifadeler (<5500 karakter) dogrudan yazilir.
    Uzun ifadeler uygun bir \\frac noktasindan kesilip {} \\dots ile bitirilir.
    """
    my_expression = str(rhs_expr)

    if len(my_expression) < 5500:
        fout.write(r"\begin{dmath*}" + "\n")
        fout.write(lhs + " = " + my_expression + "\n")
        fout.write(r"\end{dmath*}" + "\n\n")
    else:
        count_oparan = 0
        count_cparan = 0
        last_frac_locations = []
        for i in range(min(5000, len(my_expression))):
            if my_expression[i] == "{":
                count_oparan += 1
            elif my_expression[i] == "}":
                count_cparan += 1
            if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                last_frac_locations.append(i)

        if len(last_frac_locations) > 2:
            fout.write(r"\begin{dmath*}" + "\n")
            fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
            fout.write(r"\end{dmath*}" + "\n\n")
        else:
            i = 5000
            while i < min(200000, len(my_expression)):
                if my_expression[i] == "{":
                    count_oparan += 1
                elif my_expression[i] == "}":
                    count_cparan += 1
                if len(my_expression) <= i + 5:
                    # Ifade tamamen taranabildi, hepsini yaz
                    fout.write(r"\begin{dmath*}" + "\n")
                    fout.write(lhs + " = " + my_expression + "\n")
                    fout.write(r"\end{dmath*}" + "\n\n")
                    return
                if my_expression[i:i+5] == r"\frac" and count_oparan == count_cparan:
                    last_frac_locations.append(i)
                    if len(last_frac_locations) > 2:
                        break
                i += 1

            if not last_frac_locations or last_frac_locations[-1] == 0:
                # Uygun kesme noktasi bulunamadi, yine de yaz
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")
            else:
                fout.write(r"\begin{dmath*}" + "\n")
                fout.write(lhs + " = " + my_expression[:last_frac_locations[-1]] + r"{} \dots" + "\n")
                fout.write(r"\end{dmath*}" + "\n\n")


def write_dmath(fout, lhs, rhs):
    """latex_write ile uzun ifade truncation destekli yazim."""
    latex_write(fout, lhs, rhs)

def write_display_line(fout, text):
    fout.write("\\begin{dmath*}\n")
    fout.write(text + "\n")
    fout.write("\\end{dmath*}\n\n")

def write_section(fout, title):
    fout.write(r"\vspace{0.45cm}" + "\n")
    fout.write(r"{\Large\bfseries " + title + "}\n\n")

def nonzero_tensor_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def nonzero_vector_components(components, coords):
    pieces = []
    for comp, coord in zip(components, coords):
        expr = safe_expr(comp)
        if is_zero_expr(expr):
            continue
        pieces.append(r"\left(" + fitEq(expr) + r"\right)\,d" + latex(coord))
    if not pieces:
        return "0"
    return " + ".join(pieces)

def write_named_exprs(fout, title, items, skip_zero=False):
    write_section(fout, title)
    wrote_any = False
    for lhs, expr in items:
        if skip_zero and is_zero_expr(expr):
            continue
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))
        wrote_any = True
    if skip_zero and not wrote_any:
        fout.write(r"\textit{All expressions in this section vanish.}" + "\n\n")

def write_equation_section_with_summary(fout, title, items):
    nonzero_items = []
    vanished = False

    for lhs, expr in items:
        if is_zero_expr(expr):
            vanished = True
        else:
            nonzero_items.append((lhs, expr))

    write_section(fout, title)

    for lhs, expr in nonzero_items:
        write_dmath(fout, lhs, fitEq(safe_expr(expr)))

    if vanished:
        fout.write(r"\textit{Equations are vanished.}" + "\n\n")
    else:
        fout.write(r"\textit{Equations are not vanished.}" + "\n\n")


metric_name = Path(fout.name).stem
metric_title = f"Stephani et al., Equation ({metric_name})"



tmpstr = r'''\documentclass[landscape]{article}
\usepackage[utf8]{inputenc}
\usepackage[T1]{fontenc}
\usepackage[a4paper,landscape,margin=1.6cm]{geometry}
\usepackage[fleqn]{amsmath}
\usepackage{amssymb}
\usepackage{mathtools}
\usepackage{breqn}
\usepackage{xcolor}
\usepackage{lmodern}
\usepackage{microtype}

\setlength{\mathindent}{0pt}
\setlength{\parindent}{0pt}
\setlength{\parskip}{5pt}

\begin{document}
\raggedright

{\Huge\bfseries Newman-Penrose Formalism Calculations}

\vspace{0.2cm}
{\LARGE ''' + metric_title + r'''}

'''
fout.write(tmpstr)

write_section(fout, "Metric")
write_dmath(fout, r"ds^2", clean_metric_latex(met.g.display()))

write_section(fout, "Coordinates")
write_dmath(fout, r"\left(x^\mu\right)", fitEq(MyCoordinates[:]))

# Metrik fonksiyonları: eğer tanımlanmışsa yaz
try:
    if metric_functions:
        write_section(fout, "Metric Functions")
        for lhs, expr in metric_functions:
            write_dmath(fout, lhs, fitEq(expr))
except NameError:
    pass


write_section(fout, "Null Tetrad")

fout.write(r"{\large\itshape Covariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_tensor_components([met.lNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_tensor_components([met.nNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_tensor_components([met.mNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_tensor_components([met.mbarNP[i] for i in range(4)], MyCoordinates))

fout.write(r"{\large\itshape Contravariant components}" + "\n\n")
write_dmath(fout, "l", nonzero_vector_components([met.lupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "n", nonzero_vector_components([met.nupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, "m", nonzero_vector_components([met.mupNP[i] for i in range(4)], MyCoordinates))
write_dmath(fout, r"\overline{m}", nonzero_vector_components([met.mbarupNP[i] for i in range(4)], MyCoordinates))

write_section(fout, "Directional Derivatives")
write_dmath(fout, "D", directional_operator_latex(met.lupNP, MyCoordinates[:]))
write_dmath(fout, r"\Delta", directional_operator_latex(met.nupNP, MyCoordinates[:]))
write_dmath(fout, r"\delta", directional_operator_latex(met.mupNP, MyCoordinates[:]))
write_dmath(fout, r"\overline{\delta}", directional_operator_latex(met.mbarupNP, MyCoordinates[:]))

write_named_exprs(fout, "Spin Coefficients", [
    (r"\rho", met.rhoNP),
    (r"\sigma", met.sigmaNP),
    (r"\kappa", met.kappaNP),
    (r"\mu", met.muNP),
    (r"\lambda", met.lambdaNP),
    (r"\nu", met.nuNP),
    (r"\alpha", met.alphaNP),
    (r"\beta", met.betaNP),
    (r"\tau", met.tauNP),
    (r"\pi", met.piNP),
    (r"\epsilon", met.epsilonNP),
    (r"\gamma", met.gammaNP),
], skip_zero=False)

write_named_exprs(fout, "Ricci Tensor Components", [
    (r"\Phi_{00}", met.Phi00NP),
    (r"\Phi_{01}", met.Phi01NP),
    (r"\Phi_{02}", met.Phi02NP),
    (r"\Phi_{10}", met.Phi10NP),
    (r"\Phi_{11}", met.Phi11NP),
    (r"\Phi_{12}", met.Phi12NP),
    (r"\Phi_{20}", met.Phi20NP),
    (r"\Phi_{21}", met.Phi21NP),
    (r"\Phi_{22}", met.Phi22NP),
    (r"\Lambda", met.LambdaNP),
], skip_zero=False)

write_named_exprs(fout, "Weyl Tensor Components", [
    (r"\Psi_0", met.Psi0NP),
    (r"\Psi_1", met.Psi1NP),
    (r"\Psi_2", met.Psi2NP),
    (r"\Psi_3", met.Psi3NP),
    (r"\Psi_4", met.Psi4NP),
], skip_zero=False)

write_equation_section_with_summary(fout, "Newman-Penrose Equations", [
    (r"NP1", met.NPeq1),
    (r"NP2", met.NPeq2),
    (r"NP3", met.NPeq3),
    (r"NP4", met.NPeq4),
    (r"NP5", met.NPeq5),
    (r"NP6", met.NPeq6),
    (r"NP7", met.NPeq7),
    (r"NP8", met.NPeq8),
    (r"NP9", met.NPeq9),
    (r"NP10", met.NPeq10),
    (r"NP11", met.NPeq11),
    (r"NP12", met.NPeq12),
    (r"NP13", met.NPeq13),
    (r"NP14", met.NPeq14),
    (r"NP15", met.NPeq15),
    (r"NP16", met.NPeq16),
    (r"NP17", met.NPeq17),
    (r"NP18", met.NPeq18),
])

write_equation_section_with_summary(fout, "Bianchi Identities", [
    (r"BI1", met.BI1),
    (r"BI2", met.BI2),
    (r"BI3", met.BI3),
    (r"BI4", met.BI4),
    (r"BI5", met.BI5),
    (r"BI6", met.BI6),
    (r"BI7", met.BI7),
    (r"BI8", met.BI8),
    (r"BI9", met.BI9),
    (r"BI10", met.BI10),
    (r"BI11", met.BI11),
])

write_section(fout, "Petrov Type")
petrov = getattr(met, 'petrovtype', None)
if not petrov or petrov.strip() == '':
    try:
        import io, sys,re
        _old_stdout = sys.stdout
        sys.stdout = _buf = io.StringIO()
        met.Petrov_fromWeyl()
        _out = _buf.getvalue()
        sys.stdout = _old_stdout
        _m = re.search(r'Petrov\s*[Tt]ype\s*[=:]?\s*(O|I|II|III|D|N)\b', _out)
        if _m:
            petrov = _m.group(1)
        else:
            petrov = getattr(met, 'petrovtype', 'Unknown')
    except Exception:
        petrov = 'Unknown'
if not petrov or petrov.strip() == '':
    petrov = 'Unknown'
write_display_line(fout, r'\mathrm{Type}\ "' + str(petrov) + r'"')


fout.write(r"\end{document}")
fout.close()

print("tex dosyasi olusturuldu.")

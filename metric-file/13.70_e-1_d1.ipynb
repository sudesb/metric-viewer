# %%
from SageNP import NewmanPenrose
MyManifold = Manifold(4 , 'MyManifold', r'\mathcal{Man}')
MyCoordinates.<u, r, v, y> = MyManifold.chart(r'u r v y')
f = MyManifold.scalar_field(function('f')(*MyCoordinates))
tetrad_type = 'covariant'

var('delta, gamma, epsilon ,f1, w')
delta = 1
epsilon = -1


lvec	 = [exp(gamma)/sqrt(f*2),exp(gamma)/sqrt(f*2),0,0]

nvec = [exp(gamma)/sqrt(f*2),-exp(gamma)/sqrt(f*2),0,0]


mvec = [0,0,sqrt(f/2),sqrt(f/2)*u*w+I*r/sqrt(f*2)]
mbarvec=[0,0,sqrt(f/2),sqrt(f/2)*u*w-I*r/sqrt(f*2)]


met = NewmanPenrose(MyManifold, MyCoordinates, lvec, nvec, mvec, mbarvec, tetrad_type)
# Out:
# 'The metric:'
# g = -e^(2*gamma)/f(u, r, v, y) du⊗du + e^(2*gamma)/f(u, r, v, y) dr⊗dr + f(u, r, v, y) dv⊗dv + u*w*f(u, r, v, y) dv⊗dy + u*w*f(u, r, v, y) dy⊗dv + (u^2*w^2*f(u, r, v, y)^2 + r^2)/f(u, r, v, y) dy⊗dy

# %%
met.calculate_spincoefficients()
met.show_spincoefficients()
# Out:
# Calculating spin coefficients...
# 'kappaNP=' 0
# 'tauNP=' -1/4*sqrt(2)*(I*u*w*f(u, r, v, y)*diff(f(u, r, v, y), v) - r*diff(f(u, r, v, y), v) - I*f(u, r, v, y)*diff(f(u, r, v, y), y))/(r*f(u, r, v, y)^(3/2))
# 'sigmaNP=' 1/4*(I*sqrt(2)*w*f(u, r, v, y)^2 + sqrt(2)*r*diff(f(u, r, v, y), u) - sqrt(2)*r*diff(f(u, r, v, y), r) + sqrt(2)*f(u, r, v, y))*e^(-gamma)/(r*sqrt(f(u, r, v, y)))
# 'rhoNP=' -1/4*sqrt(2)*e^(-gamma)*sqrt(f(u, r, v, y))/r
# 'piNP=' -1/4*sqrt(2)*(I*u*w*f(u, r, v, y)*diff(f(u, r, v, y), v) + r*diff(f(u, r, v, y), v) - I*f(u, r, v, y)*diff(f(u, r, v, y), y))/(r*f(u, r, v, y)^(3/2))
# 'nuNP=' 0
# 'muNP=' -1/4*sqrt(2)*e^(-gamma)*sqrt(f(u, r, v, y))/r
# 'lambdaNP=' 1/4*(I*sqrt(2)*w*f(u, r, v, y)^2 - sqrt(2)*r*diff(f(u, r, v, y), u) - sqrt(2)*r*diff(f(u, r, v, y), r) + sqrt(2)*f(u, r, v, y))*e^(-gamma)/(r*sqrt(f(u, r, v, y)))
# 'epsilonNP=' 1/8*sqrt(2)*(I*w*f(u, r, v, y)^2 + r*diff(f(u, r, v, y), u) - r*diff(f(u, r, v, y), r))*e^(-gamma)/(r*sqrt(f(u, r, v, y)))
# 'gammaNP=' 1/8*sqrt(2)*(I*w*f(u, r, v, y)^2 - r*diff(f(u, r, v, y), u) - r*diff(f(u, r, v, y), r))*e^(-gamma)/(r*sqrt(f(u, r, v, y)))
# 'betaNP=' -1/8*(I*sqrt(2)*u*w*f(u, r, v, y)*diff(f(u, r, v, y), v) + sqrt(2)*r*diff(f(u, r, v, y), v) - I*sqrt(2)*f(u, r, v, y)*diff(f(u, r, v, y), y))/(r*f(u, r, v, y)^(3/2))
# 'alphaNP=' -1/8*(I*sqrt(2)*u*w*f(u, r, v, y)*diff(f(u, r, v, y), v) - sqrt(2)*r*diff(f(u, r, v, y), v) - I*sqrt(2)*f(u, r, v, y)*diff(f(u, r, v, y), y))/(r*f(u, r, v, y)^(3/2))

# %%
met.calculate_Weyl()
met.show_Weyl()
# Out:
# Calculating Weyl components...
# 'Psi0NP=' 1/4*(w^2*f(u, r, v, y)^3 - r^2*diff(f(u, r, v, y), u, u) + 2*r^2*diff(f(u, r, v, y), u, r) - r^2*diff(f(u, r, v, y), r, r) + (-3*I*r*f(u, r, v, y)*diff(f(u, r, v, y), u) + 3*I*r*f(u, r, v, y)*diff(f(u, r, v, y), r) - I*f(u, r, v, y)^2)*w)*e^(-2*gamma)/r^2
# 'Psi1NP=' -1/8*(3*u*w^2*f(u, r, v, y)*diff(f(u, r, v, y), v) + (-2*I*r*u*diff(f(u, r, v, y), u, v) + 2*I*r*u*diff(f(u, r, v, y), r, v) + (-I*r - 2*I*u)*diff(f(u, r, v, y), v) - 3*f(u, r, v, y)*diff(f(u, r, v, y), y))*w + 2*I*r*diff(f(u, r, v, y), u, y) - 2*I*r*diff(f(u, r, v, y), r, y) + 2*I*diff(f(u, r, v, y), y))*e^(-gamma)/r^2
# 'Psi2NP=' 1/12*((2*u^2*e^(2*gamma)*diff(f(u, r, v, y), v, v) + f(u, r, v, y)^3)*w^2 + r^2*diff(f(u, r, v, y), u, u) - r^2*diff(f(u, r, v, y), r, r) + (3*I*r*f(u, r, v, y)*diff(f(u, r, v, y), r) - 4*u*e^(2*gamma)*diff(f(u, r, v, y), v, y) - 3*I*f(u, r, v, y)^2)*w + 2*r*diff(f(u, r, v, y), r) + 2*e^(2*gamma)*diff(f(u, r, v, y), y, y))*e^(-2*gamma)/r^2
# 'Psi3NP=' -1/8*(3*u*w^2*f(u, r, v, y)*diff(f(u, r, v, y), v) + (2*I*r*u*diff(f(u, r, v, y), u, v) + 2*I*r*u*diff(f(u, r, v, y), r, v) + (I*r - 2*I*u)*diff(f(u, r, v, y), v) - 3*f(u, r, v, y)*diff(f(u, r, v, y), y))*w - 2*I*r*diff(f(u, r, v, y), u, y) - 2*I*r*diff(f(u, r, v, y), r, y) + 2*I*diff(f(u, r, v, y), y))*e^(-gamma)/r^2
# 'Psi4NP=' 1/4*(w^2*f(u, r, v, y)^3 - r^2*diff(f(u, r, v, y), u, u) - 2*r^2*diff(f(u, r, v, y), u, r) - r^2*diff(f(u, r, v, y), r, r) + (3*I*r*f(u, r, v, y)*diff(f(u, r, v, y), u) + 3*I*r*f(u, r, v, y)*diff(f(u, r, v, y), r) - I*f(u, r, v, y)^2)*w)*e^(-2*gamma)/r^2

# %%
met.calculate_Ricci()
met.show_Ricci()
# Out:
# Calculating Ricci components...
# 'Phi00NP=' -1/8*(w^2*f(u, r, v, y)^4 + r^2*diff(f(u, r, v, y), u)^2 - 2*r^2*diff(f(u, r, v, y), u)*diff(f(u, r, v, y), r) + r^2*diff(f(u, r, v, y), r)^2)*e^(-2*gamma)/(r^2*f(u, r, v, y))
# 'Phi01NP=' 1/8*(2*u*w^2*f(u, r, v, y)^3*diff(f(u, r, v, y), v) - 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), u, v) + 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), r, v) - (2*f(u, r, v, y)^3*diff(f(u, r, v, y), y) - (-I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), u) + I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v))*w + 3*(r^2*diff(f(u, r, v, y), u) - r^2*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v) + (I*r*f(u, r, v, y)*diff(f(u, r, v, y), u) - I*r*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), y))*e^(-gamma)/(r^2*f(u, r, v, y)^2)
# 'Phi10NP=' 1/8*(2*u*w^2*f(u, r, v, y)^3*diff(f(u, r, v, y), v) - 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), u, v) + 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), r, v) - (2*f(u, r, v, y)^3*diff(f(u, r, v, y), y) - (I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), u) - I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v))*w + 3*(r^2*diff(f(u, r, v, y), u) - r^2*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v) + (-I*r*f(u, r, v, y)*diff(f(u, r, v, y), u) + I*r*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), y))*e^(-gamma)/(r^2*f(u, r, v, y)^2)
# 'Phi02NP=' -1/8*(2*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), u)^2 - 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), u, u) - 2*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), r)^2 + 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), r, r) + 2*r*f(u, r, v, y)^3*diff(f(u, r, v, y), r) + 3*r^2*e^(2*gamma)*diff(f(u, r, v, y), v)^2 - 2*r^2*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v, v) - 4*I*r*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v, y) + 6*I*r*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v)*diff(f(u, r, v, y), y) - 3*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), y)^2 + 2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), y, y) - (3*u^2*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)^2 - 2*u^2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, v) - 2*f(u, r, v, y)^6)*w^2 - 2*(2*I*r*f(u, r, v, y)^4*diff(f(u, r, v, y), u) + 3*I*r*u*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v)^2 - 2*I*r*u*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v, v) + 2*u*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, y) - 3*u*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)*diff(f(u, r, v, y), y))*w)*e^(-2*gamma)/(r^2*f(u, r, v, y)^3)
# 'Phi20NP=' -1/8*(2*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), u)^2 - 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), u, u) - 2*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), r)^2 + 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), r, r) + 2*r*f(u, r, v, y)^3*diff(f(u, r, v, y), r) + 3*r^2*e^(2*gamma)*diff(f(u, r, v, y), v)^2 - 2*r^2*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v, v) + 4*I*r*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v, y) - 6*I*r*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v)*diff(f(u, r, v, y), y) - 3*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), y)^2 + 2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), y, y) - (3*u^2*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)^2 - 2*u^2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, v) - 2*f(u, r, v, y)^6)*w^2 - 2*(-2*I*r*f(u, r, v, y)^4*diff(f(u, r, v, y), u) - 3*I*r*u*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v)^2 + 2*I*r*u*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v, v) + 2*u*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, y) - 3*u*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)*diff(f(u, r, v, y), y))*w)*e^(-2*gamma)/(r^2*f(u, r, v, y)^3)
# 'Phi11NP=' -1/16*(3*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), u)^2 - 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), u, u) - 3*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), r)^2 + 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), r, r) + 2*r*f(u, r, v, y)^3*diff(f(u, r, v, y), r) + 3*r^2*e^(2*gamma)*diff(f(u, r, v, y), v)^2 - 2*r^2*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v, v) - e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), y)^2 + 2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), y, y) - (u^2*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)^2 - 2*u^2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, v) - f(u, r, v, y)^6)*w^2 - 2*(2*u*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, y) - u*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)*diff(f(u, r, v, y), y))*w)*e^(-2*gamma)/(r^2*f(u, r, v, y)^3)
# 'Phi12NP=' 1/8*(2*u*w^2*f(u, r, v, y)^3*diff(f(u, r, v, y), v) - 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), u, v) - 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), r, v) - (2*f(u, r, v, y)^3*diff(f(u, r, v, y), y) - (-I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), u) - I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v))*w + 3*(r^2*diff(f(u, r, v, y), u) + r^2*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v) + (I*r*f(u, r, v, y)*diff(f(u, r, v, y), u) + I*r*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), y))*e^(-gamma)/(r^2*f(u, r, v, y)^2)
# 'Phi21NP=' 1/8*(2*u*w^2*f(u, r, v, y)^3*diff(f(u, r, v, y), v) - 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), u, v) - 2*r^2*f(u, r, v, y)*diff(f(u, r, v, y), r, v) - (2*f(u, r, v, y)^3*diff(f(u, r, v, y), y) - (I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), u) + I*r*u*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v))*w + 3*(r^2*diff(f(u, r, v, y), u) + r^2*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), v) + (-I*r*f(u, r, v, y)*diff(f(u, r, v, y), u) - I*r*f(u, r, v, y)*diff(f(u, r, v, y), r))*diff(f(u, r, v, y), y))*e^(-gamma)/(r^2*f(u, r, v, y)^2)
# 'Phi22NP=' -1/8*(w^2*f(u, r, v, y)^4 + r^2*diff(f(u, r, v, y), u)^2 + 2*r^2*diff(f(u, r, v, y), u)*diff(f(u, r, v, y), r) + r^2*diff(f(u, r, v, y), r)^2)*e^(-2*gamma)/(r^2*f(u, r, v, y))
# 'LambdaNP=' 1/48*(3*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), u)^2 - 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), u, u) - 3*r^2*f(u, r, v, y)^2*diff(f(u, r, v, y), r)^2 + 2*r^2*f(u, r, v, y)^3*diff(f(u, r, v, y), r, r) + 2*r*f(u, r, v, y)^3*diff(f(u, r, v, y), r) - 15*r^2*e^(2*gamma)*diff(f(u, r, v, y), v)^2 + 6*r^2*e^(2*gamma)*f(u, r, v, y)*diff(f(u, r, v, y), v, v) - 3*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), y)^2 + 2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), y, y) - (3*u^2*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)^2 - 2*u^2*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, v) - f(u, r, v, y)^6)*w^2 - 2*(2*u*e^(2*gamma)*f(u, r, v, y)^3*diff(f(u, r, v, y), v, y) - 3*u*e^(2*gamma)*f(u, r, v, y)^2*diff(f(u, r, v, y), v)*diff(f(u, r, v, y), y))*w)*e^(-2*gamma)/(r^2*f(u, r, v, y)^3)

# %%
met.calculate_NPeq()
met.show_NPeq()
# Out:
# Calculating NP equations...
# 'NPeq1=' 0
# 'NPeq2=' 0
# 'NPeq3=' 0
# 'NPeq4=' 0
# 'NPeq5=' 0
# 'NPeq6=' 0
# 'NPeq7=' 0
# 'NPeq8=' 0
# 'NPeq9=' 0
# 'NPeq10=' 0
# 'NPeq11=' 0
# 'NPeq12=' 0
# 'NPeq13=' 0
# 'NPeq14=' 0
# 'NPeq15=' 0
# 'NPeq16=' 0
# 'NPeq17=' 0
# 'NPeq18=' 0

# %%
met.calculate_Bianchi()
met.show_Bianchi()
# Out:
# Calculating Bianchi identities...
# 'BI1=' 0
# 'BI2=' 0
# 'BI3=' 0
# 'BI4=' 0
# 'BI5=' 0
# 'BI6=' 0
# 'BI7=' 0
# 'BI8=' 0
# 'BI9=' 0
# 'BI10=' 0
# 'BI11=' 0

# %%
met.Petrov_fromWeyl()
met.Petrov_frominvariants()
# Out:
# Calculating Petrov Type...
# Attention: This procedure depends on the simplification of the structures. Therefore the Petrov type can be simpler.
# Calculating Petrov Type...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 met.Petrov_fromWeyl()
# ----> 2 met.Petrov_frominvariants()
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:1011, in NewmanPenrose.Petrov_frominvariants(self)
#    1009 KK=NewmanPenrose.simplify_fullfull(self.PetrovinvKNP.expr())
#    1010 NN=NewmanPenrose.simplify_fullfull(self.PetrovinvNNP.expr())
# -> 1011 IIJJterm=NewmanPenrose.simplify_fullfull((II**_sage_const_3 -_sage_const_27 *JJ**_sage_const_2 ))
#    1012 if IIJJterm==_sage_const_0 :
#    1013     if II==_sage_const_0  and JJ==_sage_const_0 :
#
# File ~/Library/SageMath-10-7/lib/python3.13/site-packages/SageNP/SageNP.py:536, in NewmanPenrose.simplify_fullfull(x)
#     534 def simplify_fullfull(x):
#     535     #This routine is used at some points in the functions
# --> 536     return x.expand().canonicalize_radical().simplify_rectform().simplify_full()
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/symbolic/expression.pyx:11459, in sage.symbolic.expression.Expression.canonicalize_radical (build/cythonized/sage/symbolic/expression.cpp:112595)()
#   11457     """
#   11458     from sage.calculus.calculus import maxima
# > 11459     return self.parent()(self._maxima_().radcan())
#   11460
#   11461 def simplify_log(self, algorithm=None):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:701, in InterfaceFunctionElement.__call__(self, *args, **kwds)
#     700 def __call__(self, *args, **kwds):
# --> 701     return self._obj.parent().function_call(self._name, [self._obj] + list(args), kwds)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:620, in Interface.function_call(self, function, args, kwds)
#     616 self._check_valid_function_name(function)
#     617 s = self._function_call_string(function,
#     618                                [s.name() for s in args],
#     619                                ['%s=%s' % (key, value.name()) for key, value in kwds.items()])
# --> 620 return self.new(s)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:386, in Interface.new(self, code)
#     385 def new(self, code):
# --> 386     return self(code)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:299, in Interface.__call__(self, x, name)
#     296         pass
#     298 if isinstance(x, str):
# --> 299     return cls(self, x, name=name)
#     300 try:
#     301     # Special methods do not and should not have an option to
#     302     # set the name directly, as the identifier assigned by the
#     303     # interface should stay consistent. An identifier with a
#     304     # user-assigned name might change its value, so we return a
#     305     # new element.
#     306     result = self._coerce_from_special_method(x)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/interface.py:753, in InterfaceElement.__init__(self, parent, value, is_name, name)
#     751 else:
#     752     try:
# --> 753         self._name = parent._create(value, name=name)
#     754     except (TypeError, RuntimeError, ValueError) as x:
#     755         raise TypeError(x)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:624, in MaximaLib._create(self, value, name)
#     622         maxima_eval([[msetq], cadadr("#$%s$#$" % name), value])
#     623     else:
# --> 624         self.set(name, value)
#     625 except RuntimeError as error:
#     626     s = str(error)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:534, in MaximaLib.set(self, var, value)
#     532     raise TypeError
#     533 cmd = '%s : %s$' % (var, value.rstrip(';'))
# --> 534 self.eval(cmd)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/interfaces/maxima_lib.py:480, in MaximaLib._eval_line(self, line, locals, reformat, **kwds)
#     478         line = line[ind_dollar + 1:]
#     479         if statement:
# --> 480             maxima_eval("#$%s$" % statement)
#     481 if not reformat:
#     482     return result
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:828, in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:12202)()
#     826     """
#     827     lispargs = EclObject(list(args))
# --> 828     return ecl_wrap(ecl_safe_apply(self.obj, (<EclObject>lispargs).obj))
#     829
#     830 def __richcmp__(left, right, int op):
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/site-packages/sage/libs/ecl.pyx:354, in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:9658)()
#     352 message = ecl_string_to_python(error)
#     353 if "Console interrupt" in message:
# --> 354     raise KeyboardInterrupt("ECL says: {}".format(message))
#     355 else:
#     356     raise RuntimeError("ECL says: {}".format(message))
#
# KeyboardInterrupt: ECL says: Console interrupt.

# %%
def fitEq(expr):
    expanded_expr = expr.expand()

    latex_expr = latex(expanded_expr)

    return latex_expr

# Yardımcı fonksiyonlar
def compare_expressions(orig, trans):
    """Dönüşümleri karşılaştır"""
    if trans == 0:
        return "0"
    try:
        if bool(trans == orig):
            return None
    except:
        if str(trans) == str(orig):
            return None
    return str(latex(fitEq(trans)))

def write_transformation_section(fout, coeffs, title):
    """Dönüşüm bölümünü yaz"""
    fout.write(f"\n\\textit{{{title}:}}\n\n")
    
    for symbol, orig, trans in coeffs:
        result = compare_expressions(orig, trans)
        if result is None:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {symbol}\n\\end{{dmath}}\n\n")
        else:
            fout.write(f"\\begin{{dmath}}\n{symbol}' = {result}\n\\end{{dmath}}\n\n")

def write_transformations(fout, met, transform_type):
    """Tüm dönüşümleri yaz"""
    tr_suffix = f"_tr{transform_type}"
    
    fout.write(f"\n\\newpage\n\\underline{{{transform_type} Type transformations:}}\n")
    
    # Spin coefficients
    spin_coeffs = [
        ('\\rho', met.rhoNP.expr(), getattr(met, f'rhoNP{tr_suffix}')),
        ('\\sigma', met.sigmaNP.expr(), getattr(met, f'sigmaNP{tr_suffix}')),
        ('\\kappa', met.kappaNP.expr(), getattr(met, f'kappaNP{tr_suffix}')),
        ('\\mu', met.muNP.expr(), getattr(met, f'muNP{tr_suffix}')),
        ('\\lambda', met.lambdaNP.expr(), getattr(met, f'lambdaNP{tr_suffix}')),
        ('\\nu', met.nuNP.expr(), getattr(met, f'nuNP{tr_suffix}')),
        ('\\alpha', met.alphaNP.expr(), getattr(met, f'alphaNP{tr_suffix}')),
        ('\\beta', met.betaNP.expr(), getattr(met, f'betaNP{tr_suffix}')),
        ('\\tau', met.tauNP.expr(), getattr(met, f'tauNP{tr_suffix}')),
        ('\\pi', met.piNP.expr(), getattr(met, f'piNP{tr_suffix}')),
        ('\\epsilon', met.epsilonNP.expr(), getattr(met, f'epsilonNP{tr_suffix}')),
        ('\\gamma', met.gammaNP.expr(), getattr(met, f'gammaNP{tr_suffix}'))
    ]
    write_transformation_section(fout, spin_coeffs, "Spin coefficients")
    
    # Weyl components
    weyl_comps = [
        ('\\Psi_0', met.Psi0NP.expr(), getattr(met, f'Psi0NP{tr_suffix}')),
        ('\\Psi_1', met.Psi1NP.expr(), getattr(met, f'Psi1NP{tr_suffix}')),
        ('\\Psi_2', met.Psi2NP.expr(), getattr(met, f'Psi2NP{tr_suffix}')),
        ('\\Psi_3', met.Psi3NP.expr(), getattr(met, f'Psi3NP{tr_suffix}')),
        ('\\Psi_4', met.Psi4NP.expr(), getattr(met, f'Psi4NP{tr_suffix}'))
    ]
    write_transformation_section(fout, weyl_comps, "Weyl components")
    
    # Ricci components
    ricci_comps = [
        ('\\Phi_{00}', met.Phi00NP.expr(), getattr(met, f'Phi00NP{tr_suffix}')),
        ('\\Phi_{01}', met.Phi01NP.expr(), getattr(met, f'Phi01NP{tr_suffix}')),
        ('\\Phi_{02}', met.Phi02NP.expr(), getattr(met, f'Phi02NP{tr_suffix}')),
        ('\\Phi_{10}', met.Phi10NP.expr(), getattr(met, f'Phi10NP{tr_suffix}')),
        ('\\Phi_{11}', met.Phi11NP.expr(), getattr(met, f'Phi11NP{tr_suffix}')),
        ('\\Phi_{12}', met.Phi12NP.expr(), getattr(met, f'Phi12NP{tr_suffix}')),
        ('\\Phi_{20}', met.Phi20NP.expr(), getattr(met, f'Phi20NP{tr_suffix}')),
        ('\\Phi_{21}', met.Phi21NP.expr(), getattr(met, f'Phi21NP{tr_suffix}')),
        ('\\Phi_{22}', met.Phi22NP.expr(), getattr(met, f'Phi22NP{tr_suffix}'))
    ]
    write_transformation_section(fout, ricci_comps, "Ricci components")

# %%
# Latex formatında rapor dosyası oluşturmak için bu kodu kullanabilirsiniz.
# (Dosyanin adini uygun sekilde degistirmeyi unutmayin.)
fout = open('13.70.tex',"w")
tmpstr=r'''\documentclass[landscape]{article}
%\documentclass[11pt,a4paper,reqno]{amsart}
%%%%%%%%%%%%%%%%%%%%%%
\usepackage[fleqn]{amsmath} %Denklemleri sola daya
\usepackage{amssymb}
\usepackage{authblk}
\usepackage{caption}
\usepackage{cite}
\usepackage{xcolor}
\usepackage{color}
\usepackage{float}
\usepackage{geometry}
\usepackage{graphicx}
\usepackage{mdframed}
\usepackage{hyperref}
\usepackage{textcomp}
\usepackage{epstopdf}
\usepackage{subcaption}
\usepackage{lscape}
\usepackage{breqn}
%\usepackage{soul}
%%%%%%%%%%%%%%%%%%%%%%
\setlength\parindent{0pt}
\setlength{\parskip}{5pt}
\geometry{left=20mm,right=20mm,top=30mm,bottom=20mm}
\hyphenation{Schwarz-schild}
%%%%%%%%%%%%%%%%%%%%%%
\newcommand{\etalchar}[1]{$^{#1}$}
\newcommand\hl[1]{%
	\bgroup
	\hskip0pt\color{red!80!black}%
	#1%
	\egroup
}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\begin{document}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\textbf{Newman-Penrose Formalism Calculations for}
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{metric:} 

\textit{Name:} Stephani et al., Equation (13.70)

\textit{Alias:} Stephanietal\_13\_70

\textit{Reference(s):} \cite{stefani}

\textit{Line element:} 

\begin{dmath}'''
fout.write(tmpstr)


fout.write("ds^2 " + str(latex(met.g.display()))[2:])
fout.write(r"\end{dmath}")


fout.write(r"\textit{Coordinates:} "+str(latex(MyCoordinates[:])))
tmpstr=r'''
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\vspace{10pt}
\textbf{Null tetrad components: }

\textit{Covariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}

\textit{Contravariant components:}
\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"l&= " +r"\left("+str(latex(met.lupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.lupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.lupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.lupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"n&= " +r"\left("+str(latex(met.nupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.nupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.nupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.nupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"m&= " +r"\left("+str(latex(met.mupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)

fout.write(r"\overline{m}&= " +r"\left("+str(latex(met.mbarupNP[0])) +r"\right) d"+str(latex(MyCoordinates[0]))  +r"+\left( " +str(latex(met.mbarupNP[1])) +r"\right) d"+str(latex(MyCoordinates[1])) + r"+\left( " + str(latex(met.mbarupNP[2])) +r"\right) d"+str(latex(MyCoordinates[2]))
           +r"+\left( " +str(latex(met.mbarupNP[3])) +r"\right) d"+str(latex(MyCoordinates[3]))+r" \\ ")

tmpstr=r'''
\end{dmath}


\newpage
\textbf{Directional derivatives: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"D&=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\Delta&=" + str(latex(fitEq( met.DeltanNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\delta&=" + str(latex(fitEq( met.deltamNP(f).expr()))) +r" \\ ")
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"\overline{\delta}&=" + str(latex(fitEq( met.deltambarNP(f).expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Spin coefficients: }

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\rho&="+str(latex(fitEq(met.rhoNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\sigma&="+str(latex(fitEq(met.sigmaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\kappa&="+str(latex(fitEq(met.kappaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\mu&="+str(latex(fitEq(met.muNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\lambda&="+str(latex(met.lambdaNP.expr()))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\nu&="+str(latex(fitEq(met.nuNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\alpha&="+str(latex(fitEq(met.alphaNP.expr()))))

tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\beta&="+str(latex(fitEq(met.betaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\tau&="+str(latex(fitEq(met.tauNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\pi&="+str(latex(fitEq(met.piNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\epsilon&="+str(latex(fitEq(met.epsilonNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\gamma&="+str(latex(fitEq(met.gammaNP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage

\textbf{Relations between spin coefficients: }


%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Ricci tensor components: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{00}&="+str(latex(fitEq(met.Phi00NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{01}&="+str(latex(fitEq(met.Phi01NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{02}&="+str(latex(fitEq(met.Phi02NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{10}&="+str(latex(fitEq(met.Phi10NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{11}&="+str(latex(fitEq(met.Phi11NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{12}&="+str(latex(fitEq(met.Phi12NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{20}&="+str(latex(fitEq(met.Phi20NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{21}&="+str(latex(fitEq(met.Phi21NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"\Phi_{22}&="+str(latex(fitEq(met.Phi22NP.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Weyl tensor components: }
\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_0&="+str(latex(fitEq(met.Psi0NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_1&="+str(latex(fitEq(met.Psi1NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_2&="+str(latex(fitEq(met.Psi2NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_3&="+str(latex(fitEq(met.Psi3NP.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}
'''
fout.write(tmpstr)
fout.write(r"\Psi_4&="+str(latex(fitEq(met.Psi4NP.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Newman-Penrose equations: }
\begin{dmath}'''
fout.write(tmpstr)

fout.write(r"NP1&="+str(latex(fitEq(met.NPeq1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP2&="+str(latex(fitEq(met.NPeq2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP3&="+str(latex(fitEq(met.NPeq3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP4&="+str(latex(fitEq(met.NPeq4.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP5&="+str(latex(fitEq(met.NPeq5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP6&="+str(latex(fitEq(met.NPeq6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP7&="+str(latex(fitEq(met.NPeq7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP8&="+str(latex(fitEq(met.NPeq8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP9&="+str(latex(fitEq(met.NPeq9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP10&="+str(latex(fitEq(met.NPeq10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP11&="+str(latex(fitEq(met.NPeq11.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP12&="+str(latex(fitEq(met.NPeq12.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP13&="+str(latex(fitEq(met.NPeq13.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP14&="+str(latex(fitEq(met.NPeq14.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP15&="+str(latex(fitEq(met.NPeq15.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP16&="+str(latex(fitEq(met.NPeq16.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP17&="+str(latex(fitEq(met.NPeq17.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"NP18&="+str(latex(fitEq(met.NPeq18.expr()))))

tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\newpage
\textbf{Bianchi identities: }

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI1&="+str(latex(fitEq(met.BI1.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI2&="+str(latex(fitEq(met.BI2.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI3&="+str(latex(fitEq(met.BI3.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI4&="+str(latex(fitEq(met.BI4.expr())))+r' \\ '),
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI5&="+str(latex(fitEq(met.BI5.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI6&="+str(latex(fitEq(met.BI6.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI7&="+str(latex(fitEq(met.BI7.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI8&="+str(latex(fitEq(met.BI8.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI9&="+str(latex(fitEq(met.BI9.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI10&="+str(latex(fitEq(met.BI10.expr())))+r' \\ ')
tmpstr=r'''
\end{dmath}

\begin{dmath}'''
fout.write(tmpstr)
fout.write(r"BI11&="+str(latex(fitEq(met.BI11.expr()))))
tmpstr=r'''
\end{dmath}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


\newpage
\textbf{Petrov classification:} \\
\vspace{2cm}
\textit{Petrov class: III} 
\vspace{2cm}




%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

\begin{thebibliography}{99}

\bibitem{stefani}
 H. Stephani, D. Kramer, M. MacCallum, C. Hoenselaers, and E. Herlt, Exact Solutions of Einstein’s Field Equations. Cambridge Monographs on Mathematical Physics, Cambridge University Press, 2009.
\end{thebibliography}
\begin{mdframed}
\textbf{Calculated by:}

\textit{Name: Şimal Serdaroğlu} 

\textit{E-mail: } 
\textit{Date: } 29.12.2025
\end{mdframed}
\end{document}
'''
fout.write(tmpstr)
fout.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 151
#     142 tmpstr=r'''
#     143 \end{dmath}
#     144
#    (...)    148
#     149 \begin{dmath}'''
#     150 fout.write(tmpstr)
# --> 151 fout.write(r"D&=" + str(latex(fitEq(met.DlNP(f).expr()))) +r" \\ ")
#     152 tmpstr=r'''
#     153 \end{dmath}
#     154
#     155 \begin{dmath}'''
#     156 fout.write(tmpstr)
#
# File ~/Library/SageMath-10-6/lib/python3.12/site-packages/SageNP/SageNP.py:862, in NewmanPenrose.DlNP(self, X)
#     860     return _sage_const_0
#     861 else:
# --> 862     return self.lupNP['^i']*self.nab(X)['_i']
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/manifolds/differentiable/affine_connection.py:1508, in AffineConnection.__call__(self, tensor)
#    1506 from sage.manifolds.differentiable.tensorfield_paral import TensorFieldParal
#    1507 from sage.tensor.modules.format_utilities import format_unop_latex
# -> 1508 dom_resu = self._domain.intersection(tensor._domain)
#    1509 tensor_r = tensor.restrict(dom_resu)
#    1510 if tensor_r._tensor_type == (0,0):  # scalar field case
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:495, in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:11829)()
#     493         AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'...
#     494     """
# --> 495     return self.getattr_from_category(name)
#     496
#     497 cdef getattr_from_category(self, name):
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:508, in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:11939)()
#     506     else:
#     507         cls = P._abstract_element_class
# --> 508     return getattr_from_other_class(self, cls, name)
#     509
#     510 def __dir__(self):
#
# File /private/var/tmp/sage-10.6-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/cpython/getattr.pyx:363, in sage.cpython.getattr.getattr_from_other_class (build/cythonized/sage/cpython/getattr.c:4458)()
#     361     dummy_error_message.cls = type(self)
#     362     dummy_error_message.name = name
# --> 363     raise AttributeError(dummy_error_message)
#     364 attribute = <object>attr
#     365 # Check for a descriptor (__get__ in Python)
#
# AttributeError: 'sage.symbolic.expression.Expression' object has no attribute '_domain'
